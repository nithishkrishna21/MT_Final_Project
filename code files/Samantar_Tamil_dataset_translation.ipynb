# %%
import numpy as np
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.gleu_score import sentence_gleu
from nltk.translate.meteor_score import meteor_score
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# %%
import re
from sklearn.model_selection import train_test_split

# %%
english_scripts_file_path = "../datasets/Samantar dataset/final_data/en-ta/train.en"
native_scripts_file_path = "../datasets/Samantar dataset/final_data/en-ta/train.ta"

# %%
native_lines = []
with open(native_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        native_lines.append(line)

english_lines = []
with open(english_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        english_lines.append(line)

# %%
native_lines[1]
# Out:
# 'ஒவ்வொரு சுற்றுப்பயணமும் கடினமானது.\n'

# %%
english_lines[1]
# Out:
# 'Every tournament is difficult.\n'

# %%
len(native_lines)
# Out:
# 5167241

# %%
len(english_lines)
# Out:
# 5167241

# %%
df = pd.DataFrame({'Tamil': native_lines, 'English': english_lines})
print(df.head())
# Out:
#                                                Tamil  \
# 0                  என்றுதான் நான் சொல்ல வருகிறேன்.\n
# 1               ஒவ்வொரு சுற்றுப்பயணமும் கடினமானது.\n
# 2  பல வருடங்களாக அவர் அந்த நித்திய எரிநரக தண்டனைய...
# 3  அவர் நிதி அமைச்சர் அருண்ஜேட்லியின் முயற்சியை த...
# 4  சில கலை வரலாற்றாசிரியர்கள் அவர் ஒரு வருடத்திற்...
#
#                                              English
# 0                         That's what I am saying.\n
# 1                   Every tournament is difficult.\n
# 2  One of the first questions Flavio posed was, D...
# 3  He gave full credit to the Union Finance Minis...
# 4  Some art historians have suggested that he onl...

# %%
len(df)
# Out:
# 5167241

# %%
dev_set = df.sample(n = 500, replace = False, random_state = np.random.randint(low=1, high=1234))
remaining_data = df.drop(dev_set.index)

test_set = remaining_data.sample(n = 1000, random_state = np.random.randint(low=1, high=1234))
print(f"Test set size: {len(test_set)}")
print(f"Dev set size: {len(dev_set)}")
# Out:
# Test set size: 1000
# Dev set size: 500

# %%
native_tamil_sentences_dev_set = dev_set['Tamil'].values
print(type(native_tamil_sentences_dev_set))
print(native_tamil_sentences_dev_set.shape)
english_sentences_dev_set = dev_set['English'].values
# Out:
# <class 'numpy.ndarray'>
# (500,)

# %%
print(len(english_sentences_dev_set))
# Out:
# 500

# %%
def calculate_scores(english_sentence, translation):
    reference = [english_sentence.split()]
    transformed_tokens = translation.split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    return bleu_score, gleu_score, met_score

# %%
# Native hindi to english translations using the Facebook model
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

m2m100_bleu_scores = []
m2m100_gleu_scores = []
m2m100_meteor_scores = []

# translate Hindi to English
tokenizer.src_lang = "ta"
for i, tamil_text in enumerate(native_tamil_sentences_dev_set):

    encoded_ta = tokenizer(tamil_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_ta, forced_bos_token_id=tokenizer.get_lang_id("en"))
    translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    bleu_score, gleu_score, met_score = calculate_scores(english_sentences_dev_set[i], translation)

    m2m100_bleu_scores.append(bleu_score)
    m2m100_gleu_scores.append(gleu_score)
    m2m100_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Tamil text :', tamil_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translation)
        print('Average BLEU score :', np.mean(m2m100_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(m2m100_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(m2m100_meteor_scores), '\n')
        print()
# Out:
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence  1
# Original Tamil text : சாரங்கி வாசிப்பது அவ்வளவு சுலபம் இல்லை.
#
# Original English Conversion : Its not easy reading.
#
# Translated to English : It’s not so hard to get a lot of money.
# Average BLEU score : 1.0244914152188952e-231
#
# Average GLEU score : 0.029411764705882353
#
# Average METEOR score : 0.10869565217391304
#
#
# Translating sentence  11
# Original Tamil text : 210 கோடி வசூலித்துள்ளது.
#
# Original English Conversion : 210 crore.
#
# Translated to English : There are 210 cents.
# Average BLEU score : 0.03142916224017645
#
# Average GLEU score : 0.0923019543340399
#
# Average METEOR score : 0.2091386960288684
#
#
# Translating sentence  21
# Original Tamil text : நான் பயம் விரும்புகிறேன்.
#
# Original English Conversion : I like the fear.
#
# Translated to English : I want fear.
# Average BLEU score : 0.016462894506759095
#
# Average GLEU score : 0.0909226072551541
#
# Average METEOR score : 0.18956725710783084
#
#
# Translating sentence  31
# Original Tamil text : பிரச்சினை எல்லாம் தீர்க்கப்பட வேணும்.
#
# Original English Conversion : All problems must be solved.
#
# Translated to English : All problems are solved.
# Average BLEU score : 0.055762661763181225
#
# Average GLEU score : 0.14373328631413
#
# Average METEOR score : 0.27763071971427794
#
#
# Translating sentence  41
# Original Tamil text : யெகோவாவின் நியாயத்தீர்ப்பு நாள் அருகில் இருக்கிறது, சீக்கிரத்தில் அவர் தம்முடைய சத்துருக்களை பழிவாங்குவார்.
#
# Original English Conversion : The execution of Gods wrath upon Judah and Jerusalem was a day of distress and of anguish.
#
# Translated to English : The Day of Judgment is near, and in Cyprus he will dissolve his covenant.
# Average BLEU score : 0.04216201255264922
#
# Average GLEU score : 0.13120706345068955
#
# Average METEOR score : 0.25486121889250507
#
#
# Translating sentence  51
# Original Tamil text : காட்டிக் கொடுப்பதென்பது இதைத்தானா!
#
# Original English Conversion : This is betrayal!
#
# Translated to English : That’s what you don’t give it!
# Average BLEU score : 0.03389495126781604
#
# Average GLEU score : 0.1175455502017645
#
# Average METEOR score : 0.23781494829431832
#
#
# Translating sentence  61
# Original Tamil text : இவருக்கு திருமணம் ஆகி ரோகினி என்ற மனைவியும், ஒரு மகன் மற்றும் மகள் உள்ளனர்.
#
# Original English Conversion : He is survived by wife, a son and a daughter.
#
# Translated to English : They are married and have a wife, a son and a wife.
# Average BLEU score : 0.03353550538542559
#
# Average GLEU score : 0.10672797341248585
#
# Average METEOR score : 0.21609786669581105
#
#
# Translating sentence  71
# Original Tamil text : ஏற்பாட்டினை வர்த்தக சங்கத்தினர் செய்திருந்தனர்.
#
# Original English Conversion : The talk was organised by the Commerce Society.
#
# Translated to English : They were the ones who had made it.
# Average BLEU score : 0.028812194767760018
#
# Average GLEU score : 0.09703587903555176
#
# Average METEOR score : 0.20041060346240622
#
#
# Translating sentence  81
# Original Tamil text : உத்தரகாண்ட் மாநிலத்தில் கடந்த சில நாட்களாக கன மழை பெய்து வருவதால் ஆறுகளில் வெள்ளப்பெருக்கு ஏற்பட்டுள்ளது.
#
# Original English Conversion : Heavy rains have been wreaking havoc in Uttarkhand over the last few days.
#
# Translated to English : In the last few days, when the water has been drowned, the water has been drowned in the mountains.
# Average BLEU score : 0.026963393362396445
#
# Average GLEU score : 0.09528541777895806
#
# Average METEOR score : 0.2031339678690999
#
#
# Translating sentence  91
# Original Tamil text : தமிழ், தெலுங்கு, மலையாளம், ஹிந்தி என நான்கு மொழிகளில் பிசியாக இருந்தேன்.
#
# Original English Conversion : I have acted in all the four regional languages Tamil, Telugu, Malayalam and Kannada.
#
# Translated to English : I was in the midst, in the midst, in the midst, in the midst, in the midst, and in the midst.
# Average BLEU score : 0.02400038310279244
#
# Average GLEU score : 0.09695849038680644
#
# Average METEOR score : 0.20692203886680244
#
#
# Translating sentence  101
# Original Tamil text : சிலசமயங்களில் இது லாபத்தின் ஒரு பிரச்னையாகிறது.
#
# Original English Conversion : There is no money in tropical diseases, admits New Scientist, because, by and large, those who are affected cannot afford medicines.
#
# Translated to English : In some instances, this is a breakthrough of the lobby.
# Average BLEU score : 0.021624107548060517
#
# Average GLEU score : 0.09285586055161185
#
# Average METEOR score : 0.2031530670915712
#
#
# Translating sentence  111
# Original Tamil text : அந்த வாய்ப்பைச் சட்டென்று பிடித்துக் கொண்டேன்.
#
# Original English Conversion : I grabbed that chance.
#
# Translated to English : I’m going to take that box.
# Average BLEU score : 0.01967598975093795
#
# Average GLEU score : 0.09160229772312807
#
# Average METEOR score : 0.2006200370835078
#
#
# Translating sentence  121
# Original Tamil text : ஆகவே எப்போதும் செருக்கில்லாமல் இருப்து நல்லது.
#
# Original English Conversion : So its always better to stay away from it.
#
# Translated to English : Therefore, it is always good to stay untouched.
# Average BLEU score : 0.022490246514594078
#
# Average GLEU score : 0.09858801572200762
#
# Average METEOR score : 0.21117534854319897
#
#
# Translating sentence  131
# Original Tamil text : | படம்: ஏஎன்ஐ
#
# Original English Conversion : | Photo: ANI
#
# Translated to English : The name of the word: Aden.
# Average BLEU score : 0.02487484575708133
#
# Average GLEU score : 0.09767328867786973
#
# Average METEOR score : 0.2067478708258262
#
#
# Translating sentence  141
# Original Tamil text : திருமாவளவனைக் கண்டித்து பாஜக மகளிர் அணியினர் நாமாக்கலில் ஆர்ப்பாட்டம்
#
# Original English Conversion : BJP women protest Namtara firing
#
# Translated to English : and the children of the day, and the children of the day, and the children of the day,
# Average BLEU score : 0.027476726841704668
#
# Average GLEU score : 0.09998158216484831
#
# Average METEOR score : 0.2114188920080257
#
#
# Translating sentence  151
# Original Tamil text : ஏனைய 13 கொத்துவழிப் பங்காளிகளை காரியக்காரர்களாகவும் ஆக்கினர்.
#
# Original English Conversion : They are searching for at least 13 other suspects.
#
# Translated to English : Thirty-thirds of them have been killed and killed.
# Average BLEU score : 0.02582177485439881
#
# Average GLEU score : 0.09550437884507422
#
# Average METEOR score : 0.20462655203272317
#
#
# Translating sentence  161
# Original Tamil text : இந்த உளவியல் மாற்றம் மற்றும் கால மாற்றத்தை நாம் உணர்ந்துகொள்ள வேண்டும்.
#
# Original English Conversion : We have to understand this transformation of psychology and changing times
#
# Translated to English : We need to feel this physical change and time change.
# Average BLEU score : 0.02421793790692062
#
# Average GLEU score : 0.09474695416268275
#
# Average METEOR score : 0.2052600653686143
#
#
# Translating sentence  171
# Original Tamil text : இவ்வாணையம் ஓய்வுபெற்ற உயர்நீதிமன்ற நீதிபதி, நீதியரசர் திரு. எம்.எஸ். ஜனார்த்தனம் அவர்கள் தலைமையில் 8 உறுப்பினர்களுடன், 28.12.2015 அன்று 3 ஆண்டுகள் பதவிக்காலத்துடன் திருத்தியமைக்கப் பட்டுள்ளது.
#
# Original English Conversion : The Commission has been reconstituted for a period of 3 years on 28.12.2015 under the Chairmanship of Justice Thiru M.S.Janarthanam , retired Judge of High Court and eight Members.
#
# Translated to English : The President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania, President of the Republic of Lithuania and President of the Republic of Lithuania.
# Average BLEU score : 0.023332198574875042
#
# Average GLEU score : 0.09659059609528128
#
# Average METEOR score : 0.20791003013345838
#
#
# Translating sentence  181
# Original Tamil text : இடம்தான் வேறு.
#
# Original English Conversion : Different venue.
#
# Translated to English : The place is different.
# Average BLEU score : 0.02204312683040681
#
# Average GLEU score : 0.09346274306748925
#
# Average METEOR score : 0.20401383902895712
#
#
# Translating sentence  191
# Original Tamil text : அதில் அவர்கள் போல்டான் அணியை 4-2 வித்தியாசத்தில் வெற்றி பெற்றனர்.
#
# Original English Conversion : There they, defeated the Cleveland Cavaliers 42.
#
# Translated to English : They won the team in 4-2 wins.
# Average BLEU score : 0.024422257611691107
#
# Average GLEU score : 0.09486022276533713
#
# Average METEOR score : 0.20527200764104883
#
#
# Translating sentence  201
# Original Tamil text : எனவேதான் இது மோசமான பிரச்சினையாக பார்க்கப்படுகிறது.
#
# Original English Conversion : Thats why this is a big problem.
#
# Translated to English : So this is seen as a bad problem.
# Average BLEU score : 0.02320721991956717
#
# Average GLEU score : 0.09513978460505536
#
# Average METEOR score : 0.20874974318057612
#
#
# Translating sentence  211
# Original Tamil text : மேலும் அவர்களிடமிருந்து பயங்கர ஆயுதங்கள் மற்றும் வெடிமருந்துகள் பறிமுதல் செய்யப்பட்டன.
#
# Original English Conversion : Firearms and ammunition were also seized from them.
#
# Translated to English : Thus, there were also scattered weapons and firearms from them.
# Average BLEU score : 0.02336729649999805
#
# Average GLEU score : 0.09485012307715922
#
# Average METEOR score : 0.20940311493237407
#
#
# Translating sentence  221
# Original Tamil text : கல்வி, பண்பாடு, உடல்நலத்துறை அமைச்சர்
#
# Original English Conversion : Education and Health Minister, said.
#
# Translated to English : Department of Health, Department of Health, Department of Health
# Average BLEU score : 0.022309952766966464
#
# Average GLEU score : 0.09344826872660046
#
# Average METEOR score : 0.2081800206248975
#
#
# Translating sentence  231
# Original Tamil text : அவன் பைத்தியம் முற்றி வெளியேறியவன்’.
#
# Original English Conversion : He is gone crazy.'
#
# Translated to English : He will go out of the Bible.”
# Average BLEU score : 0.022134554443605504
#
# Average GLEU score : 0.09239709328679234
#
# Average METEOR score : 0.20623871050728898
#
#
# Translating sentence  241
# Original Tamil text : இவ்வழக்கு தொடர்பாக பள்ளி நிர்வாகம் மற்றும் ஆசிரியைக்கு எதிராக வழக்குப்பதிவு செய்த போலீஸ் பாவனாவை கைது செய்து உள்ளது.
#
# Original English Conversion : The police have registered a case against the school principal and the teacher.
#
# Translated to English : The police have been arrested in connection with the school manager and the law enforcement officer.
# Average BLEU score : 0.021216108201132244
#
# Average GLEU score : 0.09129998810034684
#
# Average METEOR score : 0.20547106335651003
#
#
# Translating sentence  251
# Original Tamil text : மற்ற தூதர்கள், கடவுளுக்கு விரோதமான கலகத்தில் சாத்தானோடு சேர்ந்துகொண்டனர்.
#
# Original English Conversion : The Bible shows him to be thoroughly evil and vicious. Other angels joined Satans rebellion against God.
#
# Translated to English : And the other prophets came together in the temple of God.
# Average BLEU score : 0.021866430560567623
#
# Average GLEU score : 0.0935755473112071
#
# Average METEOR score : 0.2078674403612997
#
#
# Translating sentence  261
# Original Tamil text : காவேரி நதி ஒரு புண்ணிய நதியாகும்.
#
# Original English Conversion : The Cauvery is a glorious river.
#
# Translated to English : It’s a good thing to see.
# Average BLEU score : 0.02180170725206597
#
# Average GLEU score : 0.09291313636793035
#
# Average METEOR score : 0.2065257492425626
#
#
# Translating sentence  271
# Original Tamil text : இயக்குநர் ராகுல் ரவாய்ல் தலையிலான குழுவினர் தேசிய விருதுகளை அறிவித்தனர்.
#
# Original English Conversion : The awards were announced by jury head Rahul Rawail.
#
# Translated to English : Thus, the worshipers of the worshipers of the worshipers of the worshipers of the worshipers of the worshipers of the worshipers of the worshipers.
# Average BLEU score : 0.02099721620955431
#
# Average GLEU score : 0.09230623707072015
#
# Average METEOR score : 0.2041530235588594
#
#
# Translating sentence  281
# Original Tamil text : """ (மீண்டும் மன்னிக்க!"
#
# Original English Conversion : (I apologise!
#
# Translated to English : “I’m forgiven!”
# Average BLEU score : 0.020249984315975862
#
# Average GLEU score : 0.09276347481734813
#
# Average METEOR score : 0.2054467486483336
#
#
# Translating sentence  291
# Original Tamil text : இந்தப்படம் ரசிகர்களிடையே அமோக வரவேற்பை பெற்றது.
#
# Original English Conversion : The film was well-received by fans.
#
# Translated to English : This is the case with the Russians.
# Average BLEU score : 0.01955410856628597
#
# Average GLEU score : 0.09060607222346868
#
# Average METEOR score : 0.20371826211468086
#
#
# Translating sentence  301
# Original Tamil text : அவர்களுக்கே உரித்தான குல்லாவையோ, உடைகளையோ அணிவதில்லை.
#
# Original English Conversion : They dont wear masks or gloves.
#
# Translated to English : They do not have the right, nor have the right, nor have the right, nor have the right.
# Average BLEU score : 0.0189044704079376
#
# Average GLEU score : 0.08917984948105337
#
# Average METEOR score : 0.20222131091981224
#
#
# Translating sentence  311
# Original Tamil text : உணர்ச்சிகளிலேயே மிகச் சக்திவாய்ந்த ஒன்றைப் பற்றிய பொதுவான ஒரு நோக்குநிலையை பூர்வீக ரோம கவிஞர் ஹோராஷியுஸ் அவ்வாறுதான் தெரிவித்தார்.
#
# Original English Conversion : Thus the ancient Roman poet Horace [Latin: Horatius] voiced a common view of one of the strongest of all emotions.
#
# Translated to English : In the same way, the righteous, the righteous, the righteous, the righteous, the righteous, the righteous, the righteous, the righteous, the righteous, the righteous, the righteous.
# Average BLEU score : 0.018296609623116456
#
# Average GLEU score : 0.08920678502830835
#
# Average METEOR score : 0.2023956205440034
#
#
# Translating sentence  321
# Original Tamil text : (நயியே!) தங்கள் இறைவனுடைய திருப் பொருத்தத்தை நாடி, எவர் காலையிலும் மாலையிலும், அவனை(ப் பிரார்த்தித்து) அழைத்துக் கொண்டிருக்கிறார்களோ அவர்களை நீர் விரட்டி விடாதீர். அவர்களுடைய கேள்வி கணக்குப் பற்றி உம்மீது பொறுப்பில்லை, உம்முடைய கேள்வி கணக்குப் பற்றி அவர்கள் மீதும் யாதொரு பொறுப்புமில்லை - எனவே நீர் அவர்களை விரட்டி விட்டால், நீரும் அநியாயம் செய்பவர்களில் ஒருவராகி விடுவீர்.
#
# Original English Conversion : And do not drive away those who invoke their Lord in the morning and the evening, seeking His pleasure all the time. You are by no means accountable for them just as they are by no means accountable for you. If you still drive them away, you will become among the wrong-doers.
#
# Translated to English : You shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go, and you shall not let them go.
# Average BLEU score : 0.017726621784390086
#
# Average GLEU score : 0.08745288072322588
#
# Average METEOR score : 0.19951957200130857
#
#
# Translating sentence  331
# Original Tamil text : இச்சம்பவம் குறித்து தாண்டிக்குடி போலீஸாா் வழக்குப் பதிவு செய்து விசாரணை நடத்தி வருகின்றனா்.
#
# Original English Conversion : The police have registered a case and are investigating the case.
#
# Translated to English : They will be able to investigate, and they will be able to investigate.
# Average BLEU score : 0.01719107429845685
#
# Average GLEU score : 0.08568504358796733
#
# Average METEOR score : 0.19586344893655208
#
#
# Translating sentence  341
# Original Tamil text : மருத்துவமனைக்கு கொண்டு சென்ற போது அவர் மாரடைப்பால் இறந்தது தெரியவந்தது.
#
# Original English Conversion : He was declared dead when rushed to the hospital.
#
# Translated to English : When he went to the hospital, he knew he was dead.
# Average BLEU score : 0.01668693722225577
#
# Average GLEU score : 0.08492548746675538
#
# Average METEOR score : 0.19516558316323424
#
#
# Translating sentence  351
# Original Tamil text : சென்று எந்தப் பயனுமில்லை.
#
# Original English Conversion : There is no use.
#
# Translated to English : There is no fear of going.
# Average BLEU score : 0.016211525905382388
#
# Average GLEU score : 0.08452849827232409
#
# Average METEOR score : 0.19473747380707998
#
#
# Translating sentence  361
# Original Tamil text : ﻿ ‘ஆப்பிரிக்கா விழித்து கொள்ள வேண்டும்’
#
# Original English Conversion : Africa should wake up.
#
# Translated to English : “We need to break off.”
# Average BLEU score : 0.015762453165621103
#
# Average GLEU score : 0.08347696536809564
#
# Average METEOR score : 0.1928991700430069
#
#
# Translating sentence  371
# Original Tamil text : அனைத்து புளுட்டோனியம் சேர்மங்களையும் போலவே இதுவும் அணு பரவல் அல்லாத ஒப்பந்தத்தின் கீழ் கட்டுப்பாட்டுக்கு உட்பட்டதாகும்.
#
# Original English Conversion : As with all plutonium compounds, it is subject to control under the Nuclear Non-Proliferation Treaty.
#
# Translated to English : And all of them, as well as all of them, are in the shadow of the shadow of the shadow of the shadow.
# Average BLEU score : 0.01533758919889277
#
# Average GLEU score : 0.08374839841040004
#
# Average METEOR score : 0.1935606201223408
#
#
# Translating sentence  381
# Original Tamil text : டெல்லியில் பிரதமர் மோடி மற்றும் உள்துறை அமைச்சர் அமித்ஷாவை சந்திக்க உள்ளதாக தகவல் வெளியாகி உள்ளது.
#
# Original English Conversion : Sources said that in Delhi he will meet Prime Minister Narendra Modi and Union Home Minister Amit Shah.
#
# Translated to English : In Delhi, the Prime Minister Modi and the Ministry of Security have been informed that they are meeting.
# Average BLEU score : 0.015571961881112005
#
# Average GLEU score : 0.08362949631511211
#
# Average METEOR score : 0.1930055003386083
#
#
# Translating sentence  391
# Original Tamil text : பக்கோவைட்டு (Bukovite) என்பது Tl2Cu3FeSe4 என்ற மூலக்கூற்று வாய்ப்பாட்டால் விவரிக்கப்படும் ஒரு கனிமம் ஆகும்.
#
# Original English Conversion : Bukovite is a rare selenide mineral with formula Tl2Cu3FeSe4.
#
# Translated to English : Bukovite (Bukovite) is a chemistry that can be dispersed by the molecular capacity of Tl2Cu3FeSe4.
# Average BLEU score : 0.01517370198645441
#
# Average GLEU score : 0.08402404736762095
#
# Average METEOR score : 0.1948041919945268
#
#
# Translating sentence  401
# Original Tamil text : தற்போதைய, பொது முடக்கச் சூழலில், நிலக்கரி அமைச்சகத்தின் எந்த ஒப்புதலும் தடைபடாது என்று திரு.
#
# Original English Conversion : Shri Pralhad Joshi further assured that no approvals requiring concurrence of Ministry of Coal would be held up during the current lockdown period.
#
# Translated to English : At present, in the general sunshine, there is no deal with the state ministry.
# Average BLEU score : 0.014795305428188715
#
# Average GLEU score : 0.08415907543112512
#
# Average METEOR score : 0.19408027876635922
#
#
# Translating sentence  411
# Original Tamil text : பிரதமர் நரேந்திர மோடி சத்திஸ்கர் மாநிலம் ராஜ்நந்த்காவுன் மாவட்டத்திலுள்ள குருபாட்டிலிருந்து தேசிய ரூர்பன் இயக்கத்தை இன்று தொடங்கி வைத்தார்.
#
# Original English Conversion : The Prime Minister, Shri Narendra Modi, today launched the National Rurban Mission from Kurubhat, in Rajnandgaon district of Chhattisgarh.
#
# Translated to English : And he was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one who was the one.
# Average BLEU score : 0.014435322327746167
#
# Average GLEU score : 0.08291069762964426
#
# Average METEOR score : 0.1912240473173131
#
#
# Translating sentence  421
# Original Tamil text : கிறிஸ்தவ கிரேக்க வேதாகமத்தில் “சீஷன் ” என மொழிபெயர்க்கப்பட்டுள்ள வார்த்தை அடிப்படையில், ஏதோ ஒன்றிடம் தன் மனதை ஒருமுகப்படுத்துபவர் அல்லது கற்றுக்கொள்பவர் என்பதையே அர்த்தப்படுத்துகிறது.
#
# Original English Conversion : ( b) Why is it important to ask ourselves, Whose disciple have I become? In the Christian Greek Scriptures, the word translated disciple basically means one who directs his mind to something, or one who learns.
#
# Translated to English : As the word translated in Christ’s Greek Writing “Sishan” is based on the meaning of something that means that he is the one who understands or understands his mind.
# Average BLEU score : 0.014976979729685645
#
# Average GLEU score : 0.08307275975216001
#
# Average METEOR score : 0.19147477981533662
#
#
# Translating sentence  431
# Original Tamil text : நிச்சயமாக இதில் இறையச்சம் கொள்வோருக்கு படிப்பினை இருக்கிறது.
#
# Original English Conversion : Indeed in this is a lesson for one who fears.
#
# Translated to English : There is no doubt that there is a death in this.
# Average BLEU score : 0.0146294860004586
#
# Average GLEU score : 0.0823005174300279
#
# Average METEOR score : 0.18985235688288699
#
#
# Translating sentence  441
# Original Tamil text : 04.1979 முதல் 31.03.1982 வரை ரூ.25/-வீதம் (அரசாணை நிலை எண். 805, நிதித்துறை, நாள் 11.06.79)
#
# Original English Conversion : From 1.04.79 to 31.03.1982 at Rs.25 /-(G.O.Ms. No.805, Finance Department dated 11.06.1979)
#
# Translated to English : From 04.1979 to 31.03.1982 Rs.25/-houses (Government Status No. 805, Finance, day 11.06.79)
# Average BLEU score : 0.014297751624030967
#
# Average GLEU score : 0.0816421957137531
#
# Average METEOR score : 0.1884236978219672
#
#
# Translating sentence  451
# Original Tamil text : 8 ஸ்பீடு ஆட்டோமேட்டிக் கியர்பாக்ஸ் பொருத்தப்பட்டு இருக்கிறது
#
# Original English Conversion : The engine is paired to an 8-speed automatic gearbox
#
# Translated to English : 8 spacecraft atomatic cybers are covered.
# Average BLEU score : 0.01398072830642496
#
# Average GLEU score : 0.08064973202424519
#
# Average METEOR score : 0.18680337330614877
#
#
# Translating sentence  461
# Original Tamil text : மனித அரசாங்கங்களின் தோல்விகளை அவர் கவனித்திருக்கிறார்.
#
# Original English Conversion : This proclamation from the highest authority in the universe is cause for hope.
#
# Translated to English : He has taken care of the people’s rule.
# Average BLEU score : 0.013677458711925503
#
# Average GLEU score : 0.08013351453124454
#
# Average METEOR score : 0.18631683197721474
#
#
# Translating sentence  471
# Original Tamil text : பிஜி நாளை முன்னிட்டு பிஜி நாட்டு மக்களுக்கு பிரதமர் வாழ்த்து
#
# Original English Conversion : PM conveys his greetings to the people of Fiji, on Fiji Day
#
# Translated to English : The day before the day, the day before the day, the day before the day, the day before the day.
# Average BLEU score : 0.013834719770463202
#
# Average GLEU score : 0.08040231251446876
#
# Average METEOR score : 0.18625018325274487
#
#
# Translating sentence  481
# Original Tamil text : காண்பித்துக் கொண்டிருக்கிறது.
#
# Original English Conversion : It shows.
#
# Translated to English : He is watching.
# Average BLEU score : 0.014236924640691399
#
# Average GLEU score : 0.08093018115991858
#
# Average METEOR score : 0.18784433920365873
#
#
# Translating sentence  491
# Original Tamil text : இந்தியாவில் தொழிலாளர் இடப்பெயர்ச்சி விரைவாக அதிகரித்து வருகிறது என ஆய்வுத் தகவல் : பொருளாதார ஆய்வறிக்கை 2016-17
#
# Original English Conversion : Labour migration in India increasing at an accelerating rate, reveals new study: Economic Survey 2016-17
#
# Translated to English : India's manufacturers' positioning is growing rapidly Study Information: Economic Survey 2016-17
# Average BLEU score : 0.014672837878834992
#
# Average GLEU score : 0.08115836137798671
#
# Average METEOR score : 0.18729917489476877

# %%
average_bleu_score = np.mean(m2m100_bleu_scores)
average_gleu_score = np.mean(m2m100_gleu_scores)
average_meteor_score = np.mean(m2m100_meteor_scores)
print('Average BLEU Score for Dev Set using Facebooks M2M2100 model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using Facebooks M2M100 model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using Facebooks M2M100 model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using Facebooks M2M2100 model:  0.015776594402065847
# Average GLEU Score for Dev Set using Facebooks M2M100 model:  0.08141351290061871
# Average METEOR Score for Dev Set using Facebooks M2M100 model:  0.1870810822993451

# %%
# Native hindi to english translations using the Facebook's MBART model
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

mbart_bleu_scores = []
mbart_gleu_scores = []
mbart_meteor_scores = []

# translate Tamil to English
tokenizer.src_lang = "ta_IN"
for i, tamil_text in enumerate(native_tamil_sentences_dev_set):
    encoded_ta = tokenizer(tamil_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_ta, forced_bos_token_id=tokenizer.lang_code_to_id['en_XX'])
    translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    bleu_score, gleu_score, met_score = calculate_scores(english_sentences_dev_set[i], translation)

    mbart_bleu_scores.append(bleu_score)
    mbart_gleu_scores.append(gleu_score)
    mbart_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Tamil text :', tamil_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translation)
        print('Average BLEU score :', np.mean(mbart_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(mbart_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(mbart_meteor_scores), '\n')
        print()
# Out:
# Translating sentence  1
# Original Tamil text : சாரங்கி வாசிப்பது அவ்வளவு சுலபம் இல்லை.
#
# Original English Conversion : Its not easy reading.
#
# Translated to English : It's not that easy to read a car.
# Average BLEU score : 1.2882297539194154e-231
#
# Average GLEU score : 0.07692307692307693
#
# Average METEOR score : 0.22727272727272727
#
#
# Translating sentence  11
# Original Tamil text : 210 கோடி வசூலித்துள்ளது.
#
# Original English Conversion : 210 crore.
#
# Translated to English : 210 crore.
# Average BLEU score : 0.02388099904021962
#
# Average GLEU score : 0.1924608368458636
#
# Average METEOR score : 0.37767832022564213
#
#
# Translating sentence  21
# Original Tamil text : நான் பயம் விரும்புகிறேன்.
#
# Original English Conversion : I like the fear.
#
# Translated to English : I want to be afraid.
# Average BLEU score : 0.050957526058052593
#
# Average GLEU score : 0.18751547402318053
#
# Average METEOR score : 0.35532152152049645
#
#
# Translating sentence  31
# Original Tamil text : பிரச்சினை எல்லாம் தீர்க்கப்பட வேணும்.
#
# Original English Conversion : All problems must be solved.
#
# Translated to English : The problem has to be solved.
# Average BLEU score : 0.03451961442642273
#
# Average GLEU score : 0.18874797334830912
#
# Average METEOR score : 0.38327069452616186
#
#
# Translating sentence  41
# Original Tamil text : யெகோவாவின் நியாயத்தீர்ப்பு நாள் அருகில் இருக்கிறது, சீக்கிரத்தில் அவர் தம்முடைய சத்துருக்களை பழிவாங்குவார்.
#
# Original English Conversion : The execution of Gods wrath upon Judah and Jerusalem was a day of distress and of anguish.
#
# Translated to English : The day of judgment of Jeroboam is near, and he shall surely avenge his enemies.
# Average BLEU score : 0.03997055008955163
#
# Average GLEU score : 0.17960729323220848
#
# Average METEOR score : 0.3701192972928239
#
#
# Translating sentence  51
# Original Tamil text : காட்டிக் கொடுப்பதென்பது இதைத்தானா!
#
# Original English Conversion : This is betrayal!
#
# Translated to English : Is that what betrayal is all about?
# Average BLEU score : 0.051741030464149344
#
# Average GLEU score : 0.18277462376501727
#
# Average METEOR score : 0.3598217392706459
#
#
# Translating sentence  61
# Original Tamil text : இவருக்கு திருமணம் ஆகி ரோகினி என்ற மனைவியும், ஒரு மகன் மற்றும் மகள் உள்ளனர்.
#
# Original English Conversion : He is survived by wife, a son and a daughter.
#
# Translated to English : He has a wife, a son and a daughter.
# Average BLEU score : 0.0548002258679198
#
# Average GLEU score : 0.18066470087702632
#
# Average METEOR score : 0.3480169786931724
#
#
# Translating sentence  71
# Original Tamil text : ஏற்பாட்டினை வர்த்தக சங்கத்தினர் செய்திருந்தனர்.
#
# Original English Conversion : The talk was organised by the Commerce Society.
#
# Translated to English : The plan was made by the trade unions.
# Average BLEU score : 0.0470818841963818
#
# Average GLEU score : 0.17359824966482412
#
# Average METEOR score : 0.33709219695570086
#
#
# Translating sentence  81
# Original Tamil text : உத்தரகாண்ட் மாநிலத்தில் கடந்த சில நாட்களாக கன மழை பெய்து வருவதால் ஆறுகளில் வெள்ளப்பெருக்கு ஏற்பட்டுள்ளது.
#
# Original English Conversion : Heavy rains have been wreaking havoc in Uttarkhand over the last few days.
#
# Translated to English : River flooding has occurred in Uttarakhand due to heavy rains in the last few days.
# Average BLEU score : 0.0456230318366059
#
# Average GLEU score : 0.18179268032017154
#
# Average METEOR score : 0.3511960776545241
#
#
# Translating sentence  91
# Original Tamil text : தமிழ், தெலுங்கு, மலையாளம், ஹிந்தி என நான்கு மொழிகளில் பிசியாக இருந்தேன்.
#
# Original English Conversion : I have acted in all the four regional languages Tamil, Telugu, Malayalam and Kannada.
#
# Translated to English : I was a fan of Tamil, Telugu, Malayalam and Hindi.
# Average BLEU score : 0.04543014817630347
#
# Average GLEU score : 0.17747889572864067
#
# Average METEOR score : 0.345183146741573
#
#
# Translating sentence  101
# Original Tamil text : சிலசமயங்களில் இது லாபத்தின் ஒரு பிரச்னையாகிறது.
#
# Original English Conversion : There is no money in tropical diseases, admits New Scientist, because, by and large, those who are affected cannot afford medicines.
#
# Translated to English : In some cases, this is a problem of profit.
# Average BLEU score : 0.04332954871304964
#
# Average GLEU score : 0.16848408510251725
#
# Average METEOR score : 0.3294652008981242
#
#
# Translating sentence  111
# Original Tamil text : அந்த வாய்ப்பைச் சட்டென்று பிடித்துக் கொண்டேன்.
#
# Original English Conversion : I grabbed that chance.
#
# Translated to English : I seized the opportunity to legislate.
# Average BLEU score : 0.044999689475815716
#
# Average GLEU score : 0.16469958523544398
#
# Average METEOR score : 0.32571821211448965
#
#
# Translating sentence  121
# Original Tamil text : ஆகவே எப்போதும் செருக்கில்லாமல் இருப்து நல்லது.
#
# Original English Conversion : So its always better to stay away from it.
#
# Translated to English : So it is always good to be quiet.
# Average BLEU score : 0.04128070687450864
#
# Average GLEU score : 0.1642057551751756
#
# Average METEOR score : 0.3266431336312161
#
#
# Translating sentence  131
# Original Tamil text : | படம்: ஏஎன்ஐ
#
# Original English Conversion : | Photo: ANI
#
# Translated to English : | Film: INA
# Average BLEU score : 0.0440689683089736
#
# Average GLEU score : 0.1667279261286392
#
# Average METEOR score : 0.33301969638970147
#
#
# Translating sentence  141
# Original Tamil text : திருமாவளவனைக் கண்டித்து பாஜக மகளிர் அணியினர் நாமாக்கலில் ஆர்ப்பாட்டம்
#
# Original English Conversion : BJP women protest Namtara firing
#
# Translated to English : BJP women's march against Thirumavalavan in Namakhal
# Average BLEU score : 0.0462964038181676
#
# Average GLEU score : 0.16911102855424429
#
# Average METEOR score : 0.3382222556837369
#
#
# Translating sentence  151
# Original Tamil text : ஏனைய 13 கொத்துவழிப் பங்காளிகளை காரியக்காரர்களாகவும் ஆக்கினர்.
#
# Original English Conversion : They are searching for at least 13 other suspects.
#
# Translated to English : Thirty-three other men were appointed to the position.
# Average BLEU score : 0.04664237344020406
#
# Average GLEU score : 0.16594288764652296
#
# Average METEOR score : 0.33135984261900064
#
#
# Translating sentence  161
# Original Tamil text : இந்த உளவியல் மாற்றம் மற்றும் கால மாற்றத்தை நாம் உணர்ந்துகொள்ள வேண்டும்.
#
# Original English Conversion : We have to understand this transformation of psychology and changing times
#
# Translated to English : We need to understand this psychological change and the changing times.
# Average BLEU score : 0.04716501166619003
#
# Average GLEU score : 0.16650943402217055
#
# Average METEOR score : 0.33473205248839777
#
#
# Translating sentence  171
# Original Tamil text : இவ்வாணையம் ஓய்வுபெற்ற உயர்நீதிமன்ற நீதிபதி, நீதியரசர் திரு. எம்.எஸ். ஜனார்த்தனம் அவர்கள் தலைமையில் 8 உறுப்பினர்களுடன், 28.12.2015 அன்று 3 ஆண்டுகள் பதவிக்காலத்துடன் திருத்தியமைக்கப் பட்டுள்ளது.
#
# Original English Conversion : The Commission has been reconstituted for a period of 3 years on 28.12.2015 under the Chairmanship of Justice Thiru M.S.Janarthanam , retired Judge of High Court and eight Members.
#
# Translated to English : The Ordinance was amended on 28.12.2015 with 8 members under the chairmanship of retired High Court Judge, Justice Shri M.S. Janarthanam ji for a term of office of 3 years.
# Average BLEU score : 0.044406823849453776
#
# Average GLEU score : 0.1703389247587112
#
# Average METEOR score : 0.3400256091934105
#
#
# Translating sentence  181
# Original Tamil text : இடம்தான் வேறு.
#
# Original English Conversion : Different venue.
#
# Translated to English : The place is different.
# Average BLEU score : 0.04195340816716352
#
# Average GLEU score : 0.16620635320471894
#
# Average METEOR score : 0.33706199851101687
#
#
# Translating sentence  191
# Original Tamil text : அதில் அவர்கள் போல்டான் அணியை 4-2 வித்தியாசத்தில் வெற்றி பெற்றனர்.
#
# Original English Conversion : There they, defeated the Cleveland Cavaliers 42.
#
# Translated to English : They won the match 4–2.
# Average BLEU score : 0.04558693094985498
#
# Average GLEU score : 0.16715041595010494
#
# Average METEOR score : 0.3410049241575892
#
#
# Translating sentence  201
# Original Tamil text : எனவேதான் இது மோசமான பிரச்சினையாக பார்க்கப்படுகிறது.
#
# Original English Conversion : Thats why this is a big problem.
#
# Translated to English : That's why it's seen as a bad problem.
# Average BLEU score : 0.04331892443493682
#
# Average GLEU score : 0.16558445909311817
#
# Average METEOR score : 0.34224373169417693
#
#
# Translating sentence  211
# Original Tamil text : மேலும் அவர்களிடமிருந்து பயங்கர ஆயுதங்கள் மற்றும் வெடிமருந்துகள் பறிமுதல் செய்யப்பட்டன.
#
# Original English Conversion : Firearms and ammunition were also seized from them.
#
# Translated to English : Furthermore, weapons and explosives were seized from them.
# Average BLEU score : 0.0470183699819414
#
# Average GLEU score : 0.16783941255878576
#
# Average METEOR score : 0.34478565226039665
#
#
# Translating sentence  221
# Original Tamil text : கல்வி, பண்பாடு, உடல்நலத்துறை அமைச்சர்
#
# Original English Conversion : Education and Health Minister, said.
#
# Translated to English : Minister for Education, Culture and Health
# Average BLEU score : 0.04645518937027862
#
# Average GLEU score : 0.1658454078707496
#
# Average METEOR score : 0.3407603000169895
#
#
# Translating sentence  231
# Original Tamil text : அவன் பைத்தியம் முற்றி வெளியேறியவன்’.
#
# Original English Conversion : He is gone crazy.'
#
# Translated to English : He's gone mad."
# Average BLEU score : 0.04587108237766899
#
# Average GLEU score : 0.1639609169729012
#
# Average METEOR score : 0.3363592742410623
#
#
# Translating sentence  241
# Original Tamil text : இவ்வழக்கு தொடர்பாக பள்ளி நிர்வாகம் மற்றும் ஆசிரியைக்கு எதிராக வழக்குப்பதிவு செய்த போலீஸ் பாவனாவை கைது செய்து உள்ளது.
#
# Original English Conversion : The police have registered a case against the school principal and the teacher.
#
# Translated to English : Police have arrested Bhavana, who has filed a lawsuit against the school administration and the teacher.
# Average BLEU score : 0.04475769217827249
#
# Average GLEU score : 0.16632985736487707
#
# Average METEOR score : 0.340909747653019
#
#
# Translating sentence  251
# Original Tamil text : மற்ற தூதர்கள், கடவுளுக்கு விரோதமான கலகத்தில் சாத்தானோடு சேர்ந்துகொண்டனர்.
#
# Original English Conversion : The Bible shows him to be thoroughly evil and vicious. Other angels joined Satans rebellion against God.
#
# Translated to English : The other messengers joined Satan in a rebellion against God.
# Average BLEU score : 0.044892880570263645
#
# Average GLEU score : 0.16665503696362288
#
# Average METEOR score : 0.34046334572834996
#
#
# Translating sentence  261
# Original Tamil text : காவேரி நதி ஒரு புண்ணிய நதியாகும்.
#
# Original English Conversion : The Cauvery is a glorious river.
#
# Translated to English : Kaveri River is a sacred river.
# Average BLEU score : 0.046266174987748196
#
# Average GLEU score : 0.16624633113862228
#
# Average METEOR score : 0.3390663525630468
#
#
# Translating sentence  271
# Original Tamil text : இயக்குநர் ராகுல் ரவாய்ல் தலையிலான குழுவினர் தேசிய விருதுகளை அறிவித்தனர்.
#
# Original English Conversion : The awards were announced by jury head Rahul Rawail.
#
# Translated to English : The team headed by Director Rahul Raowal announced the National Awards.
# Average BLEU score : 0.0519320698157074
#
# Average GLEU score : 0.16969769284798839
#
# Average METEOR score : 0.34030630670180606
#
#
# Translating sentence  281
# Original Tamil text : """ (மீண்டும் மன்னிக்க!"
#
# Original English Conversion : (I apologise!
#
# Translated to English : "Excuse me again!"
# Average BLEU score : 0.05185923876165433
#
# Average GLEU score : 0.1686101479548569
#
# Average METEOR score : 0.3379054491288458
#
#
# Translating sentence  291
# Original Tamil text : இந்தப்படம் ரசிகர்களிடையே அமோக வரவேற்பை பெற்றது.
#
# Original English Conversion : The film was well-received by fans.
#
# Translated to English : The film received a great reception among the fans.
# Average BLEU score : 0.050077134336855206
#
# Average GLEU score : 0.16665465803829171
#
# Average METEOR score : 0.33541414070955944
#
#
# Translating sentence  301
# Original Tamil text : அவர்களுக்கே உரித்தான குல்லாவையோ, உடைகளையோ அணிவதில்லை.
#
# Original English Conversion : They dont wear masks or gloves.
#
# Translated to English : They do not wear their own crowns or garments.
# Average BLEU score : 0.05261051922242136
#
# Average GLEU score : 0.16985372948100463
#
# Average METEOR score : 0.3363034396579121
#
#
# Translating sentence  311
# Original Tamil text : உணர்ச்சிகளிலேயே மிகச் சக்திவாய்ந்த ஒன்றைப் பற்றிய பொதுவான ஒரு நோக்குநிலையை பூர்வீக ரோம கவிஞர் ஹோராஷியுஸ் அவ்வாறுதான் தெரிவித்தார்.
#
# Original English Conversion : Thus the ancient Roman poet Horace [Latin: Horatius] voiced a common view of one of the strongest of all emotions.
#
# Translated to English : That is how the ancient Roman poet Horatius put forward a common stance on the most powerful of emotions.
# Average BLEU score : 0.05178308382359639
#
# Average GLEU score : 0.16811212816930524
#
# Average METEOR score : 0.3342415036385396
#
#
# Translating sentence  321
# Original Tamil text : (நயியே!) தங்கள் இறைவனுடைய திருப் பொருத்தத்தை நாடி, எவர் காலையிலும் மாலையிலும், அவனை(ப் பிரார்த்தித்து) அழைத்துக் கொண்டிருக்கிறார்களோ அவர்களை நீர் விரட்டி விடாதீர். அவர்களுடைய கேள்வி கணக்குப் பற்றி உம்மீது பொறுப்பில்லை, உம்முடைய கேள்வி கணக்குப் பற்றி அவர்கள் மீதும் யாதொரு பொறுப்புமில்லை - எனவே நீர் அவர்களை விரட்டி விட்டால், நீரும் அநியாயம் செய்பவர்களில் ஒருவராகி விடுவீர்.
#
# Original English Conversion : And do not drive away those who invoke their Lord in the morning and the evening, seeking His pleasure all the time. You are by no means accountable for them just as they are by no means accountable for you. If you still drive them away, you will become among the wrong-doers.
#
# Translated to English : Do not drive away those who call upon their Lord morning and evening, seeking His favor. You have no power over their reckoning, nor do you have any power over their reckoning. If you drive them away, you will be among the wrong-doers.
# Average BLEU score : 0.051182019542545726
#
# Average GLEU score : 0.16674552179424046
#
# Average METEOR score : 0.33413833664040876
#
#
# Translating sentence  331
# Original Tamil text : இச்சம்பவம் குறித்து தாண்டிக்குடி போலீஸாா் வழக்குப் பதிவு செய்து விசாரணை நடத்தி வருகின்றனா்.
#
# Original English Conversion : The police have registered a case and are investigating the case.
#
# Translated to English : The Dandikudi police have filed a case and are investigating the incident.
# Average BLEU score : 0.0510957645203861
#
# Average GLEU score : 0.1655173697985732
#
# Average METEOR score : 0.33203805586706553
#
#
# Translating sentence  341
# Original Tamil text : மருத்துவமனைக்கு கொண்டு சென்ற போது அவர் மாரடைப்பால் இறந்தது தெரியவந்தது.
#
# Original English Conversion : He was declared dead when rushed to the hospital.
#
# Translated to English : When he was taken to the hospital, he was found dead.
# Average BLEU score : 0.04996542841212143
#
# Average GLEU score : 0.16369039596304108
#
# Average METEOR score : 0.3290056842637827
#
#
# Translating sentence  351
# Original Tamil text : சென்று எந்தப் பயனுமில்லை.
#
# Original English Conversion : There is no use.
#
# Translated to English : Going there is no use.
# Average BLEU score : 0.04911584327632197
#
# Average GLEU score : 0.16224317662271306
#
# Average METEOR score : 0.327127766099797
#
#
# Translating sentence  361
# Original Tamil text : ﻿ ‘ஆப்பிரிக்கா விழித்து கொள்ள வேண்டும்’
#
# Original English Conversion : Africa should wake up.
#
# Translated to English : ‘Africa must wake up’
# Average BLEU score : 0.047755293601077595
#
# Average GLEU score : 0.1604890102751683
#
# Average METEOR score : 0.32428811999755713
#
#
# Translating sentence  371
# Original Tamil text : அனைத்து புளுட்டோனியம் சேர்மங்களையும் போலவே இதுவும் அணு பரவல் அல்லாத ஒப்பந்தத்தின் கீழ் கட்டுப்பாட்டுக்கு உட்பட்டதாகும்.
#
# Original English Conversion : As with all plutonium compounds, it is subject to control under the Nuclear Non-Proliferation Treaty.
#
# Translated to English : Like all plutonium compounds, it is under the control of the Non-Proliferation Treaty.
# Average BLEU score : 0.05113009865423244
#
# Average GLEU score : 0.16371697280808614
#
# Average METEOR score : 0.3265098420429584
#
#
# Translating sentence  381
# Original Tamil text : டெல்லியில் பிரதமர் மோடி மற்றும் உள்துறை அமைச்சர் அமித்ஷாவை சந்திக்க உள்ளதாக தகவல் வெளியாகி உள்ளது.
#
# Original English Conversion : Sources said that in Delhi he will meet Prime Minister Narendra Modi and Union Home Minister Amit Shah.
#
# Translated to English : It has been reported that Prime Minister Modi and Home Minister Amit Shah will meet in Delhi.
# Average BLEU score : 0.052337469717569786
#
# Average GLEU score : 0.1640925312890328
#
# Average METEOR score : 0.3267128033676234
#
#
# Translating sentence  391
# Original Tamil text : பக்கோவைட்டு (Bukovite) என்பது Tl2Cu3FeSe4 என்ற மூலக்கூற்று வாய்ப்பாட்டால் விவரிக்கப்படும் ஒரு கனிமம் ஆகும்.
#
# Original English Conversion : Bukovite is a rare selenide mineral with formula Tl2Cu3FeSe4.
#
# Translated to English : Bukovite is a molecule described by the formula Tl2Cu3FeSe4.
# Average BLEU score : 0.051475103156697996
#
# Average GLEU score : 0.16407898591368106
#
# Average METEOR score : 0.3266081503859473
#
#
# Translating sentence  401
# Original Tamil text : தற்போதைய, பொது முடக்கச் சூழலில், நிலக்கரி அமைச்சகத்தின் எந்த ஒப்புதலும் தடைபடாது என்று திரு.
#
# Original English Conversion : Shri Pralhad Joshi further assured that no approvals requiring concurrence of Ministry of Coal would be held up during the current lockdown period.
#
# Translated to English : In the current, general stalemate, no approval from the Coal Ministry will be obstructed.
# Average BLEU score : 0.0507331693130903
#
# Average GLEU score : 0.163404680185779
#
# Average METEOR score : 0.3252927750195663
#
#
# Translating sentence  411
# Original Tamil text : பிரதமர் நரேந்திர மோடி சத்திஸ்கர் மாநிலம் ராஜ்நந்த்காவுன் மாவட்டத்திலுள்ள குருபாட்டிலிருந்து தேசிய ரூர்பன் இயக்கத்தை இன்று தொடங்கி வைத்தார்.
#
# Original English Conversion : The Prime Minister, Shri Narendra Modi, today launched the National Rurban Mission from Kurubhat, in Rajnandgaon district of Chhattisgarh.
#
# Translated to English : The Prime Minister, Shri Narendra Modi, today inaugurated the National Run from Gurupath in Rajnandkan district, Chhattisgarh.
# Average BLEU score : 0.05084248263940849
#
# Average GLEU score : 0.16320895062797894
#
# Average METEOR score : 0.3249663615658276
#
#
# Translating sentence  421
# Original Tamil text : கிறிஸ்தவ கிரேக்க வேதாகமத்தில் “சீஷன் ” என மொழிபெயர்க்கப்பட்டுள்ள வார்த்தை அடிப்படையில், ஏதோ ஒன்றிடம் தன் மனதை ஒருமுகப்படுத்துபவர் அல்லது கற்றுக்கொள்பவர் என்பதையே அர்த்தப்படுத்துகிறது.
#
# Original English Conversion : ( b) Why is it important to ask ourselves, Whose disciple have I become? In the Christian Greek Scriptures, the word translated disciple basically means one who directs his mind to something, or one who learns.
#
# Translated to English : In the Christian Greek Scriptures, the word translated “secession” means one who concentrates or learns from someone.
# Average BLEU score : 0.052857138571676995
#
# Average GLEU score : 0.1651011098090268
#
# Average METEOR score : 0.3285319843999289
#
#
# Translating sentence  431
# Original Tamil text : நிச்சயமாக இதில் இறையச்சம் கொள்வோருக்கு படிப்பினை இருக்கிறது.
#
# Original English Conversion : Indeed in this is a lesson for one who fears.
#
# Translated to English : Lo! herein verily is a lesson for the fear of Allah unto the Calvary.
# Average BLEU score : 0.05317691222744732
#
# Average GLEU score : 0.16407219391604078
#
# Average METEOR score : 0.32630946225784657
#
#
# Translating sentence  441
# Original Tamil text : 04.1979 முதல் 31.03.1982 வரை ரூ.25/-வீதம் (அரசாணை நிலை எண். 805, நிதித்துறை, நாள் 11.06.79)
#
# Original English Conversion : From 1.04.79 to 31.03.1982 at Rs.25 /-(G.O.Ms. No.805, Finance Department dated 11.06.1979)
#
# Translated to English : From 04.1979 to 31.03.1982 Rs.25/- Rate (Ministerial Position No. 805, Department of Finance, date 11.06.79)
# Average BLEU score : 0.05197108655335554
#
# Average GLEU score : 0.16340462027424554
#
# Average METEOR score : 0.32556044126986716
#
#
# Translating sentence  451
# Original Tamil text : 8 ஸ்பீடு ஆட்டோமேட்டிக் கியர்பாக்ஸ் பொருத்தப்பட்டு இருக்கிறது
#
# Original English Conversion : The engine is paired to an 8-speed automatic gearbox
#
# Translated to English : 8 Speed Automatic Gearbox has been enhanced
# Average BLEU score : 0.05200526842800213
#
# Average GLEU score : 0.16408708917232873
#
# Average METEOR score : 0.32725401669052795
#
#
# Translating sentence  461
# Original Tamil text : மனித அரசாங்கங்களின் தோல்விகளை அவர் கவனித்திருக்கிறார்.
#
# Original English Conversion : This proclamation from the highest authority in the universe is cause for hope.
#
# Translated to English : He has observed the failures of human governments.
# Average BLEU score : 0.05270533820126951
#
# Average GLEU score : 0.1632747660702858
#
# Average METEOR score : 0.326271408733066
#
#
# Translating sentence  471
# Original Tamil text : பிஜி நாளை முன்னிட்டு பிஜி நாட்டு மக்களுக்கு பிரதமர் வாழ்த்து
#
# Original English Conversion : PM conveys his greetings to the people of Fiji, on Fiji Day
#
# Translated to English : Prime Minister's Office PM greets people of Fiji on Fiji Day
# Average BLEU score : 0.05353232858494295
#
# Average GLEU score : 0.16414297733329952
#
# Average METEOR score : 0.32713828948412477
#
#
# Translating sentence  481
# Original Tamil text : காண்பித்துக் கொண்டிருக்கிறது.
#
# Original English Conversion : It shows.
#
# Translated to English : is showing.
# Average BLEU score : 0.05488354506546084
#
# Average GLEU score : 0.16483773613018451
#
# Average METEOR score : 0.32686777983028714
#
#
# Translating sentence  491
# Original Tamil text : இந்தியாவில் தொழிலாளர் இடப்பெயர்ச்சி விரைவாக அதிகரித்து வருகிறது என ஆய்வுத் தகவல் : பொருளாதார ஆய்வறிக்கை 2016-17
#
# Original English Conversion : Labour migration in India increasing at an accelerating rate, reveals new study: Economic Survey 2016-17
#
# Translated to English : Economic Survey 2016-17: Employee Migration is on the Rise in India
# Average BLEU score : 0.0550627713786519
#
# Average GLEU score : 0.16425974761971818
#
# Average METEOR score : 0.3264799998078133

# %%
average_bleu_score = np.mean(mbart_bleu_scores)
average_gleu_score = np.mean(mbart_gleu_scores)
average_meteor_score = np.mean(mbart_meteor_scores)
print('Average BLEU Score for Dev Set using Facebooks mBART model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using Facebooks mBART model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using Facebooks mBART model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using Facebooks mBART model:  0.05498409590800934
# Average GLEU Score for Dev Set using Facebooks mBART model:  0.16362644131676832
# Average METEOR Score for Dev Set using Facebooks mBART model:  0.3247924788070061

# %%
import torch
import numpy as np
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor

# Initialize metrics
indict2_bleu_scores = []
indict2_gleu_scores = []
indict2_meteor_scores = []

# Model and tokenizer setup
model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True).to("cuda" if torch.cuda.is_available() else "cpu")
ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "tam_Taml", "eng_Latn"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Convert numpy array to a list
native_tamil_sentences = native_tamil_sentences_dev_set.tolist()
english_sentences = english_sentences_dev_set.tolist()

# Ensure the datasets are aligned
assert len(native_tamil_sentences) == len(english_sentences), "Dev sets must be of equal length."

for i, tamil_text in enumerate(native_tamil_sentences):
    try:
        # print(f"Processing sentence {i+1}...")
        
        # Preprocessing
        batch = ip.preprocess_batch(
            [tamil_text],
            src_lang=src_lang,
            tgt_lang=tgt_lang,
        )
        # print(f"Preprocessed batch: {batch}")
        
        # Tokenize the sentences and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=1,
                num_return_sequences=1,
            )
        # print(f"Generated tokens: {generated_tokens}")

        # Decode the generated tokens into text
        with tokenizer.as_target_tokenizer():
            generated_tokens = tokenizer.batch_decode(
                generated_tokens.detach().cpu().tolist(),
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )
        translation = ip.postprocess_batch(generated_tokens, lang=tgt_lang)[0]
        bleu_score, gleu_score, met_score = calculate_scores(english_sentences_dev_set[i], translation)

        indict2_bleu_scores.append(bleu_score)
        indict2_gleu_scores.append(gleu_score)
        indict2_meteor_scores.append(met_score)

        # Log progress every 10 sentences
        if i % 10 == 0:
            print("Translating sentence", i + 1)
            print("Original Tamil text:", tamil_text)
            print("Original English Conversion:", english_sentences[i])
            print("Translated to English:", translation)
            print("Average BLEU score:", np.mean(indict2_bleu_scores))
            print("Average GLEU score:", np.mean(indict2_gleu_scores))
            print("Average METEOR score:", np.mean(indict2_meteor_scores))
            print()

    except Exception as e:
        print(f"Error processing sentence {i+1}: {e}")
        continue
# Out:
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\transformers\tokenization_utils_base.py:4114: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Translating sentence 1
# Original Tamil text: சாரங்கி வாசிப்பது அவ்வளவு சுலபம் இல்லை.
#
# Original English Conversion: Its not easy reading.
#
# Translated to English: It is not easy to read the Sarangi.
# Average BLEU score: 6.484592771860512e-155
# Average GLEU score: 0.11538461538461539
# Average METEOR score: 0.5808080808080809
#
# Translating sentence 11
# Original Tamil text: 210 கோடி வசூலித்துள்ளது.
#
# Original English Conversion: 210 crore.
#
# Translated to English: 210 crores.
# Average BLEU score: 0.0805639056465013
# Average GLEU score: 0.19156091117813603
# Average METEOR score: 0.38968411342302184
#
# Translating sentence 21
# Original Tamil text: நான் பயம் விரும்புகிறேன்.
#
# Original English Conversion: I like the fear.
#
# Translated to English: I like the fear.
# Average BLEU score: 0.1456564005148834
# Average GLEU score: 0.23342938242165226
# Average METEOR score: 0.4011436649063266
#
# Translating sentence 31
# Original Tamil text: பிரச்சினை எல்லாம் தீர்க்கப்பட வேணும்.
#
# Original English Conversion: All problems must be solved.
#
# Translated to English: All issues must be resolved.
# Average BLEU score: 0.17890416753393457
# Average GLEU score: 0.28365535593619584
# Average METEOR score: 0.46840978881713946
#
# Translating sentence 41
# Original Tamil text: யெகோவாவின் நியாயத்தீர்ப்பு நாள் அருகில் இருக்கிறது, சீக்கிரத்தில் அவர் தம்முடைய சத்துருக்களை பழிவாங்குவார்.
#
# Original English Conversion: The execution of Gods wrath upon Judah and Jerusalem was a day of distress and of anguish.
#
# Translated to English: Jehovahs day of judgment is near, and soon he will avenge his enemies.
# Average BLEU score: 0.1435302469630544
# Average GLEU score: 0.24848854604090498
# Average METEOR score: 0.43026813414699466
#
# Translating sentence 51
# Original Tamil text: காட்டிக் கொடுப்பதென்பது இதைத்தானா!
#
# Original English Conversion: This is betrayal!
#
# Translated to English: Is this cheating?
# Average BLEU score: 0.1401457081358362
# Average GLEU score: 0.25588336565000736
# Average METEOR score: 0.43095026531673325
#
# Translating sentence 61
# Original Tamil text: இவருக்கு திருமணம் ஆகி ரோகினி என்ற மனைவியும், ஒரு மகன் மற்றும் மகள் உள்ளனர்.
#
# Original English Conversion: He is survived by wife, a son and a daughter.
#
# Translated to English: He is married to Rohini and has a son and a daughter.
# Average BLEU score: 0.1420931303743381
# Average GLEU score: 0.266433681299163
# Average METEOR score: 0.44021670189320355
#
# Translating sentence 71
# Original Tamil text: ஏற்பாட்டினை வர்த்தக சங்கத்தினர் செய்திருந்தனர்.
#
# Original English Conversion: The talk was organised by the Commerce Society.
#
# Translated to English: The trade union had arranged the event.
# Average BLEU score: 0.12820879127235746
# Average GLEU score: 0.2514921915468223
# Average METEOR score: 0.4202044345066693
#
# Translating sentence 81
# Original Tamil text: உத்தரகாண்ட் மாநிலத்தில் கடந்த சில நாட்களாக கன மழை பெய்து வருவதால் ஆறுகளில் வெள்ளப்பெருக்கு ஏற்பட்டுள்ளது.
#
# Original English Conversion: Heavy rains have been wreaking havoc in Uttarkhand over the last few days.
#
# Translated to English: Uttarakhand has been receiving heavy rainfall in the last few days, leading to flooding in rivers.
# Average BLEU score: 0.12088900202457982
# Average GLEU score: 0.267586863888475
# Average METEOR score: 0.44705527770173886
#
# Translating sentence 91
# Original Tamil text: தமிழ், தெலுங்கு, மலையாளம், ஹிந்தி என நான்கு மொழிகளில் பிசியாக இருந்தேன்.
#
# Original English Conversion: I have acted in all the four regional languages Tamil, Telugu, Malayalam and Kannada.
#
# Translated to English: I was busy with four languages - Tamil, Telugu, Malayalam and Hindi.
# Average BLEU score: 0.1298983420934105
# Average GLEU score: 0.26944866439845017
# Average METEOR score: 0.4539100095148639
#
# Translating sentence 101
# Original Tamil text: சிலசமயங்களில் இது லாபத்தின் ஒரு பிரச்னையாகிறது.
#
# Original English Conversion: There is no money in tropical diseases, admits New Scientist, because, by and large, those who are affected cannot afford medicines.
#
# Translated to English: Sometimes it becomes a problem of profit.
# Average BLEU score: 0.1364022790537684
# Average GLEU score: 0.26530851457311483
# Average METEOR score: 0.43981300108313215
#
# Translating sentence 111
# Original Tamil text: அந்த வாய்ப்பைச் சட்டென்று பிடித்துக் கொண்டேன்.
#
# Original English Conversion: I grabbed that chance.
#
# Translated to English: I grabbed the opportunity.
# Average BLEU score: 0.12872614959683834
# Average GLEU score: 0.25527375577227307
# Average METEOR score: 0.4290153509721509
#
# Translating sentence 121
# Original Tamil text: ஆகவே எப்போதும் செருக்கில்லாமல் இருப்து நல்லது.
#
# Original English Conversion: So its always better to stay away from it.
#
# Translated to English: So it is always better to be careful.
# Average BLEU score: 0.1263520876466864
# Average GLEU score: 0.25167864900417
# Average METEOR score: 0.42008770629779885
#
# Translating sentence 131
# Original Tamil text: | படம்: ஏஎன்ஐ
#
# Original English Conversion: | Photo: ANI
#
# Translated to English: | Photo: ANI
# Average BLEU score: 0.12198900179623925
# Average GLEU score: 0.25480969415666027
# Average METEOR score: 0.4230000044945473
#
# Translating sentence 141
# Original Tamil text: திருமாவளவனைக் கண்டித்து பாஜக மகளிர் அணியினர் நாமாக்கலில் ஆர்ப்பாட்டம்
#
# Original English Conversion: BJP women protest Namtara firing
#
# Translated to English: BJP women's wing stages protest against Thirumavalavan
# Average BLEU score: 0.11920416534581657
# Average GLEU score: 0.25156440883002984
# Average METEOR score: 0.42465246908785637
#
# Translating sentence 151
# Original Tamil text: ஏனைய 13 கொத்துவழிப் பங்காளிகளை காரியக்காரர்களாகவும் ஆக்கினர்.
#
# Original English Conversion: They are searching for at least 13 other suspects.
#
# Translated to English: They also made 13 other mason partners as stewards.
# Average BLEU score: 0.11236138448152987
# Average GLEU score: 0.24396305450732522
# Average METEOR score: 0.4147922744030325
#
# Translating sentence 161
# Original Tamil text: இந்த உளவியல் மாற்றம் மற்றும் கால மாற்றத்தை நாம் உணர்ந்துகொள்ள வேண்டும்.
#
# Original English Conversion: We have to understand this transformation of psychology and changing times
#
# Translated to English: We have to realize this psychological change and change in time.
# Average BLEU score: 0.1129853003290755
# Average GLEU score: 0.24383575609066704
# Average METEOR score: 0.4148577698048963
#
# Translating sentence 171
# Original Tamil text: இவ்வாணையம் ஓய்வுபெற்ற உயர்நீதிமன்ற நீதிபதி, நீதியரசர் திரு. எம்.எஸ். ஜனார்த்தனம் அவர்கள் தலைமையில் 8 உறுப்பினர்களுடன், 28.12.2015 அன்று 3 ஆண்டுகள் பதவிக்காலத்துடன் திருத்தியமைக்கப் பட்டுள்ளது.
#
# Original English Conversion: The Commission has been reconstituted for a period of 3 years on 28.12.2015 under the Chairmanship of Justice Thiru M.S.Janarthanam , retired Judge of High Court and eight Members.
#
# Translated to English: The Commission is headed by retired High Court Judge, Justice M.S. Janardhanam with 8 members, with a tenure of 3 years on 28.12.2015.
# Average BLEU score: 0.10705750166913165
# Average GLEU score: 0.24479373625475281
# Average METEOR score: 0.4158344755378686
#
# Translating sentence 181
# Original Tamil text: இடம்தான் வேறு.
#
# Original English Conversion: Different venue.
#
# Translated to English: It's a different place.
# Average BLEU score: 0.10198562605696201
# Average GLEU score: 0.2381367471641034
# Average METEOR score: 0.408286328109441
#
# Translating sentence 191
# Original Tamil text: அதில் அவர்கள் போல்டான் அணியை 4-2 வித்தியாசத்தில் வெற்றி பெற்றனர்.
#
# Original English Conversion: There they, defeated the Cleveland Cavaliers 42.
#
# Translated to English: They beat Bolton 4-2.
# Average BLEU score: 0.10674834984175766
# Average GLEU score: 0.24138282371346095
# Average METEOR score: 0.41269982011570444
#
# Translating sentence 201
# Original Tamil text: எனவேதான் இது மோசமான பிரச்சினையாக பார்க்கப்படுகிறது.
#
# Original English Conversion: Thats why this is a big problem.
#
# Translated to English: That is why it is seen as a bad problem.
# Average BLEU score: 0.10698791496947634
# Average GLEU score: 0.2409475380073852
# Average METEOR score: 0.413780020965482
#
# Translating sentence 211
# Original Tamil text: மேலும் அவர்களிடமிருந்து பயங்கர ஆயுதங்கள் மற்றும் வெடிமருந்துகள் பறிமுதல் செய்யப்பட்டன.
#
# Original English Conversion: Firearms and ammunition were also seized from them.
#
# Translated to English: Arms and ammunition were also recovered from their possession.
# Average BLEU score: 0.10794420115079668
# Average GLEU score: 0.23907111265958825
# Average METEOR score: 0.4147081004821474
#
# Translating sentence 221
# Original Tamil text: கல்வி, பண்பாடு, உடல்நலத்துறை அமைச்சர்
#
# Original English Conversion: Education and Health Minister, said.
#
# Translated to English: Minister of Education, Culture and Health
# Average BLEU score: 0.10937279814697998
# Average GLEU score: 0.2395670185182447
# Average METEOR score: 0.41643201588705503
#
# Translating sentence 231
# Original Tamil text: அவன் பைத்தியம் முற்றி வெளியேறியவன்’.
#
# Original English Conversion: He is gone crazy.'
#
# Translated to English: He is crazy. "
# Average BLEU score: 0.10989604378250914
# Average GLEU score: 0.23936069456440048
# Average METEOR score: 0.41535809765882375
#
# Translating sentence 241
# Original Tamil text: இவ்வழக்கு தொடர்பாக பள்ளி நிர்வாகம் மற்றும் ஆசிரியைக்கு எதிராக வழக்குப்பதிவு செய்த போலீஸ் பாவனாவை கைது செய்து உள்ளது.
#
# Original English Conversion: The police have registered a case against the school principal and the teacher.
#
# Translated to English: Police have registered a case against the school management and the teacher.
# Average BLEU score: 0.11016292547966473
# Average GLEU score: 0.23987392026839832
# Average METEOR score: 0.41987882060034715
#
# Translating sentence 251
# Original Tamil text: மற்ற தூதர்கள், கடவுளுக்கு விரோதமான கலகத்தில் சாத்தானோடு சேர்ந்துகொண்டனர்.
#
# Original English Conversion: The Bible shows him to be thoroughly evil and vicious. Other angels joined Satans rebellion against God.
#
# Translated to English: The other angels joined Satan in his rebellion against God.
# Average BLEU score: 0.11094731669439133
# Average GLEU score: 0.2422081963067318
# Average METEOR score: 0.421185486716012
#
# Translating sentence 261
# Original Tamil text: காவேரி நதி ஒரு புண்ணிய நதியாகும்.
#
# Original English Conversion: The Cauvery is a glorious river.
#
# Translated to English: The Kaveri River is a sacred river.
# Average BLEU score: 0.11047436117827832
# Average GLEU score: 0.24174433628410252
# Average METEOR score: 0.4222502883358854
#
# Translating sentence 271
# Original Tamil text: இயக்குநர் ராகுல் ரவாய்ல் தலையிலான குழுவினர் தேசிய விருதுகளை அறிவித்தனர்.
#
# Original English Conversion: The awards were announced by jury head Rahul Rawail.
#
# Translated to English: The team headed by director Rahul Roy announced the National Awards.
# Average BLEU score: 0.11048445880707154
# Average GLEU score: 0.2407781007358985
# Average METEOR score: 0.41960960660972274
#
# Translating sentence 281
# Original Tamil text: """ (மீண்டும் மன்னிக்க!"
#
# Original English Conversion: (I apologise!
#
# Translated to English: "" "Sorry again!" ""
# Average BLEU score: 0.11081772543438455
# Average GLEU score: 0.24193444914223253
# Average METEOR score: 0.42158361639908265
#
# Translating sentence 291
# Original Tamil text: இந்தப்படம் ரசிகர்களிடையே அமோக வரவேற்பை பெற்றது.
#
# Original English Conversion: The film was well-received by fans.
#
# Translated to English: The film was well received by fans.
# Average BLEU score: 0.10881251380793112
# Average GLEU score: 0.24220448123624141
# Average METEOR score: 0.4242495178110886
#
# Translating sentence 301
# Original Tamil text: அவர்களுக்கே உரித்தான குல்லாவையோ, உடைகளையோ அணிவதில்லை.
#
# Original English Conversion: They dont wear masks or gloves.
#
# Translated to English: They do not wear the kulhas or the clothes that are theirs.
# Average BLEU score: 0.11005462078107153
# Average GLEU score: 0.24840700454734413
# Average METEOR score: 0.4277255311155445
#
# Translating sentence 311
# Original Tamil text: உணர்ச்சிகளிலேயே மிகச் சக்திவாய்ந்த ஒன்றைப் பற்றிய பொதுவான ஒரு நோக்குநிலையை பூர்வீக ரோம கவிஞர் ஹோராஷியுஸ் அவ்வாறுதான் தெரிவித்தார்.
#
# Original English Conversion: Thus the ancient Roman poet Horace [Latin: Horatius] voiced a common view of one of the strongest of all emotions.
#
# Translated to English: That is how the native Roman poet Horatius expressed a common view of one of the most powerful of emotions.
# Average BLEU score: 0.11242719622861494
# Average GLEU score: 0.24903189796477523
# Average METEOR score: 0.42864497651279126
#
# Translating sentence 321
# Original Tamil text: (நயியே!) தங்கள் இறைவனுடைய திருப் பொருத்தத்தை நாடி, எவர் காலையிலும் மாலையிலும், அவனை(ப் பிரார்த்தித்து) அழைத்துக் கொண்டிருக்கிறார்களோ அவர்களை நீர் விரட்டி விடாதீர். அவர்களுடைய கேள்வி கணக்குப் பற்றி உம்மீது பொறுப்பில்லை, உம்முடைய கேள்வி கணக்குப் பற்றி அவர்கள் மீதும் யாதொரு பொறுப்புமில்லை - எனவே நீர் அவர்களை விரட்டி விட்டால், நீரும் அநியாயம் செய்பவர்களில் ஒருவராகி விடுவீர்.
#
# Original English Conversion: And do not drive away those who invoke their Lord in the morning and the evening, seeking His pleasure all the time. You are by no means accountable for them just as they are by no means accountable for you. If you still drive them away, you will become among the wrong-doers.
#
# Translated to English: Do not drive away those who seek the pleasure of their Lord and call on Him morning and evening. You have no responsibility for their question, nor do you have any responsibility for their question. If you drive them away, you will be one of the wrongdoers.
# Average BLEU score: 0.11140734417542741
# Average GLEU score: 0.2473094151271232
# Average METEOR score: 0.4275269179081876
#
# Translating sentence 331
# Original Tamil text: இச்சம்பவம் குறித்து தாண்டிக்குடி போலீஸாா் வழக்குப் பதிவு செய்து விசாரணை நடத்தி வருகின்றனா்.
#
# Original English Conversion: The police have registered a case and are investigating the case.
#
# Translated to English: The police have registered a case and are investigating the incident.
# Average BLEU score: 0.11073991378283708
# Average GLEU score: 0.24517389034335924
# Average METEOR score: 0.425626064995773
#
# Translating sentence 341
# Original Tamil text: மருத்துவமனைக்கு கொண்டு சென்ற போது அவர் மாரடைப்பால் இறந்தது தெரியவந்தது.
#
# Original English Conversion: He was declared dead when rushed to the hospital.
#
# Translated to English: He was declared dead on arrival at hospital.
# Average BLEU score: 0.11013513687685023
# Average GLEU score: 0.2430847501151715
# Average METEOR score: 0.4223713833548585
#
# Translating sentence 351
# Original Tamil text: சென்று எந்தப் பயனுமில்லை.
#
# Original English Conversion: There is no use.
#
# Translated to English: There is no use going.
# Average BLEU score: 0.10802341928424788
# Average GLEU score: 0.24074111739912493
# Average METEOR score: 0.4195685324108748
#
# Translating sentence 361
# Original Tamil text: ﻿ ‘ஆப்பிரிக்கா விழித்து கொள்ள வேண்டும்’
#
# Original English Conversion: Africa should wake up.
#
# Translated to English: "Africa needs to wake up." ""
# Average BLEU score: 0.10717048646880431
# Average GLEU score: 0.24133231110360207
# Average METEOR score: 0.4201346856183126
#
# Translating sentence 371
# Original Tamil text: அனைத்து புளுட்டோனியம் சேர்மங்களையும் போலவே இதுவும் அணு பரவல் அல்லாத ஒப்பந்தத்தின் கீழ் கட்டுப்பாட்டுக்கு உட்பட்டதாகும்.
#
# Original English Conversion: As with all plutonium compounds, it is subject to control under the Nuclear Non-Proliferation Treaty.
#
# Translated to English: Like all plutonium compounds, it is subject to regulation under the Nuclear Non-Proliferation Treaty.
# Average BLEU score: 0.11273820508411796
# Average GLEU score: 0.24587291792567792
# Average METEOR score: 0.4227177347353411
#
# Translating sentence 381
# Original Tamil text: டெல்லியில் பிரதமர் மோடி மற்றும் உள்துறை அமைச்சர் அமித்ஷாவை சந்திக்க உள்ளதாக தகவல் வெளியாகி உள்ளது.
#
# Original English Conversion: Sources said that in Delhi he will meet Prime Minister Narendra Modi and Union Home Minister Amit Shah.
#
# Translated to English: He is scheduled to meet Prime Minister Narendra Modi and Union Home Minister Amit Shah in Delhi.
# Average BLEU score: 0.11412556998565039
# Average GLEU score: 0.24827547792881174
# Average METEOR score: 0.42467237400930746
#
# Translating sentence 391
# Original Tamil text: பக்கோவைட்டு (Bukovite) என்பது Tl2Cu3FeSe4 என்ற மூலக்கூற்று வாய்ப்பாட்டால் விவரிக்கப்படும் ஒரு கனிமம் ஆகும்.
#
# Original English Conversion: Bukovite is a rare selenide mineral with formula Tl2Cu3FeSe4.
#
# Translated to English: Bukovite is a mineral with the formula Tl2Cu3FeSe4.
# Average BLEU score: 0.11407428961486046
# Average GLEU score: 0.24928614900702206
# Average METEOR score: 0.426269149308879
#
# Translating sentence 401
# Original Tamil text: தற்போதைய, பொது முடக்கச் சூழலில், நிலக்கரி அமைச்சகத்தின் எந்த ஒப்புதலும் தடைபடாது என்று திரு.
#
# Original English Conversion: Shri Pralhad Joshi further assured that no approvals requiring concurrence of Ministry of Coal would be held up during the current lockdown period.
#
# Translated to English: Shri Goyal said that in the current lockdown situation, no approval from the Ministry of Coal will be held up.
# Average BLEU score: 0.11282942720896444
# Average GLEU score: 0.2474991920442127
# Average METEOR score: 0.4242091117811499
#
# Translating sentence 411
# Original Tamil text: பிரதமர் நரேந்திர மோடி சத்திஸ்கர் மாநிலம் ராஜ்நந்த்காவுன் மாவட்டத்திலுள்ள குருபாட்டிலிருந்து தேசிய ரூர்பன் இயக்கத்தை இன்று தொடங்கி வைத்தார்.
#
# Original English Conversion: The Prime Minister, Shri Narendra Modi, today launched the National Rurban Mission from Kurubhat, in Rajnandgaon district of Chhattisgarh.
#
# Translated to English: Prime Minister Narendra Modi launched the National Rurban Mission from Kurubat in Rajnandgaon district of Chhattisgarh today.
# Average BLEU score: 0.11142732913340188
# Average GLEU score: 0.24552173256137969
# Average METEOR score: 0.42272696784703057
#
# Translating sentence 421
# Original Tamil text: கிறிஸ்தவ கிரேக்க வேதாகமத்தில் “சீஷன் ” என மொழிபெயர்க்கப்பட்டுள்ள வார்த்தை அடிப்படையில், ஏதோ ஒன்றிடம் தன் மனதை ஒருமுகப்படுத்துபவர் அல்லது கற்றுக்கொள்பவர் என்பதையே அர்த்தப்படுத்துகிறது.
#
# Original English Conversion: ( b) Why is it important to ask ourselves, Whose disciple have I become? In the Christian Greek Scriptures, the word translated disciple basically means one who directs his mind to something, or one who learns.
#
# Translated to English: The word translated disciple in the Christian Greek Scriptures basically means one who concentrates his mind on something or one who learns.
# Average BLEU score: 0.11296127740569804
# Average GLEU score: 0.24730872342345145
# Average METEOR score: 0.4246473812041736
#
# Translating sentence 431
# Original Tamil text: நிச்சயமாக இதில் இறையச்சம் கொள்வோருக்கு படிப்பினை இருக்கிறது.
#
# Original English Conversion: Indeed in this is a lesson for one who fears.
#
# Translated to English: Surely in this is a lesson for those who are pious.
# Average BLEU score: 0.11186065202501101
# Average GLEU score: 0.24601263088111314
# Average METEOR score: 0.42427100387162353
#
# Translating sentence 441
# Original Tamil text: 04.1979 முதல் 31.03.1982 வரை ரூ.25/-வீதம் (அரசாணை நிலை எண். 805, நிதித்துறை, நாள் 11.06.79)
#
# Original English Conversion: From 1.04.79 to 31.03.1982 at Rs.25 /-(G.O.Ms. No.805, Finance Department dated 11.06.1979)
#
# Translated to English: Rs.25 / - (G.O. Level No.805, Finance Department, Dated 11.06.79) for 04.1979 to 31.03.1982
# Average BLEU score: 0.11242062640733394
# Average GLEU score: 0.24645682963469437
# Average METEOR score: 0.42429303891743214
#
# Translating sentence 451
# Original Tamil text: 8 ஸ்பீடு ஆட்டோமேட்டிக் கியர்பாக்ஸ் பொருத்தப்பட்டு இருக்கிறது
#
# Original English Conversion: The engine is paired to an 8-speed automatic gearbox
#
# Translated to English: It is mated to an 8-speed automatic gearbox
# Average BLEU score: 0.11371154515090931
# Average GLEU score: 0.24787798555722648
# Average METEOR score: 0.42681836486929203
#
# Translating sentence 461
# Original Tamil text: மனித அரசாங்கங்களின் தோல்விகளை அவர் கவனித்திருக்கிறார்.
#
# Original English Conversion: This proclamation from the highest authority in the universe is cause for hope.
#
# Translated to English: He has observed the failures of human governments.
# Average BLEU score: 0.11391147630110811
# Average GLEU score: 0.2471265100441486
# Average METEOR score: 0.42657651498175625
#
# Translating sentence 471
# Original Tamil text: பிஜி நாளை முன்னிட்டு பிஜி நாட்டு மக்களுக்கு பிரதமர் வாழ்த்து
#
# Original English Conversion: PM conveys his greetings to the people of Fiji, on Fiji Day
#
# Translated to English: PM greets the people of Fiji on Fiji Day
# Average BLEU score: 0.11520697069501515
# Average GLEU score: 0.24818763991471068
# Average METEOR score: 0.42824779233121163
#
# Translating sentence 481
# Original Tamil text: காண்பித்துக் கொண்டிருக்கிறது.
#
# Original English Conversion: It shows.
#
# Translated to English: It's showing.
# Average BLEU score: 0.11653753380940539
# Average GLEU score: 0.24817271929331158
# Average METEOR score: 0.4274403040579637
#
# Translating sentence 491
# Original Tamil text: இந்தியாவில் தொழிலாளர் இடப்பெயர்ச்சி விரைவாக அதிகரித்து வருகிறது என ஆய்வுத் தகவல் : பொருளாதார ஆய்வறிக்கை 2016-17
#
# Original English Conversion: Labour migration in India increasing at an accelerating rate, reveals new study: Economic Survey 2016-17
#
# Translated to English: Labour migration in India increasing rapidly, says Economic Survey
# Average BLEU score: 0.11811831325440987
# Average GLEU score: 0.24851393993537066
# Average METEOR score: 0.4271632928454857

# %%
average_bleu_score = np.mean(indict2_bleu_scores)
average_gleu_score = np.mean(indict2_gleu_scores)
average_meteor_score = np.mean(indict2_meteor_scores)
print('Average BLEU Score for Dev Set using IndicTrans2 model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using IndicTrans2 model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using IndicTrans2 model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using IndicTrans2 model:  0.11736283037882865
# Average GLEU Score for Dev Set using IndicTrans2 model:  0.24793760969661255
# Average METEOR Score for Dev Set using IndicTrans2 model:  0.425951905439129

# %%
# Opus MarianMT
from transformers import pipeline
OpusMT_translator = pipeline("translation", model="Helsinki-NLP/opus-mt-mul-en")

opusMT_bleu_scores = []
opusMT_gleu_scores = []
opusMT_meteor_scores = []

for i, tamil_text in enumerate(native_tamil_sentences_dev_set):

    translation = OpusMT_translator(tamil_text)[0]["translation_text"]
    bleu_score, gleu_score, met_score = calculate_scores(english_sentences_dev_set[i], translation)

    opusMT_bleu_scores.append(bleu_score)
    opusMT_gleu_scores.append(gleu_score)
    opusMT_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Tamil text :', tamil_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translation)
        print('Average BLEU score :', np.mean(opusMT_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(opusMT_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(opusMT_meteor_scores), '\n')
        print()
# Out:
# Translating sentence  1
# Original Tamil text : சாரங்கி வாசிப்பது அவ்வளவு சுலபம் இல்லை.
#
# Original English Conversion : Its not easy reading.
#
# Translated to English : It is not so easy to read aloud.
# Average BLEU score : 1.2882297539194154e-231
#
# Average GLEU score : 0.07692307692307693
#
# Average METEOR score : 0.34090909090909094
#
#
# Translating sentence  11
# Original Tamil text : 210 கோடி வசூலித்துள்ளது.
#
# Original English Conversion : 210 crore.
#
# Translated to English : It is worth 210 million dollars.
# Average BLEU score : 0.03801274224112792
#
# Average GLEU score : 0.08942669579163644
#
# Average METEOR score : 0.23569669821979228
#
#
# Translating sentence  21
# Original Tamil text : நான் பயம் விரும்புகிறேன்.
#
# Original English Conversion : I like the fear.
#
# Translated to English : I want to be scared.
# Average BLEU score : 0.029506396486812043
#
# Average GLEU score : 0.09878293886531438
#
# Average METEOR score : 0.2507784915834043
#
#
# Translating sentence  31
# Original Tamil text : பிரச்சினை எல்லாம் தீர்க்கப்பட வேணும்.
#
# Original English Conversion : All problems must be solved.
#
# Translated to English : The problem needs to be resolved.
# Average BLEU score : 0.03280862426058647
#
# Average GLEU score : 0.1080886675538075
#
# Average METEOR score : 0.28070785859631064
#
#
# Translating sentence  41
# Original Tamil text : யெகோவாவின் நியாயத்தீர்ப்பு நாள் அருகில் இருக்கிறது, சீக்கிரத்தில் அவர் தம்முடைய சத்துருக்களை பழிவாங்குவார்.
#
# Original English Conversion : The execution of Gods wrath upon Judah and Jerusalem was a day of distress and of anguish.
#
# Translated to English : Jehovah’s day of judgment is near, and he will soon execute judgment on his enemies.
# Average BLEU score : 0.033430618567010975
#
# Average GLEU score : 0.10133052716940448
#
# Average METEOR score : 0.2656329227724098
#
#
# Translating sentence  51
# Original Tamil text : காட்டிக் கொடுப்பதென்பது இதைத்தானா!
#
# Original English Conversion : This is betrayal!
#
# Translated to English : What a fine example for us to follow!
# Average BLEU score : 0.026875595318577448
#
# Average GLEU score : 0.09724966232124929
#
# Average METEOR score : 0.2562789900891385
#
#
# Translating sentence  61
# Original Tamil text : இவருக்கு திருமணம் ஆகி ரோகினி என்ற மனைவியும், ஒரு மகன் மற்றும் மகள் உள்ளனர்.
#
# Original English Conversion : He is survived by wife, a son and a daughter.
#
# Translated to English : His wife, Rokini, also has a son and daughter.
# Average BLEU score : 0.02667933457885848
#
# Average GLEU score : 0.0987243250210533
#
# Average METEOR score : 0.2470408227976774
#
#
# Translating sentence  71
# Original Tamil text : ஏற்பாட்டினை வர்த்தக சங்கத்தினர் செய்திருந்தனர்.
#
# Original English Conversion : The talk was organised by the Commerce Society.
#
# Translated to English : The organization was made up of trade unions.
# Average BLEU score : 0.03302090920286463
#
# Average GLEU score : 0.101758726900536
#
# Average METEOR score : 0.24553899316534575
#
#
# Translating sentence  81
# Original Tamil text : உத்தரகாண்ட் மாநிலத்தில் கடந்த சில நாட்களாக கன மழை பெய்து வருவதால் ஆறுகளில் வெள்ளப்பெருக்கு ஏற்பட்டுள்ளது.
#
# Original English Conversion : Heavy rains have been wreaking havoc in Uttarkhand over the last few days.
#
# Translated to English : A few days ago in northern Canada, rain fell upon the white sharks.
# Average BLEU score : 0.028944253745720846
#
# Average GLEU score : 0.1040473296171494
#
# Average METEOR score : 0.24844606353554813
#
#
# Translating sentence  91
# Original Tamil text : தமிழ், தெலுங்கு, மலையாளம், ஹிந்தி என நான்கு மொழிகளில் பிசியாக இருந்தேன்.
#
# Original English Conversion : I have acted in all the four regional languages Tamil, Telugu, Malayalam and Kannada.
#
# Translated to English : I was the second of four children. I was the youngest of four children.
# Average BLEU score : 0.03355065567772651
#
# Average GLEU score : 0.11063052400456527
#
# Average METEOR score : 0.2574073859474583
#
#
# Translating sentence  101
# Original Tamil text : சிலசமயங்களில் இது லாபத்தின் ஒரு பிரச்னையாகிறது.
#
# Original English Conversion : There is no money in tropical diseases, admits New Scientist, because, by and large, those who are affected cannot afford medicines.
#
# Translated to English : At times, this is a problem of greed.
# Average BLEU score : 0.0318453226752048
#
# Average GLEU score : 0.10481208750032324
#
# Average METEOR score : 0.2497639577889009
#
#
# Translating sentence  111
# Original Tamil text : அந்த வாய்ப்பைச் சட்டென்று பிடித்துக் கொண்டேன்.
#
# Original English Conversion : I grabbed that chance.
#
# Translated to English : I took advantage of the opportunity.
# Average BLEU score : 0.03054604501192005
#
# Average GLEU score : 0.10078262558249106
#
# Average METEOR score : 0.2405515885641973
#
#
# Translating sentence  121
# Original Tamil text : ஆகவே எப்போதும் செருக்கில்லாமல் இருப்து நல்லது.
#
# Original English Conversion : So its always better to stay away from it.
#
# Translated to English : So it is good not to get caught up in it.
# Average BLEU score : 0.0280215784820093
#
# Average GLEU score : 0.10394945677493456
#
# Average METEOR score : 0.24726641190578505
#
#
# Translating sentence  131
# Original Tamil text : | படம்: ஏஎன்ஐ
#
# Original English Conversion : | Photo: ANI
#
# Translated to English : Photo: ANA
# Average BLEU score : 0.025882526689489507
#
# Average GLEU score : 0.10469658218134173
#
# Average METEOR score : 0.24425138707945201
#
#
# Translating sentence  141
# Original Tamil text : திருமாவளவனைக் கண்டித்து பாஜக மகளிர் அணியினர் நாமாக்கலில் ஆர்ப்பாட்டம்
#
# Original English Conversion : BJP women protest Namtara firing
#
# Translated to English : In Namakal, a group of wealthy girls settled in a small town in the southeastern part of the country.
# Average BLEU score : 0.025564730685536562
#
# Average GLEU score : 0.10699737770317279
#
# Average METEOR score : 0.24669465344328864
#
#
# Translating sentence  151
# Original Tamil text : ஏனைய 13 கொத்துவழிப் பங்காளிகளை காரியக்காரர்களாகவும் ஆக்கினர்.
#
# Original English Conversion : They are searching for at least 13 other suspects.
#
# Translated to English : Some of the 13 trainees also became workers.
# Average BLEU score : 0.02635773133074014
#
# Average GLEU score : 0.10684600670885248
#
# Average METEOR score : 0.2442946427174236
#
#
# Translating sentence  161
# Original Tamil text : இந்த உளவியல் மாற்றம் மற்றும் கால மாற்றத்தை நாம் உணர்ந்துகொள்ள வேண்டும்.
#
# Original English Conversion : We have to understand this transformation of psychology and changing times
#
# Translated to English : We need to feel this moderate change and change of time.
# Average BLEU score : 0.029943564262083697
#
# Average GLEU score : 0.1114526279414036
#
# Average METEOR score : 0.25221916820755286
#
#
# Translating sentence  171
# Original Tamil text : இவ்வாணையம் ஓய்வுபெற்ற உயர்நீதிமன்ற நீதிபதி, நீதியரசர் திரு. எம்.எஸ். ஜனார்த்தனம் அவர்கள் தலைமையில் 8 உறுப்பினர்களுடன், 28.12.2015 அன்று 3 ஆண்டுகள் பதவிக்காலத்துடன் திருத்தியமைக்கப் பட்டுள்ளது.
#
# Original English Conversion : The Commission has been reconstituted for a period of 3 years on 28.12.2015 under the Chairmanship of Justice Thiru M.S.Janarthanam , retired Judge of High Court and eight Members.
#
# Translated to English : Thus, on 28 December 2015, the United Nations High Court of Justice, President of the United States, has been settled for three years with 8 members in their head, on 28 December 2015.
# Average BLEU score : 0.02819247863272208
#
# Average GLEU score : 0.1157016353415653
#
# Average METEOR score : 0.25663262628407546
#
#
# Translating sentence  181
# Original Tamil text : இடம்தான் வேறு.
#
# Original English Conversion : Different venue.
#
# Translated to English : It's a different place.
# Average BLEU score : 0.0266348831281518
#
# Average GLEU score : 0.11150912088209614
#
# Average METEOR score : 0.2525128510035952
#
#
# Translating sentence  191
# Original Tamil text : அதில் அவர்கள் போல்டான் அணியை 4-2 வித்தியாசத்தில் வெற்றி பெற்றனர்.
#
# Original English Conversion : There they, defeated the Cleveland Cavaliers 42.
#
# Translated to English : There they won the Golden Party in a difference between 4 and 2.
# Average BLEU score : 0.03217025286556326
#
# Average GLEU score : 0.1147480714576735
#
# Average METEOR score : 0.2560057887572005
#
#
# Translating sentence  201
# Original Tamil text : எனவேதான் இது மோசமான பிரச்சினையாக பார்க்கப்படுகிறது.
#
# Original English Conversion : Thats why this is a big problem.
#
# Translated to English : So it is viewed as a bad problem.
# Average BLEU score : 0.030569742772749167
#
# Average GLEU score : 0.11424774786354096
#
# Average METEOR score : 0.2604332465593168
#
#
# Translating sentence  211
# Original Tamil text : மேலும் அவர்களிடமிருந்து பயங்கர ஆயுதங்கள் மற்றும் வெடிமருந்துகள் பறிமுதல் செய்யப்பட்டன.
#
# Original English Conversion : Firearms and ammunition were also seized from them.
#
# Translated to English : And deadly weapons and missiles were fired from them.
# Average BLEU score : 0.032174746543055285
#
# Average GLEU score : 0.11484645926151178
#
# Average METEOR score : 0.26043887599597637
#
#
# Translating sentence  221
# Original Tamil text : கல்வி, பண்பாடு, உடல்நலத்துறை அமைச்சர்
#
# Original English Conversion : Education and Health Minister, said.
#
# Translated to English : Education, Culture, Health Care
# Average BLEU score : 0.03071887565875414
#
# Average GLEU score : 0.11291255221492832
#
# Average METEOR score : 0.257372072014045
#
#
# Translating sentence  231
# Original Tamil text : அவன் பைத்தியம் முற்றி வெளியேறியவன்’.
#
# Original English Conversion : He is gone crazy.'
#
# Translated to English : It is He who has brought forth the pasturage .
# Average BLEU score : 0.030182459197574986
#
# Average GLEU score : 0.11171013443907284
#
# Average METEOR score : 0.2539817821794815
#
#
# Translating sentence  241
# Original Tamil text : இவ்வழக்கு தொடர்பாக பள்ளி நிர்வாகம் மற்றும் ஆசிரியைக்கு எதிராக வழக்குப்பதிவு செய்த போலீஸ் பாவனாவை கைது செய்து உள்ளது.
#
# Original English Conversion : The police have registered a case against the school principal and the teacher.
#
# Translated to English : In this regard, the police arrested the police who accused the school administration and the teacher.
# Average BLEU score : 0.030210786345333803
#
# Average GLEU score : 0.11101561228140511
#
# Average METEOR score : 0.25656186689607713
#
#
# Translating sentence  251
# Original Tamil text : மற்ற தூதர்கள், கடவுளுக்கு விரோதமான கலகத்தில் சாத்தானோடு சேர்ந்துகொண்டனர்.
#
# Original English Conversion : The Bible shows him to be thoroughly evil and vicious. Other angels joined Satans rebellion against God.
#
# Translated to English : Other angels joined Satan in his rebellion against God.
# Average BLEU score : 0.029857426061820926
#
# Average GLEU score : 0.11195183840558118
#
# Average METEOR score : 0.2576426868734917
#
#
# Translating sentence  261
# Original Tamil text : காவேரி நதி ஒரு புண்ணிய நதியாகும்.
#
# Original English Conversion : The Cauvery is a glorious river.
#
# Translated to English : The Kawari River is a fertile river.
# Average BLEU score : 0.029565710848488476
#
# Average GLEU score : 0.11182148935222745
#
# Average METEOR score : 0.25699908763653556
#
#
# Translating sentence  271
# Original Tamil text : இயக்குநர் ராகுல் ரவாய்ல் தலையிலான குழுவினர் தேசிய விருதுகளை அறிவித்தனர்.
#
# Original English Conversion : The awards were announced by jury head Rahul Rawail.
#
# Translated to English : The chairman, Raúl Raúl, told the group’s national wishes.
# Average BLEU score : 0.02847472520832285
#
# Average GLEU score : 0.10978977363203024
#
# Average METEOR score : 0.2534439297327643
#
#
# Translating sentence  281
# Original Tamil text : """ (மீண்டும் மன்னிக்க!"
#
# Original English Conversion : (I apologise!
#
# Translated to English : """" (I'm sorry again!")
# Average BLEU score : 0.028322871057321078
#
# Average GLEU score : 0.11039611871031603
#
# Average METEOR score : 0.2540978430879878
#
#
# Translating sentence  291
# Original Tamil text : இந்தப்படம் ரசிகர்களிடையே அமோக வரவேற்பை பெற்றது.
#
# Original English Conversion : The film was well-received by fans.
#
# Translated to English : This picture has come to be one of the most beautiful of all the peoples of the world.
# Average BLEU score : 0.02734957651926881
#
# Average GLEU score : 0.10939763260465009
#
# Average METEOR score : 0.2542304559690231
#
#
# Translating sentence  301
# Original Tamil text : அவர்களுக்கே உரித்தான குல்லாவையோ, உடைகளையோ அணிவதில்லை.
#
# Original English Conversion : They dont wear masks or gloves.
#
# Translated to English : They do not wear expensive jewelry or clothing.
# Average BLEU score : 0.02644095271464194
#
# Average GLEU score : 0.10903115791236086
#
# Average METEOR score : 0.2522311909195699
#
#
# Translating sentence  311
# Original Tamil text : உணர்ச்சிகளிலேயே மிகச் சக்திவாய்ந்த ஒன்றைப் பற்றிய பொதுவான ஒரு நோக்குநிலையை பூர்வீக ரோம கவிஞர் ஹோராஷியுஸ் அவ்வாறுதான் தெரிவித்தார்.
#
# Original English Conversion : Thus the ancient Roman poet Horace [Latin: Horatius] voiced a common view of one of the strongest of all emotions.
#
# Translated to English : That is how the ancient Roman poet Horashius expressed a general view of something far more powerful in emotions.
# Average BLEU score : 0.02608481966357989
#
# Average GLEU score : 0.10760082143131253
#
# Average METEOR score : 0.2497491403980067
#
#
# Translating sentence  321
# Original Tamil text : (நயியே!) தங்கள் இறைவனுடைய திருப் பொருத்தத்தை நாடி, எவர் காலையிலும் மாலையிலும், அவனை(ப் பிரார்த்தித்து) அழைத்துக் கொண்டிருக்கிறார்களோ அவர்களை நீர் விரட்டி விடாதீர். அவர்களுடைய கேள்வி கணக்குப் பற்றி உம்மீது பொறுப்பில்லை, உம்முடைய கேள்வி கணக்குப் பற்றி அவர்கள் மீதும் யாதொரு பொறுப்புமில்லை - எனவே நீர் அவர்களை விரட்டி விட்டால், நீரும் அநியாயம் செய்பவர்களில் ஒருவராகி விடுவீர்.
#
# Original English Conversion : And do not drive away those who invoke their Lord in the morning and the evening, seeking His pleasure all the time. You are by no means accountable for them just as they are by no means accountable for you. If you still drive them away, you will become among the wrong-doers.
#
# Translated to English : And do not turn away from those who call upon their Lord morning and evening seeking His Face. You are not responsible for their account, nor are they responsible for your account. If you turn away from them, you will become one of the wrongdoers.
# Average BLEU score : 0.026081098144259754
#
# Average GLEU score : 0.10677041021062333
#
# Average METEOR score : 0.2491679646762358
#
#
# Translating sentence  331
# Original Tamil text : இச்சம்பவம் குறித்து தாண்டிக்குடி போலீஸாா் வழக்குப் பதிவு செய்து விசாரணை நடத்தி வருகின்றனா்.
#
# Original English Conversion : The police have registered a case and are investigating the case.
#
# Translated to English : The police are reporting on this incident and are investigating it.
# Average BLEU score : 0.02529314955984103
#
# Average GLEU score : 0.10583846905473193
#
# Average METEOR score : 0.24709053004419468
#
#
# Translating sentence  341
# Original Tamil text : மருத்துவமனைக்கு கொண்டு சென்ற போது அவர் மாரடைப்பால் இறந்தது தெரியவந்தது.
#
# Original English Conversion : He was declared dead when rushed to the hospital.
#
# Translated to English : When he was taken to the hospital, he died of a stroke.
# Average BLEU score : 0.02878319091831408
#
# Average GLEU score : 0.10890292461120889
#
# Average METEOR score : 0.2495677923734979
#
#
# Translating sentence  351
# Original Tamil text : சென்று எந்தப் பயனுமில்லை.
#
# Original English Conversion : There is no use.
#
# Translated to English : There is no point in going away.
# Average BLEU score : 0.027963156989017385
#
# Average GLEU score : 0.10777964370358298
#
# Average METEOR score : 0.24751183067791793
#
#
# Translating sentence  361
# Original Tamil text : ﻿ ‘ஆப்பிரிக்கா விழித்து கொள்ள வேண்டும்’
#
# Original English Conversion : Africa should wake up.
#
# Translated to English : ‘ Africa’s Need to Be Watchful ’
# Average BLEU score : 0.027188554302341
#
# Average GLEU score : 0.10617380792146515
#
# Average METEOR score : 0.24469448049755912
#
#
# Translating sentence  371
# Original Tamil text : அனைத்து புளுட்டோனியம் சேர்மங்களையும் போலவே இதுவும் அணு பரவல் அல்லாத ஒப்பந்தத்தின் கீழ் கட்டுப்பாட்டுக்கு உட்பட்டதாகும்.
#
# Original English Conversion : As with all plutonium compounds, it is subject to control under the Nuclear Non-Proliferation Treaty.
#
# Translated to English : Like all the supplements of plutonium, this is also involved under the control of the agreement not to be extended.
# Average BLEU score : 0.026455709172897846
#
# Average GLEU score : 0.10662271125104324
#
# Average METEOR score : 0.24587984732428464
#
#
# Translating sentence  381
# Original Tamil text : டெல்லியில் பிரதமர் மோடி மற்றும் உள்துறை அமைச்சர் அமித்ஷாவை சந்திக்க உள்ளதாக தகவல் வெளியாகி உள்ளது.
#
# Original English Conversion : Sources said that in Delhi he will meet Prime Minister Narendra Modi and Union Home Minister Amit Shah.
#
# Translated to English : There is information about the visit of Prime Minister Mody and Homer Ammishah in Delhi.
# Average BLEU score : 0.02766957295066079
#
# Average GLEU score : 0.10694690752014543
#
# Average METEOR score : 0.24468056261819665
#
#
# Translating sentence  391
# Original Tamil text : பக்கோவைட்டு (Bukovite) என்பது Tl2Cu3FeSe4 என்ற மூலக்கூற்று வாய்ப்பாட்டால் விவரிக்கப்படும் ஒரு கனிமம் ஆகும்.
#
# Original English Conversion : Bukovite is a rare selenide mineral with formula Tl2Cu3FeSe4.
#
# Translated to English : Bukovite (Bukovite) is a quality described by the base option Tl2Cu3FeSe4.
# Average BLEU score : 0.02728618243362254
#
# Average GLEU score : 0.10743577487528706
#
# Average METEOR score : 0.2462823049995748
#
#
# Translating sentence  401
# Original Tamil text : தற்போதைய, பொது முடக்கச் சூழலில், நிலக்கரி அமைச்சகத்தின் எந்த ஒப்புதலும் தடைபடாது என்று திரு.
#
# Original English Conversion : Shri Pralhad Joshi further assured that no approvals requiring concurrence of Ministry of Coal would be held up during the current lockdown period.
#
# Translated to English : In the current, general environment, there is no ban on any agreement by the earthly organization.
# Average BLEU score : 0.026605729006350158
#
# Average GLEU score : 0.10752035420198633
#
# Average METEOR score : 0.24690044751766682
#
#
# Translating sentence  411
# Original Tamil text : பிரதமர் நரேந்திர மோடி சத்திஸ்கர் மாநிலம் ராஜ்நந்த்காவுன் மாவட்டத்திலுள்ள குருபாட்டிலிருந்து தேசிய ரூர்பன் இயக்கத்தை இன்று தொடங்கி வைத்தார்.
#
# Original English Conversion : The Prime Minister, Shri Narendra Modi, today launched the National Rurban Mission from Kurubhat, in Rajnandgaon district of Chhattisgarh.
#
# Translated to English : The prime minister of Nörendir Mody Settischer began the national operation of Rührben from a village in the province of Kurpat, in the Kingdom Hall.
# Average BLEU score : 0.025958387667996137
#
# Average GLEU score : 0.1063919128254903
#
# Average METEOR score : 0.2441232858439253
#
#
# Translating sentence  421
# Original Tamil text : கிறிஸ்தவ கிரேக்க வேதாகமத்தில் “சீஷன் ” என மொழிபெயர்க்கப்பட்டுள்ள வார்த்தை அடிப்படையில், ஏதோ ஒன்றிடம் தன் மனதை ஒருமுகப்படுத்துபவர் அல்லது கற்றுக்கொள்பவர் என்பதையே அர்த்தப்படுத்துகிறது.
#
# Original English Conversion : ( b) Why is it important to ask ourselves, Whose disciple have I become? In the Christian Greek Scriptures, the word translated disciple basically means one who directs his mind to something, or one who learns.
#
# Translated to English : On the basis of the word translated “study, ” in the Christian Greek Scriptures, it means one’s heart in one’s mind or mind.
# Average BLEU score : 0.027371937851953923
#
# Average GLEU score : 0.10680089450574008
#
# Average METEOR score : 0.24367452611243318
#
#
# Translating sentence  431
# Original Tamil text : நிச்சயமாக இதில் இறையச்சம் கொள்வோருக்கு படிப்பினை இருக்கிறது.
#
# Original English Conversion : Indeed in this is a lesson for one who fears.
#
# Translated to English : Indeed in this is a lesson for those who fear Allah.
# Average BLEU score : 0.028503137369239533
#
# Average GLEU score : 0.10766376152934097
#
# Average METEOR score : 0.24417556808209737
#
#
# Translating sentence  441
# Original Tamil text : 04.1979 முதல் 31.03.1982 வரை ரூ.25/-வீதம் (அரசாணை நிலை எண். 805, நிதித்துறை, நாள் 11.06.79)
#
# Original English Conversion : From 1.04.79 to 31.03.1982 at Rs.25 /-(G.O.Ms. No.805, Finance Department dated 11.06.1979)
#
# Translated to English : 04.1979, from 31.03.1982 until 11.06.79)
# Average BLEU score : 0.027856807723678545
#
# Average GLEU score : 0.10749288289121263
#
# Average METEOR score : 0.24392542397173397
#
#
# Translating sentence  451
# Original Tamil text : 8 ஸ்பீடு ஆட்டோமேட்டிக் கியர்பாக்ஸ் பொருத்தப்பட்டு இருக்கிறது
#
# Original English Conversion : The engine is paired to an 8-speed automatic gearbox
#
# Translated to English : 8 The Spyt Automated Cyrpax
# Average BLEU score : 0.027239140146656845
#
# Average GLEU score : 0.1071783333280463
#
# Average METEOR score : 0.24298864969720332
#
#
# Translating sentence  461
# Original Tamil text : மனித அரசாங்கங்களின் தோல்விகளை அவர் கவனித்திருக்கிறார்.
#
# Original English Conversion : This proclamation from the highest authority in the universe is cause for hope.
#
# Translated to English : He has observed the failures of human governments.
# Average BLEU score : 0.026648269427640425
#
# Average GLEU score : 0.10647087922910116
#
# Average METEOR score : 0.24199126567031157
#
#
# Translating sentence  471
# Original Tamil text : பிஜி நாளை முன்னிட்டு பிஜி நாட்டு மக்களுக்கு பிரதமர் வாழ்த்து
#
# Original English Conversion : PM conveys his greetings to the people of Fiji, on Fiji Day
#
# Translated to English : Long before the Pygmies and the Pygmies of the Pygmies
# Average BLEU score : 0.026475338007974875
#
# Average GLEU score : 0.10715602285432951
#
# Average METEOR score : 0.2423133820744355
#
#
# Translating sentence  481
# Original Tamil text : காண்பித்துக் கொண்டிருக்கிறது.
#
# Original English Conversion : It shows.
#
# Translated to English : It's showing.
# Average BLEU score : 0.02749403451924541
#
# Average GLEU score : 0.10722590348389596
#
# Average METEOR score : 0.24198894690919134
#
#
# Translating sentence  491
# Original Tamil text : இந்தியாவில் தொழிலாளர் இடப்பெயர்ச்சி விரைவாக அதிகரித்து வருகிறது என ஆய்வுத் தகவல் : பொருளாதார ஆய்வறிக்கை 2016-17
#
# Original English Conversion : Labour migration in India increasing at an accelerating rate, reveals new study: Economic Survey 2016-17
#
# Translated to English : Research information that workers in India are growing rapidly: Financial study 2016-17
# Average BLEU score : 0.02767858620491152
#
# Average GLEU score : 0.10744995387396888
#
# Average METEOR score : 0.24202694905653316

# %%
average_bleu_score = np.mean(opusMT_bleu_scores)
average_gleu_score = np.mean(opusMT_gleu_scores)
average_meteor_score = np.mean(opusMT_meteor_scores)
print('Average BLEU Score for Dev Set using OpusMT mul-en model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using OpusMT mul-en model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using OpusMT mul-en model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using OpusMT mul-en model:  0.028092826067396295
# Average GLEU Score for Dev Set using OpusMT mul-en model:  0.10745585386776603
# Average METEOR Score for Dev Set using OpusMT mul-en model:  0.24187734196922678
