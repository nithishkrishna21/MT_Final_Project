# %%
import numpy as np
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.gleu_score import sentence_gleu
from nltk.translate.meteor_score import meteor_score
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# %%
import re
from sklearn.model_selection import train_test_split

# %%
english_scripts_file_path = "../datasets/Samantar dataset/final_data/en-ta/train.en"
native_scripts_file_path = "../datasets/Samantar dataset/final_data/en-ta/train.ta"

# %%
native_lines = []
with open(native_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        native_lines.append(line)

english_lines = []
with open(english_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        english_lines.append(line)

# %%
native_lines[1]
# Out:
# 'ஒவ்வொரு சுற்றுப்பயணமும் கடினமானது.\n'

# %%
english_lines[1]
# Out:
# 'Every tournament is difficult.\n'

# %%
len(native_lines)
# Out:
# 5167241

# %%
len(english_lines)
# Out:
# 5167241

# %%
df = pd.DataFrame({'Hindi': native_lines, 'English': english_lines})
print(df.head())
# Out:
#                                                Hindi  \
# 0                  என்றுதான் நான் சொல்ல வருகிறேன்.\n
# 1               ஒவ்வொரு சுற்றுப்பயணமும் கடினமானது.\n
# 2  பல வருடங்களாக அவர் அந்த நித்திய எரிநரக தண்டனைய...
# 3  அவர் நிதி அமைச்சர் அருண்ஜேட்லியின் முயற்சியை த...
# 4  சில கலை வரலாற்றாசிரியர்கள் அவர் ஒரு வருடத்திற்...
#
#                                              English
# 0                         That's what I am saying.\n
# 1                   Every tournament is difficult.\n
# 2  One of the first questions Flavio posed was, D...
# 3  He gave full credit to the Union Finance Minis...
# 4  Some art historians have suggested that he onl...

# %%
len(df)
# Out:
# 5167241

# %%
dev_set = df.sample(n = 500, replace = False, random_state = np.random.randint(low=1, high=1234))
remaining_data = df.drop(dev_set.index)

test_set = remaining_data.sample(n = 1000, random_state = np.random.randint(low=1, high=1234))
print(f"Test set size: {len(test_set)}")
print(f"Dev set size: {len(dev_set)}")
# Out:
# Test set size: 1000
# Dev set size: 500

# %%
native_tamil_sentences_dev_set = dev_set['Hindi'].values
print(type(native_tamil_sentences_dev_set))
print(native_tamil_sentences_dev_set.shape)
english_sentences_dev_set = dev_set['English'].values
# Out:
# <class 'numpy.ndarray'>
# (500,)

# %%
print(len(english_sentences_dev_set))
# Out:
# 500

# %%
# Native hindi to english translations using the Facebook model
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

facebook_bleu_scores = []
facebook_gleu_scores = []
facebook_meteor_scores = []

# translate Hindi to English
tokenizer.src_lang = "ta"
for i, tamil_text in enumerate(native_tamil_sentences_dev_set):
    # print(i)
    encoded_ta = tokenizer(tamil_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_ta, forced_bos_token_id=tokenizer.get_lang_id("en"))
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    # print(translated_text)
    # print(translated_text[0].split())
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translated_text[0].split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    facebook_bleu_scores.append(bleu_score)
    facebook_gleu_scores.append(gleu_score)
    facebook_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Tamil text :', tamil_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translated_text[0])
        print('Average BLEU score :', np.mean(facebook_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(facebook_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(facebook_meteor_scores), '\n')
        print()
# Out:
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence  1
# Original Tamil text : மாண்புமிகு வணிகவரி மற்றும் பதிவுத் துறை அமைச்சர் அவர்களால் 21.09.2015 அன்று சட்டமன்றப் பேரவையில் வெளியிடப்பட்ட அறிவிப்பிற்கிணங்க, ரூ.5,00,43,500/மதிப்பீட்டில் வணிகவரி அலுவலகக் கட்டடங்களில் உட்கட்டமைப்பு வசதிகளை மேம்படுத்தவும்மேம்படுத்தவும்,, முழுமையான கணினி மயமாக்கல் திட்டத்தின் கீழ் அமைக்கப்பட்ட விலை உயர்ந்த தகவல் தொழில்நுட்ப சாதனங்களைப் பாதுகாக்கும் வகையில் வணிகவரி அலுவலகக் கட்டடங்களை பொதுப்பணித்துறை மூலம் பழுது பார்ப்பதற்கும், பராமரிப்பதற்கும், அலுவலகங்களுக்கு தேவையான தளவாடங்களை டான்சி மூலம் கொள்முதல் செய்வதற்கும் நிதி ஒடுக்கீடு செய்யப்பட்டுள்ளது.
#
# Original English Conversion : As announced by the Hon'ble Minister for Commercial Taxes and Registration during the demand for grants for the year 2015-16 in the Assembly on 21.09.2015, the Government have accorded sanction for a sum of Rs.10.00 crore for construction of an Integrated Office Complex at Survey No.375No.375//11,, Varadharajapuram village, Nazarathpettai in Poonamallee Taluk of Tiruvallur District, to accommodate 17 Commercial Tax Offices.
#
# Translated to English : With the announcement issued in the legislative speech on 21.09.2015 by the Secretary of the Chamber of Commerce and the Secretary of the Chamber of Commerce and the Secretary of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of the Chamber of Commerce of Commerce of the Chamber of Com
# Average BLEU score : 2.6060849094883154e-155
#
# Average GLEU score : 0.0219435736677116
#
# Average METEOR score : 0.09154929577464789
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence  11
# Original Tamil text : இம்ரான் கான், முன்னாள் பிரதமர் அப்பாஸி வேட்புமனுக்கள் தள்ளுபடி
#
# Original English Conversion : Former Pak PM Abbasi calls for elections to remove Imran Khan govt
#
# Translated to English : And he was the one who was the one who was the one who was the one who was the one who was the one.
# Average BLEU score : 9.5824471484138e-156
#
# Average GLEU score : 0.039133207099052505
#
# Average METEOR score : 0.09992419415908547
#
#
# Translating sentence  21
# Original Tamil text : 29 மாநிலங்கள் மற்றும் 2 யூனியன் பிரதேசங்களைச் சேர்ந்த அறிவியல்-தொழில்நுட்பக் கவுன்சில்களைச் சேர்ந்த அதிகாரிகள், இந்த தொடக்க நிகழ்ச்சியில் கலந்துகொண்டனர்.
#
# Original English Conversion : Officials of S& T Councils from 29 States and 2 Union Territories (UTs) participated during the inaugural session
#
# Translated to English : Officers involved in the 29 counties and 2 June counties of the Scientific and Communications Council, attended this opening event.
# Average BLEU score : 7.754031239612821e-80
#
# Average GLEU score : 0.057382419179843894
#
# Average METEOR score : 0.13391689239419527
#
#
# Translating sentence  31
# Original Tamil text : எனவே கண்டிப்பாக தண்ணீரைக் காய்ச்சி பருக வேண்டும்.
#
# Original English Conversion : So, water is a must.
#
# Translated to English : Therefore, it is necessary to be careful to the skin.
# Average BLEU score : 5.252730839737717e-80
#
# Average GLEU score : 0.045764246830054464
#
# Average METEOR score : 0.10588826869858858
#
#
# Translating sentence  41
# Original Tamil text : கல்லூரி மாணவியர் விடுதி 1 , லேடி வெலிங்டன் வளாகம், திருவல்லிக்கேனி) (மிபிவ)
#
# Original English Conversion : College Girls Hostel-11,Lady Wellington Campus (MBC)
#
# Translated to English : College Students Day 1 , Lady Wellington Factory, Return) (MBA)
# Average BLEU score : 3.971576976387055e-80
#
# Average GLEU score : 0.04748187299585089
#
# Average METEOR score : 0.112307118603494
#
#
# Translating sentence  51
# Original Tamil text : பாலிவுட்டின் முன்னணி நடிகை பிரியங்கா சோப்ரா.
#
# Original English Conversion : Bollywood actress Priyanka Chopra.
#
# Translated to English : It is not the first time that the brilliant brilliant brilliant brilliant.
# Average BLEU score : 5.265978045255241e-80
#
# Average GLEU score : 0.04666149124249779
#
# Average METEOR score : 0.11125781392194033
#
#
# Translating sentence  61
# Original Tamil text : 537 - ல் தங்கள் தாயகம் திரும்பியபோது அது தன் முதலாம் நிறைவேற்றத்தை கண்டது.
#
# Original English Conversion : It might be called a restoration prophecy, for it had its first fulfillment when the Jews returned to their homeland in 537 B.C.E.
#
# Translated to English : 537 And when he returned, he saw his first accomplishment.
# Average BLEU score : 4.402702955869136e-80
#
# Average GLEU score : 0.0467018566626346
#
# Average METEOR score : 0.11107346837326723
#
#
# Translating sentence  71
# Original Tamil text : 23 பேர் பலியாகிவிட்டனர்.
#
# Original English Conversion : 23 people died.
#
# Translated to English : 23 people were killed.
# Average BLEU score : 0.0025215922482537826
#
# Average GLEU score : 0.05312025460309788
#
# Average METEOR score : 0.12436593575816396
#
#
# Translating sentence  81
# Original Tamil text : “தொடக்கத்தில், அச்சம் நிறைய இருந்தது.
#
# Original English Conversion : """So, initially there was a lot of fear."
#
# Translated to English : “In the middle, there was a lot of awareness.
# Average BLEU score : 0.007720452634708042
#
# Average GLEU score : 0.059709020994272874
#
# Average METEOR score : 0.14183212730158365
#
#
# Translating sentence  91
# Original Tamil text : இந்த நவீன காலங்களில், அநேக நாடுகளைச் சேர்ந்த மக்கள் மற்றவர்களின் கருத்துக்களை திறந்த மனதோடு ஏற்றுக்கொள்கிறார்கள்.
#
# Original English Conversion : In modern times, people in many lands have become more open to other viewpoints, with the result that they have been willing to listen to the Bible message that Jehovahs Witnesses bring.
#
# Translated to English : In these days, people who come to the northern cities take the opinions of others with open minds.
# Average BLEU score : 0.0068720512462785875
#
# Average GLEU score : 0.05761435004143851
#
# Average METEOR score : 0.13740601125363944
#
#
# Translating sentence  101
# Original Tamil text : ஒன்று கொரிந்தியர் 6: 18 - ஐ வாசியுங்கள்.
#
# Original English Conversion : What a fine example he set for Christians, both single and married!
#
# Translated to English : 1 Corinthians 6:18 - taste it.
# Average BLEU score : 0.006191650132785657
#
# Average GLEU score : 0.05548464012653272
#
# Average METEOR score : 0.13529171335350484
#
#
# Translating sentence  111
# Original Tamil text : தற்போதைய நெருக்கடிக்கு இலகுவான தீர்வு எதுவும் இல்லை.
#
# Original English Conversion : There is no easy solution to the crisis.
#
# Translated to English : There is no solution to the current target.
# Average BLEU score : 0.005633843814516679
#
# Average GLEU score : 0.05851398906973947
#
# Average METEOR score : 0.13958931208507735
#
#
# Translating sentence  121
# Original Tamil text : இளைஞர்களின் புதுமையான முறைகள் மற்றும் ஆக்கப்பூர்வ யோசனைகளால், யோகா முன்பை விட பிரபலமும், புத்துயிரும் பெற்றுள்ளது.
#
# Original English Conversion : With the help of innovative and creative ideas of the youth, Yoga has become more popular and lively than before.
#
# Translated to English : Through the new ways of the scientists and the unprecedented ideas, Yoga is more popular and understandable than before.
# Average BLEU score : 0.0051682368876971195
#
# Average GLEU score : 0.05751859239932457
#
# Average METEOR score : 0.1402666968633307
#
#
# Translating sentence  131
# Original Tamil text : கூவிடும் அறைகூவல்!
#
# Original English Conversion : Stumping appeal!
#
# Translated to English : The Lord of the Covenant!
# Average BLEU score : 0.004773714987872912
#
# Average GLEU score : 0.05752871996160642
#
# Average METEOR score : 0.14219444309354418
#
#
# Translating sentence  141
# Original Tamil text : தினமும் சாகுறாங்களே
#
# Original English Conversion : Floss daily
#
# Translated to English : The day and the day.
# Average BLEU score : 0.004435153641215259
#
# Average GLEU score : 0.05473446387441409
#
# Average METEOR score : 0.1376783192486898
#
#
# Translating sentence  151
# Original Tamil text : மோசமானது என்று கூற முடியாது என்றார்.
#
# Original English Conversion : You can't say it is a bad thing to do.
#
# Translated to English : I can’t say it’s bad.
# Average BLEU score : 0.004141434857028817
#
# Average GLEU score : 0.05590811899344138
#
# Average METEOR score : 0.139828143899613
#
#
# Translating sentence  161
# Original Tamil text : மாராவிலிருந்து புறப்பட்டு, ஏலிமுக்குப் போனார்கள். ஏலிமிலே பன்னிரண்டு நீரூற்றுகளும் எழுபது பேரீச்சமரங்களும் இருந்தது. அங்கே பாளயமிறங்கினார்கள்.
#
# Original English Conversion : And they removed from Marah, and came to Elim: and in Elim were twelve fountains of water, and three score and ten palm trees. and they pitched there.
#
# Translated to English : They came from Maryam, and they went to Al-Aqsa, and in Al-Aqsa, there were a hundred and a hundred and a hundred and a hundred and a hundred and a hundred and a hundred and a hundred and a hundred.
# Average BLEU score : 0.0038842028783313753
#
# Average GLEU score : 0.05846063509199152
#
# Average METEOR score : 0.14440054140332695
#
#
# Translating sentence  171
# Original Tamil text : சமூகவலைதளப் பக்கங்களில் பல விநோதமான வீடியோக்களும், புகைப்படங்களும் கொட்டிக்கிடக்கின்றன.
#
# Original English Conversion : Numerous videos and photographs of the jubilation are circulating across social media platforms.
#
# Translated to English : There are a lot of people in the city, and there are a lot of people in the city, and there are a lot of people in the city.
# Average BLEU score : 0.0036570565111774937
#
# Average GLEU score : 0.05766848139080387
#
# Average METEOR score : 0.14361772715801474
#
#
# Translating sentence  181
# Original Tamil text : வரிசையை விரிவாக்கு (_E)
#
# Original English Conversion : _Expand Array
#
# Translated to English : It is the line (E)
# Average BLEU score : 0.004415209210514497
#
# Average GLEU score : 0.05805127988479359
#
# Average METEOR score : 0.14278457623049517
#
#
# Translating sentence  191
# Original Tamil text : """அவன் உங்களுக்கு (ஆடு, மாடு, ஒட்டகை போன்ற) கால்நடைகளையும், பிள்ளைகளையும் கொண்டு உதவியளித்தான்."
#
# Original English Conversion : Have fear of Him Who has provided you with all the (good) things you know.
#
# Translated to English : “He has helped you with his arms and his sons.”
# Average BLEU score : 0.006931354266302912
#
# Average GLEU score : 0.06173019300190641
#
# Average METEOR score : 0.14991467553373766
#
#
# Translating sentence  201
# Original Tamil text : நினைவாற்றலும், விழிப்புணர்வு சக்தியும் அதிகரிக்கும்.
#
# Original English Conversion : It increases alertness and awareness.
#
# Translated to English : Remember, the power of disintegration will be increased.
# Average BLEU score : 0.006586510770466946
#
# Average GLEU score : 0.05975495812758131
#
# Average METEOR score : 0.14690381328092875
#
#
# Translating sentence  211
# Original Tamil text : கெடிட் தானியங்கு ஓரச்சீர்மையை இயலுமை படுத்த வேண்டுமா.
#
# Original English Conversion : Whether gedit should enable automatic indentation.
#
# Translated to English : You need to take the cardboard on your own.
# Average BLEU score : 0.008869227101283418
#
# Average GLEU score : 0.06422930812909117
#
# Average METEOR score : 0.15376009271232574
#
#
# Translating sentence  221
# Original Tamil text : இப்படத்தின் படப்பிடிப்பு சத்தமில்லாமல் நடந்து முடிந்துள்ளது.
#
# Original English Conversion : The shooting of the movie has been completed.
#
# Translated to English : This is the end of the event.
# Average BLEU score : 0.008467904608012675
#
# Average GLEU score : 0.06324496771384563
#
# Average METEOR score : 0.15198443481569185
#
#
# Translating sentence  231
# Original Tamil text : சகோதரர் நேதன் எச்.
#
# Original English Conversion : I understand that you agree to remain in Bethel until the Lord takes you away.
#
# Translated to English : What the brother did.
# Average BLEU score : 0.00810132865095585
#
# Average GLEU score : 0.06335159598867249
#
# Average METEOR score : 0.15141713706101786
#
#
# Translating sentence  241
# Original Tamil text : “ மிகச் சிறந்த பத்திரிகைகளை பிரசுரிப்பதற்காக உங்களுக்கு நன்றி.
#
# Original English Conversion : Thank you for continuing to produce the finest magazines available.
#
# Translated to English : “Thank you for delivering the best news.
# Average BLEU score : 0.008940253416928319
#
# Average GLEU score : 0.06387340543250236
#
# Average METEOR score : 0.15193181134856626
#
#
# Translating sentence  251
# Original Tamil text : தலை, காது, முதுகுப் பகுதிகளில் கடுமையாகத் தாக்கியுள்ளனர்.
#
# Original English Conversion : He sustained injuries on his head, chest and ear.
#
# Translated to English : They were in the midst, in the midst, in the midst, and in the midst.
# Average BLEU score : 0.008584068021831573
#
# Average GLEU score : 0.0630474211953475
#
# Average METEOR score : 0.15128902504746644
#
#
# Translating sentence  261
# Original Tamil text : கிறிஸ்தவ சீஷர்கள் தங்கள் நியமிப்பை யெகோவாவின் தவறாத அட்டவணையின்படி படிப்படியாக முன்னேற்றுவித்து நிறைவேற்றி முடிப்பதில் அது அவர்களுக்கு உதவியிருக்கிறது.
#
# Original English Conversion : It has helped Christs disciples to carry out the progression of their assignment according to Jehovahs unerring schedule.
#
# Translated to English : It will help them when the Christian disciples end up reading their discourse as the wrong judgment of Yehuwa.
# Average BLEU score : 0.009447673930313356
#
# Average GLEU score : 0.06562713273411204
#
# Average METEOR score : 0.1556941528002954
#
#
# Translating sentence  271
# Original Tamil text : இக்கூடலில் 30 உறுப்பினர்கள் கலந்துகொண்டனர்.
#
# Original English Conversion : Nearly 30 students participated.
#
# Translated to English : At the time there were 30 members involved.
# Average BLEU score : 0.011540271674773384
#
# Average GLEU score : 0.06667106548181197
#
# Average METEOR score : 0.15582957479170276
#
#
# Translating sentence  281
# Original Tamil text : இதனால் உங்கள் இருவருக்குள் காதல் அதிகமாகி உறவை வலுக்கச் செய்யும்.
#
# Original English Conversion : This will increase the closeness between your relationships.
#
# Translated to English : This will make you a great deal of pleasure and a great deal of love.
# Average BLEU score : 0.011129585850048354
#
# Average GLEU score : 0.06648447815733191
#
# Average METEOR score : 0.15643036229952598
#
#
# Translating sentence  291
# Original Tamil text : “இதை எப்பிடி அணைக்கறது?
#
# Original English Conversion : How do you stop that?
#
# Translated to English : “Are this going to be overwhelming?
# Average BLEU score : 0.010747125855201331
#
# Average GLEU score : 0.06671243013238595
#
# Average METEOR score : 0.15535761932111875
#
#
# Translating sentence  301
# Original Tamil text : அவ்வாறு செய்வதற்கான சட்ட அதிகாரமும் அவருக்கு இல்லை.
#
# Original English Conversion : She doesnt have the authority to do so.
#
# Translated to English : He has no authority to do that.
# Average BLEU score : 0.010914388656262581
#
# Average GLEU score : 0.06688308789240915
#
# Average METEOR score : 0.15540044759045102
#
#
# Translating sentence  311
# Original Tamil text : மத்திய பாதுகாப்பு துறை அமைச்சராக திருமதி நிர்மலா சீதாராமன் நாளை பதவியேற்ப்பு
#
# Original English Conversion : Nirmala Sitharaman takes over as Defence Minister
#
# Translated to English : The Secretary of State of the Security Council of the Republic of Lithuania married the Minister of Foreign Affairs of the Republic of Lithuania.
# Average BLEU score : 0.010563443683392402
#
# Average GLEU score : 0.06629937668742146
#
# Average METEOR score : 0.15477721300908737
#
#
# Translating sentence  321
# Original Tamil text : அதிகமாக போதைப்பொருள்
#
# Original English Conversion : High on drugs
#
# Translated to English : Not to go too much.
# Average BLEU score : 0.010691681236550092
#
# Average GLEU score : 0.066475415244365
#
# Average METEOR score : 0.15517101639836667
#
#
# Translating sentence  331
# Original Tamil text : இவர் மீது, 15க்கும் மேற்பட்ட வழக்குகள் உள்ளன.
#
# Original English Conversion : He had over 15 cases registered against him.
#
# Translated to English : On him, there are more than 15 superior ways.
# Average BLEU score : 0.011610765238166463
#
# Average GLEU score : 0.06678078885594618
#
# Average METEOR score : 0.1556655442114572
#
#
# Translating sentence  341
# Original Tamil text : இவர்களில் பெண்கள் 1853 பேரும் ஆண்கள் 1859 பேரும் உள்ளனர்.
#
# Original English Conversion : The delegations as they existed in 1859.
#
# Translated to English : Among them women 1853 and men 1859.
# Average BLEU score : 0.01127027358895337
#
# Average GLEU score : 0.06609581927372014
#
# Average METEOR score : 0.15570293992929357
#
#
# Translating sentence  351
# Original Tamil text : பைபிள் காலங்களில், விதவைகள் மற்றும் அநாதைகளுடைய சரீர தேவைகளையும் ஆன்மீக தேவைகளையும் கவனித்துக்கொள்வது எப்பொழுதும் வழிபாட்டின் இன்றியமையாத பாகமாக இருந்திருக்கிறது.
#
# Original English Conversion : Will this problem ever be eliminated? Loving Care in Bible Times
#
# Translated to English : In the biblical times, it is a moment that the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples and the demands of the disciples.
# Average BLEU score : 0.010949183173313672
#
# Average GLEU score : 0.06738153066832325
#
# Average METEOR score : 0.15767879149470612
#
#
# Translating sentence  361
# Original Tamil text : இந்த மனு மேலூர் கோர்ட்டில் நிலுவையில் உள்ளது.
#
# Original English Conversion : The petition is pending before the court.
#
# Translated to English : This is located in the county.
# Average BLEU score : 0.010645881700368695
#
# Average GLEU score : 0.06862425370014948
#
# Average METEOR score : 0.16043742079540557
#
#
# Translating sentence  371
# Original Tamil text : டேட்டா பயன்பாடு
#
# Original English Conversion : Application of data
#
# Translated to English : The use of data.
# Average BLEU score : 0.010826335641388542
#
# Average GLEU score : 0.06862888725825814
#
# Average METEOR score : 0.16173960693284065
#
#
# Translating sentence  381
# Original Tamil text : சிறையின் பெரும்பாலான காலத்தை இவர் ராபன் தீவில் சிறிய சிறை அறையில் கழித்தார்.
#
# Original English Conversion : It is far smaller than the lakes it shares the caldera with (Buyan and Bratan), but is a popular one among hikers.
#
# Translated to English : It was a little bit of a little bit of a little bit of a little bit of a little bit of a little bit of a little bit of a little bit of a little bit.
# Average BLEU score : 0.010542179850275982
#
# Average GLEU score : 0.06862380737903113
#
# Average METEOR score : 0.16177956683241534
#
#
# Translating sentence  391
# Original Tamil text : 2017-ம் ஆண்டு ஸ்மார்ட் இந்தியா ஹாக்கதான் அறிமுகத்தின்போது கிடைத்த மாபெரும் ஆதரவு, இப்போது ஆண்டு முழுவதும் தொடர்கிறது.
#
# Original English Conversion : The Smart India Hackathon has received huge response when it was launched in 2017 and this would be continued as annual event.
#
# Translated to English : 2017 Smart India Hack is the greatest support received when it was announced, now it begins throughout the year.
# Average BLEU score : 0.010272558882238233
#
# Average GLEU score : 0.06872173625598982
#
# Average METEOR score : 0.1612913095767633
#
#
# Translating sentence  401
# Original Tamil text : இயேசுவுக்கு இருந்த நம்பிக்கை தானாக வந்ததல்ல.
#
# Original English Conversion : How can we maintain our confidence in the hope ahead? The sort of confidence that Jesus had is not automatic.
#
# Translated to English : The faith in Jesus did not come.
# Average BLEU score : 0.010016385344027804
#
# Average GLEU score : 0.06864235382795994
#
# Average METEOR score : 0.16073174443476818
#
#
# Translating sentence  411
# Original Tamil text : சரக்குகள் மற்றும் சேவைகள் வரி மாமன்றத்தின் பரிந்துரைகளின் அடிப்படையில் அறிவிக்கைகள், பல சுற்றறிக்கைகள் மற்றும் தெளிவுரைகள் சரக்குகள் மற்றும் சேவைகள் வரி சட்டத்தின் கீழ் வழங்கப்பட்டு வருகின்றன.
#
# Original English Conversion : Based on the recommendations by the GST Council, various Notifications, Circulars and Clarifications are being issued under GST Act.
#
# Translated to English : Notifications, many reports and clarifications are provided on the basis of the recommendations of the Board of Directors of the Board of Directors and Services under the Board of Directors and Services Act.
# Average BLEU score : 0.010139465221081983
#
# Average GLEU score : 0.06954554501695641
#
# Average METEOR score : 0.16323297813081758
#
#
# Translating sentence  421
# Original Tamil text : மல்கியா 3: 1 - 3 வரை இருக்கிற வசனங்கள், 1914 - க்கும் 1919 - ன் ஆரம்பத்திற்கும் இடைப்பட்ட காலத்தில் பைபிள் மாணாக்கர்களுக்கு என்ன நடந்தது என்று விளக்குகிறது.
#
# Original English Conversion : Malachi 3: 1 - 3 describes the time from 1914 to early 1919 when the anointed sons of Levi would undergo a period of refinement.
#
# Translated to English : The verses in Matthew 3: 1 - 3 reveal what happened to the Bible citizens during the period of 1914 - until 1919.
# Average BLEU score : 0.010201925122286692
#
# Average GLEU score : 0.0694073492767138
#
# Average METEOR score : 0.16236723534569245
#
#
# Translating sentence  431
# Original Tamil text : அமைச்சர் செங்கோட்டையன் கூறினார்.
#
# Original English Conversion : The Minister said.
#
# Translated to English : The Minister said.
# Average BLEU score : 0.011728181350659606
#
# Average GLEU score : 0.07383451760044747
#
# Average METEOR score : 0.16704035841111922
#
#
# Translating sentence  441
# Original Tamil text : "நாங்கள் அல்மதீனாவுக்குத் திரும்புவோமானால், கண்ணியமானவர்கள் தாழ்ந்தவர்களை அதிலிருந்து நிச்சயமாக வெளியேற்றிவிடுவார்கள்"" என்று அவர்கள் கூறுகின்றனர், ஆனால் கண்ணியம் அல்லாஹ்வுக்கும், அவனுடைய தூதருக்கும், முஃமின்களுக்குமே உரியது, எனினும், இந்நயவஞ்சர்கள் (அதை) அறிந்து கொள்ளமாட்டார்கள்."
#
# Original English Conversion : "They say, ""If we return to al-Madinah, the more honored [for power] will surely expel therefrom the more humble."" And to Allah belongs [all] honor, and to His Messenger, and to the believers, but the hypocrites do not know."
#
# Translated to English : They say, "If we return to Almaty, the sighted will clearly bring out those who have been destroyed," but the sight is for Allah and His Prophet and the Pharaohs, so the sighted will not know."
# Average BLEU score : 0.011462236195315851
#
# Average GLEU score : 0.07374739371404879
#
# Average METEOR score : 0.16798408345796145
#
#
# Translating sentence  451
# Original Tamil text : யூதமதமானது கிறிஸ்தவ மதம் செய்த அதே கருத்தில் மிஷனரி நடவடிக்கையை ஊக்குவிக்கவில்லை, ஆனால் “ஓரளவு மதம் மாற்றம் செய்தது ” என்று யூதமதமும் கிறிஸ்தவ மதத் துவக்கங்களும் (Judaism and Christian Beginnings) புத்தகம் விளக்குகிறது.
#
# Original English Conversion : Judaism and Christian Beginnings explains that Judaism did not promote missionary activity in the same sense that Christianity did but was relatively non - proselytizing.
#
# Translated to English : Judah did not interfere with the Messiah’s action in the same way that the Messiah made the Messiah, but “The Messiah changed the Messiah” explains the book of Judah and Christian Beginnings (Judaism and Christian Beginnings).
# Average BLEU score : 0.011208084616705744
#
# Average GLEU score : 0.0734863498621519
#
# Average METEOR score : 0.1680785567182819
#
#
# Translating sentence  461
# Original Tamil text : கேள்வி நியாயமாகத்தான் இருக்கிறது.
#
# Original English Conversion : The question is right.
#
# Translated to English : The question is unfair.
# Average BLEU score : 0.011715048889496833
#
# Average GLEU score : 0.0748237935433469
#
# Average METEOR score : 0.16945978078768612
#
#
# Translating sentence  471
# Original Tamil text : விராட் கோலி தலைமையிலான இந்திய அணி டெஸ்ட் தொடரில் தொடர்ந்து சிறப்பாக ஆடி வருகிறது.
#
# Original English Conversion : Virat Kohli has been leading the Indian team exceptionally well in Test cricket.
#
# Translated to English : The head of this team will continue to work well in the test series.
# Average BLEU score : 0.011971100155122174
#
# Average GLEU score : 0.07405753215946789
#
# Average METEOR score : 0.1678356201064208
#
#
# Translating sentence  481
# Original Tamil text : இதுவே, இதுவரை உச்ச அளவாக இருந்தது.
#
# Original English Conversion : This was the highest this season so far.
#
# Translated to English : That was, it was so long.
# Average BLEU score : 0.011909045646025452
#
# Average GLEU score : 0.07361609818501641
#
# Average METEOR score : 0.16761884680370912
#
#
# Translating sentence  491
# Original Tamil text : ( 2) தம்முடைய வார்த்தையின் மூலம் அவர் புத்திமதியும் வழிநடத்துதலும் அளிக்கிறார்.
#
# Original English Conversion : ( 2) By means of his Word, he provides counsel and guidance for us.
#
# Translated to English : 2) He is the one who gives his word to the righteous; he is the one who gives his word to the righteous.
# Average BLEU score : 0.011666498891523915
#
# Average GLEU score : 0.07337235013632237
#
# Average METEOR score : 0.16817263986853123

# %%
average_bleu_score = np.mean(facebook_bleu_scores)
average_gleu_score = np.mean(facebook_gleu_scores)
average_meteor_score = np.mean(facebook_meteor_scores)
print('Average BLEU Score for Test Set using Facebooks model: ', average_bleu_score)
print('Average GLEU Score for Test Set using Facebooks model: ', average_gleu_score)
print('Average METEOR Score for Test Set using Facebooks model: ', average_meteor_score)
# Out:
# Average BLEU Score for Test Set using Facebooks model:  0.011616463774013108
# Average GLEU Score for Test Set using Facebooks model:  0.0735773947236834
# Average METEOR Score for Test Set using Facebooks model:  0.16908943906807566

# %%
import accelerate
print(accelerate.__version__)
# Out:
# 1.1.1

# %%
"""
from transformers import T5ForConditionalGeneration, T5Tokenizer

model_name = 'jbochi/madlad400-3b-mt'
model = T5ForConditionalGeneration.from_pretrained(model_name, device_map="auto")
tokenizer = T5Tokenizer.from_pretrained(model_name)

google_bleu_scores = []
google_gleu_scores = []
google_meteor_scores = []

for i, hindi_text in enumerate(native_hindi_sentences_dev_set):
    # print(i)
    input_ids = tokenizer(text, return_tensors="pt").input_ids.to(model.device)
    outputs = model.generate(input_ids=input_ids)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translated_text.split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    google_bleu_scores.append(bleu_score)
    google_gleu_scores.append(gleu_score)
    google_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Hindi text :', hindi_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translated_text[0])
        print('Average BLEU score :', np.mean(google_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(google_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(google_meteor_scores), '\n')
        print()
"""
# Out:
# '\nfrom transformers import T5ForConditionalGeneration, T5Tokenizer\n\nmodel_name = \'jbochi/madlad400-3b-mt\'\nmodel = T5ForConditionalGeneration.from_pretrained(model_name, device_map="auto")\ntokenizer = T5Tokenizer.from_pretrained(model_name)\n\ngoogle_bleu_scores = []\ngoogle_gleu_scores = []\ngoogle_meteor_scores = []\n\nfor i, hindi_text in enumerate(native_hindi_sentences_dev_set):\n    # print(i)\n    input_ids = tokenizer(text, return_tensors="pt").input_ids.to(model.device)\n    outputs = model.generate(input_ids=input_ids)\n    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)\n    reference = [english_sentences_dev_set[i].split()]\n    transformed_tokens = translated_text.split()\n\n    bleu_score = sentence_bleu(reference, transformed_tokens)\n    gleu_score = sentence_gleu(reference, transformed_tokens)\n    met_score = meteor_score(reference, transformed_tokens)\n\n    google_bleu_scores.append(bleu_score)\n    google_gleu_scores.append(gleu_score)\n    google_meteor_scores.append(met_score)\n\n    if i % 10 == 0:\n        print("Translating sentence ", i+1)\n        print(\'Original Hindi text :\', hindi_text)\n        print(\'Original English Conversion :\', english_sentences_dev_set[i])\n        print(\'Translated to English :\', translated_text[0])\n        print(\'Average BLEU score :\', np.mean(google_bleu_scores), \'\n\')\n        print(\'Average GLEU score :\', np.mean(google_gleu_scores), \'\n\')\n        print(\'Average METEOR score :\', np.mean(google_meteor_scores), \'\n\')\n        print()\n'

# %%
"""
average_bleu_score = np.mean(google_bleu_scores)
average_gleu_score = np.mean(google_gleu_scores)
average_meteor_score = np.mean(google_meteor_scores)
print('Average BLEU Score for Test Set using Googles model: ', average_bleu_score)
print('Average GLEU Score for Test Set using Googles model: ', average_gleu_score)
print('Average METEOR Score for Test Set using Googles model: ', average_meteor_score)
"""
# Out:
# "\naverage_bleu_score = np.mean(google_bleu_scores)\naverage_gleu_score = np.mean(google_gleu_scores)\naverage_meteor_score = np.mean(google_meteor_scores)\nprint('Average BLEU Score for Test Set using Googles model: ', average_bleu_score)\nprint('Average GLEU Score for Test Set using Googles model: ', average_gleu_score)\nprint('Average METEOR Score for Test Set using Googles model: ', average_meteor_score)\n"

# %%
import torch
import numpy as np
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor

# Initialize metrics
indict2_bleu_scores = []
indict2_gleu_scores = []
indict2_meteor_scores = []

# Model and tokenizer setup
model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True).to("cuda" if torch.cuda.is_available() else "cpu")
ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "tam_Taml", "eng_Latn"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Convert numpy array to a list
native_tamil_sentences = native_tamil_sentences_dev_set.tolist()
english_sentences = english_sentences_dev_set.tolist()

# Ensure the datasets are aligned
assert len(native_tamil_sentences) == len(english_sentences), "Dev sets must be of equal length."

for i, tamil_text in enumerate(native_tamil_sentences):
    try:
        # print(f"Processing sentence {i+1}...")
        
        # Preprocessing
        batch = ip.preprocess_batch(
            [tamil_text],
            src_lang=src_lang,
            tgt_lang=tgt_lang,
        )
        # print(f"Preprocessed batch: {batch}")
        
        # Tokenize the sentences and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=1,
                num_return_sequences=1,
            )
        # print(f"Generated tokens: {generated_tokens}")

        # Decode the generated tokens into text
        with tokenizer.as_target_tokenizer():
            generated_tokens = tokenizer.batch_decode(
                generated_tokens.detach().cpu().tolist(),
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )
        translated_text = ip.postprocess_batch(generated_tokens, lang=tgt_lang)[0]
        # print(f"Translated text: {translated_text}")

        reference = [english_sentences_dev_set[i].split()]
        transformed_tokens = translated_text.split()

        bleu_score = sentence_bleu(reference, transformed_tokens)
        gleu_score = sentence_gleu(reference, transformed_tokens)
        met_score = meteor_score(reference, transformed_tokens)

        indict2_bleu_scores.append(bleu_score)
        indict2_gleu_scores.append(gleu_score)
        indict2_meteor_scores.append(met_score)

        # Log progress every 10 sentences
        if i % 10 == 0:
            print("Translating sentence", i + 1)
            print("Original Tamil text:", tamil_text)
            print("Original English Conversion:", english_sentences[i])
            print("Translated to English:", translated_text)
            print("Average BLEU score:", np.mean(indict2_bleu_scores))
            print("Average GLEU score:", np.mean(indict2_gleu_scores))
            print("Average METEOR score:", np.mean(indict2_meteor_scores))
            print()

    except Exception as e:
        print(f"Error processing sentence {i+1}: {e}")
        continue
# Out:
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\transformers\tokenization_utils_base.py:4114: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Translating sentence 1
# Original Tamil text: மாண்புமிகு வணிகவரி மற்றும் பதிவுத் துறை அமைச்சர் அவர்களால் 21.09.2015 அன்று சட்டமன்றப் பேரவையில் வெளியிடப்பட்ட அறிவிப்பிற்கிணங்க, ரூ.5,00,43,500/மதிப்பீட்டில் வணிகவரி அலுவலகக் கட்டடங்களில் உட்கட்டமைப்பு வசதிகளை மேம்படுத்தவும்மேம்படுத்தவும்,, முழுமையான கணினி மயமாக்கல் திட்டத்தின் கீழ் அமைக்கப்பட்ட விலை உயர்ந்த தகவல் தொழில்நுட்ப சாதனங்களைப் பாதுகாக்கும் வகையில் வணிகவரி அலுவலகக் கட்டடங்களை பொதுப்பணித்துறை மூலம் பழுது பார்ப்பதற்கும், பராமரிப்பதற்கும், அலுவலகங்களுக்கு தேவையான தளவாடங்களை டான்சி மூலம் கொள்முதல் செய்வதற்கும் நிதி ஒடுக்கீடு செய்யப்பட்டுள்ளது.
#
# Original English Conversion: As announced by the Hon'ble Minister for Commercial Taxes and Registration during the demand for grants for the year 2015-16 in the Assembly on 21.09.2015, the Government have accorded sanction for a sum of Rs.10.00 crore for construction of an Integrated Office Complex at Survey No.375No.375//11,, Varadharajapuram village, Nazarathpettai in Poonamallee Taluk of Tiruvallur District, to accommodate 17 Commercial Tax Offices.
#
# Translated to English: As per the announcement made by the Hon'ble Minister of Commercial Taxes & Registration in the Legislative Assembly on 21.09.2015, a sum of Rs. 5,00,43, 500 / - has been sanctioned for the development and improvement of infrastructure facilities in the Commercial Tax Office buildings, repair and maintenance of Commercial Tax Office buildings by PWD and procurement of necessary office equipment by TANSI to protect the costly IT equipment set up under the complete computerization project.
# Average BLEU score: 0.07953262524851432
# Average GLEU score: 0.1476510067114094
# Average METEOR score: 0.3582265625
#
# Translating sentence 11
# Original Tamil text: இம்ரான் கான், முன்னாள் பிரதமர் அப்பாஸி வேட்புமனுக்கள் தள்ளுபடி
#
# Original English Conversion: Former Pak PM Abbasi calls for elections to remove Imran Khan govt
#
# Translated to English: Nominations of Imran Khan, former PM Abbasi rejected
# Average BLEU score: 0.08363771378414576
# Average GLEU score: 0.19053633573846326
# Average METEOR score: 0.42117497260347503
#
# Translating sentence 21
# Original Tamil text: 29 மாநிலங்கள் மற்றும் 2 யூனியன் பிரதேசங்களைச் சேர்ந்த அறிவியல்-தொழில்நுட்பக் கவுன்சில்களைச் சேர்ந்த அதிகாரிகள், இந்த தொடக்க நிகழ்ச்சியில் கலந்துகொண்டனர்.
#
# Original English Conversion: Officials of S& T Councils from 29 States and 2 Union Territories (UTs) participated during the inaugural session
#
# Translated to English: Officials from Science and Technology Councils from 29 States and 2 Union Territories attended the launch.
# Average BLEU score: 0.10057385143423052
# Average GLEU score: 0.2064088489581803
# Average METEOR score: 0.4019633184927328
#
# Translating sentence 31
# Original Tamil text: எனவே கண்டிப்பாக தண்ணீரைக் காய்ச்சி பருக வேண்டும்.
#
# Original English Conversion: So, water is a must.
#
# Translated to English: Therefore, water must be boiled.
# Average BLEU score: 0.10896449154146544
# Average GLEU score: 0.25690895013696513
# Average METEOR score: 0.4203263190332636
#
# Translating sentence 41
# Original Tamil text: கல்லூரி மாணவியர் விடுதி 1 , லேடி வெலிங்டன் வளாகம், திருவல்லிக்கேனி) (மிபிவ)
#
# Original English Conversion: College Girls Hostel-11,Lady Wellington Campus (MBC)
#
# Translated to English: College Girls Hostel 1, Lady Wellington Campus, Thiruvallikeni (MIBV)
# Average BLEU score: 0.09476124365530153
# Average GLEU score: 0.24481938305907522
# Average METEOR score: 0.41092090164683887
#
# Translating sentence 51
# Original Tamil text: பாலிவுட்டின் முன்னணி நடிகை பிரியங்கா சோப்ரா.
#
# Original English Conversion: Bollywood actress Priyanka Chopra.
#
# Translated to English: Priyanka Chopra is a very popular Bollywood actress.
# Average BLEU score: 0.08786870121810203
# Average GLEU score: 0.22249106251078335
# Average METEOR score: 0.3840074668034748
#
# Translating sentence 61
# Original Tamil text: 537 - ல் தங்கள் தாயகம் திரும்பியபோது அது தன் முதலாம் நிறைவேற்றத்தை கண்டது.
#
# Original English Conversion: It might be called a restoration prophecy, for it had its first fulfillment when the Jews returned to their homeland in 537 B.C.E.
#
# Translated to English: It saw its first fulfillment when they returned to their homeland in 537.
# Average BLEU score: 0.08575390182905919
# Average GLEU score: 0.21788250499471973
# Average METEOR score: 0.3755189778603597
#
# Translating sentence 71
# Original Tamil text: 23 பேர் பலியாகிவிட்டனர்.
#
# Original English Conversion: 23 people died.
#
# Translated to English: At least 23 people were killed.
# Average BLEU score: 0.07983334931142222
# Average GLEU score: 0.21641551110772836
# Average METEOR score: 0.37547245483862113
#
# Translating sentence 81
# Original Tamil text: “தொடக்கத்தில், அச்சம் நிறைய இருந்தது.
#
# Original English Conversion: """So, initially there was a lot of fear."
#
# Translated to English: "At first, there was a lot of fear.
# Average BLEU score: 0.0855722895311994
# Average GLEU score: 0.2159725196433959
# Average METEOR score: 0.38103327264002795
#
# Translating sentence 91
# Original Tamil text: இந்த நவீன காலங்களில், அநேக நாடுகளைச் சேர்ந்த மக்கள் மற்றவர்களின் கருத்துக்களை திறந்த மனதோடு ஏற்றுக்கொள்கிறார்கள்.
#
# Original English Conversion: In modern times, people in many lands have become more open to other viewpoints, with the result that they have been willing to listen to the Bible message that Jehovahs Witnesses bring.
#
# Translated to English: In these modern times, people from many countries are open to the ideas of others.
# Average BLEU score: 0.08292465499976281
# Average GLEU score: 0.2129819158017032
# Average METEOR score: 0.3846986205133133
#
# Translating sentence 101
# Original Tamil text: ஒன்று கொரிந்தியர் 6: 18 - ஐ வாசியுங்கள்.
#
# Original English Conversion: What a fine example he set for Christians, both single and married!
#
# Translated to English: Read 1 Corinthians 6: 18.
# Average BLEU score: 0.07605429106406843
# Average GLEU score: 0.20409042894226148
# Average METEOR score: 0.3706945520345173
#
# Translating sentence 111
# Original Tamil text: தற்போதைய நெருக்கடிக்கு இலகுவான தீர்வு எதுவும் இல்லை.
#
# Original English Conversion: There is no easy solution to the crisis.
#
# Translated to English: There is no easy solution to the current crisis.
# Average BLEU score: 0.08472274899859523
# Average GLEU score: 0.20959878646731855
# Average METEOR score: 0.3785181179020001
#
# Translating sentence 121
# Original Tamil text: இளைஞர்களின் புதுமையான முறைகள் மற்றும் ஆக்கப்பூர்வ யோசனைகளால், யோகா முன்பை விட பிரபலமும், புத்துயிரும் பெற்றுள்ளது.
#
# Original English Conversion: With the help of innovative and creative ideas of the youth, Yoga has become more popular and lively than before.
#
# Translated to English: With the innovative methods and creative ideas of the youth, yoga has become more popular and rejuvenated than ever before.
# Average BLEU score: 0.08774679416417484
# Average GLEU score: 0.21246860198577602
# Average METEOR score: 0.386601815829153
#
# Translating sentence 131
# Original Tamil text: கூவிடும் அறைகூவல்!
#
# Original English Conversion: Stumping appeal!
#
# Translated to English: Shout out!
# Average BLEU score: 0.08514997755554907
# Average GLEU score: 0.2063765631061666
# Average METEOR score: 0.38053002428971466
#
# Translating sentence 141
# Original Tamil text: தினமும் சாகுறாங்களே
#
# Original English Conversion: Floss daily
#
# Translated to English: Every day
# Average BLEU score: 0.08294923685011636
# Average GLEU score: 0.20704315118243832
# Average METEOR score: 0.3850006174592225
#
# Translating sentence 151
# Original Tamil text: மோசமானது என்று கூற முடியாது என்றார்.
#
# Original English Conversion: You can't say it is a bad thing to do.
#
# Translated to English: He can't say it's bad.
# Average BLEU score: 0.07929539271038138
# Average GLEU score: 0.2019512555676963
# Average METEOR score: 0.3775962736625013
#
# Translating sentence 161
# Original Tamil text: மாராவிலிருந்து புறப்பட்டு, ஏலிமுக்குப் போனார்கள். ஏலிமிலே பன்னிரண்டு நீரூற்றுகளும் எழுபது பேரீச்சமரங்களும் இருந்தது. அங்கே பாளயமிறங்கினார்கள்.
#
# Original English Conversion: And they removed from Marah, and came to Elim: and in Elim were twelve fountains of water, and three score and ten palm trees. and they pitched there.
#
# Translated to English: And they departed from Marah, and came to Elim. and at Elim there were twelve springs of water, and seventy palm trees: and they encamped there.
# Average BLEU score: 0.08145613394296292
# Average GLEU score: 0.20625145602999193
# Average METEOR score: 0.3839584826919925
#
# Translating sentence 171
# Original Tamil text: சமூகவலைதளப் பக்கங்களில் பல விநோதமான வீடியோக்களும், புகைப்படங்களும் கொட்டிக்கிடக்கின்றன.
#
# Original English Conversion: Numerous videos and photographs of the jubilation are circulating across social media platforms.
#
# Translated to English: There are many pictures and videos of the bizarre incident on social media.
# Average BLEU score: 0.08389525343022317
# Average GLEU score: 0.2106997720198899
# Average METEOR score: 0.39548833514420356
#
# Translating sentence 181
# Original Tamil text: வரிசையை விரிவாக்கு (_E)
#
# Original English Conversion: _Expand Array
#
# Translated to English: _ Expand the queue
# Average BLEU score: 0.08472002445748117
# Average GLEU score: 0.20898203573507879
# Average METEOR score: 0.39061723708268475
#
# Translating sentence 191
# Original Tamil text: """அவன் உங்களுக்கு (ஆடு, மாடு, ஒட்டகை போன்ற) கால்நடைகளையும், பிள்ளைகளையும் கொண்டு உதவியளித்தான்."
#
# Original English Conversion: Have fear of Him Who has provided you with all the (good) things you know.
#
# Translated to English: "" "He helped you with livestock (sheep, cattle, camels, etc.) and children."
# Average BLEU score: 0.08610872865719472
# Average GLEU score: 0.21085218224704322
# Average METEOR score: 0.3915546734530146
#
# Translating sentence 201
# Original Tamil text: நினைவாற்றலும், விழிப்புணர்வு சக்தியும் அதிகரிக்கும்.
#
# Original English Conversion: It increases alertness and awareness.
#
# Translated to English: Boosts memory and concentration.
# Average BLEU score: 0.08182471230609052
# Average GLEU score: 0.20793535327310966
# Average METEOR score: 0.3870386797618161
#
# Translating sentence 211
# Original Tamil text: கெடிட் தானியங்கு ஓரச்சீர்மையை இயலுமை படுத்த வேண்டுமா.
#
# Original English Conversion: Whether gedit should enable automatic indentation.
#
# Translated to English: Whether to enable the ketit auto-alignment.
# Average BLEU score: 0.08154788084917433
# Average GLEU score: 0.21511445627818276
# Average METEOR score: 0.39209094949291584
#
# Translating sentence 221
# Original Tamil text: இப்படத்தின் படப்பிடிப்பு சத்தமில்லாமல் நடந்து முடிந்துள்ளது.
#
# Original English Conversion: The shooting of the movie has been completed.
#
# Translated to English: The shooting of the film has been completed without any noise.
# Average BLEU score: 0.08294930620495937
# Average GLEU score: 0.21598864206754723
# Average METEOR score: 0.3984863591466313
#
# Translating sentence 231
# Original Tamil text: சகோதரர் நேதன் எச்.
#
# Original English Conversion: I understand that you agree to remain in Bethel until the Lord takes you away.
#
# Translated to English: Brother Nathan H.
# Average BLEU score: 0.08508622167841451
# Average GLEU score: 0.21854054930348102
# Average METEOR score: 0.399711065324974
#
# Translating sentence 241
# Original Tamil text: “ மிகச் சிறந்த பத்திரிகைகளை பிரசுரிப்பதற்காக உங்களுக்கு நன்றி.
#
# Original English Conversion: Thank you for continuing to produce the finest magazines available.
#
# Translated to English: "Thank you for publishing the best magazines.
# Average BLEU score: 0.08273075254283267
# Average GLEU score: 0.2142856399523514
# Average METEOR score: 0.39395670974448266
#
# Translating sentence 251
# Original Tamil text: தலை, காது, முதுகுப் பகுதிகளில் கடுமையாகத் தாக்கியுள்ளனர்.
#
# Original English Conversion: He sustained injuries on his head, chest and ear.
#
# Translated to English: He was hit on the head, neck and back.
# Average BLEU score: 0.08117742948102188
# Average GLEU score: 0.21324253137010463
# Average METEOR score: 0.3953844293880218
#
# Translating sentence 261
# Original Tamil text: கிறிஸ்தவ சீஷர்கள் தங்கள் நியமிப்பை யெகோவாவின் தவறாத அட்டவணையின்படி படிப்படியாக முன்னேற்றுவித்து நிறைவேற்றி முடிப்பதில் அது அவர்களுக்கு உதவியிருக்கிறது.
#
# Original English Conversion: It has helped Christs disciples to carry out the progression of their assignment according to Jehovahs unerring schedule.
#
# Translated to English: It has helped Christian disciples to progress and complete their assignments in accordance with Jehovahs infallible schedule.
# Average BLEU score: 0.08207589472080429
# Average GLEU score: 0.21388668089825516
# Average METEOR score: 0.3964811430754187
#
# Translating sentence 271
# Original Tamil text: இக்கூடலில் 30 உறுப்பினர்கள் கலந்துகொண்டனர்.
#
# Original English Conversion: Nearly 30 students participated.
#
# Translated to English: About 30 members attended the meeting.
# Average BLEU score: 0.0809549139339007
# Average GLEU score: 0.2143776288621861
# Average METEOR score: 0.3958230845110884
#
# Translating sentence 281
# Original Tamil text: இதனால் உங்கள் இருவருக்குள் காதல் அதிகமாகி உறவை வலுக்கச் செய்யும்.
#
# Original English Conversion: This will increase the closeness between your relationships.
#
# Translated to English: This will increase the love between you two and strengthen the relationship.
# Average BLEU score: 0.08282998316952112
# Average GLEU score: 0.21647229213687144
# Average METEOR score: 0.3972169736592904
#
# Translating sentence 291
# Original Tamil text: “இதை எப்பிடி அணைக்கறது?
#
# Original English Conversion: How do you stop that?
#
# Translated to English: "How do you stop this?
# Average BLEU score: 0.08463195053545836
# Average GLEU score: 0.22184362450410425
# Average METEOR score: 0.4019432203979199
#
# Translating sentence 301
# Original Tamil text: அவ்வாறு செய்வதற்கான சட்ட அதிகாரமும் அவருக்கு இல்லை.
#
# Original English Conversion: She doesnt have the authority to do so.
#
# Translated to English: He has no legal authority to do so.
# Average BLEU score: 0.09100503339852038
# Average GLEU score: 0.22494850372272873
# Average METEOR score: 0.40308476957879974
#
# Translating sentence 311
# Original Tamil text: மத்திய பாதுகாப்பு துறை அமைச்சராக திருமதி நிர்மலா சீதாராமன் நாளை பதவியேற்ப்பு
#
# Original English Conversion: Nirmala Sitharaman takes over as Defence Minister
#
# Translated to English: Nirmala Sitharaman to be sworn in as Defence Minister tomorrow
# Average BLEU score: 0.0940849322861222
# Average GLEU score: 0.22674592213812128
# Average METEOR score: 0.40376652154909826
#
# Translating sentence 321
# Original Tamil text: அதிகமாக போதைப்பொருள்
#
# Original English Conversion: High on drugs
#
# Translated to English: Too much of drugs
# Average BLEU score: 0.09543553531501853
# Average GLEU score: 0.22805059678226688
# Average METEOR score: 0.4069599799683252
#
# Translating sentence 331
# Original Tamil text: இவர் மீது, 15க்கும் மேற்பட்ட வழக்குகள் உள்ளன.
#
# Original English Conversion: He had over 15 cases registered against him.
#
# Translated to English: He has over 15 cases registered against him.
# Average BLEU score: 0.0985917491935007
# Average GLEU score: 0.22970843971794044
# Average METEOR score: 0.4100081081306221
#
# Translating sentence 341
# Original Tamil text: இவர்களில் பெண்கள் 1853 பேரும் ஆண்கள் 1859 பேரும் உள்ளனர்.
#
# Original English Conversion: The delegations as they existed in 1859.
#
# Translated to English: Out of these, 1853 were females and 1859 were males.
# Average BLEU score: 0.09712641213337185
# Average GLEU score: 0.22572188774077
# Average METEOR score: 0.40394981892143944
#
# Translating sentence 351
# Original Tamil text: பைபிள் காலங்களில், விதவைகள் மற்றும் அநாதைகளுடைய சரீர தேவைகளையும் ஆன்மீக தேவைகளையும் கவனித்துக்கொள்வது எப்பொழுதும் வழிபாட்டின் இன்றியமையாத பாகமாக இருந்திருக்கிறது.
#
# Original English Conversion: Will this problem ever be eliminated? Loving Care in Bible Times
#
# Translated to English: In Bible times, caring for the physical needs and spiritual needs of widows and orphans has always been an essential part of worship.
# Average BLEU score: 0.09706285604898315
# Average GLEU score: 0.22652913774022618
# Average METEOR score: 0.4053861929285706
#
# Translating sentence 361
# Original Tamil text: இந்த மனு மேலூர் கோர்ட்டில் நிலுவையில் உள்ளது.
#
# Original English Conversion: The petition is pending before the court.
#
# Translated to English: The petition is pending in the Melur court.
# Average BLEU score: 0.09773494284235754
# Average GLEU score: 0.22878312944287274
# Average METEOR score: 0.4092595298957719
#
# Translating sentence 371
# Original Tamil text: டேட்டா பயன்பாடு
#
# Original English Conversion: Application of data
#
# Translated to English: Data usage
# Average BLEU score: 0.09716438692949521
# Average GLEU score: 0.22777396514449702
# Average METEOR score: 0.4088602475873351
#
# Translating sentence 381
# Original Tamil text: சிறையின் பெரும்பாலான காலத்தை இவர் ராபன் தீவில் சிறிய சிறை அறையில் கழித்தார்.
#
# Original English Conversion: It is far smaller than the lakes it shares the caldera with (Buyan and Bratan), but is a popular one among hikers.
#
# Translated to English: He spent most of his time in small jail cell on Robben Island.
# Average BLEU score: 0.09943488511050942
# Average GLEU score: 0.22895900282980133
# Average METEOR score: 0.41072037963945324
#
# Translating sentence 391
# Original Tamil text: 2017-ம் ஆண்டு ஸ்மார்ட் இந்தியா ஹாக்கதான் அறிமுகத்தின்போது கிடைத்த மாபெரும் ஆதரவு, இப்போது ஆண்டு முழுவதும் தொடர்கிறது.
#
# Original English Conversion: The Smart India Hackathon has received huge response when it was launched in 2017 and this would be continued as annual event.
#
# Translated to English: The massive support received during the launch of Smart India Hackathon in 2017, is now continuing throughout the year.
# Average BLEU score: 0.09853746831525537
# Average GLEU score: 0.22814967061378
# Average METEOR score: 0.4083342373879661
#
# Translating sentence 401
# Original Tamil text: இயேசுவுக்கு இருந்த நம்பிக்கை தானாக வந்ததல்ல.
#
# Original English Conversion: How can we maintain our confidence in the hope ahead? The sort of confidence that Jesus had is not automatic.
#
# Translated to English: The hope that Jesus had did not come automatically.
# Average BLEU score: 0.09761510277107979
# Average GLEU score: 0.22597352035979107
# Average METEOR score: 0.4053943963870852
#
# Translating sentence 411
# Original Tamil text: சரக்குகள் மற்றும் சேவைகள் வரி மாமன்றத்தின் பரிந்துரைகளின் அடிப்படையில் அறிவிக்கைகள், பல சுற்றறிக்கைகள் மற்றும் தெளிவுரைகள் சரக்குகள் மற்றும் சேவைகள் வரி சட்டத்தின் கீழ் வழங்கப்பட்டு வருகின்றன.
#
# Original English Conversion: Based on the recommendations by the GST Council, various Notifications, Circulars and Clarifications are being issued under GST Act.
#
# Translated to English: Notifications, several circulars and clarifications based on the recommendations of the Goods and Services Tax (GST) Council are being issued under the GST Act.
# Average BLEU score: 0.0961147036182259
# Average GLEU score: 0.22710592948890518
# Average METEOR score: 0.40669589097041486
#
# Translating sentence 421
# Original Tamil text: மல்கியா 3: 1 - 3 வரை இருக்கிற வசனங்கள், 1914 - க்கும் 1919 - ன் ஆரம்பத்திற்கும் இடைப்பட்ட காலத்தில் பைபிள் மாணாக்கர்களுக்கு என்ன நடந்தது என்று விளக்குகிறது.
#
# Original English Conversion: Malachi 3: 1 - 3 describes the time from 1914 to early 1919 when the anointed sons of Levi would undergo a period of refinement.
#
# Translated to English: Verses from Malachi 3: 1 - 3 describe what happened to the Bible Students between 1914 and early 1919.
# Average BLEU score: 0.09422206394258588
# Average GLEU score: 0.22597233581955142
# Average METEOR score: 0.4059892985578182
#
# Translating sentence 431
# Original Tamil text: அமைச்சர் செங்கோட்டையன் கூறினார்.
#
# Original English Conversion: The Minister said.
#
# Translated to English: Minister Sengottaiyan said.
# Average BLEU score: 0.09611908261132308
# Average GLEU score: 0.22958198181926393
# Average METEOR score: 0.4089034277664707
#
# Translating sentence 441
# Original Tamil text: "நாங்கள் அல்மதீனாவுக்குத் திரும்புவோமானால், கண்ணியமானவர்கள் தாழ்ந்தவர்களை அதிலிருந்து நிச்சயமாக வெளியேற்றிவிடுவார்கள்"" என்று அவர்கள் கூறுகின்றனர், ஆனால் கண்ணியம் அல்லாஹ்வுக்கும், அவனுடைய தூதருக்கும், முஃமின்களுக்குமே உரியது, எனினும், இந்நயவஞ்சர்கள் (அதை) அறிந்து கொள்ளமாட்டார்கள்."
#
# Original English Conversion: "They say, ""If we return to al-Madinah, the more honored [for power] will surely expel therefrom the more humble."" And to Allah belongs [all] honor, and to His Messenger, and to the believers, but the hypocrites do not know."
#
# Translated to English: "They say," "If we return to Al-Madinah, the honourable will surely expel the lowly from it." "But the honourable belongs to Allah, His Messenger, and the believers, but the ignorant will not know."
# Average BLEU score: 0.09427723568309097
# Average GLEU score: 0.22830360055975993
# Average METEOR score: 0.4088956453608161
#
# Translating sentence 451
# Original Tamil text: யூதமதமானது கிறிஸ்தவ மதம் செய்த அதே கருத்தில் மிஷனரி நடவடிக்கையை ஊக்குவிக்கவில்லை, ஆனால் “ஓரளவு மதம் மாற்றம் செய்தது ” என்று யூதமதமும் கிறிஸ்தவ மதத் துவக்கங்களும் (Judaism and Christian Beginnings) புத்தகம் விளக்குகிறது.
#
# Original English Conversion: Judaism and Christian Beginnings explains that Judaism did not promote missionary activity in the same sense that Christianity did but was relatively non - proselytizing.
#
# Translated to English: The book Judaism and Christian Beginnings explains that Judaism did not encourage missionary activity in the same sense that Christianity did, but "did proselytize to some degree."
# Average BLEU score: 0.09340687766024976
# Average GLEU score: 0.22855322251932542
# Average METEOR score: 0.4078214642700647
#
# Translating sentence 461
# Original Tamil text: கேள்வி நியாயமாகத்தான் இருக்கிறது.
#
# Original English Conversion: The question is right.
#
# Translated to English: The question is fair.
# Average BLEU score: 0.09705937924190008
# Average GLEU score: 0.23199195463281322
# Average METEOR score: 0.4111733329686849
#
# Translating sentence 471
# Original Tamil text: விராட் கோலி தலைமையிலான இந்திய அணி டெஸ்ட் தொடரில் தொடர்ந்து சிறப்பாக ஆடி வருகிறது.
#
# Original English Conversion: Virat Kohli has been leading the Indian team exceptionally well in Test cricket.
#
# Translated to English: Virat Kohli-led Team India have been in sublime form in the Test series.
# Average BLEU score: 0.09577475175368905
# Average GLEU score: 0.23118045601464524
# Average METEOR score: 0.4121433789180977
#
# Translating sentence 481
# Original Tamil text: இதுவே, இதுவரை உச்ச அளவாக இருந்தது.
#
# Original English Conversion: This was the highest this season so far.
#
# Translated to English: This was the highest ever so far.
# Average BLEU score: 0.09688213402445067
# Average GLEU score: 0.23145926336697098
# Average METEOR score: 0.4123448680488323
#
# Translating sentence 491
# Original Tamil text: ( 2) தம்முடைய வார்த்தையின் மூலம் அவர் புத்திமதியும் வழிநடத்துதலும் அளிக்கிறார்.
#
# Original English Conversion: ( 2) By means of his Word, he provides counsel and guidance for us.
#
# Translated to English: (2) He provides counsel and guidance through his Word.
# Average BLEU score: 0.09799461326545017
# Average GLEU score: 0.23402196276293605
# Average METEOR score: 0.41466775085775787

# %%
average_bleu_score = np.mean(indict2_bleu_scores)
average_gleu_score = np.mean(indict2_gleu_scores)
average_meteor_score = np.mean(indict2_meteor_scores)
print('Average BLEU Score for Test Set using IndicTrans2 model: ', average_bleu_score)
print('Average GLEU Score for Test Set using IndicTrans2 model: ', average_gleu_score)
print('Average METEOR Score for Test Set using IndicTrans2 model: ', average_meteor_score)
# Out:
# Average BLEU Score for Test Set using IndicTrans2 model:  0.09696862190068785
# Average GLEU Score for Test Set using IndicTrans2 model:  0.23192238550458905
# Average METEOR Score for Test Set using IndicTrans2 model:  0.41127465985968154
