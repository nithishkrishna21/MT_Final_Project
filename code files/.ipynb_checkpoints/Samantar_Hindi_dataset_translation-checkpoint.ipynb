# %%
import numpy as np
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.gleu_score import sentence_gleu
from nltk.translate.meteor_score import meteor_score
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# %%
import re
from sklearn.model_selection import train_test_split

# %%
english_scripts_file_path = "../datasets/Samantar dataset/final_data/en-hi/train.en"
native_scripts_file_path = "../datasets/Samantar dataset/final_data/en-hi/train.hi"

# %%
native_lines = []
with open(native_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        native_lines.append(line)

english_lines = []
with open(english_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        english_lines.append(line)

# %%
native_lines[1]
# Out:
# 'यूरोपीय संघ के महत्वपूर्ण संस्थानों में यूरोपियन कमीशन, यूरोपीय संसद, यूरोपीय संघ परिषद, यूरोपीय न्यायलय एवं यूरोपियन सेंट्रल बैंक इत्यादि शामिल हैं।\n'

# %%
english_lines[1]
# Out:
# 'The European Union has seven principal decision-making bodies, its institutions: the European Parliament, the European Council, the Council of the European Union, the European Commission, the Court of Justice of the European Union, the European Central Bank and the European Court of Auditors.\n'

# %%
len(native_lines)
# Out:
# 8568307

# %%
len(english_lines)
# Out:
# 8568307

# %%
df = pd.DataFrame({'Hindi': native_lines, 'English': english_lines})
print(df.head())
# Out:
#                                                Hindi  \
# 0        जिसके जवाब में पाक ने अच्छी शुरुआत की थी.\n
# 1  यूरोपीय संघ के महत्वपूर्ण संस्थानों में यूरोपि...
# 2  कांग्रेस नेता तमिलनाडु से शिवगंगा लोकसभा क्षेत...
# 3  संबंधन प्रयास के बारे में उपयोक्ता को प्रांप्ट...
# 4  वित्त मंत्री ने घोषणा कि जमा बीमा और ऋण गारंटी...
#
#                                              English
# 0     In reply, Pakistan got off to a solid start.\n
# 1  The European Union has seven principal decisio...
# 2  The Congress leader represents Sivaganga Lok S...
# 3        Prompt the user about connection attempts\n
# 4  Further, the Minister announced that Deposit I...

# %%
len(df)
# Out:
# 8568307

# %%
dev_set = df.sample(n = 500, replace = False, random_state = np.random.randint(low=1, high=1234))
remaining_data = df.drop(dev_set.index)

test_set = remaining_data.sample(n = 1000, random_state = np.random.randint(low=1, high=1234))
print(f"Test set size: {len(test_set)}")
print(f"Dev set size: {len(dev_set)}")
# Out:
# Test set size: 1000
# Dev set size: 500

# %%
native_hindi_sentences_dev_set = dev_set['Hindi'].values
print(type(native_hindi_sentences_dev_set))
print(native_hindi_sentences_dev_set.shape)
english_sentences_dev_set = dev_set['English'].values
# Out:
# <class 'numpy.ndarray'>
# (500,)

# %%
print(len(english_sentences_dev_set))
# Out:
# 500

# %%
# Native hindi to english translations using the Facebook model
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

facebook_bleu_scores = []
facebook_gleu_scores = []
facebook_meteor_scores = []

# translate Hindi to English
tokenizer.src_lang = "hi"
for i, hindi_text in enumerate(native_hindi_sentences_dev_set):
    # print(i)
    encoded_hi = tokenizer(hindi_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.get_lang_id("en"))
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    # print(translated_text)
    # print(translated_text[0].split())
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translated_text[0].split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    facebook_bleu_scores.append(bleu_score)
    facebook_gleu_scores.append(gleu_score)
    facebook_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Hindi text :', hindi_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translated_text[0])
        print('Average BLEU score :', np.mean(facebook_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(facebook_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(facebook_meteor_scores), '\n')
        print()
# Out:
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence  1
# Original Hindi text : उसकी पत्नी ने एक लड़के को जन्म दिया है.
#
# Original English Conversion : His wife delivers a baby boy.
#
# Translated to English : His wife has given birth to a boy.
# Average BLEU score : 7.711523862191631e-155
#
# Average GLEU score : 0.19230769230769232
#
# Average METEOR score : 0.5090725806451614
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence  11
# Original Hindi text : पीएम मोदी ने दी नयी परिभाषा
#
# Original English Conversion : PM Modi kicks off new term
#
# Translated to English : PM Modi has given a new definition
# Average BLEU score : 0.0358366358434621
#
# Average GLEU score : 0.14102967065293978
#
# Average METEOR score : 0.35461355284418833
#
#
# Translating sentence  21
# Original Hindi text : मुख्य प्रथा जुआन रोड्रिग्ज़ फ्रेल के द्वारा लिखी गई पुस्तक एल कार्नेरो की कथाओं में पाई जाती है।
#
# Original English Conversion : The original narrative can be found in the rambling chronicle El Carnero of Juan Rodriguez Freyle.
#
# Translated to English : The main practice is found in El Carnero's stories in the book written by Juan Rodriguez Frell.
# Average BLEU score : 0.07382846224997847
#
# Average GLEU score : 0.1703872009804717
#
# Average METEOR score : 0.37899086065223936
#
#
# Translating sentence  31
# Original Hindi text : आम तौर से दो दवाएं उपयोग की जाती हैं जिनमें से एक अक्सर प्लेटिनम आधारित (सिस्प्लाटिन या कार्बोप्लाटिन) होती है।
#
# Original English Conversion : Typically, two drugs are used, of which one is often platinum-based (either cisplatin or carboplatin).
#
# Translated to English : Usually two medications are used, one of which is often platinum-based (splatin or carboplatin).
# Average BLEU score : 0.05241999850293566
#
# Average GLEU score : 0.1692859339339454
#
# Average METEOR score : 0.36919847212634305
#
#
# Translating sentence  41
# Original Hindi text : नाख़्मानदीज़ बहस में भाग लेने को राज़ी होने से झिझक रहा था क्योंकि वह समझ गया कि डोमीनीकी पादरी निष्पक्ष होना नहीं चाहते थे ।
#
# Original English Conversion : The Dominicans realized that in order to humiliate the Jews effectively, he, their foremost rabbi, would have to be the one to debate.
#
# Translated to English : Nakhmandias was shaken to be pleased to participate in the debate because he understood that the Dominican pastors did not want to be fair.
# Average BLEU score : 0.07073541366037751
#
# Average GLEU score : 0.17511578899803615
#
# Average METEOR score : 0.3816899857845757
#
#
# Translating sentence  51
# Original Hindi text : जम्मू-कश्मीर में छह आतंकवादी ढेर
#
# Original English Conversion : Six militants killed in Jammu and Kashmir
#
# Translated to English : Six terrorist attacks in Kashmir
# Average BLEU score : 0.06892039437307337
#
# Average GLEU score : 0.187574469237691
#
# Average METEOR score : 0.3882869502817913
#
#
# Translating sentence  61
# Original Hindi text : देर रात तक लोगों को मौज-मस्ती में देखा।
#
# Original English Conversion : People were seen to enjoy the occasion till late night.
#
# Translated to English : I saw the people late in the night.
# Average BLEU score : 0.06280850703523946
#
# Average GLEU score : 0.17620254292157425
#
# Average METEOR score : 0.36347845365189907
#
#
# Translating sentence  71
# Original Hindi text : सूचना मिलते ही पुलिस ने मामला दर्ज कर जांच शुरू कर दी थी।
#
# Original English Conversion : Upon receiving the information, the police have registered a case and initiated the investigation.
#
# Translated to English : After the incident was announced, the police began the investigation.
# Average BLEU score : 0.0646548510804765
#
# Average GLEU score : 0.17310121083362234
#
# Average METEOR score : 0.3630169353399131
#
#
# Translating sentence  81
# Original Hindi text : 1907 से अब तक मैं कुल मिलाकर चौदह-पंद्रह युवक एकत्र कर चुका हूं।
#
# Original English Conversion : I collected altogether fourteen or fifteen young men from about the beginning of 1907 till now.
#
# Translated to English : From 1907 to now I have gathered a total of fourteen-five youths.
# Average BLEU score : 0.058192776116420444
#
# Average GLEU score : 0.16526875001038224
#
# Average METEOR score : 0.3545799432325878
#
#
# Translating sentence  91
# Original Hindi text : इस बारे में विमानन नियामक (डीजीसीए) को भी सूचित किया गया है.
#
# Original English Conversion : The airline has also filed a report with aviation regulator DGCA.
#
# Translated to English : The aircraft regulator (DGCA) has also been informed about this.
# Average BLEU score : 0.0635982799042099
#
# Average GLEU score : 0.16827624598117702
#
# Average METEOR score : 0.354994469305788
#
#
# Translating sentence  101
# Original Hindi text : यह करोड़ों लोगों को एक ऑटोमेटिड वित्‍तीय लेन-देन प्रणाली के दायरे में लाएगी।
#
# Original English Conversion : This will bring in crores of people into an automated financial transaction system.
#
# Translated to English : This will bring millions of people into the scope of an automated financial transaction system.
# Average BLEU score : 0.06969483902505355
#
# Average GLEU score : 0.17371222748936657
#
# Average METEOR score : 0.36174682843213524
#
#
# Translating sentence  111
# Original Hindi text : इस से पहले भी अफगान दूतावास के संस्कृति विभाग ने सूचना एवं प्रसारण मंत्रालय से फिल्म के बारे में जानकारी मांगी थी.
#
# Original English Conversion : Earlier, the culture department of the Embassy of Afghan had also written to the I&B ministry seeking information about the film.
#
# Translated to English : Even before this, the Ministry of Culture of the Afghan Embassy had requested information about the film from the Ministry of Information and Broadcasting.
# Average BLEU score : 0.06788862823997971
#
# Average GLEU score : 0.17173744417424353
#
# Average METEOR score : 0.3628749385651477
#
#
# Translating sentence  121
# Original Hindi text : परिजन और शिक्षकों ने तुरंत बच्चों को जिला अस्पताल भेजा।
#
# Original English Conversion : The local people rushed the father and the daughter to District Hospital immediately.
#
# Translated to English : Families and teachers immediately sent the children to the district hospital.
# Average BLEU score : 0.07178460955765063
#
# Average GLEU score : 0.1753624622151926
#
# Average METEOR score : 0.36821956800557626
#
#
# Translating sentence  131
# Original Hindi text : उन्‍होंने कहा कि इससे होम और कार लोन सहित अन्‍य लोन भी महंगे हो जाएंगे।
#
# Original English Conversion : """Hence, various loans like Housing Loan, Vehicle Loan etc., will become cheaper"", it added."
#
# Translated to English : He said that it would make home and car loons too expensive.
# Average BLEU score : 0.06769497439781712
#
# Average GLEU score : 0.17723238412254064
#
# Average METEOR score : 0.3711544975422308
#
#
# Translating sentence  141
# Original Hindi text : महमूद साहब का अंतिम संस्कार मुंबई में हुआ था.
#
# Original English Conversion : His funeral took place in Mumbai.
#
# Translated to English : Mr. Mahmoud’s final funeral took place in Mumbai.
# Average BLEU score : 0.07079301132586582
#
# Average GLEU score : 0.17861993550947444
#
# Average METEOR score : 0.3717632141541748
#
#
# Translating sentence  151
# Original Hindi text : इस अवसर पर डॉ एसपी धूमकेती, डीके रोहितास, डॉ अंजली पंड्या, डॉ अंजू सिंह, रूपेष भादे, डॉ प्रदीप सोनी सहित छात्राएं एवं समस्त कॉलेज स्टॉफ उपस्थित रहा।
#
# Original English Conversion : On the occasion, Dr Shahid Ali, Pankajnauan Pandey, Dr Rajendra Mohanty, Nripendra Sharma, Dr Abhishek Dubey, Ashutosh Mandavi besides all students and staff members of the university were present.Registrar of the University Dr Sandeep Vansutre proposed the vote of thanks.
#
# Translated to English : At this occasion Dr. S.P. Dumketi, D.K. Rohitas, Dr. Anjli Pandya, Dr. Anju Singh, Ruseish Brothers, Dr. Pridip Sonny and all the college staff were present.
# Average BLEU score : 0.0692873713654727
#
# Average GLEU score : 0.1757847916805152
#
# Average METEOR score : 0.3697100510102126
#
#
# Translating sentence  161
# Original Hindi text : भारत-वेस्टइंडीज़ के बीच तीसरा टी-20 मुकाबला मुंबई के वानखेड़े स्टेडियम में खेला जाएगा।
#
# Original English Conversion : Mumbai cricket team are playing their 500th Ranji Trophy match against Baroda at the Wankhede stadium.
#
# Translated to English : The third T-20 match between India and West Indies will be played at the Vancouver Stadium in Mumbai.
# Average BLEU score : 0.06755768191981491
#
# Average GLEU score : 0.17328057858542947
#
# Average METEOR score : 0.36821075743238857
#
#
# Translating sentence  171
# Original Hindi text : तब क्या जब हम दिन भर काम करने के बाद थके - हारे घर लौटते हैं?
#
# Original English Conversion : What about the times when we come home tired after a long days work? We might have to push ourselves to attend Christian meetings.
#
# Translated to English : So when we get tired - lost home after working all day?
# Average BLEU score : 0.06668034355826023
#
# Average GLEU score : 0.172518319385655
#
# Average METEOR score : 0.36571959303106516
#
#
# Translating sentence  181
# Original Hindi text : सलमान खान की ‘दबंग 3’ में महेश मांजरेकर की पत्नी मेधा उनकी पत्नी की भूमिका निभा रही हैं, जो एक तरह से मांजरेकर परिवार के लिए ऑन-स्क्रीन रीयूनियन होगा.
#
# Original English Conversion : Mahesh Manjrekar's wife Medha is roped in to play his better half in Salman Khan's Dabangg 3 which becomes the on-screen reunion for the Manjrekar family.
#
# Translated to English : In Salman Khan's 'Debang 3', Mahesh's wife, Meda, is playing the role of her wife, which will be a way on-screen reunion for the family.
# Average BLEU score : 0.06672121704731106
#
# Average GLEU score : 0.17308343646909918
#
# Average METEOR score : 0.36479250648529393
#
#
# Translating sentence  191
# Original Hindi text : जल्‍द ही नामों की घोषणा होने की संभावना है।
#
# Original English Conversion : The names will be announced soon.
#
# Translated to English : The names are likely to be announced soon.
# Average BLEU score : 0.06422919903630626
#
# Average GLEU score : 0.1723412518662547
#
# Average METEOR score : 0.36548369031121286
#
#
# Translating sentence  201
# Original Hindi text : उन्‍हें अनुसंधान, डिजाइन, विश्‍लेषण, विकास, परीक्षण और विक्रय से जुड़े पदों सहित अनेक प्रकार के रोजगारों में से चुनना होता है।
#
# Original English Conversion : They have many different types of jobs to choose from, including research, design, analysis, development, testing, and sales positions.
#
# Translated to English : They have to choose from many types of jobs including research, design, analysis, development, testing and sales-related positions.
# Average BLEU score : 0.06633150713507867
#
# Average GLEU score : 0.1732222587007083
#
# Average METEOR score : 0.3672951959198592
#
#
# Translating sentence  211
# Original Hindi text : अतीत को जलाकर, आप एक नई शुरुआत के लिए तैयार हो जाते हैं।
#
# Original English Conversion : Burning the past, you gear up for a new beginning.
#
# Translated to English : Burning the past, you are prepared for a new beginning.
# Average BLEU score : 0.06722288068043604
#
# Average GLEU score : 0.17967895667845407
#
# Average METEOR score : 0.37338596635138344
#
#
# Translating sentence  221
# Original Hindi text : परिवार की ज़िम्मेदारियों की देखरेख करते हुए हम प्रचार के काम में भी काफी व्यस्त रहे ।
#
# Original English Conversion : It was unlike those we held in Greece where we had to meet secretly in the woods because our work was banned.
#
# Translated to English : We were very busy watching the family’s responsibilities as well.
# Average BLEU score : 0.06723290247675533
#
# Average GLEU score : 0.17965946923170836
#
# Average METEOR score : 0.3754049263429483
#
#
# Translating sentence  231
# Original Hindi text : ऐसी कोई विधि '% 1' नहीं है.
#
# Original English Conversion : No such method '%1'.
#
# Translated to English : No such method is '% 1'.
# Average BLEU score : 0.06935485641371643
#
# Average GLEU score : 0.1811262445556471
#
# Average METEOR score : 0.3764934089422281
#
#
# Translating sentence  241
# Original Hindi text : पाकिस्तान की तरह राहुल गांधी भी 370 और 35ए हटाने का विरोध करते हैं।
#
# Original English Conversion : Rahul Gandhi also protests against the abrogation of Article 370 and 35A, like Pakistan.
#
# Translated to English : Raul Gandhi, like Pakistan, also opposes the removal of 370 and 35A.
# Average BLEU score : 0.07004406118270576
#
# Average GLEU score : 0.1818696479770923
#
# Average METEOR score : 0.3771260835431869
#
#
# Translating sentence  251
# Original Hindi text : निर्माण करना या उत्पादन करना।
#
# Original English Conversion : To construct or manufacture.
#
# Translated to English : to build or produce.
# Average BLEU score : 0.06782876106337661
#
# Average GLEU score : 0.1807203389647926
#
# Average METEOR score : 0.37846593864171957
#
#
# Translating sentence  261
# Original Hindi text : इसकी सभी को बधाई.
#
# Original English Conversion : Congratulations to all.
#
# Translated to English : Congratulations to all of them.
# Average BLEU score : 0.07061390230151617
#
# Average GLEU score : 0.18341915581696597
#
# Average METEOR score : 0.38203648169376686
#
#
# Translating sentence  271
# Original Hindi text : उन्होंने उसकी अखलाख से बात करवाई।
#
# Original English Conversion : He talked to her.
#
# Translated to English : He talked to his discourse.
# Average BLEU score : 0.07081243278457514
#
# Average GLEU score : 0.1841724652679674
#
# Average METEOR score : 0.3822197108685128
#
#
# Translating sentence  281
# Original Hindi text : Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji | Good News : सैफ अली खान के बाद अजय देवगन की 'तानाजी' में इस सुपरस्टार की हुई एंट्री - Firstpost Hindi
#
# Original English Conversion : Casting Coup: After Saif Ali Khan, Salman Khan To Also Join Ajay Devgn's 'Taanaji'?
#
# Translated to English : Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji♰ Good News : Aftre Saif Ali Khan's 'Tanji' in this superstar's entry - Firstpost Hindi
# Average BLEU score : 0.06923499196177854
#
# Average GLEU score : 0.1823638948121858
#
# Average METEOR score : 0.38048980162035523
#
#
# Translating sentence  291
# Original Hindi text : स्पष्टीकरण 3ख.—शंकाओं को दूर करने के लिए यह घोषित किया जाता है कि जहां इस धारा के खंड (च) में निर्दिष्ट किसी राशि की बाबत कटौती उस पूर्ववर्ष की (जो 1 अप्रैल, 2001 को प्रारंभ होने वाले निर्धारण वर्ष या उससे पूर्व के किसी निर्धारण वर्ष से सुसंगत पूर्ववर्ष है), जिसमें निर्धारिती द्वारा ऐसी राशि अदा करने का दायित्व उपगत किया गया था, धारा 28 में उल्लिखित आय की संगणना करने में अनुज्ञात की जाती है वहां निर्धारिती उस पूर्ववर्ष की, जिसमें उसके द्वारा ऐसी राशि वास्तव में अदा की जाती है, आय की संगणना करने में ऐसी राशि की बाबत इस धारा के अधीन किसी कटौती का हकदार नहीं होगा।
#
# Original English Conversion : Explanation 3B.For the removal of doubts, it is hereby declared that where a deduction in respect of any sum referred to in clause (f) of this section is allowed in computing the income, referred to in section 28, of the previous year (being a previous year relevant to the assessment year commencing on the 1st day of April, 2001, or any earlier assessment year) in which the liability to pay such sum was incurred by the assessee, the assessee shall not be entitled to any deduction under this section in respect of such sum in computing the income of the previous year in which the sum is actually paid by him.
#
# Translated to English : Explanation 3b. — In order to remove concerns, it is declared that where the cut of the amount specified in section (h) of this section of the previous year (which is the preceding year in accordance with the determined year starting on April 1, 2001 or preceding it), in which the determination has imposed the obligation to pay such amount, it is permitted to calculate the income referred to in section 28, the determination of the preceding year by which it is actually awarded, shall not be entitled to any cut of the amount under this section of the calculation of the income.
# Average BLEU score : 0.07130588253515248
#
# Average GLEU score : 0.18485385546510724
#
# Average METEOR score : 0.38338875547701795
#
#
# Translating sentence  301
# Original Hindi text : पुलिस उसे वहां से अस्पताल ले गई जहां जांच द्वारा उसके साथ बलात्कार किए जाने की पुष्टि की गई।
#
# Original English Conversion : The police rushed the girl to a hospital where her examination confirmed rape.
#
# Translated to English : Police took him from the hospital where the investigation confirmed that he was raped with him.
# Average BLEU score : 0.07081357603163828
#
# Average GLEU score : 0.18434870813016688
#
# Average METEOR score : 0.3815120148384458
#
#
# Translating sentence  311
# Original Hindi text : तब जाकर हमारे पास इन सवालों के जवाब मिलेंगे
#
# Original English Conversion : I will ask these questions
#
# Translated to English : Then we will get the answers to these questions.
# Average BLEU score : 0.0703789376224034
#
# Average GLEU score : 0.18288405051322373
#
# Average METEOR score : 0.37952588390931863
#
#
# Translating sentence  321
# Original Hindi text : आपको सार्वजनिक भावना को समझना चाहिए और न ही एनआरसी को उसके वर्तमान स्वरूप में घोषित करना चाहिए, न ही सीएए को लागू किया जा चाहिए.
#
# Original English Conversion : "You should understand public sentiment&announce neither NRC in its current form,nor CAA will be implemented,"" he said."
#
# Translated to English : You should understand the public spirit and not declare the NRC in its current form, nor should the CAA be applied.
# Average BLEU score : 0.07170149760552655
#
# Average GLEU score : 0.18386094502583405
#
# Average METEOR score : 0.3818287667901736
#
#
# Translating sentence  331
# Original Hindi text : यही बात भविष्यवाणी के अगले शब्दों में भी कही गयी है ।
#
# Original English Conversion : Imagine that you are standing with the prophetic woman on Mount Zion.
#
# Translated to English : This is also stated in the following words.
# Average BLEU score : 0.0725564372549064
#
# Average GLEU score : 0.1846755242803241
#
# Average METEOR score : 0.38014706019730765
#
#
# Translating sentence  341
# Original Hindi text : फ्लाइट में मौजूद एक यात्री ने बताया कि फ्लाइट को सिक्युरिटि कारणों के चलते अहमदाबाद डायवर्ट किया गया था, जिसके बाद प्लेन से सभी यात्रियों को उतर जाने के लिए कहा गया।
#
# Original English Conversion : "A passenger onboard said the flight was diverted to Ahmedabad citing ""security reasons""."
#
# Translated to English : A passenger present in the flight that the flight was diverted due to security reasons, after which all passengers were asked to land.
# Average BLEU score : 0.07350074146477607
#
# Average GLEU score : 0.18482796206735455
#
# Average METEOR score : 0.3802682220897227
#
#
# Translating sentence  351
# Original Hindi text : आउटलुक DBX आयात
#
# Original English Conversion : Outlook DBX import
#
# Translated to English : Outlook DBX Import
# Average BLEU score : 0.07302633444370206
#
# Average GLEU score : 0.18499754938530497
#
# Average METEOR score : 0.38162493356477717
#
#
# Translating sentence  361
# Original Hindi text : मेलबर्न: ऑस्ट्रेलिया के विश्व के नंबर एक तेज गेंदबाज पैट कमिंस ने भारत के मध्य क्रम के मुख्य बल्लेबाज चेतेश्वर पुजारा को टेस्ट क्रिकेट में गेंदबाजी क .
#
# Original English Conversion : "MELBOURNE: Australia's world number one pacer Pat Cummins finds India's middle-order mainstay Cheteshwar Pujara the toughest batsman to bowl at in Test cricket and called him a ""pain in the back"" for his team."
#
# Translated to English : Melbourne: Australia's world number one fast basketball player Pat Kummins made the main basketball player of India's mid-range Chetašver Pujara basketball in Test Cricket.
# Average BLEU score : 0.07466066994742619
#
# Average GLEU score : 0.18611406200128217
#
# Average METEOR score : 0.3829840430070632
#
#
# Translating sentence  371
# Original Hindi text : आईसीसी की वनडे रैंकिंग जारी, विराट कोहली और बुमराह टॉप पर कायम
#
# Original English Conversion : ICC ODI rankings: Virat Kohli, Jasprit Bumrah remain on top
#
# Translated to English : ICC's One Day Ranking Continues, Virat Kohli and Bumrah Top
# Average BLEU score : 0.0743327113678898
#
# Average GLEU score : 0.18570709771098196
#
# Average METEOR score : 0.3824215121536784
#
#
# Translating sentence  381
# Original Hindi text : PNB घोटालेबाज मेहुल चोकसी बोला – भारत आया तो हो जाएगी मेरी भी मॉब लिंचिंग
#
# Original English Conversion : PNB scam: Fugitive businessman Mehul Choksi says he fears mob lynching if hes brought back to India
#
# Translated to English : PNB scandalist Mehul Choksi said – India came then will be my too Mob Lynching
# Average BLEU score : 0.07540029711907009
#
# Average GLEU score : 0.18585871257396847
#
# Average METEOR score : 0.3815804593627861
#
#
# Translating sentence  391
# Original Hindi text : बाढ़ग्रस्त पंजाब में नुकसान का आकलन करने के लिए एक केंद्रीय टीम जल्द ही राज्य का दौरा करेगी।
#
# Original English Conversion : A central team will soon visit Punjab to assess the damage and loss due to floods in the state.
#
# Translated to English : A central team will soon visit the state to assess the loss in the flooded Punjab.
# Average BLEU score : 0.07493733377602542
#
# Average GLEU score : 0.1849578997935513
#
# Average METEOR score : 0.38140828604050536
#
#
# Translating sentence  401
# Original Hindi text : स्थिति अब नियंत्रण में बतायी गयी है
#
# Original English Conversion : The situation was now under control
#
# Translated to English : The situation is now under control.
# Average BLEU score : 0.07496595325161842
#
# Average GLEU score : 0.18548395482417207
#
# Average METEOR score : 0.383528433366392
#
#
# Translating sentence  411
# Original Hindi text : क्योंकि यहोवा देश के बीच होकर मिस्त्रियों को मारता जाएगा. इसलिये जहां जहां वह चौखट के सिरे, और दोनों अलंगों पर उस लोहू को देखेगा, वहां वहां वह उस द्वार को छोड़ जाएगा, और नाश करनेवाले को तुम्हारे घरों में मारने के लिये न जाने देगा।
#
# Original English Conversion : For Yahweh will pass through to strike the Egyptians. and when he sees the blood on the lintel, and on the two doorposts, Yahweh will pass over the door, and will not allow the destroyer to come in to your houses to strike you.
#
# Translated to English : For the LORD will kill the Egyptians in the midst of the land; so wherever he will see the blood on the edge and on both sides, there he will leave the door, and the destroyer will not go to your houses to kill.
# Average BLEU score : 0.07427737043426198
#
# Average GLEU score : 0.18381254374093567
#
# Average METEOR score : 0.3800723358193114
#
#
# Translating sentence  421
# Original Hindi text : यदि आप अतिरिक्‍त जानकारी प्राप्त करना चाहते हैं या आप चाहते हैं कि कोई आपके घर आकर आपके साथ मुफ़्त बाइबल अध्ययन संचालित करे, तो कृपया Watch Tower, H - 58 Old Khandala Road, Lonavla 410 401, Mah., India को, या पृष्ठ २ पर दिए उपयुक्‍त पते पर लिखिए ।
#
# Original English Conversion : If you would welcome further information or would like to have someone call at your home to conduct a free Bible study with you, please write to Watchtower, 25 Columbia Heights, Brooklyn, NY 11201 - 2483, or to the appropriate address listed on page 2.
#
# Translated to English : If you want to obtain additional information or you want someone to come to your home and conduct free Bible studies with you, please write to Watch Tower, H - 58 Old Khandala Road, Lonavla 410 401, Mah., India, or to the appropriate address on page 2.
# Average BLEU score : 0.07578063012041857
#
# Average GLEU score : 0.1853555984108054
#
# Average METEOR score : 0.38238340509476454
#
#
# Translating sentence  431
# Original Hindi text : ’’ उन्होंने कहा, ‘‘अधिकतर अच्छे हिंदू जिन्हें मैं जानता हूं वह उस जगह पर राम मंदिर चाहते हैं जहां उनका मानना है कि उनका जन्म हुआ।
#
# Original English Conversion : """Most good Hindus I know would want a Ram temple at the place where they believe he was born."
#
# Translated to English : “Most of the good Hindu I know want Ram Temple where they believe they were born.
# Average BLEU score : 0.0781756298597982
#
# Average GLEU score : 0.18823787150041782
#
# Average METEOR score : 0.38594348810976065
#
#
# Translating sentence  441
# Original Hindi text : इसे चालान व ऑनलाइन के माध्यम से दिया जा सकता है।
#
# Original English Conversion : This can be paid online or through a challan.
#
# Translated to English : It can be made through online and online.
# Average BLEU score : 0.07976449315002958
#
# Average GLEU score : 0.19084690088201045
#
# Average METEOR score : 0.3886924004190454
#
#
# Translating sentence  451
# Original Hindi text : उन्होंने कहा, ‘‘यहां (गोरखपुर) की तरह, राज्य के अन्य भागों में भी मुस्लिम सुरक्षित महसूस करते हैं।
#
# Original English Conversion : """Like here (Gorakhpur), Muslims feel safe in other parts of the state,"" he said."
#
# Translated to English : He said, “As here (Gorakhpur), Muslims also feel safe in other parts of the state.
# Average BLEU score : 0.08209784400311389
#
# Average GLEU score : 0.1935588895147629
#
# Average METEOR score : 0.39173936579927127
#
#
# Translating sentence  461
# Original Hindi text : कर्ज के बोझ से दबे अपने राज्य के लिए विशेष वित्तीय पैकेज की मांग के साथ बनर्जी ने पहले संसद भवन में मोदी से मुलाकात की और बाद में अपनी पार्टी के सांसदों के एक प्रतिनिधिमंडल के साथ फिर से प्रधानमंत्री से मिलीं।
#
# Original English Conversion : Seeking a special financial package for her debt-ridden state, Banerjee initially met Modi in Parliament House before calling on him again with a delegation of MPs from her party.
#
# Translated to English : With the demand for a special financial package for his state, Banerji first met with Modi in the parliament building and later met with a representative of his party members again with the Prime Minister.
# Average BLEU score : 0.08234873142552857
#
# Average GLEU score : 0.19364412993519595
#
# Average METEOR score : 0.3933975297040237
#
#
# Translating sentence  471
# Original Hindi text : मोदी कैबिनेट में रहते हुए उन्होंने केंद्रीय ग्रामीण विकास राज्य मंत्री पेयजल, स्वच्छता और पंचायती राज मंत्री का पद भी संभाला.
#
# Original English Conversion : He served as the Minister of Rural Development, Minister of Parliamentary Affairs, Panchayati Raj and Mines in the Modi government.
#
# Translated to English : While living in the Modi Cabinet, he also held the post of the Central Rural Development State Minister Peijal, Health and Penitentian Government Minister.
# Average BLEU score : 0.0816815647827369
#
# Average GLEU score : 0.19296911852013388
#
# Average METEOR score : 0.3915219946616377
#
#
# Translating sentence  481
# Original Hindi text : भूमि अधिग्रहण क़ानून में संशोधन
#
# Original English Conversion : Amendments to Land Acquisition Act
#
# Translated to English : Land acquisition in the law
# Average BLEU score : 0.08197918963137774
#
# Average GLEU score : 0.19265505753981563
#
# Average METEOR score : 0.3902388930145905
#
#
# Translating sentence  491
# Original Hindi text : चम्बल इटावा के पास तथा बेतवा हमीरपुर के पास यमुना में मिलती हैं।
#
# Original English Conversion : chambal comes from itva, and betab in hamirpur and then they meet with yamuna
#
# Translated to English : Chambles meet in Yumuna near Italy and Bathwa Hamirpur.
# Average BLEU score : 0.0808539566072655
#
# Average GLEU score : 0.1929640422595396
#
# Average METEOR score : 0.39106923737601734

# %%
average_bleu_score = np.mean(facebook_bleu_scores)
average_gleu_score = np.mean(facebook_gleu_scores)
average_meteor_score = np.mean(facebook_meteor_scores)
print('Average BLEU Score for Dev Set using Facebooks model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using Facebooks model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using Facebooks model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using Facebooks model:  0.08167956371696915
# Average GLEU Score for Dev Set using Facebooks model:  0.19350009450494746
# Average METEOR Score for Dev Set using Facebooks model:  0.39126703007862956

# %%
# Native hindi to english translations using the Facebook's MBART model
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

mbart_bleu_scores = []
mbart_gleu_scores = []
mbart_meteor_scores = []

# translate Hindi to English
tokenizer.src_lang = "hi_IN"
for i, hindi_text in enumerate(native_hindi_sentences_dev_set):
    # print(i)
    encoded_hi = tokenizer(hindi_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.lang_code_to_id['en_XX'])
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    # print(translated_text)
    # print(translated_text[0].split())
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translated_text[0].split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    mbart_bleu_scores.append(bleu_score)
    mbart_gleu_scores.append(gleu_score)
    mbart_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Hindi text :', hindi_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translated_text[0])
        print('Average BLEU score :', np.mean(mbart_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(mbart_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(mbart_meteor_scores), '\n')
        print()
# Out:
# Translating sentence  1
# Original Hindi text : उसकी पत्नी ने एक लड़के को जन्म दिया है.
#
# Original English Conversion : His wife delivers a baby boy.
#
# Translated to English : His wife has given birth to a boy.
# Average BLEU score : 7.711523862191631e-155
#
# Average GLEU score : 0.19230769230769232
#
# Average METEOR score : 0.5090725806451614
#
#
# Translating sentence  11
# Original Hindi text : पीएम मोदी ने दी नयी परिभाषा
#
# Original English Conversion : PM Modi kicks off new term
#
# Translated to English : PM Modi gave a new definition
# Average BLEU score : 0.07353618779524558
#
# Average GLEU score : 0.17826428272623704
#
# Average METEOR score : 0.431765867933693
#
#
# Translating sentence  21
# Original Hindi text : मुख्य प्रथा जुआन रोड्रिग्ज़ फ्रेल के द्वारा लिखी गई पुस्तक एल कार्नेरो की कथाओं में पाई जाती है।
#
# Original English Conversion : The original narrative can be found in the rambling chronicle El Carnero of Juan Rodriguez Freyle.
#
# Translated to English : The main tradition is found in the stories of El Carnero, a book written by Juan Rodriguez - Fell.
# Average BLEU score : 0.08852096571937894
#
# Average GLEU score : 0.19032043520499964
#
# Average METEOR score : 0.4358468331488465
#
#
# Translating sentence  31
# Original Hindi text : आम तौर से दो दवाएं उपयोग की जाती हैं जिनमें से एक अक्सर प्लेटिनम आधारित (सिस्प्लाटिन या कार्बोप्लाटिन) होती है।
#
# Original English Conversion : Typically, two drugs are used, of which one is often platinum-based (either cisplatin or carboplatin).
#
# Translated to English : Usually two drugs are used, one of which is often platinum based (cisplatin or carboplatin).
# Average BLEU score : 0.07262291710184196
#
# Average GLEU score : 0.18746917456910217
#
# Average METEOR score : 0.4133825040581563
#
#
# Translating sentence  41
# Original Hindi text : नाख़्मानदीज़ बहस में भाग लेने को राज़ी होने से झिझक रहा था क्योंकि वह समझ गया कि डोमीनीकी पादरी निष्पक्ष होना नहीं चाहते थे ।
#
# Original English Conversion : The Dominicans realized that in order to humiliate the Jews effectively, he, their foremost rabbi, would have to be the one to debate.
#
# Translated to English : He was embarrassed to be willing to participate in a non - impartial debate because he understood that the Dominican priests did not want to be impartial.
# Average BLEU score : 0.08660246391879758
#
# Average GLEU score : 0.19244717758656496
#
# Average METEOR score : 0.42279391748563916
#
#
# Translating sentence  51
# Original Hindi text : जम्मू-कश्मीर में छह आतंकवादी ढेर
#
# Original English Conversion : Six militants killed in Jammu and Kashmir
#
# Translated to English : Six terrorist heaps in Jammu and Kashmir
# Average BLEU score : 0.0829911042758476
#
# Average GLEU score : 0.2006753743564534
#
# Average METEOR score : 0.4379480538822591
#
#
# Translating sentence  61
# Original Hindi text : देर रात तक लोगों को मौज-मस्ती में देखा।
#
# Original English Conversion : People were seen to enjoy the occasion till late night.
#
# Translated to English : Till late at night, I saw people in the market.
# Average BLEU score : 0.07826542525674336
#
# Average GLEU score : 0.2044819085989136
#
# Average METEOR score : 0.42500427779363265
#
#
# Translating sentence  71
# Original Hindi text : सूचना मिलते ही पुलिस ने मामला दर्ज कर जांच शुरू कर दी थी।
#
# Original English Conversion : Upon receiving the information, the police have registered a case and initiated the investigation.
#
# Translated to English : As soon as the information was received, the police filed the case and began the investigation.
# Average BLEU score : 0.07686693279538753
#
# Average GLEU score : 0.2010371531032634
#
# Average METEOR score : 0.41870626234531544
#
#
# Translating sentence  81
# Original Hindi text : 1907 से अब तक मैं कुल मिलाकर चौदह-पंद्रह युवक एकत्र कर चुका हूं।
#
# Original English Conversion : I collected altogether fourteen or fifteen young men from about the beginning of 1907 till now.
#
# Translated to English : From 1907 onwards I have gathered a total of fourteen to fifteen young men.
# Average BLEU score : 0.07358785281474785
#
# Average GLEU score : 0.1953852534526921
#
# Average METEOR score : 0.41465945857636094
#
#
# Translating sentence  91
# Original Hindi text : इस बारे में विमानन नियामक (डीजीसीए) को भी सूचित किया गया है.
#
# Original English Conversion : The airline has also filed a report with aviation regulator DGCA.
#
# Translated to English : The Aviation Regulatory Authority (DGA) has also been informed about this.
# Average BLEU score : 0.07546213555679913
#
# Average GLEU score : 0.19545875556651793
#
# Average METEOR score : 0.4097663556669187
#
#
# Translating sentence  101
# Original Hindi text : यह करोड़ों लोगों को एक ऑटोमेटिड वित्‍तीय लेन-देन प्रणाली के दायरे में लाएगी।
#
# Original English Conversion : This will bring in crores of people into an automated financial transaction system.
#
# Translated to English : It will bring millions of people into the scope of an automated commercial transaction system.
# Average BLEU score : 0.08292792993291713
#
# Average GLEU score : 0.1979570612377456
#
# Average METEOR score : 0.41092235971895597
#
#
# Translating sentence  111
# Original Hindi text : इस से पहले भी अफगान दूतावास के संस्कृति विभाग ने सूचना एवं प्रसारण मंत्रालय से फिल्म के बारे में जानकारी मांगी थी.
#
# Original English Conversion : Earlier, the culture department of the Embassy of Afghan had also written to the I&B ministry seeking information about the film.
#
# Translated to English : Even before this, the Department of Culture of the Afghan Embassy had asked the Ministry of Information and Broadcasting for information about the film.
# Average BLEU score : 0.09288081413066251
#
# Average GLEU score : 0.20683652146582795
#
# Average METEOR score : 0.4236763597111595
#
#
# Translating sentence  121
# Original Hindi text : परिजन और शिक्षकों ने तुरंत बच्चों को जिला अस्पताल भेजा।
#
# Original English Conversion : The local people rushed the father and the daughter to District Hospital immediately.
#
# Translated to English : The family and teachers immediately sent the children to the district hospital.
# Average BLEU score : 0.09957369548689896
#
# Average GLEU score : 0.21327764439493568
#
# Average METEOR score : 0.43076511547527874
#
#
# Translating sentence  131
# Original Hindi text : उन्‍होंने कहा कि इससे होम और कार लोन सहित अन्‍य लोन भी महंगे हो जाएंगे।
#
# Original English Conversion : """Hence, various loans like Housing Loan, Vehicle Loan etc., will become cheaper"", it added."
#
# Translated to English : He said that it would also make the home and car loans more expensive.
# Average BLEU score : 0.10193522653069009
#
# Average GLEU score : 0.21574083993682786
#
# Average METEOR score : 0.4333802510204127
#
#
# Translating sentence  141
# Original Hindi text : महमूद साहब का अंतिम संस्कार मुंबई में हुआ था.
#
# Original English Conversion : His funeral took place in Mumbai.
#
# Translated to English : Mahmoud Saheb 's last ceremony took place in Mumbai.
# Average BLEU score : 0.10275506484081132
#
# Average GLEU score : 0.21419373372139583
#
# Average METEOR score : 0.42927157764983226
#
#
# Translating sentence  151
# Original Hindi text : इस अवसर पर डॉ एसपी धूमकेती, डीके रोहितास, डॉ अंजली पंड्या, डॉ अंजू सिंह, रूपेष भादे, डॉ प्रदीप सोनी सहित छात्राएं एवं समस्त कॉलेज स्टॉफ उपस्थित रहा।
#
# Original English Conversion : On the occasion, Dr Shahid Ali, Pankajnauan Pandey, Dr Rajendra Mohanty, Nripendra Sharma, Dr Abhishek Dubey, Ashutosh Mandavi besides all students and staff members of the university were present.Registrar of the University Dr Sandeep Vansutre proposed the vote of thanks.
#
# Translated to English : On the occasion, students including Dr. S.P. Dumketi, D.K. Rohitas, Dr. Anjali Panda, Dr. Anju Singh, Rupesh Bhade, Dr. Pradeep Soni and the entire college staff were present.
# Average BLEU score : 0.0992564125507473
#
# Average GLEU score : 0.21074450925420957
#
# Average METEOR score : 0.42637242029198985
#
#
# Translating sentence  161
# Original Hindi text : भारत-वेस्टइंडीज़ के बीच तीसरा टी-20 मुकाबला मुंबई के वानखेड़े स्टेडियम में खेला जाएगा।
#
# Original English Conversion : Mumbai cricket team are playing their 500th Ranji Trophy match against Baroda at the Wankhede stadium.
#
# Translated to English : The third T - 20 match between India and the West Indies will be played at Wankhede Stadium in Mumbai.
# Average BLEU score : 0.10287534746480302
#
# Average GLEU score : 0.21327372946115056
#
# Average METEOR score : 0.42906347242942294
#
#
# Translating sentence  171
# Original Hindi text : तब क्या जब हम दिन भर काम करने के बाद थके - हारे घर लौटते हैं?
#
# Original English Conversion : What about the times when we come home tired after a long days work? We might have to push ourselves to attend Christian meetings.
#
# Translated to English : What if we return home tired after a day 's work?
# Average BLEU score : 0.10364471999519556
#
# Average GLEU score : 0.21295728663291347
#
# Average METEOR score : 0.42758478468202976
#
#
# Translating sentence  181
# Original Hindi text : सलमान खान की ‘दबंग 3’ में महेश मांजरेकर की पत्नी मेधा उनकी पत्नी की भूमिका निभा रही हैं, जो एक तरह से मांजरेकर परिवार के लिए ऑन-स्क्रीन रीयूनियन होगा.
#
# Original English Conversion : Mahesh Manjrekar's wife Medha is roped in to play his better half in Salman Khan's Dabangg 3 which becomes the on-screen reunion for the Manjrekar family.
#
# Translated to English : In Salman Khan 's 'Dbang 3,' Mahesh Mazarkar' s wife Madha plays the role of his wife, who will be an on - screen writer for the Mazarkar family in a way.
# Average BLEU score : 0.10418867884015165
#
# Average GLEU score : 0.21377200706113703
#
# Average METEOR score : 0.4280359517592068
#
#
# Translating sentence  191
# Original Hindi text : जल्‍द ही नामों की घोषणा होने की संभावना है।
#
# Original English Conversion : The names will be announced soon.
#
# Translated to English : It is likely that the same names will be announced.
# Average BLEU score : 0.10111910441254093
#
# Average GLEU score : 0.2121772874409976
#
# Average METEOR score : 0.43048805030471776
#
#
# Translating sentence  201
# Original Hindi text : उन्‍हें अनुसंधान, डिजाइन, विश्‍लेषण, विकास, परीक्षण और विक्रय से जुड़े पदों सहित अनेक प्रकार के रोजगारों में से चुनना होता है।
#
# Original English Conversion : They have many different types of jobs to choose from, including research, design, analysis, development, testing, and sales positions.
#
# Translated to English : They have to choose from several types of employment including positions related to research, design, analysis, development, testing and sale.
# Average BLEU score : 0.10325018403094514
#
# Average GLEU score : 0.2133758749120757
#
# Average METEOR score : 0.43080734887230004
#
#
# Translating sentence  211
# Original Hindi text : अतीत को जलाकर, आप एक नई शुरुआत के लिए तैयार हो जाते हैं।
#
# Original English Conversion : Burning the past, you gear up for a new beginning.
#
# Translated to English : By burning the past, you are ready for a new beginning.
# Average BLEU score : 0.10458029578655105
#
# Average GLEU score : 0.21888155922872135
#
# Average METEOR score : 0.43697692857706893
#
#
# Translating sentence  221
# Original Hindi text : परिवार की ज़िम्मेदारियों की देखरेख करते हुए हम प्रचार के काम में भी काफी व्यस्त रहे ।
#
# Original English Conversion : It was unlike those we held in Greece where we had to meet secretly in the woods because our work was banned.
#
# Translated to English : While taking care of family responsibilities, we were also busy in the field of publicity.
# Average BLEU score : 0.10310590297771106
#
# Average GLEU score : 0.21830277570075282
#
# Average METEOR score : 0.4386080727062839
#
#
# Translating sentence  231
# Original Hindi text : ऐसी कोई विधि '% 1' नहीं है.
#
# Original English Conversion : No such method '%1'.
#
# Translated to English : There is no such method '% 1'.
# Average BLEU score : 0.10556438955235659
#
# Average GLEU score : 0.2209744099860859
#
# Average METEOR score : 0.4440817807785867
#
#
# Translating sentence  241
# Original Hindi text : पाकिस्तान की तरह राहुल गांधी भी 370 और 35ए हटाने का विरोध करते हैं।
#
# Original English Conversion : Rahul Gandhi also protests against the abrogation of Article 370 and 35A, like Pakistan.
#
# Translated to English : Like Pakistan, Rahul Gandhi also opposes the deletion of 370 and 35A.
# Average BLEU score : 0.10333170381518007
#
# Average GLEU score : 0.21934248403995352
#
# Average METEOR score : 0.4435298376752368
#
#
# Translating sentence  251
# Original Hindi text : निर्माण करना या उत्पादन करना।
#
# Original English Conversion : To construct or manufacture.
#
# Translated to English : To make or produce.
# Average BLEU score : 0.09921490286636812
#
# Average GLEU score : 0.21601244564492547
#
# Average METEOR score : 0.4418740298925735
#
#
# Translating sentence  261
# Original Hindi text : इसकी सभी को बधाई.
#
# Original English Conversion : Congratulations to all.
#
# Translated to English : Congratulations to all of you.
# Average BLEU score : 0.09975578236036295
#
# Average GLEU score : 0.2152544091786353
#
# Average METEOR score : 0.44110821308202103
#
#
# Translating sentence  271
# Original Hindi text : उन्होंने उसकी अखलाख से बात करवाई।
#
# Original English Conversion : He talked to her.
#
# Translated to English : He talked to his uncle.
# Average BLEU score : 0.09838951027180859
#
# Average GLEU score : 0.22087623357557665
#
# Average METEOR score : 0.4452705047692899
#
#
# Translating sentence  281
# Original Hindi text : Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji | Good News : सैफ अली खान के बाद अजय देवगन की 'तानाजी' में इस सुपरस्टार की हुई एंट्री - Firstpost Hindi
#
# Original English Conversion : Casting Coup: After Saif Ali Khan, Salman Khan To Also Join Ajay Devgn's 'Taanaji'?
#
# Translated to English : Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji | Good News : The entry of Ajay Devgan after Saif Ali Khan in 'Tanaji' - Firstpost Hindi
# Average BLEU score : 0.09705224279888561
#
# Average GLEU score : 0.21897668011729243
#
# Average METEOR score : 0.4435057773198301
#
#
# Translating sentence  291
# Original Hindi text : स्पष्टीकरण 3ख.—शंकाओं को दूर करने के लिए यह घोषित किया जाता है कि जहां इस धारा के खंड (च) में निर्दिष्ट किसी राशि की बाबत कटौती उस पूर्ववर्ष की (जो 1 अप्रैल, 2001 को प्रारंभ होने वाले निर्धारण वर्ष या उससे पूर्व के किसी निर्धारण वर्ष से सुसंगत पूर्ववर्ष है), जिसमें निर्धारिती द्वारा ऐसी राशि अदा करने का दायित्व उपगत किया गया था, धारा 28 में उल्लिखित आय की संगणना करने में अनुज्ञात की जाती है वहां निर्धारिती उस पूर्ववर्ष की, जिसमें उसके द्वारा ऐसी राशि वास्तव में अदा की जाती है, आय की संगणना करने में ऐसी राशि की बाबत इस धारा के अधीन किसी कटौती का हकदार नहीं होगा।
#
# Original English Conversion : Explanation 3B.For the removal of doubts, it is hereby declared that where a deduction in respect of any sum referred to in clause (f) of this section is allowed in computing the income, referred to in section 28, of the previous year (being a previous year relevant to the assessment year commencing on the 1st day of April, 2001, or any earlier assessment year) in which the liability to pay such sum was incurred by the assessee, the assessee shall not be entitled to any deduction under this section in respect of such sum in computing the income of the previous year in which the sum is actually paid by him.
#
# Translated to English : Explanation 3B.—For the removal of doubts, it is hereby declared that where a deduction in respect of any sum referred to in clause (f) of this section is allowed in computing the income referred to in section 28 of the previous year (which is a previous year relevant to the assessment year commencing on or before the 1st day of April, 2001), in which the obligation to pay such sum was incurred by the assessee, the assessee shall not be entitled to any deduction under this section in respect of such sum in computing the income of the previous year in which such sum is actually paid by him.
# Average BLEU score : 0.10188782239820307
#
# Average GLEU score : 0.2239613077904293
#
# Average METEOR score : 0.44785437995507593
#
#
# Translating sentence  301
# Original Hindi text : पुलिस उसे वहां से अस्पताल ले गई जहां जांच द्वारा उसके साथ बलात्कार किए जाने की पुष्टि की गई।
#
# Original English Conversion : The police rushed the girl to a hospital where her examination confirmed rape.
#
# Translated to English : The police took her to the hospital where the investigation confirmed her rape.
# Average BLEU score : 0.10170202906334361
#
# Average GLEU score : 0.22343277896702782
#
# Average METEOR score : 0.4463313512821162
#
#
# Translating sentence  311
# Original Hindi text : तब जाकर हमारे पास इन सवालों के जवाब मिलेंगे
#
# Original English Conversion : I will ask these questions
#
# Translated to English : then we 'll get the answers to these questions.
# Average BLEU score : 0.10252227721630026
#
# Average GLEU score : 0.22247256354251557
#
# Average METEOR score : 0.44352198215709226
#
#
# Translating sentence  321
# Original Hindi text : आपको सार्वजनिक भावना को समझना चाहिए और न ही एनआरसी को उसके वर्तमान स्वरूप में घोषित करना चाहिए, न ही सीएए को लागू किया जा चाहिए.
#
# Original English Conversion : "You should understand public sentiment&announce neither NRC in its current form,nor CAA will be implemented,"" he said."
#
# Translated to English : You must understand the public spirit and neither the NRC should be declared as it is nor the CAA should be applied.
# Average BLEU score : 0.1006460284821999
#
# Average GLEU score : 0.21997790010071383
#
# Average METEOR score : 0.4419697804104669
#
#
# Translating sentence  331
# Original Hindi text : यही बात भविष्यवाणी के अगले शब्दों में भी कही गयी है ।
#
# Original English Conversion : Imagine that you are standing with the prophetic woman on Mount Zion.
#
# Translated to English : This is also stated in the next words of the prophecy.
# Average BLEU score : 0.09848910068338104
#
# Average GLEU score : 0.21990916627872356
#
# Average METEOR score : 0.44165374682726505
#
#
# Translating sentence  341
# Original Hindi text : फ्लाइट में मौजूद एक यात्री ने बताया कि फ्लाइट को सिक्युरिटि कारणों के चलते अहमदाबाद डायवर्ट किया गया था, जिसके बाद प्लेन से सभी यात्रियों को उतर जाने के लिए कहा गया।
#
# Original English Conversion : "A passenger onboard said the flight was diverted to Ahmedabad citing ""security reasons""."
#
# Translated to English : A passenger on the flight reported that the flight had been diverted to Ahmedabad for security reasons, after which all passengers were asked to disembark from the plane.
# Average BLEU score : 0.09883017520897967
#
# Average GLEU score : 0.21985653231739305
#
# Average METEOR score : 0.4418014085476663
#
#
# Translating sentence  351
# Original Hindi text : आउटलुक DBX आयात
#
# Original English Conversion : Outlook DBX import
#
# Translated to English : Outlook DBX Import
# Average BLEU score : 0.09943922431941397
#
# Average GLEU score : 0.2209097072179192
#
# Average METEOR score : 0.44444294311245924
#
#
# Translating sentence  361
# Original Hindi text : मेलबर्न: ऑस्ट्रेलिया के विश्व के नंबर एक तेज गेंदबाज पैट कमिंस ने भारत के मध्य क्रम के मुख्य बल्लेबाज चेतेश्वर पुजारा को टेस्ट क्रिकेट में गेंदबाजी क .
#
# Original English Conversion : "MELBOURNE: Australia's world number one pacer Pat Cummins finds India's middle-order mainstay Cheteshwar Pujara the toughest batsman to bowl at in Test cricket and called him a ""pain in the back"" for his team."
#
# Translated to English : Melbourne: Pat Comins, Australia 's world 's number one fast bowler, bowled in Test cricket to Cheteshwar Pujara, India' s leading midfielder.
# Average BLEU score : 0.10041125530687724
#
# Average GLEU score : 0.22122302181811276
#
# Average METEOR score : 0.4451637464637407
#
#
# Translating sentence  371
# Original Hindi text : आईसीसी की वनडे रैंकिंग जारी, विराट कोहली और बुमराह टॉप पर कायम
#
# Original English Conversion : ICC ODI rankings: Virat Kohli, Jasprit Bumrah remain on top
#
# Translated to English : ICC 's One - Day Rankings Continued, Virat Kohli and Bumara Tops Established
# Average BLEU score : 0.10045831594779854
#
# Average GLEU score : 0.2207009798798459
#
# Average METEOR score : 0.4437717648089354
#
#
# Translating sentence  381
# Original Hindi text : PNB घोटालेबाज मेहुल चोकसी बोला – भारत आया तो हो जाएगी मेरी भी मॉब लिंचिंग
#
# Original English Conversion : PNB scam: Fugitive businessman Mehul Choksi says he fears mob lynching if hes brought back to India
#
# Translated to English : PNB scammer Mehul Chokri said - If I come to India, I too will have a mob lynching
# Average BLEU score : 0.1025281356722124
#
# Average GLEU score : 0.22142979733720083
#
# Average METEOR score : 0.44502065702151905
#
#
# Translating sentence  391
# Original Hindi text : बाढ़ग्रस्त पंजाब में नुकसान का आकलन करने के लिए एक केंद्रीय टीम जल्द ही राज्य का दौरा करेगी।
#
# Original English Conversion : A central team will soon visit Punjab to assess the damage and loss due to floods in the state.
#
# Translated to English : A central team will soon visit the State to assess the damage in flooded Punjab.
# Average BLEU score : 0.10318108790381908
#
# Average GLEU score : 0.221525645131718
#
# Average METEOR score : 0.4437960576949074
#
#
# Translating sentence  401
# Original Hindi text : स्थिति अब नियंत्रण में बतायी गयी है
#
# Original English Conversion : The situation was now under control
#
# Translated to English : The status is now in control
# Average BLEU score : 0.1043832348820516
#
# Average GLEU score : 0.22159841395510416
#
# Average METEOR score : 0.44407842659313834
#
#
# Translating sentence  411
# Original Hindi text : क्योंकि यहोवा देश के बीच होकर मिस्त्रियों को मारता जाएगा. इसलिये जहां जहां वह चौखट के सिरे, और दोनों अलंगों पर उस लोहू को देखेगा, वहां वहां वह उस द्वार को छोड़ जाएगा, और नाश करनेवाले को तुम्हारे घरों में मारने के लिये न जाने देगा।
#
# Original English Conversion : For Yahweh will pass through to strike the Egyptians. and when he sees the blood on the lintel, and on the two doorposts, Yahweh will pass over the door, and will not allow the destroyer to come in to your houses to strike you.
#
# Translated to English : For Jehovah will kill the women in the midst of the land, so wherever he sees the cow at the end of the field and on both sides, he will leave the door, and will not let the destroyer go to kill you in your houses.
# Average BLEU score : 0.10244924328195645
#
# Average GLEU score : 0.22006354580663895
#
# Average METEOR score : 0.4412318023751189
#
#
# Translating sentence  421
# Original Hindi text : यदि आप अतिरिक्‍त जानकारी प्राप्त करना चाहते हैं या आप चाहते हैं कि कोई आपके घर आकर आपके साथ मुफ़्त बाइबल अध्ययन संचालित करे, तो कृपया Watch Tower, H - 58 Old Khandala Road, Lonavla 410 401, Mah., India को, या पृष्ठ २ पर दिए उपयुक्‍त पते पर लिखिए ।
#
# Original English Conversion : If you would welcome further information or would like to have someone call at your home to conduct a free Bible study with you, please write to Watchtower, 25 Columbia Heights, Brooklyn, NY 11201 - 2483, or to the appropriate address listed on page 2.
#
# Translated to English : If you wish to obtain additional information or if you want someone to come to your home and conduct a free Bible study with you, please write to Watch Tower, H - 58 Old Khandala Road, Lonavla 410 401, Mah., India, or at the appropriate address given on page 2.
# Average BLEU score : 0.1067814084257482
#
# Average GLEU score : 0.2233018933162691
#
# Average METEOR score : 0.4445552892945189
#
#
# Translating sentence  431
# Original Hindi text : ’’ उन्होंने कहा, ‘‘अधिकतर अच्छे हिंदू जिन्हें मैं जानता हूं वह उस जगह पर राम मंदिर चाहते हैं जहां उनका मानना है कि उनका जन्म हुआ।
#
# Original English Conversion : """Most good Hindus I know would want a Ram temple at the place where they believe he was born."
#
# Translated to English : He said, "Most of the good Hindus I know want the Ram temple where they believe they were born.
# Average BLEU score : 0.10834560609549208
#
# Average GLEU score : 0.22536719158726728
#
# Average METEOR score : 0.4466678554875016
#
#
# Translating sentence  441
# Original Hindi text : इसे चालान व ऑनलाइन के माध्यम से दिया जा सकता है।
#
# Original English Conversion : This can be paid online or through a challan.
#
# Translated to English : It can be given through courier and online.
# Average BLEU score : 0.10830670998334076
#
# Average GLEU score : 0.22578594772089314
#
# Average METEOR score : 0.44788776285298065
#
#
# Translating sentence  451
# Original Hindi text : उन्होंने कहा, ‘‘यहां (गोरखपुर) की तरह, राज्य के अन्य भागों में भी मुस्लिम सुरक्षित महसूस करते हैं।
#
# Original English Conversion : """Like here (Gorakhpur), Muslims feel safe in other parts of the state,"" he said."
#
# Translated to English : He said, "Like here in Gorakhpur, Muslims feel safe in other parts of the State.
# Average BLEU score : 0.11237752109023572
#
# Average GLEU score : 0.22861577702638153
#
# Average METEOR score : 0.4495934524572695
#
#
# Translating sentence  461
# Original Hindi text : कर्ज के बोझ से दबे अपने राज्य के लिए विशेष वित्तीय पैकेज की मांग के साथ बनर्जी ने पहले संसद भवन में मोदी से मुलाकात की और बाद में अपनी पार्टी के सांसदों के एक प्रतिनिधिमंडल के साथ फिर से प्रधानमंत्री से मिलीं।
#
# Original English Conversion : Seeking a special financial package for her debt-ridden state, Banerjee initially met Modi in Parliament House before calling on him again with a delegation of MPs from her party.
#
# Translated to English : With a demand for a special financial package for his state burdened by debt, Banerjee first met Modi at Parliament House and later met the Prime Minister again with a delegation of MPs of his party.
# Average BLEU score : 0.11211227939612038
#
# Average GLEU score : 0.2289875503536737
#
# Average METEOR score : 0.4503737395975221
#
#
# Translating sentence  471
# Original Hindi text : मोदी कैबिनेट में रहते हुए उन्होंने केंद्रीय ग्रामीण विकास राज्य मंत्री पेयजल, स्वच्छता और पंचायती राज मंत्री का पद भी संभाला.
#
# Original English Conversion : He served as the Minister of Rural Development, Minister of Parliamentary Affairs, Panchayati Raj and Mines in the Modi government.
#
# Translated to English : While in the Modi Cabinet, he also served as the Union Minister of State for Rural Development, Drinking Water, Sanitation and Panchayat Raj.
# Average BLEU score : 0.11054688711033976
#
# Average GLEU score : 0.22776120161685198
#
# Average METEOR score : 0.44931770073759264
#
#
# Translating sentence  481
# Original Hindi text : भूमि अधिग्रहण क़ानून में संशोधन
#
# Original English Conversion : Amendments to Land Acquisition Act
#
# Translated to English : Amendment to Land Acquisition Act
# Average BLEU score : 0.11172602131106242
#
# Average GLEU score : 0.22889977514670004
#
# Average METEOR score : 0.4498880351601622
#
#
# Translating sentence  491
# Original Hindi text : चम्बल इटावा के पास तथा बेतवा हमीरपुर के पास यमुना में मिलती हैं।
#
# Original English Conversion : chambal comes from itva, and betab in hamirpur and then they meet with yamuna
#
# Translated to English : Chambal meets in Yamuna near Ithawa and Bethwa near Hamirpur.
# Average BLEU score : 0.11063914171864443
#
# Average GLEU score : 0.2285752160798411
#
# Average METEOR score : 0.45028300077695566

# %%
average_bleu_score = np.mean(mbart_bleu_scores)
average_gleu_score = np.mean(mbart_gleu_scores)
average_meteor_score = np.mean(mbart_meteor_scores)
print('Average BLEU Score for Dev Set using Facebooks mBART model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using Facebooks mBART model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using Facebooks mBART model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using Facebooks mBART model:  0.11132998186862958
# Average GLEU Score for Dev Set using Facebooks mBART model:  0.23085949016774981
# Average METEOR Score for Dev Set using Facebooks mBART model:  0.4525925927984988

# %%
import torch
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor


model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)

ip = IndicProcessor(inference=True)

input_sentences = [
    "जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।",
    "हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।",
    "अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।",
    "मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।",
]

src_lang, tgt_lang = "hin_Deva", "eng_Latn"

batch = ip.preprocess_batch(
    input_sentences,
    src_lang=src_lang,
    tgt_lang=tgt_lang,
)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Tokenize the sentences and generate input encodings
inputs = tokenizer(
    batch,
    truncation=True,
    padding="longest",
    return_tensors="pt",
    return_attention_mask=True,
).to(DEVICE)

# Generate translations using the model
with torch.no_grad():
    generated_tokens = model.generate(
        **inputs,
        use_cache=True,
        min_length=0,
        max_length=256,
        num_beams=5,
        num_return_sequences=1,
    )

# Decode the generated tokens into text
with tokenizer.as_target_tokenizer():
    generated_tokens = tokenizer.batch_decode(
        generated_tokens.detach().cpu().tolist(),
        skip_special_tokens=True,
        clean_up_tokenization_spaces=True,
    )

# Postprocess the translations, including entity replacement
translations = ip.postprocess_batch(generated_tokens, lang=tgt_lang)

for input_sentence, translation in zip(input_sentences, translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")
# Out:
# hin_Deva: जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।
# eng_Latn: When I was young, I used to go to the park every day.
# hin_Deva: हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।
# eng_Latn: We saw a new movie last week that was very inspiring.
# hin_Deva: अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।
# eng_Latn: If you'd given me a pass at that time, we'd have gone out to eat.
# hin_Deva: मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।
# eng_Latn: My friend has invited me to her birthday party, and I'll give her a present.
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\transformers\tokenization_utils_base.py:4114: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(

# %%
import torch
import numpy as np
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor

# Initialize metrics
indict2_bleu_scores = []
indict2_gleu_scores = []
indict2_meteor_scores = []

# Model and tokenizer setup
model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True).to("cuda" if torch.cuda.is_available() else "cpu")
ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "hin_Deva", "eng_Latn"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Convert numpy array to a list
native_hindi_sentences = native_hindi_sentences_dev_set.tolist()
english_sentences = english_sentences_dev_set.tolist()

# Ensure the datasets are aligned
assert len(native_hindi_sentences) == len(english_sentences), "Dev sets must be of equal length."

for i, hindi_text in enumerate(native_hindi_sentences):
    try:
        # print(f"Processing sentence {i+1}...")
        
        # Preprocessing
        batch = ip.preprocess_batch(
            [hindi_text],
            src_lang=src_lang,
            tgt_lang=tgt_lang,
        )
        # print(f"Preprocessed batch: {batch}")
        
        # Tokenize the sentences and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=1,
                num_return_sequences=1,
            )
        # print(f"Generated tokens: {generated_tokens}")

        # Decode the generated tokens into text
        with tokenizer.as_target_tokenizer():
            generated_tokens = tokenizer.batch_decode(
                generated_tokens.detach().cpu().tolist(),
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )
        translated_text = ip.postprocess_batch(generated_tokens, lang=tgt_lang)[0]
        # print(f"Translated text: {translated_text}")

        reference = [english_sentences_dev_set[i].split()]
        transformed_tokens = translated_text.split()

        bleu_score = sentence_bleu(reference, transformed_tokens)
        gleu_score = sentence_gleu(reference, transformed_tokens)
        met_score = meteor_score(reference, transformed_tokens)

        indict2_bleu_scores.append(bleu_score)
        indict2_gleu_scores.append(gleu_score)
        indict2_meteor_scores.append(met_score)

        # Log progress every 10 sentences
        if i % 10 == 0:
            print("Translating sentence", i + 1)
            print("Original Hindi text:", hindi_text)
            print("Original English Conversion:", english_sentences[i])
            print("Translated to English:", translated_text)
            print("Average BLEU score:", np.mean(indict2_bleu_scores))
            print("Average GLEU score:", np.mean(indict2_gleu_scores))
            print("Average METEOR score:", np.mean(indict2_meteor_scores))
            print()

    except Exception as e:
        print(f"Error processing sentence {i+1}: {e}")
        continue
# Out:
# Translating sentence 1
# Original Hindi text: उसकी पत्नी ने एक लड़के को जन्म दिया है.
#
# Original English Conversion: His wife delivers a baby boy.
#
# Translated to English: His wife gave birth to a baby boy.
# Average BLEU score: 5.614021910443866e-78
# Average GLEU score: 0.34615384615384615
# Average METEOR score: 0.7806451612903227
#
# Translating sentence 11
# Original Hindi text: पीएम मोदी ने दी नयी परिभाषा
#
# Original English Conversion: PM Modi kicks off new term
#
# Translated to English: PM Modi has given a new definition to the word.
# Average BLEU score: 0.14237767459099188
# Average GLEU score: 0.25227348556664414
# Average METEOR score: 0.5070000468927506
#
# Translating sentence 21
# Original Hindi text: मुख्य प्रथा जुआन रोड्रिग्ज़ फ्रेल के द्वारा लिखी गई पुस्तक एल कार्नेरो की कथाओं में पाई जाती है।
#
# Original English Conversion: The original narrative can be found in the rambling chronicle El Carnero of Juan Rodriguez Freyle.
#
# Translated to English: The main practice is found in the book El Carnero's Fables, by Juan Rodríguez Fraile.
# Average BLEU score: 0.18793776665470865
# Average GLEU score: 0.27314199945394907
# Average METEOR score: 0.4843315303906964
#
# Translating sentence 31
# Original Hindi text: आम तौर से दो दवाएं उपयोग की जाती हैं जिनमें से एक अक्सर प्लेटिनम आधारित (सिस्प्लाटिन या कार्बोप्लाटिन) होती है।
#
# Original English Conversion: Typically, two drugs are used, of which one is often platinum-based (either cisplatin or carboplatin).
#
# Translated to English: Two drugs are commonly used, one of which is often platinum-based (cisplatin or carboplatin).
# Average BLEU score: 0.16989699556815605
# Average GLEU score: 0.2661648934866134
# Average METEOR score: 0.47954467405788226
#
# Translating sentence 41
# Original Hindi text: नाख़्मानदीज़ बहस में भाग लेने को राज़ी होने से झिझक रहा था क्योंकि वह समझ गया कि डोमीनीकी पादरी निष्पक्ष होना नहीं चाहते थे ।
#
# Original English Conversion: The Dominicans realized that in order to humiliate the Jews effectively, he, their foremost rabbi, would have to be the one to debate.
#
# Translated to English: Nakhmanidze was reluctant to participate in the debate because he understood that the Dominican clergy did not want to be impartial.
# Average BLEU score: 0.19453206769311202
# Average GLEU score: 0.286606966090447
# Average METEOR score: 0.5105677059966697
#
# Translating sentence 51
# Original Hindi text: जम्मू-कश्मीर में छह आतंकवादी ढेर
#
# Original English Conversion: Six militants killed in Jammu and Kashmir
#
# Translated to English: Six militants killed in Jammu and Kashmir
# Average BLEU score: 0.18166653468119315
# Average GLEU score: 0.28956939166054463
# Average METEOR score: 0.5249551237967035
#
# Translating sentence 61
# Original Hindi text: देर रात तक लोगों को मौज-मस्ती में देखा।
#
# Original English Conversion: People were seen to enjoy the occasion till late night.
#
# Translated to English: Till late in the night, people were seen enjoying themselves.
# Average BLEU score: 0.16281553111480052
# Average GLEU score: 0.2661189224768649
# Average METEOR score: 0.4983749281533688
#
# Translating sentence 71
# Original Hindi text: सूचना मिलते ही पुलिस ने मामला दर्ज कर जांच शुरू कर दी थी।
#
# Original English Conversion: Upon receiving the information, the police have registered a case and initiated the investigation.
#
# Translated to English: After receiving information, police reached the spot and begun investigation.
# Average BLEU score: 0.15789807517410445
# Average GLEU score: 0.26059310466657465
# Average METEOR score: 0.48362538181075393
#
# Translating sentence 81
# Original Hindi text: 1907 से अब तक मैं कुल मिलाकर चौदह-पंद्रह युवक एकत्र कर चुका हूं।
#
# Original English Conversion: I collected altogether fourteen or fifteen young men from about the beginning of 1907 till now.
#
# Translated to English: In all, I have collected fourteen or fifteen young men since 1907.
# Average BLEU score: 0.15880215990391566
# Average GLEU score: 0.2568040795094856
# Average METEOR score: 0.4729199643412798
#
# Translating sentence 91
# Original Hindi text: इस बारे में विमानन नियामक (डीजीसीए) को भी सूचित किया गया है.
#
# Original English Conversion: The airline has also filed a report with aviation regulator DGCA.
#
# Translated to English: The aviation regulator (DGCA) has also been informed about it.
# Average BLEU score: 0.15949335040584767
# Average GLEU score: 0.2581880370201729
# Average METEOR score: 0.47142349509233245
#
# Translating sentence 101
# Original Hindi text: यह करोड़ों लोगों को एक ऑटोमेटिड वित्‍तीय लेन-देन प्रणाली के दायरे में लाएगी।
#
# Original English Conversion: This will bring in crores of people into an automated financial transaction system.
#
# Translated to English: This will bring crores of people under an automated financial transaction system.
# Average BLEU score: 0.16619258558171968
# Average GLEU score: 0.2603605318161884
# Average METEOR score: 0.47323550279867255
#
# Translating sentence 111
# Original Hindi text: इस से पहले भी अफगान दूतावास के संस्कृति विभाग ने सूचना एवं प्रसारण मंत्रालय से फिल्म के बारे में जानकारी मांगी थी.
#
# Original English Conversion: Earlier, the culture department of the Embassy of Afghan had also written to the I&B ministry seeking information about the film.
#
# Translated to English: Earlier, the Culture Department of the Afghan Embassy had sought information about the film from the Ministry of Information and Broadcasting.
# Average BLEU score: 0.16997733227774212
# Average GLEU score: 0.26784140513973403
# Average METEOR score: 0.48130407481197274
#
# Translating sentence 121
# Original Hindi text: परिजन और शिक्षकों ने तुरंत बच्चों को जिला अस्पताल भेजा।
#
# Original English Conversion: The local people rushed the father and the daughter to District Hospital immediately.
#
# Translated to English: The parents and teachers immediately rushed the children to the district hospital.
# Average BLEU score: 0.17974646516913534
# Average GLEU score: 0.2775002491966894
# Average METEOR score: 0.49460981765718254
#
# Translating sentence 131
# Original Hindi text: उन्‍होंने कहा कि इससे होम और कार लोन सहित अन्‍य लोन भी महंगे हो जाएंगे।
#
# Original English Conversion: """Hence, various loans like Housing Loan, Vehicle Loan etc., will become cheaper"", it added."
#
# Translated to English: He said this will make other loans, including home and car loans, costlier.
# Average BLEU score: 0.17755156502177558
# Average GLEU score: 0.28630535403825436
# Average METEOR score: 0.4975245081106675
#
# Translating sentence 141
# Original Hindi text: महमूद साहब का अंतिम संस्कार मुंबई में हुआ था.
#
# Original English Conversion: His funeral took place in Mumbai.
#
# Translated to English: Mehmood Sahab's funeral was held in Mumbai.
# Average BLEU score: 0.17849541132359423
# Average GLEU score: 0.28612962321370405
# Average METEOR score: 0.4946291492098061
#
# Translating sentence 151
# Original Hindi text: इस अवसर पर डॉ एसपी धूमकेती, डीके रोहितास, डॉ अंजली पंड्या, डॉ अंजू सिंह, रूपेष भादे, डॉ प्रदीप सोनी सहित छात्राएं एवं समस्त कॉलेज स्टॉफ उपस्थित रहा।
#
# Original English Conversion: On the occasion, Dr Shahid Ali, Pankajnauan Pandey, Dr Rajendra Mohanty, Nripendra Sharma, Dr Abhishek Dubey, Ashutosh Mandavi besides all students and staff members of the university were present.Registrar of the University Dr Sandeep Vansutre proposed the vote of thanks.
#
# Translated to English: On this occasion, Dr. S. P. Dhumketi, D. K. Rohithas, Dr. Anjali Pandya, Dr. Anju Singh, Roopesh Bhade, Dr. Pradeep Soni and all the students and staff of the college were present.
# Average BLEU score: 0.1733926075371877
# Average GLEU score: 0.2813493021904971
# Average METEOR score: 0.4881747353792012
#
# Translating sentence 161
# Original Hindi text: भारत-वेस्टइंडीज़ के बीच तीसरा टी-20 मुकाबला मुंबई के वानखेड़े स्टेडियम में खेला जाएगा।
#
# Original English Conversion: Mumbai cricket team are playing their 500th Ranji Trophy match against Baroda at the Wankhede stadium.
#
# Translated to English: The India vs West Indies 3rd T20I will be played at the Wankhede Stadium in Mumbai.
# Average BLEU score: 0.17569779939284363
# Average GLEU score: 0.281634185418394
# Average METEOR score: 0.4884300263800412
#
# Translating sentence 171
# Original Hindi text: तब क्या जब हम दिन भर काम करने के बाद थके - हारे घर लौटते हैं?
#
# Original English Conversion: What about the times when we come home tired after a long days work? We might have to push ourselves to attend Christian meetings.
#
# Translated to English: What if we come home tired after a long day at work?
# Average BLEU score: 0.17486162625956198
# Average GLEU score: 0.2816948327204014
# Average METEOR score: 0.48997577261099123
#
# Translating sentence 181
# Original Hindi text: सलमान खान की ‘दबंग 3’ में महेश मांजरेकर की पत्नी मेधा उनकी पत्नी की भूमिका निभा रही हैं, जो एक तरह से मांजरेकर परिवार के लिए ऑन-स्क्रीन रीयूनियन होगा.
#
# Original English Conversion: Mahesh Manjrekar's wife Medha is roped in to play his better half in Salman Khan's Dabangg 3 which becomes the on-screen reunion for the Manjrekar family.
#
# Translated to English: Salman Khan's Dabangg 3, which features Mahesh Manjrekar's wife Medha in the titular role, will be a sort of on-screen reunion for the Manjrekar family.
# Average BLEU score: 0.1780055324398881
# Average GLEU score: 0.28457161539113396
# Average METEOR score: 0.49381566383910397
#
# Translating sentence 191
# Original Hindi text: जल्‍द ही नामों की घोषणा होने की संभावना है।
#
# Original English Conversion: The names will be announced soon.
#
# Translated to English: The names are likely to be announced soon.
# Average BLEU score: 0.17449479749881874
# Average GLEU score: 0.2825005109980961
# Average METEOR score: 0.4965752876348353
#
# Translating sentence 201
# Original Hindi text: उन्‍हें अनुसंधान, डिजाइन, विश्‍लेषण, विकास, परीक्षण और विक्रय से जुड़े पदों सहित अनेक प्रकार के रोजगारों में से चुनना होता है।
#
# Original English Conversion: They have many different types of jobs to choose from, including research, design, analysis, development, testing, and sales positions.
#
# Translated to English: They have to choose from a wide variety of jobs, including positions in research, design, analysis, development, testing, and sales.
# Average BLEU score: 0.1737655766311452
# Average GLEU score: 0.28254938954110465
# Average METEOR score: 0.4984915114206023
#
# Translating sentence 211
# Original Hindi text: अतीत को जलाकर, आप एक नई शुरुआत के लिए तैयार हो जाते हैं।
#
# Original English Conversion: Burning the past, you gear up for a new beginning.
#
# Translated to English: By burning out the past, you are ready for a fresh start.
# Average BLEU score: 0.17116015234542964
# Average GLEU score: 0.28519301818622417
# Average METEOR score: 0.5016821318471852
#
# Translating sentence 221
# Original Hindi text: परिवार की ज़िम्मेदारियों की देखरेख करते हुए हम प्रचार के काम में भी काफी व्यस्त रहे ।
#
# Original English Conversion: It was unlike those we held in Greece where we had to meet secretly in the woods because our work was banned.
#
# Translated to English: While overseeing family responsibilities, we also kept busy in the preaching work.
# Average BLEU score: 0.17158323856761343
# Average GLEU score: 0.2847199259041354
# Average METEOR score: 0.5030824137844747
#
# Translating sentence 231
# Original Hindi text: ऐसी कोई विधि '% 1' नहीं है.
#
# Original English Conversion: No such method '%1'.
#
# Translated to English: There is no such method'% 1 '.
# Average BLEU score: 0.17083700758042045
# Average GLEU score: 0.283835847511241
# Average METEOR score: 0.5029225161335713
#
# Translating sentence 241
# Original Hindi text: पाकिस्तान की तरह राहुल गांधी भी 370 और 35ए हटाने का विरोध करते हैं।
#
# Original English Conversion: Rahul Gandhi also protests against the abrogation of Article 370 and 35A, like Pakistan.
#
# Translated to English: Like Pakistan, Rahul Gandhi also opposes the abrogation of 370 and 35A.
# Average BLEU score: 0.16904601468199876
# Average GLEU score: 0.2822235375142463
# Average METEOR score: 0.504466849777991
#
# Translating sentence 251
# Original Hindi text: निर्माण करना या उत्पादन करना।
#
# Original English Conversion: To construct or manufacture.
#
# Translated to English: to manufacture or produce.
# Average BLEU score: 0.1676528700661543
# Average GLEU score: 0.28071627005756417
# Average METEOR score: 0.5031532104494266
#
# Translating sentence 261
# Original Hindi text: इसकी सभी को बधाई.
#
# Original English Conversion: Congratulations to all.
#
# Translated to English: Congratulations to all of them.
# Average BLEU score: 0.16575961380626686
# Average GLEU score: 0.2800271164394237
# Average METEOR score: 0.5032423740409342
#
# Translating sentence 271
# Original Hindi text: उन्होंने उसकी अखलाख से बात करवाई।
#
# Original English Conversion: He talked to her.
#
# Translated to English: He spoke to her.
# Average BLEU score: 0.16501559017652123
# Average GLEU score: 0.28370337121110617
# Average METEOR score: 0.5102803208250019
#
# Translating sentence 281
# Original Hindi text: Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji | Good News : सैफ अली खान के बाद अजय देवगन की 'तानाजी' में इस सुपरस्टार की हुई एंट्री - Firstpost Hindi
#
# Original English Conversion: Casting Coup: After Saif Ali Khan, Salman Khan To Also Join Ajay Devgn's 'Taanaji'?
#
# Translated to English: Saif Ali Khan, Salman Khan join Ajay Devgn in Tanhaji
# Average BLEU score: 0.166139071993675
# Average GLEU score: 0.2844266420593267
# Average METEOR score: 0.5112559114527345
#
# Translating sentence 291
# Original Hindi text: स्पष्टीकरण 3ख.—शंकाओं को दूर करने के लिए यह घोषित किया जाता है कि जहां इस धारा के खंड (च) में निर्दिष्ट किसी राशि की बाबत कटौती उस पूर्ववर्ष की (जो 1 अप्रैल, 2001 को प्रारंभ होने वाले निर्धारण वर्ष या उससे पूर्व के किसी निर्धारण वर्ष से सुसंगत पूर्ववर्ष है), जिसमें निर्धारिती द्वारा ऐसी राशि अदा करने का दायित्व उपगत किया गया था, धारा 28 में उल्लिखित आय की संगणना करने में अनुज्ञात की जाती है वहां निर्धारिती उस पूर्ववर्ष की, जिसमें उसके द्वारा ऐसी राशि वास्तव में अदा की जाती है, आय की संगणना करने में ऐसी राशि की बाबत इस धारा के अधीन किसी कटौती का हकदार नहीं होगा।
#
# Original English Conversion: Explanation 3B.For the removal of doubts, it is hereby declared that where a deduction in respect of any sum referred to in clause (f) of this section is allowed in computing the income, referred to in section 28, of the previous year (being a previous year relevant to the assessment year commencing on the 1st day of April, 2001, or any earlier assessment year) in which the liability to pay such sum was incurred by the assessee, the assessee shall not be entitled to any deduction under this section in respect of such sum in computing the income of the previous year in which the sum is actually paid by him.
#
# Translated to English: Explanation 3B.For the removal of doubts, it is hereby declared that where a deduction in respect of any amount referred to in clause (f) of this section is allowed in computing the income referred to in section 28 of the previous year (being the previous year relevant to the assessment year commencing on the 1st day of April, 2001 or any assessment year preceding that) in which the assessee incurred an obligation to pay such amount, the assessee shall not be entitled to any deduction under this section in respect of such amount in computing the income of the previous year in which such amount is actually paid by him.
# Average BLEU score: 0.17295646148330496
# Average GLEU score: 0.2907252211681149
# Average METEOR score: 0.5158082390667087
#
# Translating sentence 301
# Original Hindi text: पुलिस उसे वहां से अस्पताल ले गई जहां जांच द्वारा उसके साथ बलात्कार किए जाने की पुष्टि की गई।
#
# Original English Conversion: The police rushed the girl to a hospital where her examination confirmed rape.
#
# Translated to English: Police took her from there to the hospital where investigations confirmed that she had been raped.
# Average BLEU score: 0.17024140840039656
# Average GLEU score: 0.2881835852574961
# Average METEOR score: 0.5110601989562717
#
# Translating sentence 311
# Original Hindi text: तब जाकर हमारे पास इन सवालों के जवाब मिलेंगे
#
# Original English Conversion: I will ask these questions
#
# Translated to English: Then we will have the answers to these questions.
# Average BLEU score: 0.1683535474587816
# Average GLEU score: 0.28607584088864346
# Average METEOR score: 0.5078633954626988
#
# Translating sentence 321
# Original Hindi text: आपको सार्वजनिक भावना को समझना चाहिए और न ही एनआरसी को उसके वर्तमान स्वरूप में घोषित करना चाहिए, न ही सीएए को लागू किया जा चाहिए.
#
# Original English Conversion: "You should understand public sentiment&announce neither NRC in its current form,nor CAA will be implemented,"" he said."
#
# Translated to English: You should understand the public sentiment and not declare NRC in its present form, nor implement CAA.
# Average BLEU score: 0.16656953734521152
# Average GLEU score: 0.28386995536535437
# Average METEOR score: 0.5067763998332488
#
# Translating sentence 331
# Original Hindi text: यही बात भविष्यवाणी के अगले शब्दों में भी कही गयी है ।
#
# Original English Conversion: Imagine that you are standing with the prophetic woman on Mount Zion.
#
# Translated to English: The same is also stated in the next words of the prophecy.
# Average BLEU score: 0.1662801750690908
# Average GLEU score: 0.2832406120069489
# Average METEOR score: 0.5053784527691121
#
# Translating sentence 341
# Original Hindi text: फ्लाइट में मौजूद एक यात्री ने बताया कि फ्लाइट को सिक्युरिटि कारणों के चलते अहमदाबाद डायवर्ट किया गया था, जिसके बाद प्लेन से सभी यात्रियों को उतर जाने के लिए कहा गया।
#
# Original English Conversion: "A passenger onboard said the flight was diverted to Ahmedabad citing ""security reasons""."
#
# Translated to English: A passenger on board said the flight was diverted to Ahmedabad for security reasons, after which all passengers were asked to deplane.
# Average BLEU score: 0.168198684136509
# Average GLEU score: 0.2839630008986632
# Average METEOR score: 0.5062481298869017
#
# Translating sentence 351
# Original Hindi text: आउटलुक DBX आयात
#
# Original English Conversion: Outlook DBX import
#
# Translated to English: Outlook DBX Import
# Average BLEU score: 0.1666100945285061
# Average GLEU score: 0.2833514999775688
# Average METEOR score: 0.5075317109585564
#
# Translating sentence 361
# Original Hindi text: मेलबर्न: ऑस्ट्रेलिया के विश्व के नंबर एक तेज गेंदबाज पैट कमिंस ने भारत के मध्य क्रम के मुख्य बल्लेबाज चेतेश्वर पुजारा को टेस्ट क्रिकेट में गेंदबाजी क .
#
# Original English Conversion: "MELBOURNE: Australia's world number one pacer Pat Cummins finds India's middle-order mainstay Cheteshwar Pujara the toughest batsman to bowl at in Test cricket and called him a ""pain in the back"" for his team."
#
# Translated to English: Melbourne: Australia's world number one fast bowler Pat Cummins has bowled to India's main middle-order batsman Cheteshwar Pujara in Test cricket.
# Average BLEU score: 0.16800668103175595
# Average GLEU score: 0.28346198482187
# Average METEOR score: 0.5075957544444553
#
# Translating sentence 371
# Original Hindi text: आईसीसी की वनडे रैंकिंग जारी, विराट कोहली और बुमराह टॉप पर कायम
#
# Original English Conversion: ICC ODI rankings: Virat Kohli, Jasprit Bumrah remain on top
#
# Translated to English: ICC ODI rankings: Virat Kohli, Bumrah retain top spots
# Average BLEU score: 0.16975175240299112
# Average GLEU score: 0.2858944344517239
# Average METEOR score: 0.5103372459987785
#
# Translating sentence 381
# Original Hindi text: PNB घोटालेबाज मेहुल चोकसी बोला – भारत आया तो हो जाएगी मेरी भी मॉब लिंचिंग
#
# Original English Conversion: PNB scam: Fugitive businessman Mehul Choksi says he fears mob lynching if hes brought back to India
#
# Translated to English: PNB scam accused Mehul Choksi says he will be lynched if he returns to India
# Average BLEU score: 0.1749197776775965
# Average GLEU score: 0.2891733686444649
# Average METEOR score: 0.5126704536119117
#
# Translating sentence 391
# Original Hindi text: बाढ़ग्रस्त पंजाब में नुकसान का आकलन करने के लिए एक केंद्रीय टीम जल्द ही राज्य का दौरा करेगी।
#
# Original English Conversion: A central team will soon visit Punjab to assess the damage and loss due to floods in the state.
#
# Translated to English: A central team will soon visit the flood-hit state of Punjab to assess the damage.
# Average BLEU score: 0.1741156373302512
# Average GLEU score: 0.2883313593501995
# Average METEOR score: 0.5114748092982877
#
# Translating sentence 401
# Original Hindi text: स्थिति अब नियंत्रण में बतायी गयी है
#
# Original English Conversion: The situation was now under control
#
# Translated to English: The situation is now stated to be under control.
# Average BLEU score: 0.17659078835104605
# Average GLEU score: 0.2901033298461263
# Average METEOR score: 0.5148275513478288
#
# Translating sentence 411
# Original Hindi text: क्योंकि यहोवा देश के बीच होकर मिस्त्रियों को मारता जाएगा. इसलिये जहां जहां वह चौखट के सिरे, और दोनों अलंगों पर उस लोहू को देखेगा, वहां वहां वह उस द्वार को छोड़ जाएगा, और नाश करनेवाले को तुम्हारे घरों में मारने के लिये न जाने देगा।
#
# Original English Conversion: For Yahweh will pass through to strike the Egyptians. and when he sees the blood on the lintel, and on the two doorposts, Yahweh will pass over the door, and will not allow the destroyer to come in to your houses to strike you.
#
# Translated to English: For the LORD will go through the midst of the land, and smite the Egyptians. Wherever he sees the blood at the top of the gate, and on both sides, there he will leave the gate. He will not let the destroyer go into your houses to smite you.
# Average BLEU score: 0.17403866035279597
# Average GLEU score: 0.2889829433408111
# Average METEOR score: 0.5141532838014793
#
# Translating sentence 421
# Original Hindi text: यदि आप अतिरिक्‍त जानकारी प्राप्त करना चाहते हैं या आप चाहते हैं कि कोई आपके घर आकर आपके साथ मुफ़्त बाइबल अध्ययन संचालित करे, तो कृपया Watch Tower, H - 58 Old Khandala Road, Lonavla 410 401, Mah., India को, या पृष्ठ २ पर दिए उपयुक्‍त पते पर लिखिए ।
#
# Original English Conversion: If you would welcome further information or would like to have someone call at your home to conduct a free Bible study with you, please write to Watchtower, 25 Columbia Heights, Brooklyn, NY 11201 - 2483, or to the appropriate address listed on page 2.
#
# Translated to English: If you would like additional information or if you would like someone to come to your home and conduct a free Bible study with you, please write to Watch Tower, H-58 Old Khandala Road, Lonavla 410 401, Mah., India, or to the appropriate address on page 2.
# Average BLEU score: 0.17878699797508105
# Average GLEU score: 0.29250476940980646
# Average METEOR score: 0.5176011674485519
#
# Translating sentence 431
# Original Hindi text: ’’ उन्होंने कहा, ‘‘अधिकतर अच्छे हिंदू जिन्हें मैं जानता हूं वह उस जगह पर राम मंदिर चाहते हैं जहां उनका मानना है कि उनका जन्म हुआ।
#
# Original English Conversion: """Most good Hindus I know would want a Ram temple at the place where they believe he was born."
#
# Translated to English: "Most good Hindus I know want a Ram temple at the place where they believe he was born.
# Average BLEU score: 0.18183544414477895
# Average GLEU score: 0.2953408955662887
# Average METEOR score: 0.5195942066373633
#
# Translating sentence 441
# Original Hindi text: इसे चालान व ऑनलाइन के माध्यम से दिया जा सकता है।
#
# Original English Conversion: This can be paid online or through a challan.
#
# Translated to English: It can be paid through challan and online.
# Average BLEU score: 0.18245091944254183
# Average GLEU score: 0.2960755949299912
# Average METEOR score: 0.5208860664719834
#
# Translating sentence 451
# Original Hindi text: उन्होंने कहा, ‘‘यहां (गोरखपुर) की तरह, राज्य के अन्य भागों में भी मुस्लिम सुरक्षित महसूस करते हैं।
#
# Original English Conversion: """Like here (Gorakhpur), Muslims feel safe in other parts of the state,"" he said."
#
# Translated to English: "Like here (Gorakhpur), Muslims feel safe in other parts of the state as well.
# Average BLEU score: 0.1864165539935662
# Average GLEU score: 0.300007494378654
# Average METEOR score: 0.5234439274374111
#
# Translating sentence 461
# Original Hindi text: कर्ज के बोझ से दबे अपने राज्य के लिए विशेष वित्तीय पैकेज की मांग के साथ बनर्जी ने पहले संसद भवन में मोदी से मुलाकात की और बाद में अपनी पार्टी के सांसदों के एक प्रतिनिधिमंडल के साथ फिर से प्रधानमंत्री से मिलीं।
#
# Original English Conversion: Seeking a special financial package for her debt-ridden state, Banerjee initially met Modi in Parliament House before calling on him again with a delegation of MPs from her party.
#
# Translated to English: Banerjee first met Modi in Parliament House and later met the prime minister again with a delegation of her party MPs, seeking a special financial package for her debt-ridden state.
# Average BLEU score: 0.18789114998288622
# Average GLEU score: 0.3014732729224614
# Average METEOR score: 0.5253991830014122
#
# Translating sentence 471
# Original Hindi text: मोदी कैबिनेट में रहते हुए उन्होंने केंद्रीय ग्रामीण विकास राज्य मंत्री पेयजल, स्वच्छता और पंचायती राज मंत्री का पद भी संभाला.
#
# Original English Conversion: He served as the Minister of Rural Development, Minister of Parliamentary Affairs, Panchayati Raj and Mines in the Modi government.
#
# Translated to English: He also held the post of Union Minister of State for Rural Development, Drinking Water, Sanitation and Panchayati Raj in the Modi cabinet.
# Average BLEU score: 0.1847772718259824
# Average GLEU score: 0.30028270695966947
# Average METEOR score: 0.5254413919102565
#
# Translating sentence 481
# Original Hindi text: भूमि अधिग्रहण क़ानून में संशोधन
#
# Original English Conversion: Amendments to Land Acquisition Act
#
# Translated to English: Amendments to the Land Acquisition Act
# Average BLEU score: 0.18576521164869267
# Average GLEU score: 0.3020234362138252
# Average METEOR score: 0.5262708698948911
#
# Translating sentence 491
# Original Hindi text: चम्बल इटावा के पास तथा बेतवा हमीरपुर के पास यमुना में मिलती हैं।
#
# Original English Conversion: chambal comes from itva, and betab in hamirpur and then they meet with yamuna
#
# Translated to English: The Chambal joins the Yamuna near Etawah and the Betwa near Hamirpur.
# Average BLEU score: 0.18702044211074265
# Average GLEU score: 0.3033794584621003
# Average METEOR score: 0.5268777824329156

# %%
average_bleu_score = np.mean(indict2_bleu_scores)
average_gleu_score = np.mean(indict2_gleu_scores)
average_meteor_score = np.mean(indict2_meteor_scores)
print('Average BLEU Score for Dev Set using IndicTrans2 model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using IndicTrans2 model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using IndicTrans2 model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using IndicTrans2 model:  0.1897920283826145
# Average GLEU Score for Dev Set using IndicTrans2 model:  0.3062570258729637
# Average METEOR Score for Dev Set using IndicTrans2 model:  0.5301611172660362

# %%
# Opus MarianMT
from transformers import pipeline
OpusMT_translator = pipeline("translation", model="Helsinki-NLP/opus-mt-mul-en")

opusMT_bleu_scores = []
opusMT_gleu_scores = []
opusMT_meteor_scores = []

for i, hindi_text in enumerate(native_hindi_sentences_dev_set):

    translation = OpusMT_translator(hindi_text)[0]["translation_text"]
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translation.split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    opusMT_bleu_scores.append(bleu_score)
    opusMT_gleu_scores.append(gleu_score)
    opusMT_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Hindi text :', hindi_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translation)
        print('Average BLEU score :', np.mean(opusMT_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(opusMT_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(opusMT_meteor_scores), '\n')
        print()
# Out:
# Translating sentence  1
# Original Hindi text : उसकी पत्नी ने एक लड़के को जन्म दिया है.
#
# Original English Conversion : His wife delivers a baby boy.
#
# Translated to English : His wife has given birth to a boy.
# Average BLEU score : 7.711523862191631e-155
#
# Average GLEU score : 0.19230769230769232
#
# Average METEOR score : 0.5090725806451614
#
#
# Translating sentence  11
# Original Hindi text : पीएम मोदी ने दी नयी परिभाषा
#
# Original English Conversion : PM Modi kicks off new term
#
# Translated to English : Cannot initialise Evolution's mail component.
# Average BLEU score : 0.07887340478026815
#
# Average GLEU score : 0.16388593427882278
#
# Average METEOR score : 0.36255486306072393
#
#
# Translating sentence  21
# Original Hindi text : मुख्य प्रथा जुआन रोड्रिग्ज़ फ्रेल के द्वारा लिखी गई पुस्तक एल कार्नेरो की कथाओं में पाई जाती है।
#
# Original English Conversion : The original narrative can be found in the rambling chronicle El Carnero of Juan Rodriguez Freyle.
#
# Translated to English : The book El Carnero, by John Rodríguez Freel, is the main story of Juan Rodríguez.
# Average BLEU score : 0.06533511753361407
#
# Average GLEU score : 0.1391909165725802
#
# Average METEOR score : 0.30379162241500274
#
#
# Translating sentence  31
# Original Hindi text : आम तौर से दो दवाएं उपयोग की जाती हैं जिनमें से एक अक्सर प्लेटिनम आधारित (सिस्प्लाटिन या कार्बोप्लाटिन) होती है।
#
# Original English Conversion : Typically, two drugs are used, of which one is often platinum-based (either cisplatin or carboplatin).
#
# Translated to English : In general, two drugs are used which are usually based on a platinum (sysplatin or carboplatin).
# Average BLEU score : 0.04832018654082463
#
# Average GLEU score : 0.1340258760687977
#
# Average METEOR score : 0.2898410040942583
#
#
# Translating sentence  41
# Original Hindi text : नाख़्मानदीज़ बहस में भाग लेने को राज़ी होने से झिझक रहा था क्योंकि वह समझ गया कि डोमीनीकी पादरी निष्पक्ष होना नहीं चाहते थे ।
#
# Original English Conversion : The Dominicans realized that in order to humiliate the Jews effectively, he, their foremost rabbi, would have to be the one to debate.
#
# Translated to English : He was reluctant to participate in the Nazi concentration camp because he realized that the Dominican clergy did not want to be neglected.
# Average BLEU score : 0.04513493389928086
#
# Average GLEU score : 0.1336421783612489
#
# Average METEOR score : 0.3001669422818075
#
#
# Translating sentence  51
# Original Hindi text : जम्मू-कश्मीर में छह आतंकवादी ढेर
#
# Original English Conversion : Six militants killed in Jammu and Kashmir
#
# Translated to English : Six Foundations in a Whosemu-Kashmir
# Average BLEU score : 0.04434639032884382
#
# Average GLEU score : 0.13498337402595953
#
# Average METEOR score : 0.300387433353743
#
#
# Translating sentence  61
# Original Hindi text : देर रात तक लोगों को मौज-मस्ती में देखा।
#
# Original English Conversion : People were seen to enjoy the occasion till late night.
#
# Translated to English : You've seen people in the museum for a long time.
# Average BLEU score : 0.04454994444154698
#
# Average GLEU score : 0.12799285000360666
#
# Average METEOR score : 0.2862043177281623
#
#
# Translating sentence  71
# Original Hindi text : सूचना मिलते ही पुलिस ने मामला दर्ज कर जांच शुरू कर दी थी।
#
# Original English Conversion : Upon receiving the information, the police have registered a case and initiated the investigation.
#
# Translated to English : When the report was received, the police started checking the case.
# Average BLEU score : 0.04197517747009551
#
# Average GLEU score : 0.12633821498533693
#
# Average METEOR score : 0.28044824879652996
#
#
# Translating sentence  81
# Original Hindi text : 1907 से अब तक मैं कुल मिलाकर चौदह-पंद्रह युवक एकत्र कर चुका हूं।
#
# Original English Conversion : I collected altogether fourteen or fifteen young men from about the beginning of 1907 till now.
#
# Translated to English : From 1907 until now I've met all and I've gathered forty-five young people.
# Average BLEU score : 0.03679305679477508
#
# Average GLEU score : 0.12104077093174748
#
# Average METEOR score : 0.27069428952801344
#
#
# Translating sentence  91
# Original Hindi text : इस बारे में विमानन नियामक (डीजीसीए) को भी सूचित किया गया है.
#
# Original English Conversion : The airline has also filed a report with aviation regulator DGCA.
#
# Translated to English : The flight manager (DG) has also been notified about this.
# Average BLEU score : 0.04257059270919404
#
# Average GLEU score : 0.12574350183121444
#
# Average METEOR score : 0.2732973869851561
#
#
# Translating sentence  101
# Original Hindi text : यह करोड़ों लोगों को एक ऑटोमेटिड वित्‍तीय लेन-देन प्रणाली के दायरे में लाएगी।
#
# Original English Conversion : This will bring in crores of people into an automated financial transaction system.
#
# Translated to English : This will bring millions of people into the power of an automated financial lease system.
# Average BLEU score : 0.04063266463035249
#
# Average GLEU score : 0.12634775035932974
#
# Average METEOR score : 0.27585799476915
#
#
# Translating sentence  111
# Original Hindi text : इस से पहले भी अफगान दूतावास के संस्कृति विभाग ने सूचना एवं प्रसारण मंत्रालय से फिल्म के बारे में जानकारी मांगी थी.
#
# Original English Conversion : Earlier, the culture department of the Embassy of Afghan had also written to the I&B ministry seeking information about the film.
#
# Translated to English : Previously, the Cultural Department of Afghan Ambassadors had requested information about the film from the Department of Public Information and Public Administration.
# Average BLEU score : 0.03929593310448855
#
# Average GLEU score : 0.12527914123985284
#
# Average METEOR score : 0.27393999301545974
#
#
# Translating sentence  121
# Original Hindi text : परिजन और शिक्षकों ने तुरंत बच्चों को जिला अस्पताल भेजा।
#
# Original English Conversion : The local people rushed the father and the daughter to District Hospital immediately.
#
# Translated to English : The teachers and teachers immediately sent out the children to the hospital.
# Average BLEU score : 0.03972738427873012
#
# Average GLEU score : 0.12662321106934085
#
# Average METEOR score : 0.27600920344942315
#
#
# Translating sentence  131
# Original Hindi text : उन्‍होंने कहा कि इससे होम और कार लोन सहित अन्‍य लोन भी महंगे हो जाएंगे।
#
# Original English Conversion : """Hence, various loans like Housing Loan, Vehicle Loan etc., will become cheaper"", it added."
#
# Translated to English : And they said, This shall be an enchanter of the furnace, and of the car of Lon.
# Average BLEU score : 0.03811627006462973
#
# Average GLEU score : 0.12510433426469492
#
# Average METEOR score : 0.2746619666164345
#
#
# Translating sentence  141
# Original Hindi text : महमूद साहब का अंतिम संस्कार मुंबई में हुआ था.
#
# Original English Conversion : His funeral took place in Mumbai.
#
# Translated to English : Muhammad's last education was in Mumbai.
# Average BLEU score : 0.03638978402263852
#
# Average GLEU score : 0.12339186018095276
#
# Average METEOR score : 0.2717652832586911
#
#
# Translating sentence  151
# Original Hindi text : इस अवसर पर डॉ एसपी धूमकेती, डीके रोहितास, डॉ अंजली पंड्या, डॉ अंजू सिंह, रूपेष भादे, डॉ प्रदीप सोनी सहित छात्राएं एवं समस्त कॉलेज स्टॉफ उपस्थित रहा।
#
# Original English Conversion : On the occasion, Dr Shahid Ali, Pankajnauan Pandey, Dr Rajendra Mohanty, Nripendra Sharma, Dr Abhishek Dubey, Ashutosh Mandavi besides all students and staff members of the university were present.Registrar of the University Dr Sandeep Vansutre proposed the vote of thanks.
#
# Translated to English : At this time, Dr. SPA smoke, Dike Rohetas, Dr. Angeli Panda, Dr. Anju Sinh, as well as tables with Dodip gold and all college staff were present.
# Average BLEU score : 0.034858517300917914
#
# Average GLEU score : 0.12085089337401103
#
# Average METEOR score : 0.270263020422222
#
#
# Translating sentence  161
# Original Hindi text : भारत-वेस्टइंडीज़ के बीच तीसरा टी-20 मुकाबला मुंबई के वानखेड़े स्टेडियम में खेला जाएगा।
#
# Original English Conversion : Mumbai cricket team are playing their 500th Ranji Trophy match against Baroda at the Wankhede stadium.
#
# Translated to English : The third T-20 will be played in the silent studio of Mumbai between India-Westlands.
# Average BLEU score : 0.03478623471349367
#
# Average GLEU score : 0.1204768636920371
#
# Average METEOR score : 0.2691506258363268
#
#
# Translating sentence  171
# Original Hindi text : तब क्या जब हम दिन भर काम करने के बाद थके - हारे घर लौटते हैं?
#
# Original English Conversion : What about the times when we come home tired after a long days work? We might have to push ourselves to attend Christian meetings.
#
# Translated to English : What if we come home tired after a long day’s work?
# Average BLEU score : 0.03930150712338279
#
# Average GLEU score : 0.12442996490103635
#
# Average METEOR score : 0.27599990868160723
#
#
# Translating sentence  181
# Original Hindi text : सलमान खान की ‘दबंग 3’ में महेश मांजरेकर की पत्नी मेधा उनकी पत्नी की भूमिका निभा रही हैं, जो एक तरह से मांजरेकर परिवार के लिए ऑन-स्क्रीन रीयूनियन होगा.
#
# Original English Conversion : Mahesh Manjrekar's wife Medha is roped in to play his better half in Salman Khan's Dabangg 3 which becomes the on-screen reunion for the Manjrekar family.
#
# Translated to English : In Solomon Khan's "Bang 3" the wife of the master manager is playing their wife's role, which will be on-screen reunion for the family.
# Average BLEU score : 0.044684965090303466
#
# Average GLEU score : 0.12977825122826972
#
# Average METEOR score : 0.2802939635563129
#
#
# Translating sentence  191
# Original Hindi text : जल्‍द ही नामों की घोषणा होने की संभावना है।
#
# Original English Conversion : The names will be announced soon.
#
# Translated to English : It's possible that names will be announced soon.
# Average BLEU score : 0.045679372465676944
#
# Average GLEU score : 0.13254707485244493
#
# Average METEOR score : 0.2854996391694269
#
#
# Translating sentence  201
# Original Hindi text : उन्‍हें अनुसंधान, डिजाइन, विश्‍लेषण, विकास, परीक्षण और विक्रय से जुड़े पदों सहित अनेक प्रकार के रोजगारों में से चुनना होता है।
#
# Original English Conversion : They have many different types of jobs to choose from, including research, design, analysis, development, testing, and sales positions.
#
# Translated to English : They choose from many types of journals, such as research, design, analysis, development, testing and sales.
# Average BLEU score : 0.04796055769352002
#
# Average GLEU score : 0.1352599803980149
#
# Average METEOR score : 0.2884429855967358
#
#
# Translating sentence  211
# Original Hindi text : अतीत को जलाकर, आप एक नई शुरुआत के लिए तैयार हो जाते हैं।
#
# Original English Conversion : Burning the past, you gear up for a new beginning.
#
# Translated to English : In the past, you're getting ready for a new start.
# Average BLEU score : 0.04718222880787233
#
# Average GLEU score : 0.13592293477840642
#
# Average METEOR score : 0.2879201893227734
#
#
# Translating sentence  221
# Original Hindi text : परिवार की ज़िम्मेदारियों की देखरेख करते हुए हम प्रचार के काम में भी काफी व्यस्त रहे ।
#
# Original English Conversion : It was unlike those we held in Greece where we had to meet secretly in the woods because our work was banned.
#
# Translated to English : While caring for family responsibilities, we also kept busy in the preaching work.
# Average BLEU score : 0.05159710739458603
#
# Average GLEU score : 0.14112318521295877
#
# Average METEOR score : 0.29369268988000063
#
#
# Translating sentence  231
# Original Hindi text : ऐसी कोई विधि '% 1' नहीं है.
#
# Original English Conversion : No such method '%1'.
#
# Translated to English : No such method '%1'.
# Average BLEU score : 0.059314297621000885
#
# Average GLEU score : 0.14710198113206113
#
# Average METEOR score : 0.3005524933365124
#
#
# Translating sentence  241
# Original Hindi text : पाकिस्तान की तरह राहुल गांधी भी 370 और 35ए हटाने का विरोध करते हैं।
#
# Original English Conversion : Rahul Gandhi also protests against the abrogation of Article 370 and 35A, like Pakistan.
#
# Translated to English : Like Pakistan, roul grunts are also opposed to removing 370 and 35ths.
# Average BLEU score : 0.0633277697417295
#
# Average GLEU score : 0.1512079337924732
#
# Average METEOR score : 0.3046192802372413
#
#
# Translating sentence  251
# Original Hindi text : निर्माण करना या उत्पादन करना।
#
# Original English Conversion : To construct or manufacture.
#
# Translated to English : Create or create.
# Average BLEU score : 0.06080475102691957
#
# Average GLEU score : 0.14929582255116094
#
# Average METEOR score : 0.30098092597784715
#
#
# Translating sentence  261
# Original Hindi text : इसकी सभी को बधाई.
#
# Original English Conversion : Congratulations to all.
#
# Translated to English : Increases all of it.
# Average BLEU score : 0.05994097873327454
#
# Average GLEU score : 0.14762082298589277
#
# Average METEOR score : 0.29831564414643985
#
#
# Translating sentence  271
# Original Hindi text : उन्होंने उसकी अखलाख से बात करवाई।
#
# Original English Conversion : He talked to her.
#
# Translated to English : They talked to him in public.
# Average BLEU score : 0.05825437884799463
#
# Average GLEU score : 0.14902700897474136
#
# Average METEOR score : 0.29900691925765244
#
#
# Translating sentence  281
# Original Hindi text : Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji | Good News : सैफ अली खान के बाद अजय देवगन की 'तानाजी' में इस सुपरस्टार की हुई एंट्री - Firstpost Hindi
#
# Original English Conversion : Casting Coup: After Saif Ali Khan, Salman Khan To Also Join Ajay Devgn's 'Taanaji'?
#
# Translated to English : Aftre Saif Ali Khan Salman Khan Joins Ajay Devgan Tanaji ← Good News: Aftre Saif Ali Khan Salman Ajay Devgan Tanaji: The entry of this superstar in the 'Tanaji' after the safe Ali Khan World · Firstpost Hindi
# Average BLEU score : 0.056181269280450336
#
# Average GLEU score : 0.14634410131027903
#
# Average METEOR score : 0.29554748204974324
#
#
# Translating sentence  291
# Original Hindi text : स्पष्टीकरण 3ख.—शंकाओं को दूर करने के लिए यह घोषित किया जाता है कि जहां इस धारा के खंड (च) में निर्दिष्ट किसी राशि की बाबत कटौती उस पूर्ववर्ष की (जो 1 अप्रैल, 2001 को प्रारंभ होने वाले निर्धारण वर्ष या उससे पूर्व के किसी निर्धारण वर्ष से सुसंगत पूर्ववर्ष है), जिसमें निर्धारिती द्वारा ऐसी राशि अदा करने का दायित्व उपगत किया गया था, धारा 28 में उल्लिखित आय की संगणना करने में अनुज्ञात की जाती है वहां निर्धारिती उस पूर्ववर्ष की, जिसमें उसके द्वारा ऐसी राशि वास्तव में अदा की जाती है, आय की संगणना करने में ऐसी राशि की बाबत इस धारा के अधीन किसी कटौती का हकदार नहीं होगा।
#
# Original English Conversion : Explanation 3B.For the removal of doubts, it is hereby declared that where a deduction in respect of any sum referred to in clause (f) of this section is allowed in computing the income, referred to in section 28, of the previous year (being a previous year relevant to the assessment year commencing on the 1st day of April, 2001, or any earlier assessment year) in which the liability to pay such sum was incurred by the assessee, the assessee shall not be entitled to any deduction under this section in respect of such sum in computing the income of the previous year in which the sum is actually paid by him.
#
# Translated to English : Explanation 3k.—It is declared to remove doubts that where the division of this rule (ch) is allowed to calculate the sentence of a race of a previous year (which is the year beginning on April 1, 2001 or a year corresponding to a previous year), which was granted by the determination of such a race, it is allowed to compile the text referred to in column 28, which determines the year in which such a race is actually Adam, and does not have the right to include such a race.
# Average BLEU score : 0.057901777147696884
#
# Average GLEU score : 0.14812217433725747
#
# Average METEOR score : 0.2980370975832525
#
#
# Translating sentence  301
# Original Hindi text : पुलिस उसे वहां से अस्पताल ले गई जहां जांच द्वारा उसके साथ बलात्कार किए जाने की पुष्टि की गई।
#
# Original English Conversion : The police rushed the girl to a hospital where her examination confirmed rape.
#
# Translated to English : The police took him out of the hospital, and tested him.
# Average BLEU score : 0.05723435733741555
#
# Average GLEU score : 0.14640394652176986
#
# Average METEOR score : 0.2961339413410602
#
#
# Translating sentence  311
# Original Hindi text : तब जाकर हमारे पास इन सवालों के जवाब मिलेंगे
#
# Original English Conversion : I will ask these questions
#
# Translated to English : Then we will find the answers to these questions.
# Average BLEU score : 0.05639808360857727
#
# Average GLEU score : 0.1447496681669478
#
# Average METEOR score : 0.2929913817296405
#
#
# Translating sentence  321
# Original Hindi text : आपको सार्वजनिक भावना को समझना चाहिए और न ही एनआरसी को उसके वर्तमान स्वरूप में घोषित करना चाहिए, न ही सीएए को लागू किया जा चाहिए.
#
# Original English Conversion : "You should understand public sentiment&announce neither NRC in its current form,nor CAA will be implemented,"" he said."
#
# Translated to English : You should understand the public feeling and not declare NARZ in its current form, nor should you apply the CIA.
# Average BLEU score : 0.057946252070575355
#
# Average GLEU score : 0.1462005194601705
#
# Average METEOR score : 0.29501467004275594
#
#
# Translating sentence  331
# Original Hindi text : यही बात भविष्यवाणी के अगले शब्दों में भी कही गयी है ।
#
# Original English Conversion : Imagine that you are standing with the prophetic woman on Mount Zion.
#
# Translated to English : The same is true of the following words of the prophecy.
# Average BLEU score : 0.06253725290346773
#
# Average GLEU score : 0.15058695353069762
#
# Average METEOR score : 0.2977539487504784
#
#
# Translating sentence  341
# Original Hindi text : फ्लाइट में मौजूद एक यात्री ने बताया कि फ्लाइट को सिक्युरिटि कारणों के चलते अहमदाबाद डायवर्ट किया गया था, जिसके बाद प्लेन से सभी यात्रियों को उतर जाने के लिए कहा गया।
#
# Original English Conversion : "A passenger onboard said the flight was diverted to Ahmedabad citing ""security reasons""."
#
# Translated to English : A visitor at the Fleet reported that the Fleet had been dialed for security reasons, after which it was asked to leave all the passengers from the plane.
# Average BLEU score : 0.06131801582281237
#
# Average GLEU score : 0.14863134321186472
#
# Average METEOR score : 0.2957459903100539
#
#
# Translating sentence  351
# Original Hindi text : आउटलुक DBX आयात
#
# Original English Conversion : Outlook DBX import
#
# Translated to English : Outlook DBX import
# Average BLEU score : 0.06041123303210616
#
# Average GLEU score : 0.15042414081423058
#
# Average METEOR score : 0.2977546334509298
#
#
# Translating sentence  361
# Original Hindi text : मेलबर्न: ऑस्ट्रेलिया के विश्व के नंबर एक तेज गेंदबाज पैट कमिंस ने भारत के मध्य क्रम के मुख्य बल्लेबाज चेतेश्वर पुजारा को टेस्ट क्रिकेट में गेंदबाजी क .
#
# Original English Conversion : "MELBOURNE: Australia's world number one pacer Pat Cummins finds India's middle-order mainstay Cheteshwar Pujara the toughest batsman to bowl at in Test cricket and called him a ""pain in the back"" for his team."
#
# Translated to English : Melburn: A fast-paced football court commission from the world of Australia called Gandbaji’s main interdepartmental Ballebage Warning Watch Tower in the Test Cricket.
# Average BLEU score : 0.06350970895765679
#
# Average GLEU score : 0.15308991664345048
#
# Average METEOR score : 0.3014885424756263
#
#
# Translating sentence  371
# Original Hindi text : आईसीसी की वनडे रैंकिंग जारी, विराट कोहली और बुमराह टॉप पर कायम
#
# Original English Conversion : ICC ODI rankings: Virat Kohli, Jasprit Bumrah remain on top
#
# Translated to English : ICC's wave rankings continue, reverse shock and boomerang top
# Average BLEU score : 0.06246654739550168
#
# Average GLEU score : 0.15327416359295962
#
# Average METEOR score : 0.30196769667807055
#
#
# Translating sentence  381
# Original Hindi text : PNB घोटालेबाज मेहुल चोकसी बोला – भारत आया तो हो जाएगी मेरी भी मॉब लिंचिंग
#
# Original English Conversion : PNB scam: Fugitive businessman Mehul Choksi says he fears mob lynching if hes brought back to India
#
# Translated to English : PNB Brochure - I'll be there when India comes, and I'll be my mobile linking.
# Average BLEU score : 0.06356007462677069
#
# Average GLEU score : 0.15436152637946912
#
# Average METEOR score : 0.30324027566784445
#
#
# Translating sentence  391
# Original Hindi text : बाढ़ग्रस्त पंजाब में नुकसान का आकलन करने के लिए एक केंद्रीय टीम जल्द ही राज्य का दौरा करेगी।
#
# Original English Conversion : A central team will soon visit Punjab to assess the damage and loss due to floods in the state.
#
# Translated to English : A central team will soon take over the state to address the damage in the Red Cross.
# Average BLEU score : 0.06415124320748669
#
# Average GLEU score : 0.15466969663004035
#
# Average METEOR score : 0.3046675061101146
#
#
# Translating sentence  401
# Original Hindi text : स्थिति अब नियंत्रण में बतायी गयी है
#
# Original English Conversion : The situation was now under control
#
# Translated to English : Status is now in control
# Average BLEU score : 0.06606008435669758
#
# Average GLEU score : 0.15583690407296702
#
# Average METEOR score : 0.30560614448418855
#
#
# Translating sentence  411
# Original Hindi text : क्योंकि यहोवा देश के बीच होकर मिस्त्रियों को मारता जाएगा. इसलिये जहां जहां वह चौखट के सिरे, और दोनों अलंगों पर उस लोहू को देखेगा, वहां वहां वह उस द्वार को छोड़ जाएगा, और नाश करनेवाले को तुम्हारे घरों में मारने के लिये न जाने देगा।
#
# Original English Conversion : For Yahweh will pass through to strike the Egyptians. and when he sees the blood on the lintel, and on the two doorposts, Yahweh will pass over the door, and will not allow the destroyer to come in to your houses to strike you.
#
# Translated to English : For Yahweh will strike the Egyptians in the midst of the land; and where he sees the blood on the head of the vineyard, and on the two doorposts, there will he leave the gate; and he will not allow the destroyer to go into your houses to strike you.
# Average BLEU score : 0.06607821121254802
#
# Average GLEU score : 0.15550707208471765
#
# Average METEOR score : 0.30569844761873133
#
#
# Translating sentence  421
# Original Hindi text : यदि आप अतिरिक्‍त जानकारी प्राप्त करना चाहते हैं या आप चाहते हैं कि कोई आपके घर आकर आपके साथ मुफ़्त बाइबल अध्ययन संचालित करे, तो कृपया Watch Tower, H - 58 Old Khandala Road, Lonavla 410 401, Mah., India को, या पृष्ठ २ पर दिए उपयुक्‍त पते पर लिखिए ।
#
# Original English Conversion : If you would welcome further information or would like to have someone call at your home to conduct a free Bible study with you, please write to Watchtower, 25 Columbia Heights, Brooklyn, NY 11201 - 2483, or to the appropriate address listed on page 2.
#
# Translated to English : If you would welcome further information or would like to have someone call at your home to conduct a free Bible study with you, please write to Watchtower, 25 Columbia Heights, Brooklyn, NY 11201 - 2483, or to the appropriate address listed on page 2.
# Average BLEU score : 0.06688395441415021
#
# Average GLEU score : 0.15687340406592007
#
# Average METEOR score : 0.30743641563516805
#
#
# Translating sentence  431
# Original Hindi text : ’’ उन्होंने कहा, ‘‘अधिकतर अच्छे हिंदू जिन्हें मैं जानता हूं वह उस जगह पर राम मंदिर चाहते हैं जहां उनका मानना है कि उनका जन्म हुआ।
#
# Original English Conversion : """Most good Hindus I know would want a Ram temple at the place where they believe he was born."
#
# Translated to English : They said, ‘The best Hindus I know are seeking the temple of Ram, where they believe that they have been born.
# Average BLEU score : 0.06631550202131116
#
# Average GLEU score : 0.1581997367345773
#
# Average METEOR score : 0.3100786046841453
#
#
# Translating sentence  441
# Original Hindi text : इसे चालान व ऑनलाइन के माध्यम से दिया जा सकता है।
#
# Original English Conversion : This can be paid online or through a challan.
#
# Translated to English : It can be delivered via movement and online.
# Average BLEU score : 0.0655581666613567
#
# Average GLEU score : 0.1581911260419724
#
# Average METEOR score : 0.3106443361094749
#
#
# Translating sentence  451
# Original Hindi text : उन्होंने कहा, ‘‘यहां (गोरखपुर) की तरह, राज्य के अन्य भागों में भी मुस्लिम सुरक्षित महसूस करते हैं।
#
# Original English Conversion : """Like here (Gorakhpur), Muslims feel safe in other parts of the state,"" he said."
#
# Translated to English : They said, ‘ Like this man, in other parts of the kingdom, Muslims feel safe and secure.
# Average BLEU score : 0.06778416266232241
#
# Average GLEU score : 0.16071643590175966
#
# Average METEOR score : 0.3136360750161981
#
#
# Translating sentence  461
# Original Hindi text : कर्ज के बोझ से दबे अपने राज्य के लिए विशेष वित्तीय पैकेज की मांग के साथ बनर्जी ने पहले संसद भवन में मोदी से मुलाकात की और बाद में अपनी पार्टी के सांसदों के एक प्रतिनिधिमंडल के साथ फिर से प्रधानमंत्री से मिलीं।
#
# Original English Conversion : Seeking a special financial package for her debt-ridden state, Banerjee initially met Modi in Parliament House before calling on him again with a delegation of MPs from her party.
#
# Translated to English : With a request for a special financial package for his kingdom from the burden of the church, Kirghiz met with a lady in the first social building and later met with a representative of his party's documents again from the Prime Minister.
# Average BLEU score : 0.06721699087666826
#
# Average GLEU score : 0.1600889273803552
#
# Average METEOR score : 0.31311565185857215
#
#
# Translating sentence  471
# Original Hindi text : मोदी कैबिनेट में रहते हुए उन्होंने केंद्रीय ग्रामीण विकास राज्य मंत्री पेयजल, स्वच्छता और पंचायती राज मंत्री का पद भी संभाला.
#
# Original English Conversion : He served as the Minister of Rural Development, Minister of Parliamentary Affairs, Panchayati Raj and Mines in the Modi government.
#
# Translated to English : While living in Modi Cabinnet, they also managed the membership of the Central Rural Development Kingdom Department, the Pejgel, the cleanup, and the presidential board.
# Average BLEU score : 0.06615921606772927
#
# Average GLEU score : 0.15929413133761147
#
# Average METEOR score : 0.312676395576443
#
#
# Translating sentence  481
# Original Hindi text : भूमि अधिग्रहण क़ानून में संशोधन
#
# Original English Conversion : Amendments to Land Acquisition Act
#
# Translated to English : An Inquiry to Earth’s Limitation Law
# Average BLEU score : 0.06683950137488805
#
# Average GLEU score : 0.1593603025731218
#
# Average METEOR score : 0.3130076181526757
#
#
# Translating sentence  491
# Original Hindi text : चम्बल इटावा के पास तथा बेतवा हमीरपुर के पास यमुना में मिलती हैं।
#
# Original English Conversion : chambal comes from itva, and betab in hamirpur and then they meet with yamuna
#
# Translated to English : And at Chimbal-tava, and at Beth-aram, which is in Immon.
# Average BLEU score : 0.0659092347915065
#
# Average GLEU score : 0.15915974808001043
#
# Average METEOR score : 0.31401400327053164

# %%
average_bleu_score = np.mean(opusMT_bleu_scores)
average_gleu_score = np.mean(opusMT_gleu_scores)
average_meteor_score = np.mean(opusMT_meteor_scores)
print('Average BLEU Score for Dev Set using OpusMT mul-en model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using OpusMT mul-en model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using OpusMT mul-en model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using OpusMT mul-en model:  0.06472286856525937
# Average GLEU Score for Dev Set using OpusMT mul-en model:  0.16009251164121446
# Average METEOR Score for Dev Set using OpusMT mul-en model:  0.3138617101674688
