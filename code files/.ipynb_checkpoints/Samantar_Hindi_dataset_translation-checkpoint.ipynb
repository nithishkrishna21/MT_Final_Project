# %%
import numpy as np
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.gleu_score import sentence_gleu
from nltk.translate.meteor_score import meteor_score
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# %%
import re
from sklearn.model_selection import train_test_split

# %%
english_scripts_file_path = "../datasets/Samantar dataset/final_data/en-hi/train.en"
native_scripts_file_path = "../datasets/Samantar dataset/final_data/en-hi/train.hi"

# %%
native_lines = []
with open(native_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        native_lines.append(line)

english_lines = []
with open(english_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        english_lines.append(line)

# %%
native_lines[1]
# Out:
# 'यूरोपीय संघ के महत्वपूर्ण संस्थानों में यूरोपियन कमीशन, यूरोपीय संसद, यूरोपीय संघ परिषद, यूरोपीय न्यायलय एवं यूरोपियन सेंट्रल बैंक इत्यादि शामिल हैं।\n'

# %%
english_lines[1]
# Out:
# 'The European Union has seven principal decision-making bodies, its institutions: the European Parliament, the European Council, the Council of the European Union, the European Commission, the Court of Justice of the European Union, the European Central Bank and the European Court of Auditors.\n'

# %%
len(native_lines)
# Out:
# 8568307

# %%
len(english_lines)
# Out:
# 8568307

# %%
df = pd.DataFrame({'Hindi': native_lines, 'English': english_lines})
print(df.head())
# Out:
#                                                Hindi  \
# 0        जिसके जवाब में पाक ने अच्छी शुरुआत की थी.\n
# 1  यूरोपीय संघ के महत्वपूर्ण संस्थानों में यूरोपि...
# 2  कांग्रेस नेता तमिलनाडु से शिवगंगा लोकसभा क्षेत...
# 3  संबंधन प्रयास के बारे में उपयोक्ता को प्रांप्ट...
# 4  वित्त मंत्री ने घोषणा कि जमा बीमा और ऋण गारंटी...
#
#                                              English
# 0     In reply, Pakistan got off to a solid start.\n
# 1  The European Union has seven principal decisio...
# 2  The Congress leader represents Sivaganga Lok S...
# 3        Prompt the user about connection attempts\n
# 4  Further, the Minister announced that Deposit I...

# %%
len(df)
# Out:
# 8568307

# %%
dev_set = df.sample(n = 500, replace = False, random_state = np.random.randint(low=1, high=1234))
remaining_data = df.drop(dev_set.index)

test_set = remaining_data.sample(n = 1000, random_state = np.random.randint(low=1, high=1234))
print(f"Test set size: {len(test_set)}")
print(f"Dev set size: {len(dev_set)}")
# Out:
# Test set size: 1000
# Dev set size: 500

# %%
native_hindi_sentences_dev_set = dev_set['Hindi'].values
print(type(native_hindi_sentences_dev_set))
print(native_hindi_sentences_dev_set.shape)
english_sentences_dev_set = dev_set['English'].values
# Out:
# <class 'numpy.ndarray'>
# (500,)

# %%
print(len(english_sentences_dev_set))
# Out:
# 500

# %%
# Native hindi to english translations using the Facebook model
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

facebook_bleu_scores = []
facebook_gleu_scores = []
facebook_meteor_scores = []

# translate Hindi to English
tokenizer.src_lang = "hi"
for i, hindi_text in enumerate(native_hindi_sentences_dev_set):
    # print(i)
    encoded_hi = tokenizer(hindi_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.get_lang_id("en"))
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    # print(translated_text)
    # print(translated_text[0].split())
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translated_text[0].split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    facebook_bleu_scores.append(bleu_score)
    facebook_gleu_scores.append(gleu_score)
    facebook_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Hindi text :', hindi_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translated_text[0])
        print('Average BLEU score :', np.mean(facebook_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(facebook_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(facebook_meteor_scores), '\n')
        print()
# Out:
# Translating sentence  1
# Original Hindi text : ऑस्ट्रिया से एक कम्प्यूटर प्रचालक, रोलान्ट और उसकी पत्नी यूटा, देश के गर्म, खुश्‍क दक्षिणी भाग में बस गए हैं ।
#
# Original English Conversion : Roland, a computer operator from Austria, and his wife, Yuta, have settled in the warm, dry, southern part of the country.
#
# Translated to English : A computer operator from Austria, Roland and his wife, Utah, have settled in the hot, southern part of the country.
# Average BLEU score : 0.45605983089973623
#
# Average GLEU score : 0.5128205128205128
#
# Average METEOR score : 0.8080992036555685
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence  11
# Original Hindi text : हालाँकि, उसने कहा कि उसे उत्तर प्रदेश पुलिस पर भरोसा नहीं है और उसने जोर देकर कहा कि वह केवल मध्य प्रदेश पुलिस के सामने आत्मसमर्पण करेगी।
#
# Original English Conversion : However, she said that she did not trust the Uttar Pradesh Police and insisted that she would only surrender to the Madhya Pradesh Police.
#
# Translated to English : However, he said he has no confidence in the Northern Pradesh police and he emphasized that he will only surrender to the Central Pradesh police.
# Average BLEU score : 0.11104515649191442
#
# Average GLEU score : 0.19245703464736758
#
# Average METEOR score : 0.38417606895226014
#
#
# Translating sentence  21
# Original Hindi text : राष्ट्रपति के दौरे को देखते हुए भारी सुक्षा व्यवस्था के इंतजाम किए गए हैं।
#
# Original English Conversion : Elaborate security arrangements were made in view of the Presidents visit.
#
# Translated to English : Due to the President's visit, a heavy supervision system has been anticipated.
# Average BLEU score : 0.0847791121030151
#
# Average GLEU score : 0.18315286980587087
#
# Average METEOR score : 0.3582013129769039
#
#
# Translating sentence  31
# Original Hindi text : महाराष्ट्र के 203 गांवों ने कोरोना मुक्त होने का दावा किया
#
# Original English Conversion : Maharashtra: 203 villages under Thane Zilla Parishad now 'corona free'
#
# Translated to English : 203 villages in Maharashtra claim to be free of corona
# Average BLEU score : 0.08726389289894848
#
# Average GLEU score : 0.19228236674604243
#
# Average METEOR score : 0.35577420822025446
#
#
# Translating sentence  41
# Original Hindi text : हिंदुस्तान मेरे अब्बा का मुल्क है.
#
# Original English Conversion : India is my motherland.
#
# Translated to English : Hinduism is my father’s land.
# Average BLEU score : 0.0965920579453735
#
# Average GLEU score : 0.20198115845762124
#
# Average METEOR score : 0.37857594042992115
#
#
# Translating sentence  51
# Original Hindi text : किस तरह की कमियां थी।
#
# Original English Conversion : What were the shortcomings in it?
#
# Translated to English : What kind of disadvantages.
# Average BLEU score : 0.0873398498959526
#
# Average GLEU score : 0.1946485737722572
#
# Average METEOR score : 0.3757497914125938
#
#
# Translating sentence  61
# Original Hindi text : इस फिल्म में उनके साख सारा अली खान नजर आने वाली हैं।
#
# Original English Conversion : In the movie, he will be seen alongside Sara Ali Khan.
#
# Translated to English : In this movie, Sarah Ali Khan will be seen.
# Average BLEU score : 0.10266404565599671
#
# Average GLEU score : 0.21133799818651627
#
# Average METEOR score : 0.3971570999344176
#
#
# Translating sentence  71
# Original Hindi text : ‘यह लोकतंत्र की जीत है कि हमने राजनीतिक वार्ता के जरिए अपने मुद्दों को सुलझा लिया।
#
# Original English Conversion : """This is the power of democracy that we resolve our issues through political dialogue."""
#
# Translated to English : “It is the victory of democracy that we resolved our issues through political talks.
# Average BLEU score : 0.1123511025927995
#
# Average GLEU score : 0.21578623499246394
#
# Average METEOR score : 0.40430766312970734
#
#
# Translating sentence  81
# Original Hindi text : हादसा कैसे हुआ, इसका पता नहीं चल पाया है।
#
# Original English Conversion : It is not clear how the accident took place.
#
# Translated to English : How it happened, I don’t know.
# Average BLEU score : 0.10400861722947043
#
# Average GLEU score : 0.20873819096899723
#
# Average METEOR score : 0.401320546201709
#
#
# Translating sentence  91
# Original Hindi text : उसकी एक बड़ी बहन ज्योति और एक छोटी बहन दीप्ति (मृतक) है।
#
# Original English Conversion : She has an elder sister Jyothi and a younger sister Deepthi (deceased).
#
# Translated to English : He has a younger sister and a younger sister.
# Average BLEU score : 0.09724790019261247
#
# Average GLEU score : 0.19693951709036064
#
# Average METEOR score : 0.39256083135620656
#
#
# Translating sentence  101
# Original Hindi text : आज भी कई लोगों को सृष्टिकर्ता का यह स्वरूप मान्य है कि भगवन्मुख भाव 573 उसने अपनी सृष्टि के दो ध्रुवों, स्वर्ग और नरक-नित्य नरक,-का निर्माण किया है और यहां तक कि कुछ धर्मों के अनुसार तो उसने पहले से ही कुछ ऐसी आत्माएं निश्चित कर रखी हैं जिन्हें उसने पाप एवं दंड के लिये नहीं, अपितु नित्य नरकयातना के लिये उत्पन्न किया है।
#
# Original English Conversion : Even now it is possible for some to believe in a Creator who has made heaven and hell, an eternal hell, the two poles of his creation, and has even according to some religions predestined the souls he has created not only to sin and punishment, but to an eternal damnation.
#
# Translated to English : Even today many believe this form of the Creator that He has created two poles of His creation, heaven and hell, and even according to some religions He has already established some souls which He has created not for sin and punishment, but for hell.
# Average BLEU score : 0.0934823733656231
#
# Average GLEU score : 0.19187811381052547
#
# Average METEOR score : 0.3907652795527541
#
#
# Translating sentence  111
# Original Hindi text : तब क्या करना चाहिए?
#
# Original English Conversion : We must do all we possibly can to set matters straight.
#
# Translated to English : So what should we do?
# Average BLEU score : 0.09042286619402672
#
# Average GLEU score : 0.1887528080167499
#
# Average METEOR score : 0.3894643698552506
#
#
# Translating sentence  121
# Original Hindi text : प्रकाश में चलनेवाले जब यहोवा के शक्‍तिशाली कामों पर विचार करते हैं तो उन पर क्या असर होता है?
#
# Original English Conversion : How do those who walk in the light respond to Jehovahs powerful works in their behalf?
#
# Translated to English : What is the effect of those who walk in the light when they consider the mighty works of the Lord?
# Average BLEU score : 0.08497595455369501
#
# Average GLEU score : 0.1830915195674838
#
# Average METEOR score : 0.378332444548668
#
#
# Translating sentence  131
# Original Hindi text : यहीं कोलकाता में 1944 में नई water policy को लेकर हुई conerence में बाबा साहेब ने कहा था कि भारत की water ways policy व्यापक होनी चाहिए।
#
# Original English Conversion : It was here at a conference in Kolkata in 1944 on the new water policy that Babasaheb had said that India's water ways policy should be comprehensive.
#
# Translated to English : In a conerence that took the new water policy in 1944 in Kolkata, Baba Saheeb said that India’s water ways policy should be widespread.
# Average BLEU score : 0.08826969957566883
#
# Average GLEU score : 0.18693398335357125
#
# Average METEOR score : 0.383961948699464
#
#
# Translating sentence  141
# Original Hindi text : संगीत के भी वो बहुत शौकीन थे.
#
# Original English Conversion : He was somewhat interested in music as well.
#
# Translated to English : The music was also very attractive.
# Average BLEU score : 0.08562633622565911
#
# Average GLEU score : 0.18511516834553815
#
# Average METEOR score : 0.3799711349845928
#
#
# Translating sentence  151
# Original Hindi text : पुलिस ने पीडि़त व्यक्ति की शिकायत पर तीनों आरोपियों के खिलाफ धोखाधड़ी के आरोप में मामला दर्ज कर कार्रवाई शुरू कर दी।
#
# Original English Conversion : Police have registered a case of molestation against the three accused and started search for the accused.
#
# Translated to English : Police launched an action against the three accusations of fraud against the victim.
# Average BLEU score : 0.09302453622042615
#
# Average GLEU score : 0.19108051664974823
#
# Average METEOR score : 0.3847022950022867
#
#
# Translating sentence  161
# Original Hindi text : हम सामाजि‍क और शैक्षणि‍क क्षेत्रों में क्षमतावर्धन परि‍योजनाओं के लि‍ए 10 मि‍लि‍यन अमरीकी डॉलर का एक नया अनुदान देंगे ।
#
# Original English Conversion : We will provide a fresh grant of 10 million US dollars for capacity building projects in the social and educational sectors.
#
# Translated to English : We will give a new grants of $10 million to the capacity enhancement plans in the common and educational areas.
# Average BLEU score : 0.08951023396279208
#
# Average GLEU score : 0.18931235612167832
#
# Average METEOR score : 0.3831819983144584
#
#
# Translating sentence  171
# Original Hindi text : उन्होंने मई 2012 में प्रधानमंत्री तथा म्यांमार के राष्ट्रपति द्वारा दिए गए संयुक्त आश्वासन को दोहराया कि दोनों में किसी भी देश की भूमि का न तो प्रशिक्षण, प्रश्रय के लिए और न ही आतंकवादी और अतिवादी संगठनों और उनके कार्यकर्ताओं द्वारा दूसरे देश के लिए हानिकारक गतिविधियों के लिए इस्तेमाल नहीं करने दिया जाएगा।
#
# Original English Conversion : He reiterated the assurance made jointly by the Prime Minister and Myanmar President in May 2012 that territories of either country would not be allowed to be used for activities inimical to the other, including for training, sanctuary and other operations by terrorist and insurgent organisations and their operatives.
#
# Translated to English : He repeated the joint assurance given by the Prime Minister and the President of Myanmar in May 2012 that any country’s land will not be allowed to be used for training, refuge, and for harmful activities by terrorist and extremist organizations and their activists to another country.
# Average BLEU score : 0.09643600129700824
#
# Average GLEU score : 0.19464741202612815
#
# Average METEOR score : 0.3862421767520046
#
#
# Translating sentence  181
# Original Hindi text : इसमें प्रदर्शन कर रहे छात्रों का कोई हाथ नहीं है।
#
# Original English Conversion : There is no involvement of students in it.
#
# Translated to English : There are no hands for the students performing.
# Average BLEU score : 0.09926202968906148
#
# Average GLEU score : 0.19783104828582235
#
# Average METEOR score : 0.38858321797875683
#
#
# Translating sentence  191
# Original Hindi text : इस प्रक्रिया को अंडरवोल्टिंग (undervolting) कहा जाता है।
#
# Original English Conversion : This process is called undervolting.
#
# Translated to English : This process is called Undervolting.
# Average BLEU score : 0.10111320574533604
#
# Average GLEU score : 0.19745929078224217
#
# Average METEOR score : 0.3874053679953881
#
#
# Translating sentence  201
# Original Hindi text : यही कारण है कि भारत को समुद्र के रास्ते आतंकवाद, डकैती और मादक पदार्थों की तस्करी जैसी चुनौतियों की भली-भांति जानकारी है, न केवल भारत को बल्कि क्षेत्र के अन्य देशों को भी इन चुनौतियों का सामना करना पड़ रहा है।
#
# Original English Conversion : That is why, he added, India is well aware of the challenges such as sea-borne terrorism, piracy, and drug trafficking, that not just India, but other nations in the region also have to face.
#
# Translated to English : This is why India has good knowledge of the challenges such as terrorism, theft and drug trafficking, not only India but other countries in the region are facing these challenges as well.
# Average BLEU score : 0.09911023804725119
#
# Average GLEU score : 0.1953892410120419
#
# Average METEOR score : 0.3868026493352346
#
#
# Translating sentence  211
# Original Hindi text : मगर हमसे यह कहा गया है कि “शालीनता और आत्म - नियन्त्रण के साथ रहें । ”
#
# Original English Conversion : But in another country or culture, some may take offense at them.
#
# Translated to English : But it is said to us that “be with goodness and self-control.”
# Average BLEU score : 0.10074001483024539
#
# Average GLEU score : 0.19527025995563602
#
# Average METEOR score : 0.38604937752674673
#
#
# Translating sentence  221
# Original Hindi text : केरल : राज्य ने कोविड-19 महामारी के मद्देनजर सरकारी कर्मचारियों के वेतन में कटौती के लिए एक अध्यादेश को स्वीकृति दी है
#
# Original English Conversion : Kerala: State approves ordinance that enables salary cut of government employees in the wake of Covid19 pandemic. earlier the Kerala HC had stayed the Govt's order on this
#
# Translated to English : Kerala: State has approved a decree for the reduction in wages of government employees from the Covid-19 epidemic
# Average BLEU score : 0.09924446453563626
#
# Average GLEU score : 0.19402008849479238
#
# Average METEOR score : 0.38540248239632263
#
#
# Translating sentence  231
# Original Hindi text : पारंपरिक रूप से यह एक पदवी है जो वेदान्त सम्प्रदाय के आचार्यों को दी जाती थी।
#
# Original English Conversion : Traditionally, reconnaissance was a role that was adopted by the cavalry.
#
# Translated to English : Traditionally, this is a posture that was given to the awareness of the Vedant Religion.
# Average BLEU score : 0.09628378814946187
#
# Average GLEU score : 0.19181769552070269
#
# Average METEOR score : 0.38534181973413884
#
#
# Translating sentence  241
# Original Hindi text : फूलों व फलों से युक्त कर देती है।
#
# Original English Conversion : Garnish with flowers and greens.
#
# Translated to English : It gives flowers and fruits.
# Average BLEU score : 0.09621503585379902
#
# Average GLEU score : 0.1916114930455162
#
# Average METEOR score : 0.38519920339101854
#
#
# Translating sentence  251
# Original Hindi text : इनमें रिटर्न न तय होता और न ही निश्चित।
#
# Original English Conversion : Returns, therefore, are neither fixed nor assured.
#
# Translated to English : It was not certain and not certain.
# Average BLEU score : 0.09502656870125728
#
# Average GLEU score : 0.18958478484335708
#
# Average METEOR score : 0.38046736654462515
#
#
# Translating sentence  261
# Original Hindi text : हमारे पेट में एक थैली होती है, जिसे बाद में खाली किया जा सकता है।
#
# Original English Conversion : We have a spare bag in our stomach which can easily be emptied later.
#
# Translated to English : There is a bag in our stomach, which can be empty later.
# Average BLEU score : 0.09330402881401371
#
# Average GLEU score : 0.18913307398365692
#
# Average METEOR score : 0.38116323481495346
#
#
# Translating sentence  271
# Original Hindi text : लेकिन ऐसा कभी-कभी होता है.
#
# Original English Conversion : But that happens sometimes.
#
# Translated to English : But that happens sometimes.
# Average BLEU score : 0.09947932202188302
#
# Average GLEU score : 0.19482706077079445
#
# Average METEOR score : 0.3865889428479815
#
#
# Translating sentence  281
# Original Hindi text : और उसी में से (और) उसी में से फिर दोबारा तुम ज़िन्दा करके निकाले जाओगे ऐ आदम की औलाद हमने तुम्हारे लिए पोशाक नाज़िल की जो तुम्हारे शर्मगाहों को छिपाती है और ज़ीनत के लिए कपड़े और इसके अलावा परहेज़गारी का लिबास है और ये सब (लिबासों) से बेहतर है ये (लिबास) भी ख़ुदा (की कुदरत) की निशानियों से है
#
# Original English Conversion : O children of Adam! We have provided you with clothing to cover your bodies, and for luxury. But the clothing of pietythat is best. These are some of Gods revelations, so that they may take heed.
#
# Translated to English : And from it you will be brought to life again, O children of Adam, We have brought to you clothes that hide your shame, and clothes for the worship, and a shelter of guardianship, and all this is better than the signs of God.
# Average BLEU score : 0.09832168400317039
#
# Average GLEU score : 0.19431087982736223
#
# Average METEOR score : 0.3849270974970816
#
#
# Translating sentence  291
# Original Hindi text : बहनों के रूप में यह हमारे जीवन के मजेदार क्षण हैं।
#
# Original English Conversion : As sisters, these are the fun girly moments in our life.
#
# Translated to English : As sisters, this is a fun moment in our lives.
# Average BLEU score : 0.09525614788050477
#
# Average GLEU score : 0.1931219218796315
#
# Average METEOR score : 0.3848679393272043
#
#
# Translating sentence  301
# Original Hindi text : उनमें से दो की हालत चिंताजनक बताई जाती है।
#
# Original English Conversion : The condition of two of them is reportedly serious.
#
# Translated to English : The two of them are concerned.
# Average BLEU score : 0.0943190303098739
#
# Average GLEU score : 0.1921298601233857
#
# Average METEOR score : 0.3842723672182226
#
#
# Translating sentence  311
# Original Hindi text : इसकी सफाई ज़रूरी है।
#
# Original English Conversion : Cleaning it is necessary.
#
# Translated to English : Its cleaning is necessary.
# Average BLEU score : 0.09262517789358395
#
# Average GLEU score : 0.19056191953422497
#
# Average METEOR score : 0.3832175292550082
#
#
# Translating sentence  321
# Original Hindi text : और वह वही हेै जो मुझे मार डालेगा और उसके बाद (फिर) मुझे ज़िन्दा करेगा
#
# Original English Conversion : Who will cause me to die and then will again restore me to life.
#
# Translated to English : And he is the one who will kill me, and will give me life after that.
# Average BLEU score : 0.09209030800324232
#
# Average GLEU score : 0.18939762832818843
#
# Average METEOR score : 0.38002341668466133
#
#
# Translating sentence  331
# Original Hindi text : "उन्होंने कहा, ""मैं फिलहाल कोई बयान नहीं दे सकता"
#
# Original English Conversion : """I have nothing really to say"
#
# Translated to English : He said, “I can’t give any statement.”
# Average BLEU score : 0.09025081382622728
#
# Average GLEU score : 0.18721205287038087
#
# Average METEOR score : 0.37723651043114986
#
#
# Translating sentence  341
# Original Hindi text : वह हमारे ज्ञान से कहीं ज़्यादा उच्च है, और उसके वर्षों की गिनती अंतहीन है ।
#
# Original English Conversion : He is more exalted than we can know, and his years are unsearchably endless.
#
# Translated to English : He is far higher than our knowledge, and his years are infinite.
# Average BLEU score : 0.08852876486899389
#
# Average GLEU score : 0.1849680830813185
#
# Average METEOR score : 0.37308675932295005
#
#
# Translating sentence  351
# Original Hindi text : "ईसीबी ने एक बयान में कहा, ""स्कैन से यह पता चला है कि उनके दाएं टखने में चोट लगी है।"
#
# Original English Conversion : """Scan results showed that he has sustained ligament damage to his right ankle,"" said the ECB statement."
#
# Translated to English : "The ECB said in a statement, "The scan revealed that his right hand was injured."
# Average BLEU score : 0.09041384356082371
#
# Average GLEU score : 0.18722434929877751
#
# Average METEOR score : 0.3749698111921326
#
#
# Translating sentence  361
# Original Hindi text : पर इसमें अभी काफी समय लगेगा।
#
# Original English Conversion : But this will take considerable time.
#
# Translated to English : But it will take a lot of time now.
# Average BLEU score : 0.08992759818074268
#
# Average GLEU score : 0.18573311657129654
#
# Average METEOR score : 0.3739866729295637
#
#
# Translating sentence  371
# Original Hindi text : अंबानी ने कहा है कि उनकी कंपनी की भूमिका केवल ऑफसेट/निर्यात दायित्व तक सीमित है।
#
# Original English Conversion : Ambani said his groups role is limited to offset/ export obligations.
#
# Translated to English : Ambani said that his role is limited only to offset/export liability.
# Average BLEU score : 0.0881982122680905
#
# Average GLEU score : 0.18482463233276591
#
# Average METEOR score : 0.3725457141605931
#
#
# Translating sentence  381
# Original Hindi text : गोपित फ़ाइल विगोपित करें
#
# Original English Conversion : Decrypt encrypted file
#
# Translated to English : Repeat the file.
# Average BLEU score : 0.08684012757065322
#
# Average GLEU score : 0.18289330393491524
#
# Average METEOR score : 0.36921517398792914
#
#
# Translating sentence  391
# Original Hindi text : क्यों नहीं होता हमें विश्वास उसकी बात पर?
#
# Original English Conversion : Why do we believe that?
#
# Translated to English : Why shouldn’t we believe in him?
# Average BLEU score : 0.08606285248658224
#
# Average GLEU score : 0.18396750465709782
#
# Average METEOR score : 0.37199316358301787
#
#
# Translating sentence  401
# Original Hindi text : जीएटीआई अधिकारियों ने सूचना दी कि नागरिक उड्डयन महानिदेशक (डीजीसीए) बीरसाला हवाई पट्टी पर हवाई दुर्घटना में पूछताछ करेंगे।
#
# Original English Conversion : Director General of Civil Aviation (DGCA) will inquire into the air crash at Birasala airstrip, informed GATI authorities.
#
# Translated to English : GATI officials that the General Director of Civil Aviation (DGCA) will investigate the air crash on the Bearsala airline.
# Average BLEU score : 0.0866552373444953
#
# Average GLEU score : 0.1841125471433332
#
# Average METEOR score : 0.3729077737045178
#
#
# Translating sentence  411
# Original Hindi text : "अजीज ने इस्लामाबाद में विदेश मंत्रालय में मीडिया से कहा, ""प्रधानमंत्री नवाज शरीफ ने इस मामले में विभिन्न देशों के 17 प्रधानमंत्रियों को निजी तौर पर पत्र भी लिखे थे, जो कि रिकॉर्ड में है।"
#
# Original English Conversion : Prime Minister Nawaz Sharif personally wrote letters to 17 prime ministers of different countries on the matter, which is on record, Aziz told senior journalists at the Ministry of Foreign Affairs in Islamabad and added that Pakistan will continue their diplomatic offensive in this regard.
#
# Translated to English : "Aziz told the media at the Ministry of Foreign Affairs in Islamabad, "Premier Nawaz Sharif had also written a private letter to 17 prime ministers from different countries in this case, which is in record."
# Average BLEU score : 0.08636877928228809
#
# Average GLEU score : 0.18364910600207277
#
# Average METEOR score : 0.3715879973412734
#
#
# Translating sentence  421
# Original Hindi text : तब मैं ने उस से पूछा, कि तू किस की बेटी है ? और उस ने कहा, मैं तो नाहोर के जन्माए मिल्का के पुत्रा बतूएल की बेटी हूं : तब मैं ने उसकी नाक में वह नत्थ, और उसके हाथों में वे कंगन पहिना दिए।
#
# Original English Conversion : I asked her, and said, 'Whose daughter are you?' She said, 'The daughter of Bethuel, Nahor's son, whom Milcah bore to him.' I put the ring on her nose, and the bracelets on her hands.
#
# Translated to English : Then I asked him, “Who’s the daughter of you?” and he said, “I am the daughter of Batuel, the son of Milka, who was born in Nahor; then I gave him the nuts in his nose, and in his hands the armbands.”
# Average BLEU score : 0.0848391839044427
#
# Average GLEU score : 0.18231454408537867
#
# Average METEOR score : 0.372035338179845
#
#
# Translating sentence  431
# Original Hindi text : वाशिंगटन। अमेरिका के राष्ट्रपति डोनाल्ड ट्रंप लोकप्रिय चैनल सीएनएन की वैश्विक प्रसारण शाखा सीएनएन इंटरनेशनल पर जमकर भड़के और आरोप लगाया कि यह समाचार चैनल उनके प्रशासन की सही तस्वीर पेश नहीं करता है।
#
# Original English Conversion : US President Donald Trump has hit out at CNN International - the global broadcast wing of popular CNN - alleging that the news channel does not portray the correct picture of his administration.
#
# Translated to English : U.S. President Donald Trump swallowed the popular channel CNN’s global broadcast branch on CNN International and alleged that this news channel does not present the exact picture of his administration.
# Average BLEU score : 0.0849409086101556
#
# Average GLEU score : 0.1824054781903066
#
# Average METEOR score : 0.37199482759770414
#
#
# Translating sentence  441
# Original Hindi text : रसायन एवं उर्वरक मंत्रालय एचआईएल इंडिया ने मलेरिया नियंत्रण कार्यक्रम के लिए दक्षिण अफ्रीका को 20.60 मिट्रिक टन डीडीटी की आपूर्ति की रसायन और उर्वरक मंत्रालय के सार्वजनिक उपक्रम एचआईएल इंडिया लिमिटेड ने मलेरिया नियंत्रण कार्यक्रम के लिए दक्षिण अफ्रीका को 20.60 मिट्रिक टन डीडीटी 75 डब्ल्यूपी की आपूर्ति की है।
#
# Original English Conversion : Ministry of Chemicals and Fertilizers HIL (India) has supplied 20.60 MT of DDT to South Africa for Malaria control program HIL (India) Limited, a PSU under the Ministry of Chemicals and Fertilizers has supplied 20.60 Metric tonne of DDT 75 WP to South Africa for their Malaria control program yesterday.
#
# Translated to English : The Ministry of Chemistry and Fertilizers HIL India has supplied 20.60 metric tons of DDT to South Africa for the Malaria Control Program and the public enterprise of the Ministry of Fertilizers HIL India Limited has supplied 20.60 metric tons of DDT 75 WP to South Africa for the Malaria Control Program.
# Average BLEU score : 0.08423678013964185
#
# Average GLEU score : 0.18155115012856157
#
# Average METEOR score : 0.3714524695635181
#
#
# Translating sentence  451
# Original Hindi text : कंपनी ने इस कार को टाटा हैरियर डार्क एडिशन के मुकाबले में उतारा है।
#
# Original English Conversion : The vehicle is meant to take on the Tata Harrier Dark Edition
#
# Translated to English : The company has launched this car compared to Tata Harrier Dark Edition.
# Average BLEU score : 0.08515782055706284
#
# Average GLEU score : 0.1823591275296712
#
# Average METEOR score : 0.37196915695013855
#
#
# Translating sentence  461
# Original Hindi text : निस्संदेह उस घड़ी का ज्ञान अल्लाह ही के पास है। वही मेंह बरसाता है और जानता है जो कुछ गर्भाशयों में होता है। कोई क्यक्ति नहीं जानता कि कल वह क्या कमाएगा और कोई व्यक्ति नहीं जानता है कि किस भूभाग में उसक मृत्यु होगी। निस्संदेह अल्लाह जाननेवाला, ख़बर रखनेवाला है
#
# Original English Conversion : With God rests the knowledge of the Hour. He sends down the rain, and He knows what the wombs contain. No soul knows what it will reap tomorrow, and no soul knows in what land it will die. God is All - Knowing, Well - Informed.
#
# Translated to English : Indeed, the knowledge of the hour is to Allah; it rains and knows what is in the wombs; no one knows what he will earn tomorrow, and no one knows in which land he will die.
# Average BLEU score : 0.08406690180791059
#
# Average GLEU score : 0.18167429627923146
#
# Average METEOR score : 0.3717596542752249
#
#
# Translating sentence  471
# Original Hindi text : खतरे में आ गयी प्रजातियों की आईयूसीएन की रेड लिस्ट में उनका मूल्यांकन सबसे कम चिंताजनक प्रजाति के रूप में किया गया है।
#
# Original English Conversion : "The species is listed as ""Least Concern"" on the IUCN red list."
#
# Translated to English : In the IUCN's Red List of Dangerous Species, they are ranked as the least worrying species.
# Average BLEU score : 0.08357857643770479
#
# Average GLEU score : 0.1804918405757027
#
# Average METEOR score : 0.368973012127218
#
#
# Translating sentence  481
# Original Hindi text : एफ़डीआर (FDR) ड्राइव और हार्लेम रिवर ड्राइव सीमित उपयोग वाले दो मार्ग हैं जो ईस्ट नदी के किनारे मैनहटन के पूर्व दिशा में स्थित है और जिसका डिजाइन न्यूयॉर्क के विवादास्पद माहिर योजनाकार रॉबर्ट मोसेस ने बनाया था।
#
# Original English Conversion : The FDR Drive and Harlem River Drive, both designed by controversial New York master planner Robert Moses, comprise a single, long limited-access parkway skirting the east side of Manhattan along the East River and Harlem River south of Dyckman Street.
#
# Translated to English : FDR (FDR) Drive and Harlem River Drive are two limited-use routes located in the east direction of Manhattan on the east river and designed by New York's controversial specialist planner Robert Moses.
# Average BLEU score : 0.08290452175960066
#
# Average GLEU score : 0.18060977890444987
#
# Average METEOR score : 0.3703973220166739
#
#
# Translating sentence  491
# Original Hindi text : अभी तक इस पर कोई आधिकारिक पुष्टि नहीं हुई है।
#
# Original English Conversion : So far there has been no official confirmation in this regard.
#
# Translated to English : No official confirmation has yet been made.
# Average BLEU score : 0.08194839040548979
#
# Average GLEU score : 0.1803875081884794
#
# Average METEOR score : 0.37069459423257106

# %%
average_bleu_score = np.mean(facebook_bleu_scores)
average_gleu_score = np.mean(facebook_gleu_scores)
average_meteor_score = np.mean(facebook_meteor_scores)
print('Average BLEU Score for Test Set using Facebooks model: ', average_bleu_score)
print('Average GLEU Score for Test Set using Facebooks model: ', average_gleu_score)
print('Average METEOR Score for Test Set using Facebooks model: ', average_meteor_score)
# Out:
# Average BLEU Score for Test Set using Facebooks model:  0.08107246167656472
# Average GLEU Score for Test Set using Facebooks model:  0.18128300433968855
# Average METEOR Score for Test Set using Facebooks model:  0.3731271913644258

# %%
import accelerate
print(accelerate.__version__)
# Out:
# 1.1.1

# %%
"""
from transformers import T5ForConditionalGeneration, T5Tokenizer

model_name = 'jbochi/madlad400-3b-mt'
model = T5ForConditionalGeneration.from_pretrained(model_name, device_map="auto")
tokenizer = T5Tokenizer.from_pretrained(model_name)

google_bleu_scores = []
google_gleu_scores = []
google_meteor_scores = []

for i, hindi_text in enumerate(native_hindi_sentences_dev_set):
    # print(i)
    input_ids = tokenizer(text, return_tensors="pt").input_ids.to(model.device)
    outputs = model.generate(input_ids=input_ids)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    reference = [english_sentences_dev_set[i].split()]
    transformed_tokens = translated_text.split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    google_bleu_scores.append(bleu_score)
    google_gleu_scores.append(gleu_score)
    google_meteor_scores.append(met_score)

    if i % 10 == 0:
        print("Translating sentence ", i+1)
        print('Original Hindi text :', hindi_text)
        print('Original English Conversion :', english_sentences_dev_set[i])
        print('Translated to English :', translated_text[0])
        print('Average BLEU score :', np.mean(google_bleu_scores), '\n')
        print('Average GLEU score :', np.mean(google_gleu_scores), '\n')
        print('Average METEOR score :', np.mean(google_meteor_scores), '\n')
        print()
"""
# Out:
# '\nfrom transformers import T5ForConditionalGeneration, T5Tokenizer\n\nmodel_name = \'jbochi/madlad400-3b-mt\'\nmodel = T5ForConditionalGeneration.from_pretrained(model_name, device_map="auto")\ntokenizer = T5Tokenizer.from_pretrained(model_name)\n\ngoogle_bleu_scores = []\ngoogle_gleu_scores = []\ngoogle_meteor_scores = []\n\nfor i, hindi_text in enumerate(native_hindi_sentences_dev_set):\n    # print(i)\n    input_ids = tokenizer(text, return_tensors="pt").input_ids.to(model.device)\n    outputs = model.generate(input_ids=input_ids)\n    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)\n    reference = [english_sentences_dev_set[i].split()]\n    transformed_tokens = translated_text.split()\n\n    bleu_score = sentence_bleu(reference, transformed_tokens)\n    gleu_score = sentence_gleu(reference, transformed_tokens)\n    met_score = meteor_score(reference, transformed_tokens)\n\n    google_bleu_scores.append(bleu_score)\n    google_gleu_scores.append(gleu_score)\n    google_meteor_scores.append(met_score)\n\n    if i % 10 == 0:\n        print("Translating sentence ", i+1)\n        print(\'Original Hindi text :\', hindi_text)\n        print(\'Original English Conversion :\', english_sentences_dev_set[i])\n        print(\'Translated to English :\', translated_text[0])\n        print(\'Average BLEU score :\', np.mean(google_bleu_scores), \'\n\')\n        print(\'Average GLEU score :\', np.mean(google_gleu_scores), \'\n\')\n        print(\'Average METEOR score :\', np.mean(google_meteor_scores), \'\n\')\n        print()\n'

# %%
"""
average_bleu_score = np.mean(google_bleu_scores)
average_gleu_score = np.mean(google_gleu_scores)
average_meteor_score = np.mean(google_meteor_scores)
print('Average BLEU Score for Test Set using Googles model: ', average_bleu_score)
print('Average GLEU Score for Test Set using Googles model: ', average_gleu_score)
print('Average METEOR Score for Test Set using Googles model: ', average_meteor_score)
"""
# Out:
# "\naverage_bleu_score = np.mean(google_bleu_scores)\naverage_gleu_score = np.mean(google_gleu_scores)\naverage_meteor_score = np.mean(google_meteor_scores)\nprint('Average BLEU Score for Test Set using Googles model: ', average_bleu_score)\nprint('Average GLEU Score for Test Set using Googles model: ', average_gleu_score)\nprint('Average METEOR Score for Test Set using Googles model: ', average_meteor_score)\n"

# %%
import torch
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor


model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)

ip = IndicProcessor(inference=True)

input_sentences = [
    "जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।",
    "हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।",
    "अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।",
    "मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।",
]

src_lang, tgt_lang = "hin_Deva", "eng_Latn"

batch = ip.preprocess_batch(
    input_sentences,
    src_lang=src_lang,
    tgt_lang=tgt_lang,
)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Tokenize the sentences and generate input encodings
inputs = tokenizer(
    batch,
    truncation=True,
    padding="longest",
    return_tensors="pt",
    return_attention_mask=True,
).to(DEVICE)

# Generate translations using the model
with torch.no_grad():
    generated_tokens = model.generate(
        **inputs,
        use_cache=True,
        min_length=0,
        max_length=256,
        num_beams=5,
        num_return_sequences=1,
    )

# Decode the generated tokens into text
with tokenizer.as_target_tokenizer():
    generated_tokens = tokenizer.batch_decode(
        generated_tokens.detach().cpu().tolist(),
        skip_special_tokens=True,
        clean_up_tokenization_spaces=True,
    )

# Postprocess the translations, including entity replacement
translations = ip.postprocess_batch(generated_tokens, lang=tgt_lang)

for input_sentence, translation in zip(input_sentences, translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")
# Out:
# hin_Deva: जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।
# eng_Latn: When I was young, I used to go to the park every day.
# hin_Deva: हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।
# eng_Latn: We saw a new movie last week that was very inspiring.
# hin_Deva: अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।
# eng_Latn: If you'd given me a pass at that time, we'd have gone out to eat.
# hin_Deva: मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।
# eng_Latn: My friend has invited me to her birthday party, and I'll give her a present.
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\transformers\tokenization_utils_base.py:4114: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(

# %%
import torch
import numpy as np
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor

# Initialize metrics
indict2_bleu_scores = []
indict2_gleu_scores = []
indict2_meteor_scores = []

# Model and tokenizer setup
model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True).to("cuda" if torch.cuda.is_available() else "cpu")
ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "hin_Deva", "eng_Latn"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Convert numpy array to a list
native_hindi_sentences = native_hindi_sentences_dev_set.tolist()
english_sentences = english_sentences_dev_set.tolist()

# Ensure the datasets are aligned
assert len(native_hindi_sentences) == len(english_sentences), "Dev sets must be of equal length."

for i, hindi_text in enumerate(native_hindi_sentences):
    try:
        # print(f"Processing sentence {i+1}...")
        
        # Preprocessing
        batch = ip.preprocess_batch(
            [hindi_text],
            src_lang=src_lang,
            tgt_lang=tgt_lang,
        )
        # print(f"Preprocessed batch: {batch}")
        
        # Tokenize the sentences and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=1,
                num_return_sequences=1,
            )
        # print(f"Generated tokens: {generated_tokens}")

        # Decode the generated tokens into text
        with tokenizer.as_target_tokenizer():
            generated_tokens = tokenizer.batch_decode(
                generated_tokens.detach().cpu().tolist(),
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )
        translated_text = ip.postprocess_batch(generated_tokens, lang=tgt_lang)[0]
        # print(f"Translated text: {translated_text}")

        reference = [english_sentences_dev_set[i].split()]
        transformed_tokens = translated_text.split()

        bleu_score = sentence_bleu(reference, transformed_tokens)
        gleu_score = sentence_gleu(reference, transformed_tokens)
        met_score = meteor_score(reference, transformed_tokens)

        indict2_bleu_scores.append(bleu_score)
        indict2_gleu_scores.append(gleu_score)
        indict2_meteor_scores.append(met_score)

        # Log progress every 10 sentences
        if i % 10 == 0:
            print("Translating sentence", i + 1)
            print("Original Hindi text:", hindi_text)
            print("Original English Conversion:", english_sentences[i])
            print("Translated to English:", translated_text)
            print("Average BLEU score:", np.mean(indict2_bleu_scores))
            print("Average GLEU score:", np.mean(indict2_gleu_scores))
            print("Average METEOR score:", np.mean(indict2_meteor_scores))
            print()

    except Exception as e:
        print(f"Error processing sentence {i+1}: {e}")
        continue
# Out:
# Translating sentence 1
# Original Hindi text: इसपर हमारा रूख स्पष्ट और अटल है।
#
# Original English Conversion: Our position on this issue has been clear and consistent.
#
# Translated to English: Our position on this is clear and consistent.
# Average BLEU score: 0.38940039153570244
# Average GLEU score: 0.47058823529411764
# Average METEOR score: 0.7059558517284465
#
# Translating sentence 11
# Original Hindi text: अतएव, मन का सर्वप्रथम कार्य तो इन्द्रियानुभव को व्यवस्थित करना है; इसके साथ ही वह देहस्थित चेतना के संकल्प की स्वाभाविक प्रतिक्रियाओं व्यवस्थित करता है और शरीर को एक साधन के रूप में प्रयुक्त करता है, अथवा, जैसा कि साधारणतया कहा जाता है, वह कर्मेन्द्रियों को अपने करण के रूप में प्रयुक्त करता है।
#
# Original English Conversion: The manas is therefore in the first place an organiser of sense experience. in addition it organises the natural reactions of the will in the embodied consciousness and uses the body as an instrument, uses, as it is ordinarily put, the organs of action.
#
# Translated to English: The first function of the mind, therefore, is to organize sense experience. it also organizes the natural reactions of the will of the consciousness in the body and uses the body as a means, or, as it is commonly called, the organs of action as its own instruments.
# Average BLEU score: 0.21516081738396095
# Average GLEU score: 0.3378127490246952
# Average METEOR score: 0.5033465848971734
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence 21
# Original Hindi text: तुम्हारें माल और तुम्हारे प्राण में तुम्हारी परीक्षा होकर रहेगी और तुम्हें उन लोगों से जिन्हें तुमसे पहले किताब प्रदान की गई थी और उन लोगों से जिन्होंने 'शिर्क' किया, बहुत-सी कष्टप्रद बातें सुननी पड़ेगी। परन्तु यदि तुम जमें रहे और (अल्लाह का) डर रखा, तो यह उन कर्मों में से है जो आवश्यक ठहरा दिया गया है
#
# Original English Conversion: You will, nonetheless, be tried with your wealth and life, and will hear many untoward things from the followers of former Books and the infidels. But if you endure with patience and follow the straight path, it will surely (accord) with God's fixed resolve about human affairs.
#
# Translated to English: You will be tested in your wealth and your lives, and you will hear many painful things from those who were given the Book before you and from those who associated others with it. But if you remain steadfast and fear Allah, then this is one of the things prescribed.
# Average BLEU score: 0.15443732955839806
# Average GLEU score: 0.27232744958294247
# Average METEOR score: 0.46104132529248854
#
# Translating sentence 31
# Original Hindi text: सोमवार को किसान संगठनों द्वारा ऐलान किया गया है कि शानिवार 6 फरवरी को पूरे देश भर में चक्का जाम करेंगे
#
# Original English Conversion: Farmers on Monday announced a countrywide 'chakka jam' on February 6
#
# Translated to English: On Monday, it was announced by the farmers'organizations that the Shanivar will stage a chakka jam across the country on February 6.
# Average BLEU score: 0.17299015592467556
# Average GLEU score: 0.27896999005879725
# Average METEOR score: 0.45928010585806084
#
# Translating sentence 41
# Original Hindi text: दोपहर के बाद, प्रधानमंत्री हजा‍रीबाग से कोडरमा के लिए भी एक नई रेल लाइन का शुभारम्‍भ करेंगे।
#
# Original English Conversion: In the afternoon, the Prime Minister will inaugurate a new railway line from Hazaribag to Kodarma.
#
# Translated to English: Later in the afternoon, the Prime Minister will also inaugurate a new rail line from Hazaribagh to Koderma.
# Average BLEU score: 0.16485537746747272
# Average GLEU score: 0.26362243703226773
# Average METEOR score: 0.4583132809565524
#
# Translating sentence 51
# Original Hindi text: समिति का कहना है कि व्यक्तिगत लोगों तथा हिंदू अविभाजित परिवारों के लिए टीडीएस दर को मौजूदा 10 फीसदी से घटाकर 5 फीसदी किया जाना चाहिए।
#
# Original English Conversion: The committee has suggested reduction in TDS rates in case of interest and commission for individuals and Hindu Undivided Families (HUFs) to 5 per cent from 10 per cent at present.
#
# Translated to English: The committee says that the TDS rate for individuals and Hindu undivided families should be reduced to 5 per cent from the current 10 per cent.
# Average BLEU score: 0.17271754595043604
# Average GLEU score: 0.2687961621288464
# Average METEOR score: 0.46553199785275046
#
# Translating sentence 61
# Original Hindi text: वर्षों से भारतीय रेलवे अपनी औद्योगिक सुरक्षा के साथ-साथ भावी पीढि़यों को जीवंत विरासत का समावेश करने के लिए निरंतर और केन्द्रित दृष्टिकोण बनाए रखने का प्रयास कर रही है।
#
# Original English Conversion: Over the years, Indian Railways has been endeavoring sustained and focused approach for safeguarding its industrial as well as living heritage and to transmit it to future generations.
#
# Translated to English: Over the years, Indian Railways has been striving to maintain a continuous and focused approach towards its industrial safety as well as to pass on a vibrant heritage to the future generations.
# Average BLEU score: 0.15273434532329033
# Average GLEU score: 0.2577278356794159
# Average METEOR score: 0.4536391551969182
#
# Translating sentence 71
# Original Hindi text: सत्तारूढ़ कम्युनिस्ट पार्टी ऑफ चीन (सीपीसी) महासचिव शी ने कहा कि राजनयिक संबंध स्थापित होने के बाद से दोनों देशों ने हमेशा एक-दूसरे का सम्मान किया है, एक-दूसरे को बराबर माना है, परस्पर राजनीतिक विश्वास को बढ़ाया है और परस्पर सहयोग को और मजबूत किया है।
#
# Original English Conversion: Xi, also General Secretary of the ruling Communist Party of China, said that since the establishment of the diplomatic ties, the two countries have always respected each other, treated each other as equals, enhanced political mutual trust and deepened mutually beneficial cooperation.
#
# Translated to English: Xi, also the ruling Communist Party of China (CPC) general secretary, said since the establishment of diplomatic relations, the two countries have always respected each other, treated each other as equals, enhanced mutual political trust, and further strengthened mutual cooperation.
# Average BLEU score: 0.166928396517288
# Average GLEU score: 0.2719097695297045
# Average METEOR score: 0.48208007178817464
#
# Translating sentence 81
# Original Hindi text: भारत फाइनल की दौड़ से बाहर होने के कगार पर
#
# Original English Conversion: India through to the finals
#
# Translated to English: India are out of the final race.
# Average BLEU score: 0.16383094035542567
# Average GLEU score: 0.27559457968867823
# Average METEOR score: 0.4966312264756404
#
# Translating sentence 91
# Original Hindi text: सुप्रीम कोर्ट की है नजर
#
# Original English Conversion: Supreme Court view
#
# Translated to English: Supreme Court is watching.
# Average BLEU score: 0.17621921989061415
# Average GLEU score: 0.29403720057419414
# Average METEOR score: 0.513396729270258
#
# Translating sentence 101
# Original Hindi text: कंपनी ने कहा कि कमोडिटी कीमतों और विभिन्‍न अन्‍य इनपुट कॉस्‍ट बढ़ने के कारण मूल्‍यवृद्धि जरूरी हो गई है।
#
# Original English Conversion: The price hike has been necessitated owing to increase in commodity prices and conversion costs, the company said.
#
# Translated to English: The company said the price hike has been necessitated due to increase in commodity prices and various other input costs.
# Average BLEU score: 0.17822160733382966
# Average GLEU score: 0.29203287294008795
# Average METEOR score: 0.5099516899458421
#
# Translating sentence 111
# Original Hindi text: घर में बैठे-बैठे लोग परेशान हो चुके हैं।
#
# Original English Conversion: People are fed-up sitting at home.
#
# Translated to English: People sitting at home have become disturbed.
# Average BLEU score: 0.1828630625942087
# Average GLEU score: 0.3023310958322503
# Average METEOR score: 0.5229020949926021
#
# Translating sentence 121
# Original Hindi text: यहोवा खरे मनुष्य का गढ़ ठहरता है, परन्तु अनर्थकारियों का विनाश होता है।
#
# Original English Conversion: The way of the LORD is strength to the upright: but destruction shall be to the workers of iniquity.
#
# Translated to English: Jehovah is the stronghold of the upright man, but the destroyer is destroyed.
# Average BLEU score: 0.18728737106073048
# Average GLEU score: 0.30273109335530096
# Average METEOR score: 0.531275533190917
#
# Translating sentence 131
# Original Hindi text: विहिप के केंद्रीय महामंत्री मिलिंद परांडे ने कहा कि महत्त्वपूर्ण बात यह है कि दीपिका जेएनयू के किन छात्रों के साथ एकजुटता दिखा रही हैं, हालिया हिंसा के वक्त वहां दो तरह के छात्र थे.
#
# Original English Conversion: "Talking to PTI, VHP's central general secretary Milind Parande said, ""What is important is that which group of JNU students that Deepika was showing her solidarity with?"
#
# Translated to English: VHP's central general secretary Milind Parande said that the important thing is that Deepika is showing solidarity with which students of JNU, there were two types of students at the time of the recent violence.
# Average BLEU score: 0.18565705332156782
# Average GLEU score: 0.29928239239570403
# Average METEOR score: 0.5253392068238003
#
# Translating sentence 141
# Original Hindi text: शुरुआती रिपोर्टें कहती हैं कि अरुम्की में आपातकालीन लैंडिंग से वंचित होने के बाद विमान को अफगानिस्तान वापस भेज दीया गया था।
#
# Original English Conversion: The early reports say the plane was diverted back to Afghanistan after being denied an emergency landing in rmqi.
#
# Translated to English: Initial reports say the plane was sent back to Afghanistan after being denied an emergency landing at Arumqi.
# Average BLEU score: 0.1907901217236295
# Average GLEU score: 0.3037847936340631
# Average METEOR score: 0.5328253556770284
#
# Translating sentence 151
# Original Hindi text: """तुम्हें अपने रब के संदेश पहुँचता हूँ और मैं तुम्हारा विश्वस्त हितैषी हूँ"
#
# Original English Conversion: I bring to you the messages of my Lord. I am your sincere friend.
#
# Translated to English: "" "I convey to you the messages of my Lord, and I am your trustworthy benefactor." ""
# Average BLEU score: 0.18563138954565803
# Average GLEU score: 0.2977800444586401
# Average METEOR score: 0.5290203577627676
#
# Translating sentence 161
# Original Hindi text: तीसरे चरण का चुनाव 28 अक्टूबर को 48 विधानसभा क्षेत्रों में होना है।
#
# Original English Conversion: The third phase of elections will take place on October 28 for 48 seats
#
# Translated to English: The third phase of elections is scheduled to be held on October 28 in 48 assembly constituencies.
# Average BLEU score: 0.18226570616063384
# Average GLEU score: 0.29125040794611134
# Average METEOR score: 0.5224594763296336
#
# Translating sentence 171
# Original Hindi text: भाजपा से बड़ा कोई माफिया नहीं
#
# Original English Conversion: There is no bigger thief than BJP.
#
# Translated to English: There is no bigger mafia than the BJP.
# Average BLEU score: 0.18167370283530393
# Average GLEU score: 0.2892991076941246
# Average METEOR score: 0.5234455054742838
#
# Translating sentence 181
# Original Hindi text: आआईएसएफ 2015 में भारत और विदेश से करीब 4000 प्रतिनिधियों के हिस्सा लेने की संभावना है।
#
# Original English Conversion: In all around 4,000 delegates from India and abroad are expected to take part in IISF 2015 which will aim to showcase the achievements of Indian scientists and institutions.
#
# Translated to English: About 4000 delegates from India and abroad are expected to participate in the IISF 2015.
# Average BLEU score: 0.18569498030659803
# Average GLEU score: 0.2909107678101286
# Average METEOR score: 0.5223651257551539
#
# Translating sentence 191
# Original Hindi text: वे यहोवा के कामों पर और उसके हाथों के कामों पर ध्यान नहीं करते, इसलिये वह उन्हें पछाड़ेगा और फिर न उठाएगा।।
#
# Original English Conversion: Because they don't respect the works of Yahweh, nor the operation of his hands, he will break them down and not build them up.
#
# Translated to English: They do not meditate on the works of the LORD, on the works of his hands, so that he will not fail them or fail them.
# Average BLEU score: 0.17944160528982311
# Average GLEU score: 0.2834610430111615
# Average METEOR score: 0.5128060249676822
#
# Translating sentence 201
# Original Hindi text: क्यों दानिय्येल यहोवा के समीप रहने का बढ़िया मिसाल है, और हम कैसे उसका अनुकरण कर सकते हैं?
#
# Original English Conversion: Why is Daniel a fine example of staying close to Jehovah, and how can we imitate him?
#
# Translated to English: Why is Daniel a fine example of staying close to Jehovah, and how can we imitate him?
# Average BLEU score: 0.18576427821470218
# Average GLEU score: 0.2876872232258901
# Average METEOR score: 0.5129515887571239
#
# Translating sentence 211
# Original Hindi text: वह शहर के कुछ स्थानों का भ्रमण क सकती हैं और कुछ कार्यक्रमों में शामिल हो सकती हैं।
#
# Original English Conversion: She is expected to visit some places and attend programmes in the city.
#
# Translated to English: She may visit some places in the city and attend some programmes.
# Average BLEU score: 0.18657663684099982
# Average GLEU score: 0.29030603526892684
# Average METEOR score: 0.5156306561544399
#
# Translating sentence 221
# Original Hindi text: स्वामी विवेकानंद की प्रतिमा का अनावरण
#
# Original English Conversion: Unveiling of Statue of Swami Vivekananda
#
# Translated to English: Swami Vivekananda's statue unveiled
# Average BLEU score: 0.18956193511029598
# Average GLEU score: 0.29103247267572113
# Average METEOR score: 0.5156366134556039
#
# Translating sentence 231
# Original Hindi text: ईश्‍वर भक्‍ति की परीक्षा का सफलता पूर्वक सामना करने वालों में हमारी मसीही बहनों की काफी संख्या है, जिनका हम गहरा सम्मान करते हैं ।
#
# Original English Conversion: Among those successfully meeting this test of devotion to God are quite a number of our Christian sisters, for whom we have the deepest regard.
#
# Translated to English: Among those who have successfully withstood the test of godliness are a number of our Christian sisters, whom we deeply respect.
# Average BLEU score: 0.19637143228527054
# Average GLEU score: 0.2979997792201181
# Average METEOR score: 0.5209303626042935
#
# Translating sentence 241
# Original Hindi text: उसकी मौसी कहाँ गई?
#
# Original English Conversion: Where did her aunt go?
#
# Translated to English: Where did her mother go?
# Average BLEU score: 0.19278628081461482
# Average GLEU score: 0.29728656912664664
# Average METEOR score: 0.5235055833093828
#
# Translating sentence 251
# Original Hindi text: पुलिस के इस प्रयास की चहुंओर सराहना हो रही है।
#
# Original English Conversion: This act of police is being appreciated widely.
#
# Translated to English: The police's efforts are being appreciated all over.
# Average BLEU score: 0.19269023255336604
# Average GLEU score: 0.29530673431904453
# Average METEOR score: 0.5227422520607626
#
# Translating sentence 261
# Original Hindi text: बसपा का तो खाता भी नहीं खुला था.
#
# Original English Conversion: The BSP could not open its account.
#
# Translated to English: The BSP could not even open its account.
# Average BLEU score: 0.18913810666492173
# Average GLEU score: 0.29257470964347626
# Average METEOR score: 0.5183838218779523
#
# Translating sentence 271
# Original Hindi text: वह इस समस्या से अपनी युवा अवस्था से ही गुजर चुका है जब उसने कुमार नामक नकली भाई बनाया था।
#
# Original English Conversion: He has been dealing with this condition from a young age, when he created a fake brother named Kumar with his imagination.
#
# Translated to English: He has been through this problem since his youth when he created a fake brother named Kumar.
# Average BLEU score: 0.18681015770128165
# Average GLEU score: 0.29084870283069364
# Average METEOR score: 0.5172298482664881
#
# Translating sentence 281
# Original Hindi text: इस अवधि के दौरान ही वीआरएस के लिए आवेदन स्वीकार किए जाएंगे.
#
# Original English Conversion: The applications for VRS will reportedly be accepted during this period only.
#
# Translated to English: Applications for VRS will be accepted during this period only.
# Average BLEU score: 0.18983398433671264
# Average GLEU score: 0.29383989239568725
# Average METEOR score: 0.5209150391483939
#
# Translating sentence 291
# Original Hindi text: इसके अलावा भाजपा विधायक और डिप्टी स्पीकर माइकल लोबो भी मंत्रिमंडल में शामिल हुए।
#
# Original English Conversion: BJP leader and Deputy Assembly Speaker Michael Lobo was also inducted into the Cabinet.
#
# Translated to English: BJP MLA and Deputy Speaker Michael Lobo also joined the cabinet.
# Average BLEU score: 0.1896472100769599
# Average GLEU score: 0.2925044226756554
# Average METEOR score: 0.5192400216143154
#
# Translating sentence 301
# Original Hindi text: भूख हड़ताल पर बैठे छात्रों की तबीयत लगातार खराब होती जा रही है.
#
# Original English Conversion: The health of the students on strike is deteriorating.
#
# Translated to English: The health of the students on hunger strike is deteriorating.
# Average BLEU score: 0.1919779894523441
# Average GLEU score: 0.29465436729901096
# Average METEOR score: 0.5220846197712958
#
# Translating sentence 311
# Original Hindi text: और ईमान लाओ उस चीज़ पर जो मैंने उतारी है, जो उसकी पुष्टि में है, जो तुम्हारे पास है, और सबसे पहले तुम ही उसके इनकार करनेवाले न बनो। और मेरी आयतों को थोड़ा मूल्य प्राप्त करने का साधन न बनाओ, मुझसे ही तुम डरो
#
# Original English Conversion: And believe in what I have sent down which verifies what is already with you. and do not be the first to deny it, nor part with it for little gain. and beware of Me.
#
# Translated to English: And believe in what I have revealed confirming what is with you, and do not be the first to disbelieve in it. And do not make My revelations a means of gaining a little price. It is I whom you should fear.
# Average BLEU score: 0.1917183181457359
# Average GLEU score: 0.2960704847070202
# Average METEOR score: 0.5248641083071008
#
# Translating sentence 321
# Original Hindi text: ख. स्वास्थ्य और मातृत्व लाभ
#
# Original English Conversion: health and maternity benefit,
#
# Translated to English: b. Health and Maternity Benefit
# Average BLEU score: 0.19115152516097722
# Average GLEU score: 0.29529896131426536
# Average METEOR score: 0.5260104824529195
#
# Translating sentence 331
# Original Hindi text: इसके अलावा, मुझे हमेशा उस तरह की स्वतंत्रता दी जाती थी, जहां आपको अपने फैसले खुद करने होते हैं।
#
# Original English Conversion: Besides that, I was always given that kind of independence where you have to make your own decisions.
#
# Translated to English: Also, I was always given that kind of freedom where you have to make your own decisions.
# Average BLEU score: 0.1940377871175751
# Average GLEU score: 0.29946471402594976
# Average METEOR score: 0.5312828959065626
#
# Translating sentence 341
# Original Hindi text: जिस पर उनके विरूद्ध कार्रवाई की गई है।
#
# Original English Conversion: Action has been taken against them.
#
# Translated to English: Action has been taken against them.
# Average BLEU score: 0.1983277342222436
# Average GLEU score: 0.3032656973360883
# Average METEOR score: 0.5343346205119365
#
# Translating sentence 351
# Original Hindi text: वहां मैं तेरा धनुष तेरे बाएं हाथ से गिराऊंगा, और तेरे तीरों को तेरे दहिने हाथ से गिरा दूंगा।
#
# Original English Conversion: And I will smite thy bow out of thy left hand, and will cause thine arrows to fall out of thy right hand.
#
# Translated to English: There I will cause your bow to fall from your left hand, and your arrows from your right hand.
# Average BLEU score: 0.19668201335321606
# Average GLEU score: 0.3014464283576471
# Average METEOR score: 0.5311689144781231
#
# Translating sentence 361
# Original Hindi text: जस्सी हरियाणा में सिरसा स्थित डेरा सच्चा सौदा के प्रमुख गुरमीत राम रहीम सिंह के संबंधी हैं।
#
# Original English Conversion: Jassi is a relative of Sirsa-based Dera Sacha Sauda head Gurmeet Ram Rahim Singh.
#
# Translated to English: Jassi is a relative of Gurmeet Ram Rahim Singh, the head of the Sirsa-based Dera Sacha Sauda in Haryana.
# Average BLEU score: 0.19678507380374938
# Average GLEU score: 0.30186194241675895
# Average METEOR score: 0.533541908846643
#
# Translating sentence 371
# Original Hindi text: तो, पहले रिकॉर्डिंग उद्देश्य के लिए रिकॉर्डिंग में विभिन्न उपकरण शामिल हैं, पहला चार्ट है, एक बुनियादी उपकरण है जो सिस्टम में एक मात्रा निर्धारण या कार्य को अलग करने में आपकी मदद कर सकता है।
#
# Original English Conversion: So, there are various tools are involved in a recording for first recording purpose, first is chart, is a basic tool which may help you in a quantification or separation of work, in a system.
#
# Translated to English: So, first is recording for recording purpose involves various tools, the first is charts, a basic tool that can help you in setting a quantity or differentiating a function in the system.
# Average BLEU score: 0.19196409216723812
# Average GLEU score: 0.2987890374260848
# Average METEOR score: 0.5297877316511007
#
# Translating sentence 381
# Original Hindi text: लोकसभा चुनाव 2019: बारामती लोकसभा सीट के बारे में जानिए
#
# Original English Conversion: Lok Sabha election 2019: A look at West Bengal constituencies: JALPAIGURI
#
# Translated to English: Lok Sabha elections 2019: All you need to know about Baramati
# Average BLEU score: 0.18927754934388583
# Average GLEU score: 0.2972474908523379
# Average METEOR score: 0.5264843933284109
#
# Translating sentence 391
# Original Hindi text: मैं इसके विवरण नहीं दे सकता।
#
# Original English Conversion: I cannot give details.
#
# Translated to English: I can't give details.
# Average BLEU score: 0.19022839830265653
# Average GLEU score: 0.2991677076822224
# Average METEOR score: 0.5272529870496048
#
# Translating sentence 401
# Original Hindi text: फिल्म में संजय दत्त के किरदार का नाम है बलराज चौधरी.
#
# Original English Conversion: Sanjay Dutt will be seen playing the character of Balraj Chaudhry in the movie.
#
# Translated to English: Sanjay Dutt's character is named Balraj Chaudhary in the film.
# Average BLEU score: 0.1879939007024765
# Average GLEU score: 0.29703520367696784
# Average METEOR score: 0.5247685629644251
#
# Translating sentence 411
# Original Hindi text: सेंट की बहनों का समाज
#
# Original English Conversion: Society of the Sisters of St.
#
# Translated to English: Society of the Sisters of St.
# Average BLEU score: 0.19002594243489004
# Average GLEU score: 0.29901512507397005
# Average METEOR score: 0.5264686768319423
#
# Translating sentence 421
# Original Hindi text: जैसा की नाम से ही स्पष्ट है कि इस पोजीशन में महिला अपने पार्टनर के उपर होती है. विन्यास के अनुसार इसमें रिसीवर () अपने पार्टनर के उपर रह कर आनंद की नाव खेता है. इस पोजीशन में प्रवेश गहराई तक होता है तथा नियंत्रण काफी कुछ हद तक महिला के पास रहता है. इस पोजीशन में महिला रति क्रीड़ा की गति और योनि में लिंग के प्रवेश की गहराई सहित उसके धक्के को नियंत्रित कर सकती है. इसलिये जब महिला तेज सेक्स से डरती हो तथा सेक्स क्रिया के दौरान पुरुष महिला को पावर का प्रयोग करते देखना चाहता है उनके लिये यह पोजीशन काफी बेहतर है.
#
# Original English Conversion: As the name suggests the woman is on top of her partner. As per arrangement, the receiver () rows the boat of pleasure being on top of the partner. This position allows deeper penetration and to some extent the woman has control. The woman can control the speed of foreplay along with the depth of penetration and the strokes. This is an ideal position when the man wants to see the woman use power during sex and is afraid to do it.
#
# Translated to English: As the name suggests, the woman is above her partner. By design, the receiver () is above her partner and pulls the pleasure boat. The penetration is deep and the control is largely with the woman. In this position, the woman can control the speed of the sexual act and the depth of penetration of the penis into the vagina, as well as its thrust. So this position is great for when the woman is afraid of loud sex and the man wants to see the woman exert power during the sexual act.
# Average BLEU score: 0.19044790820447774
# Average GLEU score: 0.2991890138147504
# Average METEOR score: 0.5273538021871045
#
# Translating sentence 431
# Original Hindi text: ऑस्ट्रेलिया की ज़िंदगी उत्तरी गोलार्द्ध के अनेक देशों से फ़र्क है ।
#
# Original English Conversion: Life in Australia is different from life in many lands in the Northern Hemisphere.
#
# Translated to English: Life in Australia is different from many countries in the Northern Hemisphere.
# Average BLEU score: 0.18989390738914136
# Average GLEU score: 0.298671197450243
# Average METEOR score: 0.5265733486703673
#
# Translating sentence 441
# Original Hindi text: उसकी पूछताछ और पुलिस शिकायत केवल उसकी निराशा का कारण बनती है।
#
# Original English Conversion: His inquiries and a police complaint only lead him to frustration and violent outbursts.
#
# Translated to English: His interrogation and police complaint only cause him frustration.
# Average BLEU score: 0.1895999868742878
# Average GLEU score: 0.29877745133914047
# Average METEOR score: 0.5261650463207364
#
# Translating sentence 451
# Original Hindi text: इस मोबाइल एप में कैथल, कुरुक्षेत्र, जींद, करनाल के 134 तीर्थ स्थानों की विस्तृत जानकारी होगी।
#
# Original English Conversion: This mobile app has detailed information of 134 pilgrimages of Kaithal, Kurukshetra, Jind and Karnal.
#
# Translated to English: The mobile app will have detailed information about 134 pilgrimage sites in Kaithal, Kurukshetra, Jind, Karnal.
# Average BLEU score: 0.19047158931136637
# Average GLEU score: 0.29867275458844006
# Average METEOR score: 0.5259751631840192
#
# Translating sentence 461
# Original Hindi text: लालू यादव की बेटी मीसा यादव को धन मुहैया कराने का भी राजेश पर आरोप है।
#
# Original English Conversion: She also levelled charges against Misa Bharti, Lalu Prasad Yadav's daughter.
#
# Translated to English: Rajesh is also accused of providing funds to Lalu Yadav's daughter Misa Yadav.
# Average BLEU score: 0.19139263110428764
# Average GLEU score: 0.29913511003380366
# Average METEOR score: 0.5255917742486999
#
# Translating sentence 471
# Original Hindi text: राष्ट्रवादी सरकार को नेवी को फंड देने के बारे में बात करनी चाहिए, सेना को केवल बयानबाजी पर नहीं छोड़ना चाहिए
#
# Original English Conversion: Nationalist govt should walk the talk on giving Navy funds, not leave forces with just rhetoric
#
# Translated to English: The Nationalist government should talk about funding the Navy, not leave the military to mere rhetoric.
# Average BLEU score: 0.18768812168871546
# Average GLEU score: 0.29592647465939137
# Average METEOR score: 0.5211967003152983
#
# Translating sentence 481
# Original Hindi text: पश्चिमी विद्वानों द्वारा भारतीय धर्म ग्रन्थों की त्रुटिपूर्ण व्याख्या की आलोचना करने में वह जरा भी नहीं हिचके।
#
# Original English Conversion: He was bold enough to criticize Western scholars for their faulty interpretations of Hindu scriptures.
#
# Translated to English: He did not hesitate to criticise the flawed interpretation of Indian religious texts by Western scholars.
# Average BLEU score: 0.18746535749536253
# Average GLEU score: 0.29565364511258924
# Average METEOR score: 0.5224055485166825
#
# Translating sentence 491
# Original Hindi text: किशनगंज में कांग्रेस उम्मीदवार मोहम्मद जावेद ने जदयू के सैयद महमूद अशरफ को हराया
#
# Original English Conversion: Mahmood Ashraf of the JD(U) was pitted against Mahagathbandhan candidate Mohammad Javed of the Congress.
#
# Translated to English: In Kishanganj, Congress candidate Mohammad Javed defeated JD (U) "s Syed Mahmood Ashraf.
# Average BLEU score: 0.18794413657740633
# Average GLEU score: 0.2962371987788956
# Average METEOR score: 0.5234561045383075

# %%
average_bleu_score = np.mean(indict2_bleu_scores)
average_gleu_score = np.mean(indict2_gleu_scores)
average_meteor_score = np.mean(indict2_meteor_scores)
print('Average BLEU Score for Test Set using IndicTrans2 model: ', average_bleu_score)
print('Average GLEU Score for Test Set using IndicTrans2 model: ', average_gleu_score)
print('Average METEOR Score for Test Set using IndicTrans2 model: ', average_meteor_score)
# Out:
# Average BLEU Score for Test Set using IndicTrans2 model:  0.18718207973299422
# Average GLEU Score for Test Set using IndicTrans2 model:  0.295210247412076
# Average METEOR Score for Test Set using IndicTrans2 model:  0.5222354091508167
