# %%
import numpy as np
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.gleu_score import sentence_gleu
from nltk.translate.meteor_score import meteor_score

# %%
import re
from sklearn.model_selection import train_test_split

# %%
english_scripts_file_path = "../datasets/Samantar dataset/final_data/en-ta/train.en"
native_scripts_file_path = "../datasets/Samantar dataset/final_data/en-ta/train.ta"

# %%
native_lines = []
with open(native_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        native_lines.append(line)

english_lines = []
with open(english_scripts_file_path, 'r', encoding='utf-8') as file:
    for line in file:
        english_lines.append(line)

# %%
df = pd.DataFrame({'Tamil': native_lines, 'English': english_lines})
print(df.head())
# Out:
#                                                Tamil  \
# 0                  என்றுதான் நான் சொல்ல வருகிறேன்.\n
# 1               ஒவ்வொரு சுற்றுப்பயணமும் கடினமானது.\n
# 2  பல வருடங்களாக அவர் அந்த நித்திய எரிநரக தண்டனைய...
# 3  அவர் நிதி அமைச்சர் அருண்ஜேட்லியின் முயற்சியை த...
# 4  சில கலை வரலாற்றாசிரியர்கள் அவர் ஒரு வருடத்திற்...
#
#                                              English
# 0                         That's what I am saying.\n
# 1                   Every tournament is difficult.\n
# 2  One of the first questions Flavio posed was, D...
# 3  He gave full credit to the Union Finance Minis...
# 4  Some art historians have suggested that he onl...

# %%
test_set = df.sample(n = 1000, random_state = 1234)
print(f"Test set size: {len(test_set)}")
print(f"Dev set size: {len(test_set)}")
# Out:
# Test set size: 1000
# Dev set size: 1000

# %%
native_tamil_sentences_test_set = test_set['Tamil'].values
print(type(native_tamil_sentences_test_set))
print(native_tamil_sentences_test_set.shape)
english_sentences_test_set = test_set['English'].values
# Out:
# <class 'numpy.ndarray'>
# (1000,)

# %%
def calculate_scores(english_sentence, translation):
    reference = [english_sentence.split()]
    transformed_tokens = translation.split()

    bleu_score = sentence_bleu(reference, transformed_tokens)
    gleu_score = sentence_gleu(reference, transformed_tokens)
    met_score = meteor_score(reference, transformed_tokens)

    return bleu_score, gleu_score, met_score

# %%
import torch
import numpy as np
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransToolkit import IndicProcessor

# Initialize metrics
indict2_bleu_scores = []
indict2_gleu_scores = []
indict2_meteor_scores = []

# Model and tokenizer setup
model_name = "ai4bharat/indictrans2-indic-en-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True).to("cuda" if torch.cuda.is_available() else "cpu")
ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "tam_Taml", "eng_Latn"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Convert numpy array to a list
native_tamil_sentences = native_tamil_sentences_test_set.tolist()
english_sentences = english_sentences_test_set.tolist()

# Ensure the datasets are aligned
assert len(native_tamil_sentences) == len(english_sentences), "Dev sets must be of equal length."

for i, tamil_text in enumerate(native_tamil_sentences):
    try:
        # print(f"Processing sentence {i+1}...")
        
        # Preprocessing
        batch = ip.preprocess_batch(
            [tamil_text],
            src_lang=src_lang,
            tgt_lang=tgt_lang,
        )
        # print(f"Preprocessed batch: {batch}")
        
        # Tokenize the sentences and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=1,
                num_return_sequences=1,
            )
        # print(f"Generated tokens: {generated_tokens}")

        # Decode the generated tokens into text
        with tokenizer.as_target_tokenizer():
            generated_tokens = tokenizer.batch_decode(
                generated_tokens.detach().cpu().tolist(),
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )
        translation = ip.postprocess_batch(generated_tokens, lang=tgt_lang)[0]
        bleu_score, gleu_score, met_score = calculate_scores(english_sentences[i], translation)

        indict2_bleu_scores.append(bleu_score)
        indict2_gleu_scores.append(gleu_score)
        indict2_meteor_scores.append(met_score)

        # Log progress every 10 sentences
        if i % 10 == 0:
            print("Translating sentence", i + 1)
            print("Original Tamil text:", tamil_text)
            print("Original English Conversion:", english_sentences[i])
            print("Translated to English:", translation)
            print("Average BLEU score:", np.mean(indict2_bleu_scores))
            print("Average GLEU score:", np.mean(indict2_gleu_scores))
            print("Average METEOR score:", np.mean(indict2_meteor_scores))
            print()

    except Exception as e:
        print(f"Error processing sentence {i+1}: {e}")
        continue
# Out:
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\transformers\tokenization_utils_base.py:4114: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence 1
# Original Tamil text: ஹிஜாப் அணிந்து வந்த பெண்ணை வெளியேற்றிய அமெரிக்க வங்கி! | Woman thrown out of US bank for wearing hijab
#
# Original English Conversion: Woman kicked out of bank for wearing hijab
#
# Translated to English: US bank throws woman out for wearing hijab
# Average BLEU score: 5.072841446586652e-78
# Average GLEU score: 0.3076923076923077
# Average METEOR score: 0.6388888888888888
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\Nithish\anaconda3\envs\mt_final_project\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Translating sentence 11
# Original Tamil text: என்ன இது மாற்றமோ ?
#
# Original English Conversion: What change is this?
#
# Translated to English: Is this change?
# Average BLEU score: 0.056729049472153764
# Average GLEU score: 0.19250985738679702
# Average METEOR score: 0.3461015802724724
#
# Translating sentence 21
# Original Tamil text: கடாயில் எண்ணெய் ஊற்றி காய்ந்ததும் அதில் மிளகு, கறிவேப்பிலை, வெங்காயம் சேர்த்து தாளித்து இஞ்சி, பூண்டு விழுதுசேர்த்து நன்கு வதக்க வேண்டும்.
#
# Original English Conversion: Once the rice is cooked and sticky, heat oil in a pan and saute garlic, leek, celery and add the sticky rice to it.
#
# Translated to English: Heat oil in a pan, add mustard seeds, when it splutters, add onion, ginger, garlic, green chilies and curry leaves.
# Average BLEU score: 0.045077185527924765
# Average GLEU score: 0.1763025932825324
# Average METEOR score: 0.3320112184048331
#
# Translating sentence 31
# Original Tamil text: ஆனால், அது ஓட்டம் பிடித்தது.
#
# Original English Conversion: But it held on.
#
# Translated to English: But it was a run.
# Average BLEU score: 0.06444136695048372
# Average GLEU score: 0.192481119990004
# Average METEOR score: 0.3396115929716699
#
# Translating sentence 41
# Original Tamil text: இதில் என்னுடைய நிலைப்பாடு என்பது இல்லை.
#
# Original English Conversion: That is not my stance.
#
# Translated to English: That is not my position.
# Average BLEU score: 0.08134543866872777
# Average GLEU score: 0.19901022763864007
# Average METEOR score: 0.3505452555660617
#
# Translating sentence 51
# Original Tamil text: அவர்தான் என் இன்ஸ்பிரேஷன்.
#
# Original English Conversion: He is my inspiration.
#
# Translated to English: He is my inspiration.
# Average BLEU score: 0.10727642320353907
# Average GLEU score: 0.2225992839977171
# Average METEOR score: 0.3854157094474655
#
# Translating sentence 61
# Original Tamil text: 121 தவணையாக ரூ.
#
# Original English Conversion: 121 from Rs.
#
# Translated to English: 121 in instalments of Rs.
# Average BLEU score: 0.09798323164241815
# Average GLEU score: 0.2347998870820973
# Average METEOR score: 0.3929271166005177
#
# Translating sentence 71
# Original Tamil text: “ அது எனக்கு ஓய்வுணர்வை அளிக்கிறது, எனக்கு மகிழ்ச்சியையும் அமைதியையும் தருகிறது. ”
#
# Original English Conversion: It relaxes me, makes me happy and peaceful.
#
# Translated to English: It gives me a sense of relaxation, it gives me joy and peace.
# Average BLEU score: 0.0996139279274755
# Average GLEU score: 0.2299641113012181
# Average METEOR score: 0.38474992679108905
#
# Translating sentence 81
# Original Tamil text: 50 லட்சத்துக்கு இது கிடைக்கும்.
#
# Original English Conversion: 50 lakh.
#
# Translated to English: It will cost Rs 50 crore.
# Average BLEU score: 0.11098957059600041
# Average GLEU score: 0.2361920588652011
# Average METEOR score: 0.39409150279642735
#
# Translating sentence 91
# Original Tamil text: நாம் அதை நடைமுறைப்படுத்தினோம்.
#
# Original English Conversion: We implemented it.
#
# Translated to English: We implemented it.
# Average BLEU score: 0.1110384461569763
# Average GLEU score: 0.24334846478325892
# Average METEOR score: 0.3966706591784306
#
# Translating sentence 101
# Original Tamil text: இந்த வீடியோ காட்சிகள் வைரல் ஆகி வருகிறது.
#
# Original English Conversion: The videos have gone viral.
#
# Translated to English: These videos are going viral.
# Average BLEU score: 0.10004454059687964
# Average GLEU score: 0.22534959911758193
# Average METEOR score: 0.3727989548716879
#
# Translating sentence 111
# Original Tamil text: படம் 1, கடலில் தங்கிவாழும் ஒரு அழகிய ஒற்றையோட்டு மெல்லுடலியாகிய புலி கோவ்ரியை (Cypraea tigris) காட்டுகிறது.
#
# Original English Conversion: Photo 1 shows a beautiful denizen of the deep called the tiger cowry (Cypraea tigris).
#
# Translated to English: Figure 1 shows the tiger goby (Cypraea tigris), a beautiful sea-dwelling unicorn.
# Average BLEU score: 0.09414612058492598
# Average GLEU score: 0.22007158178839498
# Average METEOR score: 0.3702680877158493
#
# Translating sentence 121
# Original Tamil text: 50, மிளகாய்-ரூ.
#
# Original English Conversion: 50, pepper Rs.
#
# Translated to English: 50, Chilli - Rs.
# Average BLEU score: 0.08785164905783431
# Average GLEU score: 0.21575772672761945
# Average METEOR score: 0.37164488989501565
#
# Translating sentence 131
# Original Tamil text: 'பெருமாள்' படத்தில் வில்லனாக நடிக்கிறார், தெலுங்கு நடிகர் கோட்டா சீனிவாசராவ்.
#
# Original English Conversion: Kota Srinivasan, the Telugu films fame acts as a villain in 'Perumal'.
#
# Translated to English: Telugu actor Kota Srinivas Rao plays the villain in Perumal.
# Average BLEU score: 0.08429201265136917
# Average GLEU score: 0.21078498662572964
# Average METEOR score: 0.367674846460802
#
# Translating sentence 141
# Original Tamil text: இந்த ஆராய்ச்சி மையத்தில் வயது முதிர்ந்தோர் தொடர்பான பிரச்சனைகளுக்குத் தீர்வுகள் காணப்படும்.
#
# Original English Conversion: It will also have old age, science research center, where research can be done to address problems related to old age.
#
# Translated to English: The research centre will have solutions to problems related to ageing.
# Average BLEU score: 0.08416176981487462
# Average GLEU score: 0.21133740545874097
# Average METEOR score: 0.371355135763885
#
# Translating sentence 151
# Original Tamil text: இந்நிலையில் நயன்தாரா முதல் முறையாக இரண்டு வேடங்களில் ஐரா படத்தில் நடித்துள்ளார்.
#
# Original English Conversion: Nayanthara plays a double role in this film for the first time.
#
# Translated to English: This is the first time Nayanthara is playing dual roles in Ira.
# Average BLEU score: 0.08210318384771235
# Average GLEU score: 0.20855304313326353
# Average METEOR score: 0.3723174433387678
#
# Translating sentence 161
# Original Tamil text: இத்தலம் தமிழ்நாடு கடலூர் மாவட்டத்தில் உள்ள திருநாரையூர் எனும் ஊரில் அமைந்துள்ளது.
#
# Original English Conversion: Tirunaarayur Soundaryeswarar Temple is a Hindu temple located at Thirunaraiyur in Cuddalore district of Tamil Nadu, India.
#
# Translated to English: It is located in the town of Thirunaraiyur in Cuddalore district, Tamil Nadu.
# Average BLEU score: 0.08391284308422085
# Average GLEU score: 0.21615421943930657
# Average METEOR score: 0.3788470938605683
#
# Translating sentence 171
# Original Tamil text: அ) அனைத்து அரசு/உள்ளாட்சி கட்டடங்கள் (பள்ளி கட்டடங்கள் நீங்கலாக)
#
# Original English Conversion: (a) All Buildings belonging to Government/Local Body Institutions (except School Buildings)
#
# Translated to English: a) All Government / Local Government buildings (except school buildings)
# Average BLEU score: 0.08240583902647823
# Average GLEU score: 0.21751627256309625
# Average METEOR score: 0.3791882636859762
#
# Translating sentence 181
# Original Tamil text: ஆனால் யாரும் இந்த கோரிக்கையை காதுகொடுத்து கூட கேட்கவில்லை.
#
# Original English Conversion: But nobody wanted to hear that.
#
# Translated to English: But no one has paid heed to this demand.
# Average BLEU score: 0.08539848599251297
# Average GLEU score: 0.21686824313658046
# Average METEOR score: 0.37933766320380585
#
# Translating sentence 191
# Original Tamil text: எனக்குத் தொல்லை கொடுத்தார்.
#
# Original English Conversion: He disturbed me.
#
# Translated to English: He harassed me.
# Average BLEU score: 0.08276424049323935
# Average GLEU score: 0.21746926515999201
# Average METEOR score: 0.3804756298520403
#
# Translating sentence 201
# Original Tamil text: ஆன்லைன் தேர்வு மூலம், மாலுமிகள் வெளியேறும் தேர்வுக்கு தகுதி பெறும் வாய்ப்பை, தங்கள் வீடுகளிலிருந்தே பெறுவார்கள்.
#
# Original English Conversion: With the online exam, seafarers will get a chance to qualify the exit exam at the comfort of their homes.
#
# Translated to English: Through the online exam, sailors will have the opportunity to qualify for the exit exam from the comfort of their homes.
# Average BLEU score: 0.0823812760895193
# Average GLEU score: 0.21877726952469825
# Average METEOR score: 0.38364935107689146
#
# Translating sentence 211
# Original Tamil text: தற்போது அங்கு கூடுதல் படைகள் குவிக்கப்பட்டு தீவிர தேடுதல் வேட்டை நடத்தப்பட்டு வருகிறது.
#
# Original English Conversion: Additional forces have been deployed at the spot and a search operation has been launched.
#
# Translated to English: Additional forces have been deployed and a search operation is currently underway.
# Average BLEU score: 0.08374016292115961
# Average GLEU score: 0.21730168744164913
# Average METEOR score: 0.3813254304250707
#
# Translating sentence 221
# Original Tamil text: மாவட்ட நீதிமன்றம்
#
# Original English Conversion: District/Court
#
# Translated to English: the District Court
# Average BLEU score: 0.08405507659528536
# Average GLEU score: 0.2200799592580382
# Average METEOR score: 0.38714080118151023
#
# Translating sentence 231
# Original Tamil text: அந்த நாட்டில் மத துவேஷம், கொலை, கற்பழிப்பு, போதைப்பொருள் கடத்தல் மற்றும் துப்பாக்கி முனையில் கொள்ளை ஆகிய கொடும் குற்றச் செயல்களுக்கு இஸ்லாமிய ஷரீஅத் சட்டங்களின்படி மரண தண்டனை விதிக்கப்படுகிறது.
#
# Original English Conversion: Under the kingdoms strict Islamic legal code, murder, drug trafficking, armed robbery, rape and apostasy are all punishable by death.
#
# Translated to English: The country has the death penalty under Islamic Sharia laws for heinous crimes of religious hatred, murder, rape, drug trafficking, and robbery at gunpoint.
# Average BLEU score: 0.0904714776193456
# Average GLEU score: 0.2248788483462821
# Average METEOR score: 0.39161140059376864
#
# Translating sentence 241
# Original Tamil text: என் பாதையைக் கெடுத்து, என் ஆபத்தை வர்த்திக்கப்பண்ணுகிறார்கள். அதற்கு அவர்களுக்கு ஒத்தாசைபண்ணுகிறவர்கள் தேவையில்லை.
#
# Original English Conversion: They came on me as a wide breaking in of waters: in the desolation they rolled themselves on me.
#
# Translated to English: They spoil my path and increase my danger, and they have no need of helpers.
# Average BLEU score: 0.08952299492268997
# Average GLEU score: 0.22490486266673432
# Average METEOR score: 0.39184508064847806
#
# Translating sentence 251
# Original Tamil text: வானங்களுடையவும், பூமியுடையவும் ஆட்சி அவனுக்கே உடையது, அவனே உயிர்ப்பிக்கிறான், மரிக்கும் படியும் செய்கிறான் - மேலும் அவன் அனைத்துப் பொருட்களின் மீதும் பேராற்றலுடையவன்.
#
# Original English Conversion: His is the dominion of the heavens and the earth. He gives life and causes death, and He has power over everything.
#
# Translated to English: To Him belongs the dominion of the heavens and the earth, He gives life and causes death, and He has power over all things.
# Average BLEU score: 0.0948834682444137
# Average GLEU score: 0.23297782370572845
# Average METEOR score: 0.4006309371205077
#
# Translating sentence 261
# Original Tamil text: வளிமண்டல மேலடுக்கு சுழற்சி காரணமாக தென் தமிழகத்தில் இடியுடன் கூடிய மழை பெய்ய வாய்ப்பு உள்ளதாக சென்னை வானிலை ஆய்வு மையம் தெரிவித்துள்ளது.
#
# Original English Conversion: Chennai MeT office said the south west monsoon has been vigorous over north Tamil Nadu.
#
# Translated to English: The Chennai Meteorological Department has forecast thunderstorms with rain in south Tamil Nadu due to an upper air cyclonic circulation.
# Average BLEU score: 0.0917734318863159
# Average GLEU score: 0.23052605846371546
# Average METEOR score: 0.3980942313364947
#
# Translating sentence 271
# Original Tamil text: ஏன் அந்த தாமதம்?
#
# Original English Conversion: Why the delay?
#
# Translated to English: Why the delay?
# Average BLEU score: 0.09207699528534484
# Average GLEU score: 0.23363898792580887
# Average METEOR score: 0.4018062143139537
#
# Translating sentence 281
# Original Tamil text: அவர்களுக்கும் குடும்பம், குழந்தைகள் இருக்கின்றன.
#
# Original English Conversion: I have family, children.
#
# Translated to English: They have families and children.
# Average BLEU score: 0.08880023388728985
# Average GLEU score: 0.23108096892308266
# Average METEOR score: 0.40009975956968497
#
# Translating sentence 291
# Original Tamil text: அந்த விமான நிலையத்திற்கு வரவிருந்த விமானங்கள் திசை திருப்பி விடப் பட்டன.
#
# Original English Conversion: Flights coming to the airport were diverted.
#
# Translated to English: Flights to the airport were diverted.
# Average BLEU score: 0.09180819058553912
# Average GLEU score: 0.2369044710135858
# Average METEOR score: 0.4041561385934101
#
# Translating sentence 301
# Original Tamil text: பெரியாருடன் பழகிய நாட்களையெல்லாம் நினைக்கூர்ந்தவர் சத்யராஜின் சம்பளம் பற்றி பேச ஆரம்பித்தபோது அரங்கம் சிரிப்பொலியில் நிறைந்தது.
#
# Original English Conversion: He reminisced about the times he had spent with Periyar and when he spoke of Sathyaraj's acting fee, the audience burst into laughter.
#
# Translated to English: The hall was filled with laughter when the man who remembered all his days with Periyar started talking about Sathyaraj's salary.
# Average BLEU score: 0.09185853982428467
# Average GLEU score: 0.23733370680118085
# Average METEOR score: 0.4051655543218433
#
# Translating sentence 311
# Original Tamil text: காலப்போக்கில், இஸ்ரவேலர் மெய் வணக்கத்திலிருந்து வழிவிலகிப் போயினர்.
#
# Original English Conversion: However, if they turned aside from what was right, Jehovah would remove his favor from that place, and the house itself would become heaps of ruins. 1 Kings 9: 4 - 9. 2 Chronicles 7: 16, 19, 20.
#
# Translated to English: In time, the Israelites drifted away from true worship.
# Average BLEU score: 0.09272350094177523
# Average GLEU score: 0.2361436108169918
# Average METEOR score: 0.4052412075539675
#
# Translating sentence 321
# Original Tamil text: அது உண்மை தான் போல.
#
# Original English Conversion: It is real like.
#
# Translated to English: As if that were true.
# Average BLEU score: 0.09358691077690107
# Average GLEU score: 0.23490075716452524
# Average METEOR score: 0.4053188587507675
#
# Translating sentence 331
# Original Tamil text: நியூசிலாந்திடம் இந்தியா தோல்வி
#
# Original English Conversion: India lose to New Zealand
#
# Translated to English: India lose to New Zealand
# Average BLEU score: 0.09378065969602792
# Average GLEU score: 0.23278063471577504
# Average METEOR score: 0.4017734819366191
#
# Translating sentence 341
# Original Tamil text: ருமேனியாவின் மொத்த சனத்தொகையில் இவர்கள் 10 சதவீதமாகவே உள்ளனர்.
#
# Original English Conversion: They constitute 10 per cent of the total population.
#
# Translated to English: They constitute about 10% of the total population of Romania.
# Average BLEU score: 0.09427301719519143
# Average GLEU score: 0.23468695681983845
# Average METEOR score: 0.403488204348732
#
# Translating sentence 351
# Original Tamil text: மறுநாளே எமக்கு அந்த பெண் உயிரிழந்துள்ளார் என்ற தகவல் கிடைத்தது.
#
# Original English Conversion: The woman was found dead the next day.
#
# Translated to English: The next day, we were told that the woman had died.
# Average BLEU score: 0.09208573814646212
# Average GLEU score: 0.23378158723973508
# Average METEOR score: 0.40092448960965116
#
# Translating sentence 361
# Original Tamil text: வாழ்ந்து காட்டியவளும் நீயேயன்றோ!
#
# Original English Conversion: If only you had lived!
#
# Translated to English: You are the one who lives!
# Average BLEU score: 0.09236692544204557
# Average GLEU score: 0.2321205229636553
# Average METEOR score: 0.40017974346682145
#
# Translating sentence 371
# Original Tamil text: உதவிகள் வழங்கப்படவில்லை.
#
# Original English Conversion: Theres no assistance.
#
# Translated to English: No assistance was given.
# Average BLEU score: 0.0908337687162362
# Average GLEU score: 0.22996708143722536
# Average METEOR score: 0.3978816096845894
#
# Translating sentence 381
# Original Tamil text: அதிலிருந்து அவர்களால் இறுதிவரை மீண்டு வர முடியாமல் போனது.
#
# Original English Conversion: They could never recover from there.
#
# Translated to English: They were unable to recover from this.
# Average BLEU score: 0.09257935971531707
# Average GLEU score: 0.22960326742676948
# Average METEOR score: 0.3951861881900407
#
# Translating sentence 391
# Original Tamil text: இறுதிப் போட்டியில் நுழைந்தார் ரபேல் நடால்
#
# Original English Conversion: Rafael Nadal through to final
#
# Translated to English: Rafael Nadal enters the final
# Average BLEU score: 0.09346715734612857
# Average GLEU score: 0.23040041962647234
# Average METEOR score: 0.3978907935274697
#
# Translating sentence 401
# Original Tamil text: யாரிடம் கேட்க?
#
# Original English Conversion: Who you ask?
#
# Translated to English: Who to ask?
# Average BLEU score: 0.09388827050411304
# Average GLEU score: 0.23106851826018204
# Average METEOR score: 0.3973974581217418
#
# Translating sentence 411
# Original Tamil text: தங்கம் எப்போதும் பாதுகாப்பான முதலீடாகக் கருதப்படுகிறது.
#
# Original English Conversion: Gold has always been considered the safest option for investment.
#
# Translated to English: Gold has always been considered a safe investment.
# Average BLEU score: 0.09546998853283956
# Average GLEU score: 0.23177192115691342
# Average METEOR score: 0.3978671422170483
#
# Translating sentence 421
# Original Tamil text: வேலையிடப் பாதுகாப்பு
#
# Original English Conversion: Job security
#
# Translated to English: Workplace safety
# Average BLEU score: 0.09582342172101029
# Average GLEU score: 0.2314802104994652
# Average METEOR score: 0.3980268493132442
#
# Translating sentence 431
# Original Tamil text: "மாயாவதி மேலும் கூறுகையில், ""சுஷாந்த் ராஜ்புத் சம்பவத்தில் மகாராஷ்டிரா மற்றும் பீகார் காங்கிரஸ் தலைவர்கள் எடுத்த மாறுபட்ட நிலைப்பாடு அவர்களின் அரசியல் நலன்களுக்கானது எனத் தெரிகிறது."
#
# Original English Conversion: "Mayawati further said, ""Because of the different stance taken by Congress leaders of Maharashtra and Bihar in Sushant Rajput incident, it seems that their real purpose is to first fulfil their political interests... Maharashtra government should be serious""."
#
# Translated to English: "Mayawati further said," "The divergent stand taken by the Congress leaders of Maharashtra and Bihar on the Sushant Rajput incident seems to be for their political interests."
# Average BLEU score: 0.0950492254480828
# Average GLEU score: 0.23053347723082823
# Average METEOR score: 0.3988141872070773
#
# Translating sentence 441
# Original Tamil text: துறவி சிரித்துக் கொண்டார்.
#
# Original English Conversion: The sage smiled.
#
# Translated to English: The priest laughed.
# Average BLEU score: 0.09441033213854902
# Average GLEU score: 0.22976087912292795
# Average METEOR score: 0.3976974170120187
#
# Translating sentence 451
# Original Tamil text: கூட்டணியின் முதல்வர் வேட்பாளராக முன்னாள் துணை முதல்வரும் ராஷ்ட்ரீய ஜனதாதள தலைவர் லாலு பிரசாத்தின் மகனுமான தேஜஸ்வி யாதவ் அறிவிக்கப்பட்டுள்ளார்.
#
# Original English Conversion: RJD supremo and former Chief Ministers Lalu's and Rabri's younger son Tejashwi Yadav has been chosen as the Chief Ministerial candidate of the Mahagathbandhan.
#
# Translated to English: Tejashwi Yadav, the son of former deputy chief minister and Rashtriya Janata Dal chief Lalu Prasad, has been named the chief ministerial candidate of the alliance.
# Average BLEU score: 0.09449513216580256
# Average GLEU score: 0.2292802074382623
# Average METEOR score: 0.3974434530641167
#
# Translating sentence 461
# Original Tamil text: உண்மை என்னவென்றால், தலிபான் கைதிகள் குவாண்டானமோவிற்கு அமெரிக்க அரசால் அழைத்து செல்லப்பட்டனர், அமெரிக்க அரசிற்கு சக்தி இருந்ததன் காரணமாக.
#
# Original English Conversion: The truth is that the Taliban prisoners have been taken to Guantanamo only because the US government had the physical power to do so.
#
# Translated to English: The fact is that the Taliban prisoners were taken to Guantanamo by the US government, because the US government had the power.
# Average BLEU score: 0.09472058198804703
# Average GLEU score: 0.23116396868553515
# Average METEOR score: 0.3985915135792564
#
# Translating sentence 471
# Original Tamil text: காதல் திருமணம் செய்த ஜோடிக்கு ரூ.
#
# Original English Conversion: For couples Rs.
#
# Translated to English: The couple was given Rs.
# Average BLEU score: 0.09607237335007385
# Average GLEU score: 0.23073762327621655
# Average METEOR score: 0.39786657009351795
#
# Translating sentence 481
# Original Tamil text: அவர் மீது உச்சநீதிமன்றம், நீதிமன்ற அவமதிப்பு வழக்குத் தொடர்ந்தது.
#
# Original English Conversion: He had appealed in the higher court against it.
#
# Translated to English: He was tried by the Supreme Court for contempt of court.
# Average BLEU score: 0.09671842469010841
# Average GLEU score: 0.23165297159474546
# Average METEOR score: 0.398390532504245
#
# Translating sentence 491
# Original Tamil text: இந்தக் கலவையை வடிகட்டிப் பாட்டிலில் ஊற்றி வைத்துக்கொள்ளுங்கள்.
#
# Original English Conversion: Store this mixture in a bottle.
#
# Translated to English: Strain the mixture and keep it in a bottle.
# Average BLEU score: 0.09594163262928786
# Average GLEU score: 0.23207132435753486
# Average METEOR score: 0.40084836346281505
#
# Translating sentence 501
# Original Tamil text: மக்ககள் ஏன் போராடுகிறாகள்?
#
# Original English Conversion: Why are people protesting?
#
# Translated to English: Why are people protesting?
# Average BLEU score: 0.09650982119558335
# Average GLEU score: 0.2338365016439782
# Average METEOR score: 0.404538644257463
#
# Translating sentence 511
# Original Tamil text: நானும் குழம்பிப்போயிருக்கிறேன்.
#
# Original English Conversion: Im confused.
#
# Translated to English: I'm confused.
# Average BLEU score: 0.094976971040308
# Average GLEU score: 0.23471515218472488
# Average METEOR score: 0.40637061137139985
#
# Translating sentence 521
# Original Tamil text: இதை நாங்கள் ஏற்றுக்கொள்ள மாட்டோம்.
#
# Original English Conversion: We wont accept that.
#
# Translated to English: We won't accept this.
# Average BLEU score: 0.09315399654817157
# Average GLEU score: 0.23330477337708558
# Average METEOR score: 0.4037801565492915
#
# Translating sentence 531
# Original Tamil text: இதில் முதலிடத்தில் அமேசான் நிறுவனர் ஜெஃப்ப் பீஸோஸ் உள்ளார்.
#
# Original English Conversion: Amazon CEO Founder Jeff Bezos.
#
# Translated to English: Amazon founder Jeff Bezos is the first person to do so.
# Average BLEU score: 0.09248842566316735
# Average GLEU score: 0.23371583800343654
# Average METEOR score: 0.4051445502948285
#
# Translating sentence 541
# Original Tamil text: “ ஒரு தேர்வில் மோசமான மதிப்பெண்கள் எடுத்து நான் வீடு திரும்புகையில், என் பெற்றோரிடம் அதைச் சொல்ல நான் விரும்புகிறேன்.
#
# Original English Conversion: When I come home with a bad mark on a test, I want to tell my parents, but I cant because if I tell them, theyll yell at me. 13 - year - old Benita.
#
# Translated to English: "When I return home after scoring poorly in an exam, I like to tell my parents that.
# Average BLEU score: 0.09148343645067317
# Average GLEU score: 0.23205220741732033
# Average METEOR score: 0.4019995640832672
#
# Translating sentence 551
# Original Tamil text: ஈமு இறகுத் தோகையைக் கொண்டு மிகச்சிறப்பாக அலங்கரிக்கப்பட்டிருக்கும் ஆஸ்திரேலிய லைட் ஹார்ஸ் (Australian Light Horse) படையின் தொப்பிகள் பிரபலமானவையாகும்.
#
# Original English Conversion: The hats of the Australian Light Horse are decorated with emu feather plumes.
#
# Translated to English: The Australian Light Horse's capes are famous for their emu feather tail and are richly decorated.
# Average BLEU score: 0.0922936237492223
# Average GLEU score: 0.23475453126065632
# Average METEOR score: 0.40444508423999737
#
# Translating sentence 561
# Original Tamil text: நாட்டின் முதல் முழு நேர பாதுகாப்புத் துறை பெண் அமைச்சராக கடந்த செப்டம்பர் மாதம் நியமிக்கப்பட்டார் நிர்மலா சீதாராமன்
#
# Original English Conversion: In September, Nirmala Sitharaman becomes the first full fledged woman defence minister of India,
#
# Translated to English: Nirmala Sitharaman was appointed as the country's first full-time woman defence minister in September last year.
# Average BLEU score: 0.09165887223744516
# Average GLEU score: 0.23321830828282505
# Average METEOR score: 0.40356059368114544
#
# Translating sentence 571
# Original Tamil text: பதில்:- நல்ல கேள்வி.
#
# Original English Conversion: A: Good question.
#
# Translated to English: A: Good question.
# Average BLEU score: 0.09313566201551371
# Average GLEU score: 0.23513764676600807
# Average METEOR score: 0.4046798898866184
#
# Translating sentence 581
# Original Tamil text: பழமையான ஒரு கல்வெட்டில், “தாவீதின் வீடு ” என்ற வார்த்தைகள் பொறிக்கப்பட்டிருப்பதை புதைபொருள் ஆராய்ச்சியாளர்கள் கண்டுபிடித்திருக்கிறார்கள்.
#
# Original English Conversion: Jesus identity as the Messiah is supported by two detailed genealogies showing that he descended from King David. Clearly, David was a real man.
#
# Translated to English: Archaeologists have discovered an ancient inscription inscribed with the words "House of David."
# Average BLEU score: 0.09386854571275899
# Average GLEU score: 0.23424508510500494
# Average METEOR score: 0.4038649444996775
#
# Translating sentence 591
# Original Tamil text: அவர் மக்களால் தேர்ந்தெடுக்கப்பட்ட பிரதிநிதி அல்ல.
#
# Original English Conversion: He or she is not the elected representative of the people.
#
# Translated to English: He is not a representative elected by the people.
# Average BLEU score: 0.09357923880652867
# Average GLEU score: 0.23329586880187647
# Average METEOR score: 0.40378274403055225
#
# Translating sentence 601
# Original Tamil text: சமூகமும் கப்பலை போன்றததுதான்.
#
# Original English Conversion: A community is like a ship.
#
# Translated to English: Society is like a ship.
# Average BLEU score: 0.09510333455957537
# Average GLEU score: 0.23549656499924276
# Average METEOR score: 0.4060516985111823
#
# Translating sentence 611
# Original Tamil text: குடியரசுத் தலைவர் மாளிகையில் நடைபெற்ற 47-வது ஆளுநர்கள் மாநாட்டின் நிறைவு நிகழ்ச்சியில் பிரதமர் உரையாற்றினார்.
#
# Original English Conversion: The Prime Minister, Shri Narendra Modi, addressed the concluding session of the 47th Governors Conference at Rashtrapati Bhawan today.
#
# Translated to English: The Prime Minister was addressing the valedictory session of the 47th Governors'Conference at Rashtrapati Bhavan.
# Average BLEU score: 0.0956435693172732
# Average GLEU score: 0.2369442039873585
# Average METEOR score: 0.40708528031292257
#
# Translating sentence 621
# Original Tamil text: அவங்கமேல நடவடிக்கை எடுங்க” என்று கதறியிருக்கிறார்.
#
# Original English Conversion: "Take action."""
#
# Translated to English: Take action against them, "he said.
# Average BLEU score: 0.09456148622137481
# Average GLEU score: 0.2358865965430464
# Average METEOR score: 0.40695906002543214
#
# Translating sentence 631
# Original Tamil text: இது தொடர்பாக, அந்நிறுவனத்தின் ஆண்டறிக்கையில் குறிப்பிடப்பட்டுள்ளதாவது:
#
# Original English Conversion: A report by the firm says:
#
# Translated to English: In this regard, the company's annual report states:
# Average BLEU score: 0.09455885172173108
# Average GLEU score: 0.2359322735460809
# Average METEOR score: 0.4073383003226345
#
# Translating sentence 641
# Original Tamil text: இதன் உற்பத்தி இந்தியாவிற்கே போதவில்லை.
#
# Original English Conversion: This is not done enough in India.
#
# Translated to English: Its production is not enough for India.
# Average BLEU score: 0.0949489664071627
# Average GLEU score: 0.23594300842327023
# Average METEOR score: 0.40740895958201623
#
# Translating sentence 651
# Original Tamil text: ’ அதை அவரே தொடங்கியும் வைத்தார்.
#
# Original English Conversion: He's the one who started it.
#
# Translated to English: "He started it.
# Average BLEU score: 0.09501782211847498
# Average GLEU score: 0.235744408819711
# Average METEOR score: 0.406694037837804
#
# Translating sentence 661
# Original Tamil text: உதாரணமாக, ஒரு உணவகத்தின் அல்லது காலணிக்கான ரசீதில் குறிப்பிடப்பட்ட ஜிஎஸ்டி வரிவிகிதத்தை எவரும் இதனோடு ஒப்பிட்டுச் சரிபார்த்துக்கொள்ளலாம்.
#
# Original English Conversion: For example, any person who has been billed by a hotel or a restaurant or for footwear can cross verify the correctness of the rate of GST charged.
#
# Translated to English: For example, one can compare the GST rate mentioned on the receipt for a restaurant or footwear.
# Average BLEU score: 0.09797947781904817
# Average GLEU score: 0.2379554462758225
# Average METEOR score: 0.407997472841416
#
# Translating sentence 671
# Original Tamil text: வாழ்க்கைத் தொழில் திறமைகள்
#
# Original English Conversion: Life Skills Akan education also included training in life skills.
#
# Translated to English: Life Skills
# Average BLEU score: 0.10059888949152482
# Average GLEU score: 0.2396887860462824
# Average METEOR score: 0.4101143792553554
#
# Translating sentence 681
# Original Tamil text: அவை வரும்போது, நாணய, நிதிய நெருக்கடிகள் திடீரென வளரும் போக்கைக் கொண்டிருக்கும், அதிக எச்சரிக்கை கிடைக்காது.
#
# Original English Conversion: When they come, currency and fiscal crises tend to develop suddenly and without much warning.
#
# Translated to English: When they do come, monetary and financial crises tend to develop abruptly and do not get much warning.
# Average BLEU score: 0.10079617359801522
# Average GLEU score: 0.23954110185226263
# Average METEOR score: 0.4102657314046542
#
# Translating sentence 691
# Original Tamil text: அது மூங்கில் ஆதரவுகளையும் வேயப்பட்ட கூரையையும் கொண்ட ஓரறை அமைப்பாகும்.
#
# Original English Conversion: Sleeping accommodations usually consist of a wooden bed, hammocks, or mats on the floor.
#
# Translated to English: It is a one-room structure with bamboo supports and a thatched roof.
# Average BLEU score: 0.10171450143360895
# Average GLEU score: 0.2397454104421989
# Average METEOR score: 0.41143369003689506
#
# Translating sentence 701
# Original Tamil text: உன் நிலை இப்டியா இருப்பது?
#
# Original English Conversion: What is your status?
#
# Translated to English: What is your status?
# Average BLEU score: 0.10311657701943479
# Average GLEU score: 0.2405314883867179
# Average METEOR score: 0.4113250179870729
#
# Translating sentence 711
# Original Tamil text: அவர்கள் வெளியிட்ட அறிவிப்பு கீழே…
#
# Original English Conversion: Below is their statement:
#
# Translated to English: Below is the announcement they made:
# Average BLEU score: 0.1030727433060813
# Average GLEU score: 0.2407074299800484
# Average METEOR score: 0.41178140374754063
#
# Translating sentence 721
# Original Tamil text: கரீபிய தீவில் உணவுக்கு ஆதார தாவரமாயிருக்க தென் பசிபிக் தஹித்தியிலிருந்து மாச்சத்து மிகுந்த ஈரப்பலா தாவர வகையை சேகரித்துக் கொண்டுவருவதாகும்.
#
# Original English Conversion: The ill - fated voyage ended in mutiny, with Nelson, a castaway with the captain, eventually making land on the Indonesian island of Timor, where he died.
#
# Translated to English: The source of food in the Caribbean is the collection of the highly pollinated species of humus from the South Pacific Tahiti.
# Average BLEU score: 0.10541083010967148
# Average GLEU score: 0.241937883743621
# Average METEOR score: 0.41265901010879313
#
# Translating sentence 731
# Original Tamil text: இதுகுறித்த வழக்குகளில் போலீஸார் சரிவர செயல்படுவதில்லை.
#
# Original English Conversion: The police has not acted in these cases.
#
# Translated to English: The police are not doing their job properly.
# Average BLEU score: 0.10448044965306393
# Average GLEU score: 0.24063505508247898
# Average METEOR score: 0.4119008697227547
#
# Translating sentence 741
# Original Tamil text: தேசிய பாதுகாப்பு பிரச்சனைகளுக்கு விளக்கம், அரசாங்கங்கள் ஊடகங்கள் மற்றும் பொதுமக்கள் அனைவரும் பயங்கரவாதக் கட்டுக்கோப்பை தகவல் தொடர்பு மற்றும் மதிப்பீடு மற்றும் அடையாளப்படுத்தும் நோக்கங்களுக்காக பயன்படுத்தி வருகின்றன.
#
# Original English Conversion: Governments, media, and publics use the terrorism frame for cognitive, evaluative, and communication purposes.
#
# Translated to English: Interpretation of national security issues, governments, media, and the general public have all used the terrorist network for communication and evaluation and identification purposes.
# Average BLEU score: 0.10359221858032067
# Average GLEU score: 0.24081598242407037
# Average METEOR score: 0.41269226892406374
#
# Translating sentence 751
# Original Tamil text: அல்ல்ஹ் அனைத்தும் அறிந்தவன்!
#
# Original English Conversion: Everybody knows everything!
#
# Translated to English: Allah knows best!
# Average BLEU score: 0.10344989944853832
# Average GLEU score: 0.2414660790117655
# Average METEOR score: 0.4128332546856329
#
# Translating sentence 761
# Original Tamil text: ஆம்! டெட் ஜ சேர்ந்தவர்கள் கடினமாக உழைக்கிறார்கள் அதோடு வேலையில் கேளிகையும் கொள்கிறார்கள்.
#
# Original English Conversion: (Laughter) TEDsters do have fun working. And they work hard.
#
# Translated to English: Yes! Ted's people work hard and have fun at work.
# Average BLEU score: 0.10296927042158832
# Average GLEU score: 0.24026575064821562
# Average METEOR score: 0.41137091007084914
#
# Translating sentence 771
# Original Tamil text: நேருவுக்கு மரியாதை செலுத்தும் வகையில் பிரதமா் மோடி தனது சுட்டுரையில் வெளியிட்ட பதிவில், ‘முன்னாள் பிரதமா் பண்டித ஜவாஹா்லால் நேருவின் பிறந்த நாளில் அவருக்கு அஞ்சலிகள்’ என்று கூறியுள்ளாா்.
#
# Original English Conversion: """Tributes to our former PM Pandit Jawaharlal Nehru on his birth anniversary,"" Modi said in a tweet."
#
# Translated to English: "Tributes to our former Prime Minister Pandit Jawaharlal Nehru on his birth anniversary," Modi said in a tweet.
# Average BLEU score: 0.10282819163323266
# Average GLEU score: 0.23948691857611956
# Average METEOR score: 0.41074602262152665
#
# Translating sentence 781
# Original Tamil text: பஞ்சாப், ஹரியாணா மற்றும் தில்லியின் அண்டை எல்லைப் பகுதிகளைச் சுற்றி பயிா்க் கழிவுகள் எரிப்பு நிகழ்வுகள் கண்டறியப்பட்டுள்ளதால் இது வரும் நாள்களில் தில்லியில் தாக்கத்தை ஏற்படுத்தும் என்றும் சஃபா் தெரிவித்துள்ளது.
#
# Original English Conversion: SAFAR says stubble burning around Punjab, Haryana, and neighboring border regions is likely to impact Delhi in the coming days.
#
# Translated to English: It will also impact Delhi in the coming days as instances of stubble burning have been detected around Punjab, Haryana and neighbouring border areas of Delhi, SAFAR said.
# Average BLEU score: 0.10424159545818473
# Average GLEU score: 0.24018775975369452
# Average METEOR score: 0.4119658582676294
#
# Translating sentence 791
# Original Tamil text: குரல் கண்டறிதல் தொழில்நுட்பம் நாம் இயந்திரங்களுடன் உரையாடும் முறையில் புரட்சி செய்யக்கூடியது, ஆனால் தற்போது கிடைக்கும் அமைப்புகள் விலையுயர்ந்தவை மற்றும் தனியார் உரிமம் கொண்டவை. பொதுக் குரல், குரல் கண்டறிதல் தொழில்நுட்பத்தை அனைவரும் எளிதில் அணுகக் கிடைக்கச் செய்யும் ஒரு திட்டமாகும். மக்கள் தங்களின் குரல்களை ஒரு பெரும் தரவு தளத்திற்கு கொடையளிக்கிறனர், அத்தளம் அனைவரும் தங்களின் குரல் செயலிகளுக்கு விரைவாக எளிதில் பயிற்சியளிக்க உதவுகிறது. எல்லா குரல் தரவும் உருவாக்குநர்களுக்குக் கிடைக்கக்கூடியதாக இருக்கும்.
#
# Original English Conversion: Voice recognition technology could revolutionize the way we interact with machines, but the currently available systems are expensive and proprietary. Common Voice is a project to make voice recognition technology easily accessible to everyone. People donate their voices to a massive database that will let anyone quickly and easily train voice-enabled apps. All voice data will be available to developers.
#
# Translated to English: Voice detection technology could revolutionize the way we interact with machines, but the systems available now are expensive and privately licensed. Public Voice is a program that makes voice detection technology accessible to everyone. People donate their voices to a huge data base that enables everyone to quickly and easily train their voice processors. All voice data is available to developers.
# Average BLEU score: 0.10496608532249968
# Average GLEU score: 0.24084230241977211
# Average METEOR score: 0.41281760933890693
#
# Translating sentence 801
# Original Tamil text: வடகொரியாவின் அச்சம்
#
# Original English Conversion: North Korean threat
#
# Translated to English: The Fear of North Korea
# Average BLEU score: 0.10468605599135584
# Average GLEU score: 0.24056418819200814
# Average METEOR score: 0.412800269510572
#
# Translating sentence 811
# Original Tamil text: 2 ஸ்பூன் பாதாம்
#
# Original English Conversion: 2 tbsp almonds
#
# Translated to English: 2 tablespoons of almonds
# Average BLEU score: 0.10339522916038969
# Average GLEU score: 0.24166295511274366
# Average METEOR score: 0.41271241115678436
#
# Translating sentence 821
# Original Tamil text: அந்தப் பள்ளிக்கு அவர்தான் வாத்தியார்.
#
# Original English Conversion: He was in school then.
#
# Translated to English: He was a school teacher.
# Average BLEU score: 0.1031069349197547
# Average GLEU score: 0.24210730055849713
# Average METEOR score: 0.4134526388173679
#
# Translating sentence 831
# Original Tamil text: நான் சாப்பிட்டா என்னவென்று கேட்பாள்.
#
# Original English Conversion: He asked me what I ate.
#
# Translated to English: She asked me what I ate.
# Average BLEU score: 0.10345954170850959
# Average GLEU score: 0.2421678585197627
# Average METEOR score: 0.41269826989189345
#
# Translating sentence 841
# Original Tamil text: ஒரு நல்ல படம் இப்படி பாடாய்ப் படணுமா?
#
# Original English Conversion: Is it a good film?
#
# Translated to English: Is this a good movie to watch?
# Average BLEU score: 0.10331559736178061
# Average GLEU score: 0.24141783568891137
# Average METEOR score: 0.412182585408091
#
# Translating sentence 851
# Original Tamil text: அது வெறும் கதையல்ல பெண்ணே.
#
# Original English Conversion: This is not just her story.
#
# Translated to English: It's not just a story, girl.
# Average BLEU score: 0.10243524137451859
# Average GLEU score: 0.2417734768593355
# Average METEOR score: 0.4124360049736698
#
# Translating sentence 861
# Original Tamil text: அவளை ஆசீர்வாதம் செய்தார்.
#
# Original English Conversion: He felicitated her.
#
# Translated to English: He blessed her.
# Average BLEU score: 0.10196114981827507
# Average GLEU score: 0.24143481987351068
# Average METEOR score: 0.41202862299253007
#
# Translating sentence 871
# Original Tamil text: ஓரிடத்தில் இருக்க மாட்டேன்.
#
# Original English Conversion: I won't be one.
#
# Translated to English: I won't be in one place.
# Average BLEU score: 0.10211297408054591
# Average GLEU score: 0.24166267259260155
# Average METEOR score: 0.41277111454917015
#
# Translating sentence 881
# Original Tamil text: சென்னை, வேலூர், திருவண்ணாமலை ஆகிய மாவட்டங்களில் வெப்பச்சலனம் காரணமாக மழை பெய்ய வாய்ப்பு இருப்பதாக வானிலை ஆய்வு மையம் அறிவித்துள்ளது.
#
# Original English Conversion: The MeT Department has issued heavy rainfall alert to Chennai, Kancheepuram and Tiruvallur districts, he said, adding that Vellore and Villupuram could receive moderate rains.
#
# Translated to English: The weather department has predicted heavy rainfall in Chennai, Tiruvallur and Vellore districts.
# Average BLEU score: 0.10308025385524656
# Average GLEU score: 0.24214255119729503
# Average METEOR score: 0.41348838122682235
#
# Translating sentence 891
# Original Tamil text: நீதி கிடைக்கவே இல்லை
#
# Original English Conversion: Justice Not Done
#
# Translated to English: No justice
# Average BLEU score: 0.105313618600208
# Average GLEU score: 0.24399786465627216
# Average METEOR score: 0.41480206944156567
#
# Translating sentence 901
# Original Tamil text: இருந்தாலும், யெகோவா அவர்களுடைய உணர்ச்சிகளைப் புரிந்துகொண்டார். அவர்கள் தம்முடைய ஒப்பந்தத்திற்கு மனப்பூர்வமாக கீழ்ப்படிந்ததைப் பாராட்டினார்.
#
# Original English Conversion: He told them that they would have a monument and a name to time indefinite in his house. In other words, these faithful eunuchs would have the sure hope of enjoying everlasting life under Jesus Messianic rule.
#
# Translated to English: Still, Jehovah understood their feelings and appreciated their wholehearted obedience to his covenant.
# Average BLEU score: 0.10426580811069511
# Average GLEU score: 0.24253661466577978
# Average METEOR score: 0.41290844010597805
#
# Translating sentence 911
# Original Tamil text: பிரிக்கப்பட்ட ஆந்திராவில் மொத்த 25 எம். பி. தொகுதிகள் உள்ளன.
#
# Original English Conversion: There are 25 Lok Sabha constituencies in Andhra Pradesh.
#
# Translated to English: There are a total of 25 Lok Sabha constituencies in Andhra Pradesh.
# Average BLEU score: 0.10508061955944978
# Average GLEU score: 0.2432522873570944
# Average METEOR score: 0.41542304794876633
#
# Translating sentence 921
# Original Tamil text: தொடர்ந்து புகார்கள் அளித்தும் காவல் துறையினர் எந்த நடவடிக்கையும் எடுக்கவில்லை.
#
# Original English Conversion: Police has taken no action even after complaints.
#
# Translated to English: Despite repeated complaints, the police have not taken any action.
# Average BLEU score: 0.10541778523816307
# Average GLEU score: 0.2426729695427948
# Average METEOR score: 0.4144428089534836
#
# Translating sentence 931
# Original Tamil text: ” வயிற்றுப் போக்கு?
#
# Original English Conversion: Stomach pain?
#
# Translated to English: "Stomach ache?
# Average BLEU score: 0.10473283193628638
# Average GLEU score: 0.24128530316124375
# Average METEOR score: 0.4122757703457786
#
# Translating sentence 941
# Original Tamil text: மிகவும் புராதான நிலையிலான சிற்றின்ப உணர்ச்சிக்குரிய வளர்ச்சி வாய்வழி அல்ல, ஆனால் வயிற்றுக் குடல்கள் சார்ந்த ஒன்றாக இருக்கிறது என்பதுதான் சிம்மெல்லின் அடிப்படை ஆய்வுப் பொருளாக இருக்கிறது.
#
# Original English Conversion: Simmel's fundamental thesis is that the most primitive stage of libidinal development is not the oral, but the gastrointestinal one.
#
# Translated to English: Simmel's basic thesis is that the most primitive form of erotic emotional development is not oral, but rather is abdominal.
# Average BLEU score: 0.10398150922904002
# Average GLEU score: 0.2410969668336995
# Average METEOR score: 0.41232384715292447
#
# Translating sentence 951
# Original Tamil text: இந்த புள்ளியின் துருவவரியை கட்டமை
#
# Original English Conversion: Compute the inversion of this object
#
# Translated to English: Construct the polar line of this point
# Average BLEU score: 0.1065655821971258
# Average GLEU score: 0.24353222807614444
# Average METEOR score: 0.41489329139035047
#
# Translating sentence 961
# Original Tamil text: ஆவணங்களைப் பதிவு செய்து அதன் மூலம் முத்திரைத் தீர்வை மற்றும் பதிவுக் கட்டணம் வசூலிப்பதுடன், பல்வேறு சட்டங்களின் கீழ் திருமணங்களும் துறையால் பதிவு செய்யப்படுகின்றது.
#
# Original English Conversion: Apart from registering documents and collecting Stamp Duty and Registration Fee on them, the department also registers Marriages under various Acts.
#
# Translated to English: Marriages are registered by the department under various laws, besides registering documents and collecting stamp duty and registration fees through it.
# Average BLEU score: 0.10689984340184612
# Average GLEU score: 0.24367435901257975
# Average METEOR score: 0.4152864922219945
#
# Translating sentence 971
# Original Tamil text: பிரச்னைகள் உருவாகும்போதே அவனால் அவற்றை வெளிப்படுத்த முடியவில்லையெனில், பின்னர் அவற்றைத் தன் நடத்தையில் காண்பிக்கலாம். — நீதிமொழிகள் 18: 1 - ஐ ஒப்பிடவும்.
#
# Original English Conversion: If he cannot talk out his problems when they develop, he may act them out later. Compare Proverbs 18: 1.
#
# Translated to English: If he cannot articulate problems as they arise, he can show them later in his conduct. Compare Proverbs 18: 1.
# Average BLEU score: 0.1061651261978246
# Average GLEU score: 0.2427981224091361
# Average METEOR score: 0.41487199418204307
#
# Translating sentence 981
# Original Tamil text: இந்த நிறுவனங்களுக்கு அனுப்பப்பட்ட கேள்வித்தாள்களில், இவர்களின் தளங்களில் பட்டியிலிடப்பட்ட மொத்த விற்பனையாளர்களின் எண்ணிக்கை பற்றிய கேள்விகளும் அடங்கும் என்றும், கட்டுபடுத்தப்பட்ட மற்றும் கட்டுபாடற்ற விற்பனையாளர்களின் பட்டியல் மற்றும் விற்பனையாளர்களுக்கான விநியோகஸ்தர்கள் மற்றும் சில்லறை விற்பனையாளர்களின் பட்டியல், மற்றும் முதல் ஐந்து விற்பனையாளர்களின் மொத்த விற்பனை விகிதம் உள்ளிட்ட பல தகவல்கள் கேட்கப்பட்டுள்ளதாகவும் கூறப்படுகிறது.
#
# Original English Conversion: The detailed questionnaire sent to these companies also includes queries regarding total number of sellers listed on their platforms. list and share of controlled and uncontrolled sellers. distributor and retailer price list for preferred/controlled vendors and proportion of total sales from top five sellers.
#
# Translated to English: The questionnaires sent to these companies reportedly included questions about the number of wholesalers listed on their sites, and asked for a number of information, including a list of regulated and unregulated sellers and a list of distributors and retailers for the sellers, and the total sales ratio of the top five sellers.
# Average BLEU score: 0.10519135219936994
# Average GLEU score: 0.24236677264335102
# Average METEOR score: 0.4154778796773433
#
# Translating sentence 991
# Original Tamil text: சங்கத்தமிழன் படத்தில் நடிகர் விஜய் சேதுபதி முதன்முறையாக இரண்டு தோற்றங்களில் நடித்துள்ளார்.
#
# Original English Conversion: Tamil actor Vijay Sethupathi is doing the first double role of his career in Sanga Thamizhan. there will be two heroines paired with him in the movie.
#
# Translated to English: Sangathamizhan features actor Vijay Sethupathi in dual roles for the first time.
# Average BLEU score: 0.10449876057561697
# Average GLEU score: 0.2413666067259855
# Average METEOR score: 0.4140025175811432

# %%
average_bleu_score = np.mean(indict2_bleu_scores)
average_gleu_score = np.mean(indict2_gleu_scores)
average_meteor_score = np.mean(indict2_meteor_scores)
print('Average BLEU Score for Dev Set using IndicTrans2 model: ', average_bleu_score)
print('Average GLEU Score for Dev Set using IndicTrans2 model: ', average_gleu_score)
print('Average METEOR Score for Dev Set using IndicTrans2 model: ', average_meteor_score)
# Out:
# Average BLEU Score for Dev Set using IndicTrans2 model:  0.10476763486991329
# Average GLEU Score for Dev Set using IndicTrans2 model:  0.2413630417843907
# Average METEOR Score for Dev Set using IndicTrans2 model:  0.4140084454567599
